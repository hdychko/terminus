# %%
import os
import pandas as pd
import numpy as np

# %%
DATA_PATH = os.path.join(os.getcwd(), '..')
DATA_PATH = os.path.join(DATA_PATH, 'data')
COMMERCIAL_DATA_PATH = os.path.join(DATA_PATH, 'commercial')

# %%
df = pd.read_csv(os.path.join(COMMERCIAL_DATA_PATH, 'CASHPLUS_POOLED_NON_LTD_20240319.csv'))

# %%
df.shape
# Out:
# (20237, 161)

# %%
df.head()
# Out:
#     client_id  request_date                id legal_status  legal_form  \
# 0  4543123493      20220506  DC6CB75FE956B5DD            N         NaN
# 1  4543252037      20220523  848424A55D9C5585            N         NaN
# 2  4543311625      20220510  C1C890D53D6F6B21            N         NaN
# 3  4543421615      20220521  83B77754548D1112            N         NaN
# 4  4543421621      20220516  6DA0DA2FB7404059            N         NaN
#
#    earliest_known_date  average_num_of_employees  industry_code  \
# 0           20220113.0                       NaN            NaN
# 1           20210415.0                       NaN            NaN
# 2                  NaN                       NaN            NaN
# 3           20200723.0                       NaN         1995.0
# 4           20210623.0                       NaN            NaN
#
#    sic_code_1992_1  postcode  ...  no_months_data_avail  no_of_common_terms  \
# 0              NaN       NaN  ...                   2.0                 1.0
# 1              NaN       NaN  ...                   NaN                 NaN
# 2              NaN       NaN  ...                   NaN                 NaN
# 3              0.0       NaN  ...                   NaN                 NaN
# 4              NaN       NaN  ...                   NaN                 NaN
#
#    score_override_flag  commercial_delphi_score  rating_override_flag  \
# 0                    N                     29.0                     N
# 1                    N                     28.0                     N
# 2                  NaN                      NaN                   NaN
# 3                    N                     28.0                     N
# 4                    N                     30.0                     N
#
#    credit_rating  limit_override_flag  credit_limit  \
# 0          500.0                    N         750.0
# 1          500.0                    N         750.0
# 2            NaN                  NaN           NaN
# 3          500.0                    N         750.0
# 4          500.0                    N         750.0
#
#    delphi_cashflow_scorecard  delphi_cashflow_score
# 0                       NLTD                   97.0
# 1                       NLTD                  100.0
# 2                        NaN                    NaN
# 3                       NLTD                   97.0
# 4                       NLTD                  100.0
#
# [5 rows x 161 columns]
