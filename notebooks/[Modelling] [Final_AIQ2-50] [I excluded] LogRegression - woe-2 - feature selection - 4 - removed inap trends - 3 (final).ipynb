# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import copy
from typing import (
    Dict, 
    List,
    Any
)

import mlflow
from datetime import datetime


import numpy as np
import pandas as pd

from scipy.stats import uniform
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedShuffleSplit

from joblib import load, dump

import seaborn as sns
import matplotlib.pyplot as plt

# %%
sys.path.append(os.path.join(os.getcwd(), '..'))
from utils.metrics import Metrics
from utils.modelling_tools import (
    search_hyper_params_and_log, 
    update_solver_by_penalty, 
    evaluate_model
)
from utils.metrics_by_quantile import MetricsByQuantile
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %%
RUN_NAME: str = '04-LogRegression-hyperparams_tunning'

# %%
PROJECT_PATH: str = os.path.join(os.getcwd(), '..')
DATA_PATH: str = os.path.join(PROJECT_PATH, 'data')
OPT_BIN_PATH: str = os.path.join(os.path.join(PROJECT_PATH, 'objects'), 'optbinners')
MODELS_PATH: str = os.path.join(os.path.join(PROJECT_PATH, 'objects'), 'models')

# %%
TRAIN_FROM: datetime.date = pd.to_datetime('2021-12-01').date()
TRAIN_TO: datetime.date = pd.to_datetime('2022-01-01').date()

VAL_FROM: datetime.date = pd.to_datetime('2023-01-01').date()
VAL_TO: datetime.date = pd.to_datetime('2023-05-01').date()

TEST_FROM: datetime.date = pd.to_datetime('2023-05-01').date()
TEST_TO: datetime.date = pd.to_datetime('2023-08-01').date()

# %%
# set constants
COLS_TO_USE: List[str] = [
"OPTIN_11SCN_MLOptBin",
"TRD_A_20OptBin",
# "VM01_SP_VM2_15OptBin", #inap.trend
"SP_G_37OptBin",
"TRD_C_07OptBin",
"SPA_F2_33OptBin",
"SP_G_38OptBin",
"SP_B1_14OptBin",
"GEN11_SP_N_91OptBin",
"EA5_S_01OptBin",
"CLU_CLI_L6M_NPR_L6MOptBin",
"SP_I_63_01OptBin",
"GEN11_SP_N_92_ABOtherOptBin",
]

# %%
TARGET_NAME: str = 'GB6_Flag_2Limit'
TARGET_VALS: List[int] = [0, 1]
TARGET_BIN: str = f'_{TARGET_NAME}_bin'
TARGET_BIN_0isB: str = f'_{TARGET_NAME}_bin_0isB'

PALETTE: Dict[str, str] = {
    TARGET_NAME: {
        'G': 'green',
        'B': 'red',
        'I': 'black'
    },
    TARGET_BIN: {0: 'green', 1: 'red'},
    'DataPart': {'Train+Val': 'black', 'Val': 'blue', 'Test': 'red', 'Train': 'orange'}
}

# %%
N_ITER: int = 100
RANDOM_SEED: int = 42
CONFIDENCE_LEVEL = 0.05

# %%
MODEL = LogisticRegression

# %%
PARAMS: Dict[str, Any] = dict(
    penalty=['l2', 'l1', 'elasticnet'], 
    C=uniform(loc=0, scale=20), 
    fit_intercept=[True], 
    class_weight=['balanced'], 
    random_state=[RANDOM_SEED], 
    n_jobs=[-1]
)

# %%
# read data
df: pd.DataFrame = pd.read_csv(os.path.join(DATA_PATH, 'final_aiq2_s_neg_sep_I_excl.csv'), low_memory=False)

# %%
print('Number of rows: %.0f; columns: %.0f' % df.shape)
# Out:
# Number of rows: 110462; columns: 1866

# %% [markdown]
# # Preprocessing

# %% [markdown]
# Convert dates to the corresponding types

# %%
for col in ['_RDATE_EOM', '_RDATE']:
    df[col] = pd.to_datetime(df[col]).dt.date

# %%
print('Available date range:')
df['_RDATE'].agg(['min', 'max'])
# Out:
# Available date range:
# min    2021-06-30
# max    2023-11-30
# Name: _RDATE, dtype: object

# %% [markdown]
# Generate Target, where `GB6_Flag_2Limit` in ('I','B') is '1' and GB6_Flag_2Limit in ('G') is '0'

# %%
df[f'_{TARGET_NAME}_bin_0isB'] = df[TARGET_NAME].replace(
    {
        'G': 0,
        'I': 1,
        'B': 1
    }
)
# Out:
# Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`

# %%
pd.merge(
    df[f'_{TARGET_NAME}_bin_0isB'].value_counts().reset_index(name='n'),
    (df[f'_{TARGET_NAME}_bin_0isB'].value_counts(normalize=True) * 100).reset_index(name='%'),
    on=f'_{TARGET_NAME}_bin_0isB', how='outer'
)
# Out:
#    _GB6_Flag_2Limit_bin_0isB      n          %
# 0                          0  99444  90.025529
# 1                          1  11018   9.974471

# %% [markdown]
# # Split data

# %%
df_train = df.loc[
    (df._RDATE >= TRAIN_FROM) &
    (df._RDATE < TRAIN_TO) & 
    (df[TARGET_NAME] != 'I'),
   :
].reset_index(drop=True)

df_train_val = df.loc[
    (df._RDATE >= TRAIN_FROM) &
    (df._RDATE < VAL_TO) &
    (df[TARGET_NAME] != 'I'),
    :
].reset_index(drop=True)

df_val = df.loc[
    (df._RDATE >= VAL_FROM) &
    (df._RDATE < VAL_TO) &
    (df[TARGET_NAME] != 'I'),
    :
].reset_index(drop=True)

df_test_same = df.loc[
    (df._RDATE >= TEST_FROM) &
    (df._RDATE < TEST_TO) &
    (df[TARGET_NAME] != 'I'),
    :
].reset_index(drop=True)

df_test = df.loc[
    (df._RDATE >= TEST_FROM) &
    (df._RDATE < TEST_TO),
    :
].reset_index(drop=True)

# %%
print(f'Distribution of _{TARGET_NAME}_bin_0isB on test')
pd.merge(
    df_test[f'_{TARGET_NAME}_bin_0isB'].value_counts().reset_index(name='n'),
    (df_test[f'_{TARGET_NAME}_bin_0isB'].value_counts(normalize=True) * 100).reset_index(name='%'),
    on=f'_{TARGET_NAME}_bin_0isB', how='outer'
)
# Out:
# Distribution of _GB6_Flag_2Limit_bin_0isB on test
#    _GB6_Flag_2Limit_bin_0isB      n          %
# 0                          0  13663  84.126593
# 1                          1   2578  15.873407

# %%
data_dict = {
    "df_train": df_train,
    "df_val": df_val,
    "df_train_val": df_train_val, 
    "df_test_same": df_test_same,
    "df_test": df_test
}

# %%
# randomly select N observations from test data
N = 10000
sss = StratifiedShuffleSplit(n_splits=1, train_size=N, random_state=RANDOM_SEED)
indx = sss.split(data_dict['df_test_same'].reset_index(drop=True), data_dict['df_test_same'][TARGET_BIN])
random_indx = list(indx)[0][0]

assert len(random_indx) == N, "Incorrect number of elements in the subsample"
test_sample = data_dict['df_test_same'].reset_index(drop=True).iloc[random_indx, :].reset_index(drop=True)

# %%
data_dict['df_test_same_sample'] = test_sample

# %% [markdown]
# # Run the experiment

# %%
mlflow.set_tracking_uri(uri="http://127.0.0.1:8800/")
mlflow.set_experiment("[Experian][Features 2.0]")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/562926978330189002', creation_time=1718121099087, experiment_id='562926978330189002', last_update_time=1718121099087, lifecycle_stage='active', name='[Experian][Features 2.0]', tags={}>

# %%
experiment_description = f"""
    'features': {len(COLS_TO_USE)},
    'target': {TARGET_BIN},
    'target_vals': '0==G, 1==B, 1=I',
    'model': {MODEL.__name__},
    'data_version': '22.05.2024', 
    'train_period': [{TRAIN_FROM.strftime('%Y-%m-%d') + ', ' + TRAIN_TO.strftime('%Y-%m-%d')}),
    'val_period': [{VAL_FROM.strftime('%Y-%m-%d') + ', ' + VAL_TO.strftime('%Y-%m-%d')}),
    'test_period': [{TEST_FROM.strftime('%Y-%m-%d') + ', ' + TEST_TO.strftime('%Y-%m-%d')}),
"""

# %%
print(experiment_description)
# Out:
#     'features': 12,
#     'target': _GB6_Flag_2Limit_bin,
#     'target_vals': '0==G, 1==B, 1=I',
#     'model': LogisticRegression,
#     'data_version': '22.05.2024',
#     'train_period': [2021-12-01, 2022-01-01),
#     'val_period': [2023-01-01, 2023-05-01),
#     'test_period': [2023-05-01, 2023-08-01),

# %%
with mlflow.start_run(run_name=RUN_NAME, log_system_metrics=True):
    res = search_hyper_params_and_log(
        run_name=RUN_NAME,
        data_dict=data_dict,
        cols_to_use=COLS_TO_USE,
        target_name=TARGET_BIN,
        distributions=PARAMS,
        n_iter=N_ITER,
        model=MODEL,
        custom_params_updates=update_solver_by_penalty,
        tags={'features': len(COLS_TO_USE)}, 
        palette=PALETTE['DataPart'],
        test_name='df_test_same',
        model_path=MODELS_PATH
    )
# Out:
# 2024/06/20 12:23:56 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 12:23:56 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# # 1 / 100
# # 2 / 100
# 2024/06/20 12:23:57 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 12:23:57 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 12:24:07 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 12:24:07 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 3 / 100
# # 4 / 100
# 2024/06/20 12:24:09 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 12:24:09 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 12:24:15 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 12:24:15 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 5 / 100
# # 6 / 100
# 2024/06/20 12:24:15 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# # 7 / 100
# Exception in thread 2024/06/20 12:24:15 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 12:24:20 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 12:24:20 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 8 / 100
# 2024/06/20 12:24:21 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 12:24:21 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 12:24:26 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 12:24:26 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 2024/06/20 12:24:26 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# # 9 / 100
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/20 12:24:26 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 12:24:32 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 12:24:32 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 10 / 100
# # 11 / 100
# # 12 / 100
# 2024/06/20 12:24:34 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 12:24:34 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 12:24:40 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 12:24:40 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 13 / 100
# # 14 / 100
# 2024/06/20 12:24:40 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 12:24:40 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 12:24:46 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 12:24:46 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 2024/06/20 12:24:46 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# # 15 / 100
# Exception in thread 2024/06/20 12:24:46 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 12:24:52 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 12:24:52 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 16 / 100
# 2024/06/20 12:24:52 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 12:24:52 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 12:24:58 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 12:24:58 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 17 / 100
# # 18 / 100
# # 19 / 100
# # 20 / 100
# 2024/06/20 12:24:58 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/20 12:24:58 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 12:25:04 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 12:25:04 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# #
'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# Not saved
# Test-PR_AUC 0.23767477256703262
# Test-Gini 0.5727827735111439
# The option feature_dependence has been renamed to feature_perturbation!
# The feature_perturbation option is now deprecated in favor of using the appropriate masker (maskers.Independent, or maskers.Impute)
# 2024/06/20 12:28:04 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 12:28:04 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!

# %%
df_metrics, df_coeff, data_dict, model_obj, std_scaler = res

# %% [markdown]
# # Model's quality

# %% [markdown]
# ## Coefficients

# %%
df_coeff.sort_values('Importance(%)', ascending=False)
# Out:
#                         Feature     Coeff  Importance(%)       p-value  \
# 5          OPTIN_11SCN_MLOptBin -1.154033      40.971473  0.000000e+00
# 4                     Intercept -0.848414      30.121113  0.000000e+00
# 6               SPA_F2_33OptBin -0.148684       5.278695  0.000000e+00
# 1                EA5_S_01OptBin -0.138331       4.911138  0.000000e+00
# 8                 SP_G_37OptBin -0.086573       3.073586  5.415637e-08
# 12               TRD_C_07OptBin -0.077123       2.738072  7.842710e-09
# 9                 SP_G_38OptBin -0.067252       2.387637  3.872065e-05
# 0     CLU_CLI_L6M_NPR_L6MOptBin -0.061994       2.200966  2.303975e-06
# 11               TRD_A_20OptBin -0.061793       2.193838  5.610777e-06
# 10             SP_I_63_01OptBin -0.060167       2.136115  9.207243e-07
# 2           GEN11_SP_N_91OptBin -0.043338       1.538637  8.372433e-04
# 7                SP_B1_14OptBin -0.037003       1.313715  2.707878e-03
# 3   GEN11_SP_N_92_ABOtherOptBin -0.031970       1.135015  1.432966e-02
#
#     Importance(SHAP)  Importance(SHAP, %)
# 5           1.479513            73.906958
# 4                NaN                  NaN
# 6           0.113098             5.649671
# 1           0.066979             3.345819
# 8           0.067042             3.348969
# 12          0.047802             2.387891
# 9           0.046221             2.308923
# 0           0.036894             1.842981
# 11          0.056525             2.823647
# 10          0.021221             1.060083
# 2           0.026220             1.309806
# 7           0.016091             0.803826
# 3           0.024251             1.211425

# %%
# features with 0 coefficients
df_coeff[df_coeff.Coeff == 0]
# Out:
# Empty DataFrame
# Columns: [Feature, Coeff, Importance(%), p-value, Importance(SHAP), Importance(SHAP, %)]
# Index: []

# %%
# features with high p-value
df_coeff[df_coeff['p-value'] > CONFIDENCE_LEVEL]
# Out:
# Empty DataFrame
# Columns: [Feature, Coeff, Importance(%), p-value, Importance(SHAP), Importance(SHAP, %)]
# Index: []

# %%
for col in COLS_TO_USE:
    if col not in df_coeff[df_coeff['p-value'] > CONFIDENCE_LEVEL].Feature.values:
        print(f'"{col}",')
# Out:
# "OPTIN_11SCN_MLOptBin",
# "TRD_A_20OptBin",
# "SP_G_37OptBin",
# "TRD_C_07OptBin",
# "SPA_F2_33OptBin",
# "SP_G_38OptBin",
# "SP_B1_14OptBin",
# "GEN11_SP_N_91OptBin",
# "EA5_S_01OptBin",
# "CLU_CLI_L6M_NPR_L6MOptBin",
# "SP_I_63_01OptBin",
# "GEN11_SP_N_92_ABOtherOptBin",

# %%
model_obj
# Out:
# LogisticRegression(C=0.5083825348819038, class_weight='balanced', n_jobs=-1,
#                    penalty='l1', random_state=42, solver='liblinear')

# %%
# with open(os.path.join(MODELS_PATH, '[Model][Modelling] [Final_AIQ2-50] [I excluded] LogRegression - woe-2 - feature selection - 3 (final).jblb'), 'wb') as f:
#     dump(model_obj, f)

# %%
# with open(os.path.join(MODELS_PATH, '[StdScaler][Modelling] [Final_AIQ2-50] [I excluded] LogRegression - woe-2 - feature selection - 3 (final).jblb'), 'wb') as f:
#     dump(std_scaler, f)

# %% [markdown]
# ## GINI, AU PRC

# %% [markdown]
# ## Test-same

# %%
evaluate_model(
    data=data_dict['df_test_same'], 
    cols_to_use=COLS_TO_USE,
    std_scaler=std_scaler,
    target_name=TARGET_BIN,
    model_obj=model_obj
)
# Out:
# PR_AUC 0.23767477256703262
# Gini 0.5727827735111439
# (0.23767477256703262, 0.5727827735111439)

# %% [markdown]
# ## Test-full

# %% [markdown]
# ### 'I' is 0

# %%
evaluate_model(
    data=data_dict['df_test'], 
    cols_to_use=COLS_TO_USE,
    std_scaler=std_scaler,
    target_name=TARGET_BIN,
    model_obj=model_obj
)
# Out:
# PR_AUC 0.20023873870721576
# Gini 0.5369705467250274
# (0.20023873870721576, 0.5369705467250274)

# %% [markdown]
# ### 'I' is 1

# %%
evaluate_model(
    data=data_dict['df_test'], 
    cols_to_use=COLS_TO_USE,
    std_scaler=std_scaler,
    target_name=TARGET_BIN_0isB,
    model_obj=model_obj
)
# Out:
# PR_AUC 0.3391283863494563
# Gini 0.5138100117723499
# (0.3391283863494563, 0.5138100117723499)

# %% [markdown]
# ## Outcomes distributions

# %%
data_dict['df_test']['score'] = model_obj.predict_proba(
    std_scaler.transform(data_dict['df_test'][COLS_TO_USE])
)[:, 1]
data_dict['df_test_same']['score'] = model_obj.predict_proba(
    std_scaler.transform(data_dict['df_test_same'][COLS_TO_USE])
)[:, 1]

# %% [markdown]
# ### Test-same

# %%
sns.histplot(x=data_dict['df_test_same']['score'], hue=data_dict['df_test_same'][TARGET_BIN], common_norm=False, stat='density')
# Out:
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# <Axes: xlabel='score', ylabel='Density'>

# %% [markdown]
# ### Test-full

# %% [markdown]
# ### 'I' is 0

# %%
sns.histplot(x=data_dict['df_test']['score'], hue=data_dict['df_test'][TARGET_BIN], common_norm=False, stat='density')
# Out:
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# <Axes: xlabel='score', ylabel='Density'>

# %% [markdown]
# ### 'I' is 1

# %%
sns.histplot(x=data_dict['df_test']['score'], hue=data_dict['df_test'][TARGET_BIN_0isB], common_norm=False, stat='density')
# Out:
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# <Axes: xlabel='score', ylabel='Density'>

# %% [markdown]
# ## Precision, Recall By Quantile

# %% [markdown]
# ### Test-same

# %%
m = MetricsByQuantile(metrics=["quantiles_analytics"])
r = m.compute(
    y_true=data_dict['df_test_same'][TARGET_BIN].reset_index(drop=True), 
    y_pred=data_dict['df_test_same']['score'].round(3).reset_index(drop=True), 
    list_of_metrics = [
        "cum_precision_by_quantile", "cum_recall_by_quantile", 
        "precision_by_quantile", "recall_by_quantile",
    ], 
    n_quantiles = 200
)
df_deciles = r["other"]["quantiles_analytics"]
df_deciles.head(50)
# Out:
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#     % of total population  Cumulative % of total population  Total  Bad  \
# 0                    0.44                              0.44     66   25
# 1                    0.53                              0.97     80   30
# 2                    0.45                              1.43     68   27
# 3                    0.53                              1.96     80   23
# 4                    0.38                              2.34     57   16
# 5                    0.65                              2.99     98   30
# 6                    0.41                              3.41     62   12
# 7                    0.58                              3.99     87   27
# 8                    0.49                              4.47     73   19
# 9                    0.45                              4.92     67   20
# 10                   0.48                              5.40     72   24
# 11                   0.53                              5.93     80   14
# 12                   0.57                              6.50     85   17
# 13                   0.41                              6.91     62   16
# 14                   0.58                              7.49     87   17
# 15                   0.48                              7.97     72   18
# 16                   0.32                              8.29     48   12
# 17                   0.62                              8.92     93   28
# 18                   0.53                              9.45     80   19
# 19                   0.55                             10.00     82    9
# 20                   0.41                             10.40     61   16
# 21                   0.49                             10.89     73   15
# 22                   0.52                             11.41     78   22
# 23                   0.50                             11.91     75   21
# 24                   0.55                             12.46     82    8
# 25                   0.53                             12.99     80   15
# 26                   0.39                             13.38     59    9
# 27                   0.61                             14.00     92   22
# 28                   0.41                             14.40     61   10
# 29                   0.50                             14.90     75    9
# 30                   0.56                             15.46     84   18
# 31                   0.42                             15.88     63    6
# 32                   0.51                             16.40     77   13
# 33                   0.53                             16.92     79   21
# 34                   0.56                             17.48     84   14
# 35                   0.47                             17.96     71    9
# 36                   0.52                             18.48     78   12
# 37                   0.46                             18.94     69   12
# 38                   0.51                             19.45     77   12
# 39                   0.41                             19.86     62    6
# 40                   0.55                             20.41     82    6
# 41                   0.49                             20.90     73   10
# 42                   0.57                             21.47     86    7
# 43                   0.51                             21.98     76   10
# 44                   0.45                             22.42     67    9
# 45                   0.42                             22.84     63    7
# 46                   0.65                             23.50     98    6
# 47                   0.46                             23.96     69   17
# 48                   0.55                             24.50     82   17
# 49                   0.49                             24.99     73   13
#
#     Cumulative Bad        Quantile  #Quantile  Cumulative Precision  \
# 0               25  (0.884, 0.902]        200             37.878788
# 1               55   (0.87, 0.884]        199             37.671233
# 2               82   (0.862, 0.87]        198             38.317757
# 3              105  (0.856, 0.862]        197             35.714286
# 4              121  (0.851, 0.856]        196             34.472934
# 5              151  (0.846, 0.851]        195             33.630290
# 6              163  (0.843, 0.846]        194             31.898239
# 7              190  (0.838, 0.843]        193             31.772575
# 8              209  (0.833, 0.838]        192             31.147541
# 9              229  (0.829, 0.833]        191             31.029810
# 10             253  (0.825, 0.829]        190             31.234568
# 11             267  (0.821, 0.825]        189             30.000000
# 12             284  (0.817, 0.821]        188             29.128205
# 13             300  (0.814, 0.817]        187             28.929605
# 14             317   (0.81, 0.814]        186             28.202847
# 15             335   (0.807, 0.81]        185             28.010033
# 16             347  (0.804, 0.807]        184             27.893891
# 17             375    (0.8, 0.804]        183             28.047868
# 18             394    (0.797, 0.8]        182             27.805222
# 27          39.805097  23.913043  1.649175   0.766--0.77
# 28          40.554723  16.393443  0.749625  0.763--0.766
# 29          41.229385  12.000000  0.674663  0.759--0.763
# 30          42.578711  21.428571  1.349325  0.755--0.759
# 31          43.028486   9.523810  0.449775  0.752--0.755
# 32          44.002999  16.883117  0.974513  0.748--0.752
# 33          45.577211  26.582278  1.574213  0.744--0.748
# 34          46.626687  16.666667  1.049475   0.74--0.744
# 35          47.301349  12.676056  0.674663   0.736--0.74
# 36          48.200900  15.384615  0.899550  0.732--0.736
# 37          49.100450  17.391304  0.899550  0.728--0.732
# 38          50.000000  15.584416  0.899550  0.724--0.728
# 39          50.449775   9.677419  0.449775  0.721--0.724
# 40          50.899550   7.317073  0.449775  0.718--0.721
# 41          51.649175  13.698630  0.749625  0.714--0.718
# 42          52.173913   8.139535  0.524738  0.709--0.714
# 43          52.923538  13.157895  0.749625  0.704--0.709
# 44          53.598201  13.432836  0.674663    0.7--0.704
# 45          54.122939  11.111111  0.524738    0.696--0.7
# 46          54.572714   6.122449  0.449775  0.691--0.696
# 47          55.847076  24.637681  1.274363  0.687--0.691
# 48          57.121439  20.731707  1.274363  0.683--0.687
# 49          58.095952  17.808219  0.974513  0.676--0.683

# %%
# df_deciles.to_csv('lr_metrics_by_quantile_test_same.csv')

# %% [markdown]
# ### Test-full

# %% [markdown]
# ### 'I' is 0

# %%
m = MetricsByQuantile(metrics=["quantiles_analytics"])
r = m.compute(
    y_true=data_dict['df_test'][TARGET_BIN].reset_index(drop=True), 
    y_pred=data_dict['df_test']['score'].round(3).reset_index(drop=True), 
    list_of_metrics = [
        "cum_precision_by_quantile", "cum_recall_by_quantile", 
        "precision_by_quantile", "recall_by_quantile",
    ], 
    n_quantiles = 200
)
df_deciles = r["other"]["quantiles_analytics"]
df_deciles.head(50)
# Out:
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#     % of total population  Cumulative % of total population  Total  Bad  \
# 0                    0.50                              0.50     82   23
# 1                    0.49                              1.00     80   26
# 2                    0.48                              1.48     78   27
# 3                    0.49                              1.97     80   19
# 4                    0.49                              2.46     79   21
# 5                    0.46                              2.92     75   19
# 6                    0.44                              3.36     72   16
# 7                    0.60                              3.96     97   18
# 8                    0.50                              4.46     81   21
# 9                    0.54                              4.99     87   19
# 10                   0.47                              5.46     76   20
# 11                   0.52                              5.98     85   24
# 12                   0.50                              6.48     81   11
# 13                   0.42                              6.90     68   10
# 14                   0.59                              7.49     96   20
# 15                   0.45                              7.94     73   13
# 16                   0.53                              8.47     86   17
# 17                   0.47                              8.95     77   13
# 18                   0.46                              9.40     74   22
# 19                   0.44                              9.84     71   16
# 20                   0.57                             10.41     92   19
# 21                   0.60                             11.00     97    9
# 22                   0.42                             11.42     68   16
# 23                   0.54                             11.96     87   15
# 24                   0.47                             12.43     76   17
# 25                   0.44                             12.86     71   20
# 26                   0.62                             13.48    100   13
# 27                   0.46                             13.93     74    9
# 28                   0.54                             14.48     88   13
# 29                   0.50                             14.98     82   15
# 30                   0.44                             15.42     71   13
# 31                   0.49                             15.90     79    9
# 32                   0.55                             16.45     89   13
# 33                   0.44                             16.89     71   12
# 34                   0.60                             17.49     98   10
# 35                   0.50                             18.00     82   14
# 36                   0.42                             18.42     68   16
# 37                   0.39                             18.81     64   12
# 38                   0.59                             19.40     96   11
# 39                   0.53                             19.93     86    6
# 40                   0.55                             20.49     90   15
# 41                   0.47                             20.96     77   10
# 42                   0.41                             21.37     67    8
# 43                   0.52                             21.90     85    9
# 44                   0.57                             22.46     92    7
# 45                   0.52                             22.99     85    6
# 46                   0.39                             23.38     64   10
# 47                   0.58                             23.96     95    9
# 48                   0.47                             24.43     76    7
# 49                   0.55                             24.98     89    8
#
#     Cumulative Bad        Quantile  #Quantile  Cumulative Precision  \
# 0               23  (0.886, 0.902]        200             28.048780
# 1               49  (0.873, 0.886]        199             30.246914
# 2               76  (0.864, 0.873]        198             31.666667
# 3               95  (0.858, 0.864]        197             29.687500
# 4              116  (0.853, 0.858]        196             29.072682
# 5              135  (0.849, 0.853]        195             28.481013
# 6              151  (0.846, 0.849]        194             27.655678
# 7              169  (0.842, 0.846]        193             26.283048
# 8              190  (0.838, 0.842]        192             26.243094
# 9              209  (0.833, 0.838]        191             25.770654
# 10             229  (0.829, 0.833]        190             25.817362
# 11             253  (0.825, 0.829]        189             26.028807
# 12             264  (0.822, 0.825]        188             25.071225
# 13             274  (0.819, 0.822]        187             24.442462
# 14             294  (0.815, 0.819]        186             24.157765
# 15             307  (0.812, 0.815]        185             23.798450
# 16             324  (0.809, 0.812]        184             23.546512
# 17             337  (0.806, 0.809]        183             23.193393
# 18             359  (0.803, 0.806]        182             23.510151
# 19             375    (0.8, 0.803]        181             23.466834
# 20             394    (0.797, 0.8]        180             23.313609
# 21             403  (0.794, 0.797]        179             22.551763
# 22             419   (0.79, 0.794]        178             22.587601
# 23             434   (0.787, 0.79]        177             22.348095
# 24             451  (0.785, 0.787]        176             22.348860
# 25             471  (0.782, 0.785]        175             22.546673
# 26             484  (0.778, 0.782]        174             22.110553
# 27             493  (0.775, 0.778]        173             21.785241
# 28             506  (0.771, 0.775]        172             21.522756
# 29             521  (0.768, 0.771]        171             21.413892
# 30             534  (0.765, 0.768]        170             21.325879
# 31             543  (0.762, 0.765]        169             21.022067
# 32             556  (0.758, 0.762]        168             20.808383
# 33             568  (0.755, 0.758]        167             20.707255
# 34             578  (0.751, 0.755]        166             20.344949
# 35             592  (0.747, 0.751]        165             20.253165
# 36             608  (0.744, 0.747]        164             20.327650
# 37             620  (0.741, 0.744]        163             20.294599
# 38             631  (0.737, 0.741]        162             20.025389
# 39             637  (0.733, 0.737]        161             19.678715
# 40             652  (0.729, 0.733]        160             19.597235
# 41             662  (0.725, 0.729]        159             19.447709
# 42             670  (0.722, 0.725]        158             19.302795
# 43             679  (0.719, 0.722]        157             19.094488
# 44             686  (0.715, 0.719]        156             18.804825
# 45             692  (0.711, 0.715]        155             18.537369
# 46             702  (0.707, 0.711]        154             18.488280
# %%
m = MetricsByQuantile(metrics=["quantiles_analytics"])
r = m.compute(
    y_true=data_dict['df_test'][TARGET_BIN_0isB].reset_index(drop=True), 
    y_pred=data_dict['df_test']['score'].round(3).reset_index(drop=True), 
    list_of_metrics = [
        "cum_precision_by_quantile", "cum_recall_by_quantile", 
        "precision_by_quantile", "recall_by_quantile",
    ], 
    n_quantiles = 200
)
df_deciles = r["other"]["quantiles_analytics"]
df_deciles.head(50)
# Out:
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#     % of total population  Cumulative % of total population  Total  Bad  \
# 0                    0.50                              0.50     82   44
# 1                    0.49                              1.00     80   40
# 2                    0.48                              1.48     78   40
# 3                    0.49                              1.97     80   31
# 4                    0.49                              2.46     79   33
# 5                    0.46                              2.92     75   28
# 6                    0.44                              3.36     72   32
# 7                    0.60                              3.96     97   33
# 8                    0.50                              4.46     81   35
# 9                    0.54                              4.99     87   33
# 10                   0.47                              5.46     76   29
# 11                   0.52                              5.98     85   37
# 12                   0.50                              6.48     81   28
# 13                   0.42                              6.90     68   22
# 14                   0.59                              7.49     96   29
# 15                   0.45                              7.94     73   27
# 16                   0.53                              8.47     86   31
# 17                   0.47                              8.95     77   30
# 18                   0.46                              9.40     74   28
# 19                   0.44                              9.84     71   26
# 20                   0.57                             10.41     92   31
# 21                   0.60                             11.00     97   24
# 22                   0.42                             11.42     68   23
# 23                   0.54                             11.96     87   29
# 24                   0.47                             12.43     76   29
# 25                   0.44                             12.86     71   28
# 26                   0.62                             13.48    100   28
# 27                   0.46                             13.93     74   19
# 28                   0.54                             14.48     88   25
# 29                   0.50                             14.98     82   21
# 30                   0.44                             15.42     71   29
# 31                   0.49                             15.90     79   20
# 32                   0.55                             16.45     89   28
# 33                   0.44                             16.89     71   22
# 34                   0.60                             17.49     98   25
# 35                   0.50                             18.00     82   21
# 36                   0.42                             18.42     68   23
# 37                   0.39                             18.81     64   21
# 38                   0.59                             19.40     96   23
# 39                   0.53                             19.93     86   16
# 40                   0.55                             20.49     90   29
# 41                   0.47                             20.96     77   23
# 42                   0.41                             21.37     67   10
# 43                   0.52                             21.90     85   15
# 44                   0.57                             22.46     92   19
# 45                   0.52                             22.99     85   21
# 46                   0.39                             23.38     64   14
# 47                   0.58                             23.96     95   18
# 48                   0.47                             24.43     76   18
# 49                   0.55                             24.98     89   16
#
#     Cumulative Bad        Quantile  #Quantile  Cumulative Precision  \
# 0               44  (0.886, 0.902]        200             53.658537
# 1               84  (0.873, 0.886]        199             51.851852
# 2              124  (0.864, 0.873]        198             51.666667
# 3              155  (0.858, 0.864]        197             48.437500
# 4              188  (0.853, 0.858]        196             47.117794
# 5              216  (0.849, 0.853]        195             45.569620
# 6              248  (0.846, 0.849]        194             45.421245
# 7              281  (0.842, 0.846]        193             43.701400
# 8              316  (0.838, 0.842]        192             43.646409
# 9              349  (0.833, 0.838]        191             43.033292
# 10             378  (0.829, 0.833]        190             42.615558
# 11             415  (0.825, 0.829]        189             42.695473
# 12             443  (0.822, 0.825]        188             42.070275
# 13             465  (0.819, 0.822]        187             41.480821
# 14             494  (0.815, 0.819]        186             40.591619
# 15             521  (0.812, 0.815]        185             40.387597
# 16             552  (0.809, 0.812]        184             40.116279
# 17             582  (0.806, 0.809]        183             40.055058
# 18             610  (0.803, 0.806]        182             39.947610
# 19             636    (0.8, 0.803]        181             39.799750
# 20             667    (0.797, 0.8]        180             39.467456
# 21             691  (0.794, 0.797]        179             38.668159
# 22             714   (0.79, 0.794]        178             38.490566
# 23             743   (0.787, 0.79]        177             38.259526
# 24             772  (0.785, 0.787]        176             38.255699
# 25             800  (0.782, 0.785]        175             38.295835
# 26             828  (0.778, 0.782]        174             37.825491
# 27             847  (0.775, 0.778]        173             37.428193
# 28             872  (0.771, 0.775]        172             37.090600
# 29             893  (0.768, 0.771]        171             36.703658
# 30             922  (0.765, 0.768]        170             36.821086
# 31             942  (0.762, 0.765]        169             36.469222
# 32             970  (0.758, 0.762]        168             36.302395
# 33             992  (0.755, 0.758]        167             36.164783
# 34            1017  (0.751, 0.755]        166             35.797254
# 35            1038  (0.747, 0.751]        165             35.511461
# 36            1061  (0.744, 0.747]        164             35.473086
# 37            1082  (0.741, 0.744]        163             35.417349
# 38            1105  (0.737, 0.741]        162             35.068232
# 39            1121  (0.733, 0.737]        161             34.630831
# 40            1150  (0.729, 0.733]        160             34.565675
# 41            1173  (0.725, 0.729]        159             34.459459
# 42            1183  (0.722, 0.725]        158             34.082397
# 43            1198  (0.719, 0.722]        157             33.689539
# 44            1217  (0.715, 0.719]        156             33.360746
# 45            1238  (0.711, 0.715]        155             33.163675
# 46            1252  (0.707, 0.711]        154             32.973400
# 47            1270  (0.702, 0.707]        153             32.631038
# 48            1288  (0.698, 0.702]        152             32.459677
# 49            1304  (0.694, 0.698]        151             32.141977
#
#     Cumulative Recall  Precision    Recall        Scores
# 0            1.706749  53.658537  1.706749  0.886--0.902
# 1            3.258340  50.000000  1.551590  0.873--0.886
# 2            4.809930  51.282051  1.551590  0.864--0.873
# 3            6.012413  38.750000  1.202483  0.858--0.864
# 4            7.292475  41.772152  1.280062  0.853--0.858
# 5            8.378588  37.333333  1.086113  0.849--0.853
# 6            9.619860  44.444444  1.241272  0.846--0.849
# 7           10.899922  34.020619  1.280062  0.842--0.846
# 8           12.257564  43.209877  1.357642  0.838--0.842
# 9           13.537626  37.931034  1.280062  0.833--0.838
# 10          14.662529  38.157895  1.124903  0.829--0.833
# 11          16.097750  43.529412  1.435221  0.825--0.829
# 12          17.183863  34.567901  1.086113  0.822--0.825
# 13          18.037238  32.352941  0.853375  0.819--0.822
# 14          19.162141  30.208333  1.124903  0.815--0.819
# 15          20.209465  36.986301  1.047324  0.812--0.815
# 16          21.411947  36.046512  1.202483  0.809--0.812
# 17          22.575640  38.961039  1.163693  0.806--0.809
# 18          23.661753  37.837838  1.086113  0.803--0.806
# 19          24.670287  36.619718  1.008534    0.8--0.803
# 20          25.872770  33.695652  1.202483    0.797--0.8
# 21          26.803724  24.742268  0.930954  0.794--0.797
# 22          27.695888  33.823529  0.892164   0.79--0.794
# 23          28.820791  33.333333  1.124903   0.787--0.79
# 24          29.945694  38.157895  1.124903  0.785--0.787
# 25          31.031808  39.436620  1.086113  0.782--0.785
# 26          32.117921  28.000000  1.086113  0.778--0.782
# 27          32.854926  25.675676  0.737005  0.775--0.778
# 28          33.824670  28.409091  0.969744  0.771--0.775
# 29          34.639255  25.609756  0.814585  0.768--0.771
# 30          35.764158  40.845070  1.124903  0.765--0.768
# 31          36.539953  25.316456  0.775795  0.762--0.765
# 32          37.626067  31.460674  1.086113  0.758--0.762
# 33          38.479441  30.985915  0.853375  0.755--0.758
# 34          39.449185  25.510204  0.969744  0.751--0.755
# 35          40.263770  25.609756  0.814585  0.747--0.751
# 36          41.155935  33.823529  0.892164  0.744--0.747
# 37          41.970520  32.812500  0.814585  0.741--0.744
# 38          42.862684  23.958333  0.892164  0.737--0.741
# 39          43.483320  18.604651  0.620636  0.733--0.737
# 40          44.608223  32.222222  1.124903  0.729--0.733
# 41          45.500388  29.870130  0.892164  0.725--0.729
# 42          45.888285  14.925373  0.387898  0.722--0.725
# 43          46.470132  17.647059  0.581846  0.719--0.722
# 44          47.207137  20.652174  0.737005  0.715--0.719
# 45          48.021722  24.705882  0.814585  0.711--0.715
# 46          48.564779  21.875000  0.543057  0.707--0.711
# 47          49.262995  18.947368  0.698216  0.702--0.707
# 48          49.961210  23.684211  0.698216  0.698--0.702
# 49          50.581846  17.977528  0.620636  0.694--0.698

# %%
df_coeff
# Out:
#                         Feature     Coeff  Importance(%)       p-value  \
# 0     CLU_CLI_L6M_NPR_L6MOptBin -0.061994       2.200966  2.303975e-06
# 1                EA5_S_01OptBin -0.138331       4.911138  0.000000e+00
# 2           GEN11_SP_N_91OptBin -0.043338       1.538637  8.372433e-04
# 3   GEN11_SP_N_92_ABOtherOptBin -0.031970       1.135015  1.432966e-02
# 4                     Intercept -0.848414      30.121113  0.000000e+00
# 5          OPTIN_11SCN_MLOptBin -1.154033      40.971473  0.000000e+00
# 6               SPA_F2_33OptBin -0.148684       5.278695  0.000000e+00
# 7                SP_B1_14OptBin -0.037003       1.313715  2.707878e-03
# 8                 SP_G_37OptBin -0.086573       3.073586  5.415637e-08
# 9                 SP_G_38OptBin -0.067252       2.387637  3.872065e-05
# 10             SP_I_63_01OptBin -0.060167       2.136115  9.207243e-07
# 11               TRD_A_20OptBin -0.061793       2.193838  5.610777e-06
# 12               TRD_C_07OptBin -0.077123       2.738072  7.842710e-09
#
#     Importance(SHAP)  Importance(SHAP, %)
# 0           0.036894             1.842981
# 1           0.066979             3.345819
# 2           0.026220             1.309806
# 3           0.024251             1.211425
# 4                NaN                  NaN
# 5           1.479513            73.906958
# 6           0.113098             5.649671
# 7           0.016091             0.803826
# 8           0.067042             3.348969
# 9           0.046221             2.308923
# 10          0.021221             1.060083
# 11          0.056525             2.823647
# 12          0.047802             2.387891
