# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import copy
from typing import (
    Dict, 
    List,
    Any
)


import mlflow
import warnings
from datetime import datetime

from tqdm.autonotebook import tqdm

import numpy as np
import pandas as pd

from scipy.stats import uniform

import shap

import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\hdychko\AppData\Local\Temp\ipykernel_36708\243224794.py:15: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
sys.path.append(os.path.join(os.getcwd(), '..'))
from utils.modelling_tools import *

# %%
TRAIN_FROM: datetime.date = pd.to_datetime('2021-12-01').date()
TRAIN_TO: datetime.date = pd.to_datetime('2022-01-01').date()

VAL_FROM: datetime.date = pd.to_datetime('2022-01-01').date()
VAL_TO: datetime.date = pd.to_datetime('2022-05-01').date()

TEST_FROM: datetime.date = pd.to_datetime('2022-05-01').date()
TEST_TO: datetime.date = pd.to_datetime('2022-08-01').date()

# %%
# set constants
COLS_TO_USE: List[str] = [
    "OPTIN_11SCN_MLOptBin",
"G5_ND_SPECIIOptBin",
"Marital_StatusOptBin",
"SP_F2_33OptBin",
"AFF_B_09_01OptBin",
"TRD_A_20OptBin",
"VM01_SP_VM2_15OptBin",
"SP_EDI_24OptBin",
"E4_Q_17OptBin",
"TRD_C_07OptBin",
"SP_B2_18OptBin",
"SPA_F2_33OptBin",
"VM01_SP_VM2_14OptBin",
"SP_G_38OptBin",
"TRD_O_05OptBin",
"E1_A_09OptBin",
"TRD_O_07OptBin",
"ND_INC_03OptBin",
"VM01_SP_VM2_17OptBin",
"GEN11_SP_N_91OptBin",
"GEN11_SP_EDI_07OptBin",
"TRD_B_18OptBin",
"EA5_S_01OptBin",
"CLU_CLI_L6M_NPR_L6MOptBin",
"SP_I_67_01OptBin",
"GEN11_SP_K_80OptBin",
"ND_ECC_04OptBin",
"ND_ERL_01OptBin",
"ND_HAC_06OptBin",
"AFF_E_07_01OptBin",
"TRD_O_06OptBin",
"E2_G_08OptBin",
"AFF_T_07_01OptBin",
] 

TARGET_NAME: str = 'GB6_Flag_2Limit'
TARGET_VALS: List[int] = [0, 1]
TARGET_BIN: str = f'_{TARGET_NAME}_bin'

PALETTE: Dict[str, str] = {
    TARGET_NAME: {
        'G': 'green',
        'B': 'red',
        'I': 'black'
    },
    TARGET_BIN: {0: 'green', 1: 'red'},
    'DataPart': {'Train-val': 'orange', 'Val': 'blue', 'Test': 'black'}
    # 'Test-OOT': 'black'
}

PROJECT_PATH: str = os.path.join(os.getcwd(), '..')
DATA_PATH: str = os.path.join(PROJECT_PATH, 'data')
OPT_BIN_PATH: str = os.path.join(os.path.join(PROJECT_PATH, 'objects'), 'optbinners')
MODELS_PATH: str = os.path.join(os.path.join(PROJECT_PATH, 'objects'), 'models')

# %%
N_ITER: int = 20
RANDOM_SEED: int = 42

# %%
# read data
df: pd.DataFrame = pd.read_csv(os.path.join(DATA_PATH, 'final_aiq2_optbins.csv'), low_memory=False)

# %%
print('Number of rows: %.0f; columns: %.0f' % df.shape)
# Out:
# Number of rows: 110462; columns: 2069

# %% [markdown]
# # Preprocessing

# %% [markdown]
# # Convert dates to the corresponding types

# %%
for col in ['_RDATE_EOM', '_RDATE']:
    df[col] = pd.to_datetime(df[col]).dt.date

# %%
print('Available date range:')
df['_RDATE'].agg(['min', 'max'])
# Out:
# Available date range:
# min    2021-06-30
# max    2023-11-30
# Name: _RDATE, dtype: object

# %%
pd.merge(
    pd.DataFrame(df.groupby([TARGET_NAME])[TARGET_BIN].value_counts()),
    pd.DataFrame(df[TARGET_NAME].value_counts(normalize=True)),
    how='outer', left_index=True, right_index=True
)
# Out:
#                                       count  proportion
# GB6_Flag_2Limit _GB6_Flag_2Limit_bin
# B               1                      4449    0.040276
# G               0                     99444    0.900255
# I               0                      6569    0.059468

# %%
df_train = df.loc[
    (df._RDATE >= TRAIN_FROM) &
    (df._RDATE < TRAIN_TO) & 
    (df[TARGET_NAME] != 'I'),
    COLS_TO_USE + [TARGET_NAME, TARGET_BIN, '_RDATE']
].reset_index(drop=True)

df_train_val = df.loc[
    (df._RDATE >= TRAIN_FROM) &
    (df._RDATE < VAL_TO) &
    (df[TARGET_NAME] != 'I'),
    COLS_TO_USE + [TARGET_NAME, TARGET_BIN, '_RDATE']
].reset_index(drop=True)

df_val = df.loc[
    (df._RDATE >= VAL_FROM) &
    (df._RDATE < VAL_TO) &
    (df[TARGET_NAME] != 'I'),
    COLS_TO_USE + [TARGET_NAME, TARGET_BIN, '_RDATE']
].reset_index(drop=True)

df_test_same = df.loc[
    (df._RDATE >= TEST_FROM) &
    (df._RDATE < TEST_TO) &
    (df[TARGET_NAME] != 'I'),
    COLS_TO_USE + [TARGET_NAME, TARGET_BIN, '_RDATE']
].reset_index(drop=True)

df_test = df.loc[
    (df._RDATE >= TEST_FROM) &
    (df._RDATE < TEST_TO),
    COLS_TO_USE + [TARGET_NAME, TARGET_BIN, '_RDATE']
].reset_index(drop=True)

# %%
data_dict = {
    "df_train": df_train,
    "df_val": df_val,
    "df_train_val": df_train_val, 
    "df_test_same": df_test_same,
    "df_test": df_test
}

# %%
# randomly select N observations from test data
N = 10000
sss = StratifiedShuffleSplit(n_splits=1, train_size=N, random_state=RANDOM_SEED)
indx = sss.split(data_dict['df_test_same'].reset_index(drop=True), data_dict['df_test_same'][TARGET_BIN])
random_indx = list(indx)[0][0]

assert len(random_indx) == N, "Incorrect number of elements in the subsample"
test_sample = data_dict['df_test'].reset_index(drop=True).iloc[random_indx, :].reset_index(drop=True)

# %%
data_dict['df_test_same_sample'] = test_sample

# %%
mlflow.set_tracking_uri(uri="http://127.0.0.1:5000/")
mlflow.set_experiment("[Experian]")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/696858428304145414', creation_time=1716463645799, experiment_id='696858428304145414', last_update_time=1716463645799, lifecycle_stage='active', name='[Experian]', tags={}>

# %%
MODEL = LogisticRegression

# %%
experiment_description = f"""
    'features': {len(COLS_TO_USE)},
    'target': {TARGET_BIN},
    'target_vals': '0==G, 1==B',
    'model': {MODEL.__name__},
    'data_version': '22.05.2024', 
    'train_period': [{TRAIN_FROM.strftime('%Y-%m-%d') + ', ' + TRAIN_TO.strftime('%Y-%m-%d')}),
    'val_period': [{VAL_FROM.strftime('%Y-%m-%d') + ', ' + VAL_TO.strftime('%Y-%m-%d')}),
    'test_period': [{TEST_FROM.strftime('%Y-%m-%d') + ', ' + TEST_TO.strftime('%Y-%m-%d')}),
"""

# %%
print(experiment_description)
# Out:
#     'features': 33,
#     'target': _GB6_Flag_2Limit_bin,
#     'target_vals': '0==G, 1==B',
#     'model': LogisticRegression,
#     'data_version': '22.05.2024',
#     'train_period': [2021-12-01, 2022-01-01),
#     'val_period': [2022-01-01, 2022-05-01),
#     'test_period': [2022-05-01, 2022-08-01),

# %%
PARAMS = dict(
    penalty=['l2', 'l1', 'elasticnet'], 
    C=uniform(loc=0, scale=20), 
    fit_intercept=[True], 
    class_weight=['balanced'], 
    random_state=[RANDOM_SEED], 
    n_jobs=[-1], 
)

# %%
RUN_NAME = '04-LogRegression-hyperparams_tunning'
with mlflow.start_run(run_name=RUN_NAME, log_system_metrics=True):
    res = search_hyper_params_and_log(
        run_name=RUN_NAME,
        data_dict=data_dict,
        cols_to_use=COLS_TO_USE,
        target_name=TARGET_BIN,
        distributions=PARAMS,
        n_iter=50,
        model=MODEL,
        custom_params_updates=update_solver_by_penalty,
        tags={'features': len(COLS_TO_USE)}, 
        palette=PALETTE,
        test_name='df_test_same'
    )
# Out:
# 2024/05/24 14:37:47 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/24 14:37:47 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# The max_iter was reached which means the coef_ did not converge
# # 1 / 50
# 2024/05/24 14:37:48 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:37:48 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:38:02 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:38:02 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 2 / 50
# 2024/05/24 14:38:02 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/24 14:38:02 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:38:11 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:38:11 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 3 / 50
# The max_iter was reached which means the coef_ did not converge
# 2024/05/24 14:38:12 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:38:12 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:38:22 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:38:22 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 4 / 50
# 2024/05/24 14:38:25 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/24 14:38:25 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:38:32 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:38:32 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 5 / 50
# 2024/05/24 14:38:33 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:38:33 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:38:41 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:38:41 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 6 / 50
# The max_iter was reached which means the coef_ did not converge
# 2024/05/24 14:38:42 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/24 14:38:42 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:38:52 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:38:52 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 7 / 50
# 2024/05/24 14:38:53 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/24 14:38:53 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:39:01 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:39:01 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 8 / 50
# 2024/05/24 14:39:01 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/24 14:39:01 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:39:09 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:39:09 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 9 / 50
# 2024/05/24 14:39:09 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:39:09 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:39:18 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:39:18 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 10 / 50
# 2024/05/24 14:39:18 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/24 14:39:18 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:39:26 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:39:26 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 11 / 50
# 2024/05/24 14:39:27 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/24 14:39:27 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:39:34 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:39:34 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 12 / 50
# 2024/05/24 14:39:35 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/24 14:39:35 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:39:43 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:39:43 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 13 / 50
# 2024/05/24 14:39:43 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:39:43 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:39:50 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:39:50 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 14 / 50
# 2024/05/24 14:39:51 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/24 14:39:51 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:39:59 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:39:59 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 15 / 50
# 2024/05/24 14:39:59 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:39:59 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:40:07 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:40:07 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 16 / 50
# 2024/05/24 14:40:08 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:40:08 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:40:15 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:40:15 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 17 / 50
# 2024/05/24 14:40:16 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:40:16 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:40:25 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:40:25 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 18 / 50
# 2024/05/24 14:40:25 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:40:25 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:40:33 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:40:33 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 19 / 50
# 2024/05/24 14:40:34 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:40:34 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:40:45 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:40:45 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 20 / 50
# 2024/05/24 14:40:45 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:40:45 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:40:53 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:40:53 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 21 / 50
# 2024/05/24 14:40:53 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:40:53 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:41:00 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:41:00 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 22 / 50
# 2024/05/24 14:41:01 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:41:01 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# ...
# 2024/05/24 14:45:37 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 49 / 50
# 2024/05/24 14:45:37 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:45:37 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:45:45 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:45:45 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 50 / 50
# 2024/05/24 14:45:45 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/24 14:45:45 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:45:54 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:45:54 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# Best params:
#  {'penalty': 'elasticnet', 'C': 3.4104824737458306, 'fit_intercept': True, 'class_weight': 'balanced', 'random_state': 42, 'n_jobs': -1, 'solver': 'saga', 'l1_ratio': 0.06505159298527952}
# The max_iter was reached which means the coef_ did not converge
# Test-PR_AUC 0.11915317497404254
# Test-Gini 0.5980106328245582
# Not saved
# The option feature_dependence has been renamed to feature_perturbation!
# The feature_perturbation option is now deprecated in favor of using the appropriate masker (maskers.Independent, or maskers.Impute)
# .values =
# array([-3.92893291, -3.92893291,  4.59605218, ...,  2.99687107,
#         3.88783219, -3.09094501])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([ 2.99474675,  2.99474675, -1.48385189, ..., -0.64372252,
#        -1.11178871,  2.55451004])
# .values =
# array([-0.23740464, -0.23740464,  1.56541002, ..., -0.23740464,
#        -0.23740464, -0.23740464])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([ 0.25783187,  0.25783187, -1.37849138, ...,  0.25783187,
#         0.25783187,  0.25783187])
# .values =
# array([-2.07926791, -0.95452358,  1.79507365, ..., -0.95452358,
#         1.79507365,  1.79507365])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([ 2.2584247 ,  1.43192539, -0.58856955, ...,  1.43192539,
#        -0.58856955, -0.58856955])
# .values =
# array([-0.01688722,  0.0290294 , -0.03762628, ..., -0.03762628,
#        -0.00803108, -0.00803108])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([-0.07402703,  1.67999899, -0.86626434, ..., -0.86626434,
#         0.26427951,  0.26427951])
# .values =
# array([-0.11725286, -0.11725286, -0.21217007, ..., -0.44026697,
#        -0.44026697,  0.30210922])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([ 0.11437588,  0.11437588, -0.11903656, ..., -0.67995335,
#        -0.67995335,  1.14563599])
# .values =
# array([-0.64844851, -0.64844851,  0.41458183, ...,  0.41458183,
#        -0.64844851,  0.41458183])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([ 1.42155037,  1.42155037, -0.45645552, ..., -0.45645552,
#         1.42155037, -0.45645552])
# .values =
# array([-0.60625997, -0.60625997,  0.5307016 , ...,  0.5307016 ,
#         0.41334978, -0.16142984])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([ 2.24867633,  2.24867633, -1.00554946, ..., -1.00554946,
#        -0.66966358,  0.97547792])
# .values =
# array([-0.98244884, -0.17896972, -0.17896972, ...,  0.44691031,
#         0.44691031, -0.17896972])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([ 1.76910325,  0.46029847,  0.46029847, ..., -0.55921124,
#        -0.55921124,  0.46029847])
# .values =
# array([-0.03413001, -0.03413001,  0.02323739, ..., -0.03413001,
#         0.02323739, -0.03413001])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([ 0.88915064,  0.88915064, -0.13253725, ...,  0.88915064,
#        -0.13253725,  0.88915064])
# .values =
# array([ 0.06269209, -0.41659638,  0.73113201, ...,  0.73113201,
#         0.06269209,  0.06269209])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([ 0.00824407,  0.71284345, -0.97442585, ..., -0.97442585,
#         0.00824407,  0.00824407])
# .values =
# array([-0.36422149, -0.63322875,  1.16587874, ...,  0.36419843,
#         0.36419843, -0.36422149])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([ 0.72895436,  1.11733109, -1.48011357, ..., -0.3226951 ,
#        -0.3226951 ,  0.72895436])
# .values =
# array([ 0.16931547, -0.4474495 , -0.08349742, ...,  0.16931547,
#         0.16931547,  0.16931547])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([-0.32307254,  1.92487265,  0.59836358, ..., -0.32307254,
#        -0.32307254, -0.32307254])
# .values =
# array([ 0.79959057, -0.28052322, -0.68429458, ..., -0.68429458,
#        -0.36230988,  0.36789603])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([ 1.7260953 , -0.26225749, -1.00554946, ..., -1.00554946,
#        -0.41281637,  0.93140029])
# .values =
# array([ 0.25867302,  0.25867302, -0.06398978, ..., -0.12659369,
#        -0.08395912, -0.12659369])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([ 1.82216229,  1.82216229, -0.17035703, ..., -0.55695098,
#        -0.29367241, -0.55695098])
# .values =
# array([ 0.20218932, -0.54797124,  0.20218932, ...,  0.20218932,
#        -0.54797124,  0.20218932])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([-0.22332692,  0.7066837 , -0.22332692, ..., -0.22332692,
#         0.7066837 , -0.22332692])
# .values =
# array([-0.12092314, -0.12092314,  0.30253544, ..., -0.12092314,
#         0.4029254 , -0.12092314])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([ 0.62133384,  0.62133384, -0.64862661, ...,  0.62133384,
#        -0.94969801,  0.62133384])
# .values =
# array([-0.5326459 , -0.01715644, -0.5326459 , ..., -0.5326459 ,
#        -0.5326459 , -0.5326459 ])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([-0.5840316 ,  0.25151281, -0.5840316 , ..., -0.5840316 ,
#        -0.5840316 , -0.5840316 ])
# .values =
# array([-0.23687766, -0.23687766,  0.11061713, ...,  0.11061713,
#         0.11061713,  0.05705148])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([ 0.79959541,  0.79959541, -0.22365204, ..., -0.22365204,
#        -0.22365204, -0.06592044])
# .values =
# array([-0.05453699,  0.25657043, -0.21132085, ..., -0.21132085,
#        -0.0768831 ,  0.08317528])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([-0.10043523,  1.69558986, -1.00554946, ..., -1.00554946,
#        -0.22943949,  0.69457856])
# .values =
# array([-0.11503871, -0.11503871,  0.02088407, ...,  0.07796437,
#         0.29662085, -0.11503871])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([ 0.58268625,  0.58268625,  0.07932923, ..., -0.13205379,
#        -0.94179494,  0.58268625])
# .values =
# array([-0.21672466, -0.02225835,  0.09363556, ..., -0.51298482,
#        -0.39440222,  0.09363556])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([-0.26007646,  0.09115383,  0.3004726 , ..., -0.79515906,
#        -0.58098418,  0.3004726 ])
# .values =
# array([ 0.13271447,  0.13271447, -0.63073772, ...,  0.13271447,
#        -0.30734224,  0.13271447])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([ 0.43720996,  0.43720996, -1.31650893, ...,  0.43720996,
#        -0.5736402 ,  0.43720996])
# .values =
# array([-0.13515253, -0.55989147, -0.55989147, ...,  0.44899653,
#        -0.13515253,  0.22106921])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([ 0.32010486,  0.99260162,  0.99260162, ..., -0.6047888 ,
#         0.32010486, -0.24390739])
# .values =
# array([ 0.10063149,  0.10063149, -0.21384191, ..., -0.21384191,
#         0.10063149,  0.10063149])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([ 0.31746179,  0.31746179, -0.72582094, ..., -0.72582094,
#         0.31746179,  0.31746179])
# .values =
# array([ 0.19724192, -1.04796259,  0.19724192, ...,  0.19724192,
#         0.19724192,  0.19724192])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([-0.2105276 ,  2.14196943, -0.2105276 , ..., -0.2105276 ,
#        -0.2105276 , -0.2105276 ])
# .values =
# array([ 0.03291599,  0.06090988,  0.06090988, ..., -0.00926906,
#        -0.00926906,  0.06090988])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([0.489254  , 0.81392165, 0.81392165, ..., 0.        , 0.        ,
#        0.81392165])
# .values =
# array([-0.09726106, -0.09726106,  0.91433118, ..., -0.09726106,
#        -0.09726106, -0.09726106])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([ 0.33108872,  0.33108872, -1.37415297, ...,  0.33108872,
#         0.33108872,  0.33108872])
# .values =
# array([ 0.1106378 ,  0.1106378 , -0.29913184, ...,  0.1106378 ,
#        -0.29913184,  0.1106378 ])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([ 0.25259013,  0.25259013, -0.49945757, ...,  0.25259013,
#        -0.49945757,  0.25259013])
# .values =
# array([-0.17604379,  0.50104772,  0.50104772, ..., -0.17604379,
#        -0.17604379, -0.17604379])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([-0.18718329,  0.8595552 ,  0.8595552 , ..., -0.18718329,
#        -0.18718329, -0.18718329])
# .values =
# array([-0.24406845, -0.24406845, -0.24406845, ..., -0.24406845,
#         0.44078467, -0.24406845])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([ 0.44177225,  0.44177225,  0.44177225, ...,  0.44177225,
#        -0.60684965,  0.44177225])
# .values =
# array([ 0.22302885,  0.07228639, -0.13681916, ..., -0.13681916,
#        -0.13681916,  0.22302885])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([ 1.05380532,  0.42523164, -0.44670749, ..., -0.44670749,
#        -0.44670749,  1.05380532])
# .values =
# array([-0.29756398,  0.80452483,  0.80452483, ..., -0.29756398,
#        -0.29756398, -0.29756398])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([-0.2006119 ,  0.92478913,  0.92478913, ..., -0.2006119 ,
#        -0.2006119 , -0.2006119 ])
# .values =
# array([ 0.056567  ,  0.056567  ,  0.056567  , ...,  0.056567  ,
#        -0.17117261,  0.056567  ])
#
# .base_values =
# array([-4.60943094, -4.60943094, -4.60943094, ..., -4.60943094,
#        -4.60943094, -4.60943094])
#
# .data =
# array([ 0.28199654,  0.28199654,  0.28199654, ...,  0.28199654,
#        -0.81172408,  0.28199654])
# 2024/05/24 14:46:01 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:46:01 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!

# %%
pd.merge(
    pd.DataFrame(data_dict['df_test'][TARGET_BIN].value_counts()),
    pd.DataFrame(data_dict['df_test'][TARGET_BIN].value_counts(normalize=True)),
    how='outer', left_index=True, right_index=True
)
# Out:
#                       count  proportion
# _GB6_Flag_2Limit_bin
# 0                     10941    0.968401
# 1                       357    0.031599

# %%
pd.merge(
    pd.DataFrame(data_dict['df_val'][TARGET_BIN].value_counts()),
    pd.DataFrame(data_dict['df_val'][TARGET_BIN].value_counts(normalize=True)),
    how='outer', left_index=True, right_index=True
)
# Out:
#                       count  proportion
# _GB6_Flag_2Limit_bin
# 0                     12545    0.965297
# 1                       451    0.034703

# %%
pd.merge(
    pd.DataFrame(data_dict['df_train'][TARGET_BIN].value_counts()),
    pd.DataFrame(data_dict['df_train'][TARGET_BIN].value_counts(normalize=True)),
    how='outer', left_index=True, right_index=True
)
# Out:
#                       count  proportion
# _GB6_Flag_2Limit_bin
# 0                      2518    0.968462
# 1                        82    0.031538

# %%
pd.merge(
    pd.DataFrame(data_dict['df_train_val'][TARGET_BIN].value_counts()),
    pd.DataFrame(data_dict['df_train_val'][TARGET_BIN].value_counts(normalize=True)),
    how='outer', left_index=True, right_index=True
)
# Out:
#                       count  proportion
# _GB6_Flag_2Limit_bin
# 0                     15063    0.965825
# 1                       533    0.034175

# %%
res.sort_values('PR_AUC_val', ascending=False).head()
# Out:
#     iter  GINI_train  GINI_val  GINI_prcnt_chng  PR_AUC_train  PR_AUC_val  \
# 12    12    0.702212  0.660996        -5.869548      0.150082    0.165442
# 22    22    0.678423  0.649091        -4.323558      0.150912    0.163195
# 49    49    0.642341  0.662579         3.150714      0.146086    0.159743
# 36    36    0.706213  0.680774        -3.602141      0.131604    0.156050
# 0      0    0.700343  0.645094        -7.888876      0.135697    0.155235
#
#     PR_AUC_prcnt_chng                                             params
# 12          10.234212  {'penalty': 'elasticnet', 'C': 3.4104824737458...
# 22           8.139507  {'penalty': 'elasticnet', 'C': 18.437484700462...
# 49           9.348848  {'penalty': 'elasticnet', 'C': 18.136568830915...
# 36          18.575105  {'penalty': 'elasticnet', 'C': 14.264895744459...
# 0           14.398671  {'penalty': 'elasticnet', 'C': 15.930859737204...

# %%
res.sort_values('GINI_val', ascending=False).head()
# Out:
#     iter  GINI_train  GINI_val  GINI_prcnt_chng  PR_AUC_train  PR_AUC_val  \
# 36    36    0.706213  0.680774        -3.602141      0.131604    0.156050
# 7      7    0.749056  0.680204        -9.191804      0.145034    0.138710
# 37    37    0.719570  0.679056        -5.630339      0.119532    0.131170
# 39    39    0.750015  0.671079       -10.524472      0.142086    0.133138
# 35    35    0.704353  0.670856        -4.755661      0.114088    0.144362
#
#     PR_AUC_prcnt_chng                                             params
# 36          18.575105  {'penalty': 'elasticnet', 'C': 14.264895744459...
# 7           -4.360461  {'penalty': 'l1', 'C': 0.14132610439434812, 'f...
# 37           9.736569  {'penalty': 'l1', 'C': 4.719698394979115, 'fit...
# 39          -6.297146  {'penalty': 'l1', 'C': 0.5083825348819038, 'fi...
# 35          26.535369  {'penalty': 'elasticnet', 'C': 11.224868516954...

# %%
res[res.iter == 7].params.values[0]
# Out:
# {'penalty': 'l1',
#  'C': 0.14132610439434812,
#  'fit_intercept': True,
#  'class_weight': 'balanced',
#  'random_state': 42,
#  'n_jobs': -1,
#  'solver': 'liblinear'}

# %%
params = copy.deepcopy(res[res.iter == 7].params.values[0])

# %%
params['max_iter'] = 50000

# %%
# data_dict, model, scaler = train_pred(
#     data_dict=data_dict,
#     cols_to_use=COLS_TO_USE,
#     target_name=TARGET_BIN,
#     model=MODEL,
#     params=params,
#     alias='',
#     test_name='df_test_same'
# )
data_dict, model, scaler = train_pred(
    data_dict=data_dict,
    cols_to_use=COLS_TO_USE,
    target_name=TARGET_BIN,
    model=MODEL,
    params=params,
    alias='',
    test_name='df_test'
)
# Out:
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.

# %%
model.coef_
# Out:
# array([[-1.13451479, -0.14556217, -0.7281814 ,  0.10685341,  0.19422593,
#         -0.0619959 , -0.15922418, -0.22939649,  0.07750316, -0.19915239,
#         -0.14312602, -0.19175214,  0.16299979, -0.1083937 , -0.21730958,
#          0.07620123,  0.0780406 , -0.11403907, -0.04276287, -0.22549845,
#          0.18246228,  0.14974656, -0.19933992,  0.0910498 , -0.09083651,
#         -0.10031141, -0.10747178, -0.04812219,  0.10580494, -0.11188695,
#          0.19282554,  0.14635664, -0.04764431]])

# %%
model.intercept_
# Out:
# array([-1.44445815])

# %%
df_coeff = pd.DataFrame(
    {
        'Feature': COLS_TO_USE + ['Intercept'],
        'Coeff': np.append(model.coef_[0], model.intercept_)
    }
)

# %%
df_coeff['Coeff_abs'] = df_coeff.Coeff.abs()
df_coeff['Importance (%)'] = df_coeff.Coeff_abs * 100 / df_coeff.Coeff_abs.sum()
df_coeff = df_coeff.sort_values('Coeff_abs', ascending=False)

# %%
def logit_pvalue(model, x):
    """ Calculate z-scores for scikit-learn LogisticRegression.
    parameters:
        model: fitted sklearn.linear_model.LogisticRegression with intercept and large C
        x:     matrix on which the model was fit
    This function uses asymtptics for maximum likelihood estimates.

 
    For a vector of maximum likelihood estimates theta, its variance-covariance matrix can be estimated as inverse(H), where H is the Hessian matrix of log-likelihood at theta.

 
    """
    from scipy.stats import norm
    p = model.predict_proba(x)
    n = len(p)
    m = len(model.coef_[0]) + 1
    coefs = np.concatenate([model.intercept_, model.coef_[0]])
    x_full = np.matrix(np.insert(np.array(x), 0, 1, axis = 1))
    ans = np.zeros((m, m))
    for i in range(n):
        ans = ans + np.dot(np.transpose(x_full[i, :]), x_full[i, :]) * p[i,1] * p[i, 0]
    vcov = np.linalg.inv(np.matrix(ans))
    se = np.sqrt(np.diag(vcov))
    t =  coefs/se  
    p = (1 - norm.cdf(abs(t))) * 2
    return p

# %%
df_p = pd.DataFrame(
    {
        'p-value': logit_pvalue(model, scaler.transform(data_dict['df_train_val'][COLS_TO_USE])), 
        'Feature': ['Intercept'] + COLS_TO_USE,
    }
)

# %%
df_coeff = pd.merge(df_coeff, df_p, on='Feature', how='outer')

# %%
p_value = 0.05

# %%
df_coeff[df_coeff['p-value'] >= p_value]
# Out:
#                  Feature     Coeff  Coeff_abs  Importance (%)   p-value
# 2      AFF_T_07_01OptBin -0.047644   0.047644        0.642535  0.081326
# 25        TRD_A_20OptBin -0.061996   0.061996        0.836082  0.067941
# 33  VM01_SP_VM2_17OptBin -0.042763   0.042763        0.576704  0.363599

# %%
for col in COLS_TO_USE:
    if col not in df_coeff[df_coeff['p-value'] > p_value].Feature.values:
        print(f'"{col}",')
# Out:
# "OPTIN_11SCN_MLOptBin",
# "G5_ND_SPECIIOptBin",
# "Marital_StatusOptBin",
# "SP_F2_33OptBin",
# "AFF_B_09_01OptBin",
# "VM01_SP_VM2_15OptBin",
# "SP_EDI_24OptBin",
# "E4_Q_17OptBin",
# "TRD_C_07OptBin",
# "SP_B2_18OptBin",
# "SPA_F2_33OptBin",
# "VM01_SP_VM2_14OptBin",
# "SP_G_38OptBin",
# "TRD_O_05OptBin",
# "E1_A_09OptBin",
# "TRD_O_07OptBin",
# "ND_INC_03OptBin",
# "GEN11_SP_N_91OptBin",
# "GEN11_SP_EDI_07OptBin",
# "TRD_B_18OptBin",
# "EA5_S_01OptBin",
# "CLU_CLI_L6M_NPR_L6MOptBin",
# "SP_I_67_01OptBin",
# "GEN11_SP_K_80OptBin",
# "ND_ECC_04OptBin",
# "ND_ERL_01OptBin",
# "ND_HAC_06OptBin",
# "AFF_E_07_01OptBin",
# "TRD_O_06OptBin",
# "E2_G_08OptBin",

# %%
data_dict['df_train_val'].columns
# Out:
# Index(['OPTIN_11SCN_MLOptBin', 'G5_ND_SPECIIOptBin', 'Marital_StatusOptBin',
#        'SP_F2_33OptBin', 'AFF_B_09_01OptBin', 'TRD_A_20OptBin',
#        'VM01_SP_VM2_15OptBin', 'SP_EDI_24OptBin', 'E4_Q_17OptBin',
#        'TRD_C_07OptBin', 'SP_B2_18OptBin', 'SPA_F2_33OptBin',
#        'VM01_SP_VM2_14OptBin', 'SP_G_38OptBin', 'TRD_O_05OptBin',
#        'E1_A_09OptBin', 'TRD_O_07OptBin', 'ND_INC_03OptBin',
#        'VM01_SP_VM2_17OptBin', 'GEN11_SP_N_91OptBin', 'GEN11_SP_EDI_07OptBin',
#        'TRD_B_18OptBin', 'EA5_S_01OptBin', 'CLU_CLI_L6M_NPR_L6MOptBin',
#        'SP_I_67_01OptBin', 'GEN11_SP_K_80OptBin', 'ND_ECC_04OptBin',
#        'ND_ERL_01OptBin', 'ND_HAC_06OptBin', 'AFF_E_07_01OptBin',
#        'TRD_O_06OptBin', 'E2_G_08OptBin', 'AFF_T_07_01OptBin',
#        'GB6_Flag_2Limit', '_GB6_Flag_2Limit_bin', '_RDATE', 'score_same',
#        'score'],
#       dtype='object')

# %%
roc_auc_train = roc_auc_score(data_dict['df_train_val'][TARGET_BIN], data_dict['df_train_val']['score'])
gini_train = 2 * roc_auc_train - 1

roc_auc_val = roc_auc_score(data_dict['df_test'][TARGET_BIN], data_dict['df_test']['score'])
gini_val = 2 * roc_auc_val - 1

print('Train+val: ', gini_train)
print('Test: ', gini_val)
# Out:
# Train+val:  0.7431190500834581
# Test:  0.645964079809787

# %%
roc_auc_train = roc_auc_score(data_dict['df_train_val'][TARGET_BIN], data_dict['df_train_val']['score'])
gini_train = 2 * roc_auc_train - 1

roc_auc_val = roc_auc_score(data_dict['df_test_same'][TARGET_BIN], data_dict['df_test_same']['score'])
gini_val = 2 * roc_auc_val - 1

print('Train+val: ', gini_train)
print('Test: ', gini_val)
# Out:
# Train+val:  0.7431190500834581
# Test:  0.6645019912726997

# %%
precision, recall, _ = precision_recall_curve(data_dict['df_train_val'][TARGET_BIN],  data_dict['df_train_val']['score'])
auc_train = auc(x=recall, y=precision)

precision, recall, _ = precision_recall_curve(data_dict['df_test'][TARGET_BIN], data_dict['df_test']['score'])
auc_values = auc(x=recall, y=precision)

print('Train+val: ', auc_train)
print('Test: ', auc_values)
# Out:
# Train+val:  0.18191418071229984
# Test:  0.12036248277461305

# %%
precision, recall, _ = precision_recall_curve(data_dict['df_train_val'][TARGET_BIN],  data_dict['df_train_val']['score'])
auc_train = auc(x=recall, y=precision)

precision, recall, _ = precision_recall_curve(data_dict['df_test_same'][TARGET_BIN], data_dict['df_test_same']['score'])
auc_values = auc(x=recall, y=precision)

print('Train+val: ', auc_train)
print('Test: ', auc_values)
# Out:
# Train+val:  0.18191418071229984
# Test:  0.1390076227028241

# %%
from sklearn.metrics import precision_score, recall_score

# %%
sns.histplot(x=data_dict['df_test']['score'], hue=data_dict['df_test'][TARGET_BIN], common_norm=False, stat='density')
# Out:
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# <Axes: xlabel='score', ylabel='Density'>

# %%
from utils.metrics_by_quantile import MetricsByQuantile

# %%
temp = pd.merge(
    pd.DataFrame(pd.qcut(data_dict['df_test']['score'].round(3).values, q=200, duplicates='drop').value_counts().sort_index(ascending=False).cumsum()),
    pd.DataFrame(pd.qcut(data_dict['df_test']['score'].round(3).values, q=200, duplicates='drop').value_counts().sort_index(ascending=False)),
    left_index=True, right_index=True
)
temp['%'] = (temp['count_x'] * 100 / data_dict['df_test'].shape[0]).round(2)
temp
# Out:
#                  count_x  count_y       %
# (0.932, 0.968]        56       56    0.50
# (0.921, 0.932]       113       57    1.00
# (0.912, 0.921]       164       51    1.45
# (0.903, 0.912]       222       58    1.96
# (0.898, 0.903]       278       56    2.46
# ...                  ...      ...     ...
# (0.007, 0.008]     10989       91   97.27
# (0.006, 0.007]     11078       89   98.05
# (0.005, 0.006]     11148       70   98.67
# (0.004, 0.005]     11217       69   99.28
# (0.0009, 0.004]    11298       81  100.00
#
# [192 rows x 3 columns]

# %%
m = MetricsByQuantile(metrics=["quantiles_analytics"])
r = m.compute(
    y_true=data_dict['df_test'][TARGET_BIN].reset_index(drop=True), 
    y_pred=data_dict['df_test']['score'].round(3).reset_index(drop=True), 
    list_of_metrics = [
        "cum_precision_by_quantile", "cum_recall_by_quantile", 
        "precision_by_quantile", "recall_by_quantile",
    ], 
    n_quantiles = 200
)
df_deciles = r["other"]["quantiles_analytics"]
df_deciles.head(50)
# Out:
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#     % of total population  Cumulative % of total population  Total  Bad  \
# 0                    0.50                              0.50     56    8
# 1                    0.50                              1.00     57   14
# 2                    0.45                              1.45     51   10
# 3                    0.51                              1.96     58    5
# 4                    0.50                              2.46     56   11
# 5                    0.54                              3.00     61    8
# 6                    0.48                              3.48     54   10
# 7                    0.48                              3.96     54   11
# 8                    0.55                              4.51     62   12
# 9                    0.49                              4.99     55    4
# 10                   0.42                              5.41     47    8
# 11                   0.50                              5.91     57    2
# 12                   0.52                              6.43     59    4
# 13                   0.56                              6.99     63    6
# 14                   0.42                              7.41     47    7
# 15                   0.55                              7.96     62    5
# 16                   0.55                              8.51     62    5
# 17                   0.45                              8.96     51    3
# 18                   0.44                              9.40     50    2
# 19                   0.55                              9.95     62    6
# 20                   0.50                             10.44     56    2
# 21                   0.49                             10.93     55    3
# 22                   0.54                             11.47     61    8
# 23                   0.52                             11.99     59    7
# 24                   0.50                             12.50     57    6
# 25                   0.48                             12.98     54    7
# 26                   0.51                             13.49     58    2
# 27                   0.51                             14.00     58    8
# 28                   0.44                             14.45     50    3
# 29                   0.53                             14.98     60    5
# 30                   0.51                             15.49     58    4
# 31                   0.50                             15.99     57    3
# 32                   0.46                             16.45     52    2
# 33                   0.50                             16.95     56    3
# 34                   0.50                             17.45     56    7
# 35                   0.50                             17.94     56    4
# 36                   0.49                             18.43     55    7
# 37                   0.56                             18.99     63    2
# 38                   0.50                             19.49     57    2
# 39                   0.50                             19.99     56    5
# 40                   0.46                             20.45     52    4
# 41                   0.56                             21.00     63    5
# 42                   0.43                             21.44     49    3
# 43                   0.48                             21.92     54    3
# 44                   0.57                             22.48     64    2
# 45                   0.48                             22.96     54    4
# 46                   0.50                             23.46     56    2
# 47                   0.54                             24.00     61    5
# 48                   0.45                             24.45     51    4
# 49                   0.49                             24.93     55    3
#
#     Cumulative Bad         Quantile  #Quantile  Cumulative Precision  \
# 0                8   (0.932, 0.968]        192             14.285714
# 1               22   (0.921, 0.932]        191             19.469027
# 2               32   (0.912, 0.921]        190             19.512195
# 3               37   (0.903, 0.912]        189             16.666667
# 4               48   (0.898, 0.903]        188             17.266187
# 5               56  (0.8911, 0.898]        187             16.519174
# 6               66  (0.884, 0.8911]        186             16.793893
# 7               77   (0.877, 0.884]        185             17.225951
# 8               89  (0.8686, 0.877]        184             17.485265
# 9               93   (0.86, 0.8686]        183             16.489362
# 10             101    (0.855, 0.86]        182             16.530278
# 11             103   (0.848, 0.855]        181             15.419162
# 12             107   (0.842, 0.848]        180             14.718019
# 13             113   (0.835, 0.842]        179             14.303797
# 14             120   (0.828, 0.835]        178             14.336918
# 15             125   (0.822, 0.828]        177             13.904338
# 16             130  (0.8168, 0.822]        176             13.527575
# 17             133   (0.81, 0.8168]        175             13.142292
# 18             135    (0.804, 0.81]        174             12.711864
# 19             141   (0.798, 0.804]        173             12.544484
# 20             143   (0.791, 0.798]        172             12.118644
# 21             146   (0.784, 0.791]        171             11.821862
# 22             154   (0.777, 0.784]        170             11.882716
# 23             161   (0.768, 0.777]        169             11.881919
# 24             167   (0.761, 0.768]        168             11.827195
# 25             174   (0.754, 0.761]        167             11.869031
# 26             176   (0.748, 0.754]        166             11.548556
# 27             184  (0.7414, 0.748]        165             11.630847
# 28             187  (0.735, 0.7414]        164             11.458333
# 29             192   (0.728, 0.735]        163             11.347518
# 30             196    (0.72, 0.728]        162             11.200000
# 31             199    (0.713, 0.72]        161             11.012728
# 32             201   (0.705, 0.713]        160             10.812265
# 33             204   (0.696, 0.705]        159             10.652742
# 34             211   (0.688, 0.696]        158             10.705226
# 35             215    (0.68, 0.688]        157             10.606808
# 36             222    (0.673, 0.68]        156             10.662824
# 37             224   (0.666, 0.673]        155             10.442890
# 38             226    (0.66, 0.666]        154             10.263397
# 39             231    (0.653, 0.66]        153             10.230292
# 40             235   (0.646, 0.653]        152             10.173160
# 41             240  (0.6376, 0.646]        151             10.113780
# 42             243  (0.629, 0.6376]        150             10.033031
# 43             246   (0.622, 0.629]        149              9.935380
# 44             248   (0.611, 0.622]        148              9.763780
# 45             252   (0.604, 0.611]        147              9.714726
# 46             254   (0.596, 0.604]        146              9.584906
# 47             259   (0.589, 0.596]        145              9.553670
# 48             263    (0.58, 0.589]        144              9.522085
# 49             266     (0.57, 0.58]        143              9.442670
#
#     Cumulative Recall  Precision    Recall         Scores
# 0            2.240896  14.285714  2.240896   0.932--0.968
# 1            6.162465  24.561404  3.921569   0.921--0.932
# 2            8.963585  19.607843  2.801120   0.912--0.921
# 3           10.364146   8.620690  1.400560   0.903--0.912
# 4           13.445378  19.642857  3.081232   0.898--0.903
# 5           15.686275  13.114754  2.240896  0.8911--0.898
# 6           18.487395  18.518519  2.801120  0.884--0.8911
# 7           21.568627  20.370370  3.081232   0.877--0.884
# 8           24.929972  19.354839  3.361345  0.8686--0.877
# 9           26.050420   7.272727  1.120448   0.86--0.8686
# 10          28.291317  17.021277  2.240896    0.855--0.86
# 11          28.851541   3.508772  0.560224   0.848--0.855
# 12          29.971989   6.779661  1.120448   0.842--0.848
# 13          31.652661   9.523810  1.680672   0.835--0.842
# 14          33.613445  14.893617  1.960784   0.828--0.835
# 15          35.014006   8.064516  1.400560   0.822--0.828
# 16          36.414566   8.064516  1.400560  0.8168--0.822
# 17          37.254902   5.882353  0.840336   0.81--0.8168
# 18          37.815126   4.000000  0.560224    0.804--0.81
# 19          39.495798   9.677419  1.680672   0.798--0.804
# 20          40.056022   3.571429  0.560224   0.791--0.798
# 21          40.896359   5.454545  0.840336   0.784--0.791
# 22          43.137255  13.114754  2.240896   0.777--0.784
# 23          45.098039  11.864407  1.960784   0.768--0.777
# 24          46.778711  10.526316  1.680672   0.761--0.768
# 25          48.739496  12.962963  1.960784   0.754--0.761
# 26          49.299720   3.448276  0.560224   0.748--0.754
# 27          51.540616  13.793103  2.240896  0.7414--0.748
# 28          52.380952   6.000000  0.840336  0.735--0.7414
# 29          53.781513   8.333333  1.400560   0.728--0.735
# 30          54.901961   6.896552  1.120448    0.72--0.728
# 31          55.742297   5.263158  0.840336    0.713--0.72
# 32          56.302521   3.846154  0.560224   0.705--0.713
# 33          57.142857   5.357143  0.840336   0.696--0.705
# 34          59.103641  12.500000  1.960784   0.688--0.696
# 35          60.224090   7.142857  1.120448    0.68--0.688
# 36          62.184874  12.727273  1.960784    0.673--0.68
# 37          62.745098   3.174603  0.560224   0.666--0.673
# 38          63.305322   3.508772  0.560224    0.66--0.666
# 39          64.705882   8.928571  1.400560    0.653--0.66
# 40          65.826331   7.692308  1.120448   0.646--0.653
# 41          67.226891   7.936508  1.400560  0.6376--0.646
# 42          68.067227   6.122449  0.840336  0.629--0.6376
# 43          68.907563   5.555556  0.840336   0.622--0.629
# 44          69.467787   3.125000  0.560224   0.611--0.622
# 45          70.588235   7.407407  1.120448   0.604--0.611
# 46          71.148459   3.571429  0.560224   0.596--0.604
# 47          72.549020   8.196721  1.400560   0.589--0.596
# 48          73.669468   7.843137  1.120448    0.58--0.589
# 49          74.509804   5.454545  0.840336     0.57--0.58
