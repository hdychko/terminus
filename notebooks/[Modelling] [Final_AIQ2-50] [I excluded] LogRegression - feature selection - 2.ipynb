# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import copy
from typing import (
    Dict, 
    List,
    Any
)


import mlflow
import warnings
from datetime import datetime

from tqdm.autonotebook import tqdm

import numpy as np
import pandas as pd

from scipy.stats import uniform

import shap

import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\hdychko\AppData\Local\Temp\ipykernel_29200\243224794.py:15: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
sys.path.append(os.path.join(os.getcwd(), '..'))
from utils.modelling_tools import *

# %%
TRAIN_FROM: datetime.date = pd.to_datetime('2021-12-01').date()
TRAIN_TO: datetime.date = pd.to_datetime('2022-01-01').date()

VAL_FROM: datetime.date = pd.to_datetime('2022-01-01').date()
VAL_TO: datetime.date = pd.to_datetime('2022-05-01').date()

TEST_FROM: datetime.date = pd.to_datetime('2022-05-01').date()
TEST_TO: datetime.date = pd.to_datetime('2022-08-01').date()

# %%
# set constants
COLS_TO_USE: List[str] = [
"OPTIN_11SCN_MLOptBin",
"G5_ND_SPECIIOptBin",
"Marital_StatusOptBin",
"SP_F2_33OptBin",
"AFF_B_09_01OptBin",
"VM01_SP_VM2_15OptBin",
"SP_EDI_24OptBin",
"E4_Q_17OptBin",
"TRD_C_07OptBin",
"SP_B2_18OptBin",
"SPA_F2_33OptBin",
"VM01_SP_VM2_14OptBin",
"SP_G_38OptBin",
"TRD_O_05OptBin",
"E1_A_09OptBin",
"TRD_O_07OptBin",
"ND_INC_03OptBin",
"GEN11_SP_N_91OptBin",
"GEN11_SP_EDI_07OptBin",
"TRD_B_18OptBin",
"EA5_S_01OptBin",
"CLU_CLI_L6M_NPR_L6MOptBin",
"SP_I_67_01OptBin",
"GEN11_SP_K_80OptBin",
"ND_ECC_04OptBin",
"ND_ERL_01OptBin",
"ND_HAC_06OptBin",
"AFF_E_07_01OptBin",
"TRD_O_06OptBin",
"E2_G_08OptBin",
] 

TARGET_NAME: str = 'GB6_Flag_2Limit'
TARGET_VALS: List[int] = [0, 1]
TARGET_BIN: str = f'_{TARGET_NAME}_bin'

PALETTE: Dict[str, str] = {
    TARGET_NAME: {
        'G': 'green',
        'B': 'red',
        'I': 'black'
    },
    TARGET_BIN: {0: 'green', 1: 'red'},
    'DataPart': {'Train-val': 'orange', 'Val': 'blue', 'Test': 'black'}
    # 'Test-OOT': 'black'
}

PROJECT_PATH: str = os.path.join(os.getcwd(), '..')
DATA_PATH: str = os.path.join(PROJECT_PATH, 'data')
OPT_BIN_PATH: str = os.path.join(os.path.join(PROJECT_PATH, 'objects'), 'optbinners')
MODELS_PATH: str = os.path.join(os.path.join(PROJECT_PATH, 'objects'), 'models')

# %%
N_ITER: int = 20
RANDOM_SEED: int = 42

# %%
# read data
df: pd.DataFrame = pd.read_csv(os.path.join(DATA_PATH, 'final_aiq2_optbins.csv'), low_memory=False)

# %%
print('Number of rows: %.0f; columns: %.0f' % df.shape)
# Out:
# Number of rows: 110462; columns: 2069

# %% [markdown]
# # Preprocessing

# %% [markdown]
# # Convert dates to the corresponding types

# %%
for col in ['_RDATE_EOM', '_RDATE']:
    df[col] = pd.to_datetime(df[col]).dt.date

# %%
print('Available date range:')
df['_RDATE'].agg(['min', 'max'])
# Out:
# Available date range:
# min    2021-06-30
# max    2023-11-30
# Name: _RDATE, dtype: object

# %%
pd.merge(
    pd.DataFrame(df.groupby([TARGET_NAME])[TARGET_BIN].value_counts()),
    pd.DataFrame(df[TARGET_NAME].value_counts(normalize=True)),
    how='outer', left_index=True, right_index=True
)
# Out:
#                                       count  proportion
# GB6_Flag_2Limit _GB6_Flag_2Limit_bin
# B               1                      4449    0.040276
# G               0                     99444    0.900255
# I               0                      6569    0.059468

# %%
df_train = df.loc[
    (df._RDATE >= TRAIN_FROM) &
    (df._RDATE < TRAIN_TO) & 
    (df[TARGET_NAME] != 'I'),
    COLS_TO_USE + [TARGET_NAME, TARGET_BIN, '_RDATE']
].reset_index(drop=True)

df_train_val = df.loc[
    (df._RDATE >= TRAIN_FROM) &
    (df._RDATE < VAL_TO) &
    (df[TARGET_NAME] != 'I'),
    COLS_TO_USE + [TARGET_NAME, TARGET_BIN, '_RDATE']
].reset_index(drop=True)

df_val = df.loc[
    (df._RDATE >= VAL_FROM) &
    (df._RDATE < VAL_TO) &
    (df[TARGET_NAME] != 'I'),
    COLS_TO_USE + [TARGET_NAME, TARGET_BIN, '_RDATE']
].reset_index(drop=True)

df_test_same = df.loc[
    (df._RDATE >= TEST_FROM) &
    (df._RDATE < TEST_TO) &
    (df[TARGET_NAME] != 'I'),
    COLS_TO_USE + [TARGET_NAME, TARGET_BIN, '_RDATE']
].reset_index(drop=True)

df_test = df.loc[
    (df._RDATE >= TEST_FROM) &
    (df._RDATE < TEST_TO),
    COLS_TO_USE + [TARGET_NAME, TARGET_BIN, '_RDATE']
].reset_index(drop=True)

# %%
data_dict = {
    "df_train": df_train,
    "df_val": df_val,
    "df_train_val": df_train_val, 
    "df_test_same": df_test_same,
    "df_test": df_test
}

# %%
# randomly select N observations from test data
N = 10000
sss = StratifiedShuffleSplit(n_splits=1, train_size=N, random_state=RANDOM_SEED)
indx = sss.split(data_dict['df_test_same'].reset_index(drop=True), data_dict['df_test_same'][TARGET_BIN])
random_indx = list(indx)[0][0]

assert len(random_indx) == N, "Incorrect number of elements in the subsample"
test_sample = data_dict['df_test'].reset_index(drop=True).iloc[random_indx, :].reset_index(drop=True)

# %%
data_dict['df_test_same_sample'] = test_sample

# %%
mlflow.set_tracking_uri(uri="http://127.0.0.1:5000/")
mlflow.set_experiment("[Experian]")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/696858428304145414', creation_time=1716463645799, experiment_id='696858428304145414', last_update_time=1716463645799, lifecycle_stage='active', name='[Experian]', tags={}>

# %%
MODEL = LogisticRegression

# %%
experiment_description = f"""
    'features': {len(COLS_TO_USE)},
    'target': {TARGET_BIN},
    'target_vals': '0==G, 1==B',
    'model': {MODEL.__name__},
    'data_version': '22.05.2024', 
    'train_period': [{TRAIN_FROM.strftime('%Y-%m-%d') + ', ' + TRAIN_TO.strftime('%Y-%m-%d')}),
    'val_period': [{VAL_FROM.strftime('%Y-%m-%d') + ', ' + VAL_TO.strftime('%Y-%m-%d')}),
    'test_period': [{TEST_FROM.strftime('%Y-%m-%d') + ', ' + TEST_TO.strftime('%Y-%m-%d')}),
"""

# %%
print(experiment_description)
# Out:
#     'features': 30,
#     'target': _GB6_Flag_2Limit_bin,
#     'target_vals': '0==G, 1==B',
#     'model': LogisticRegression,
#     'data_version': '22.05.2024',
#     'train_period': [2021-12-01, 2022-01-01),
#     'val_period': [2022-01-01, 2022-05-01),
#     'test_period': [2022-05-01, 2022-08-01),

# %%
PARAMS = dict(
    penalty=['l2', 'l1', 'elasticnet'], 
    C=uniform(loc=0, scale=20), 
    fit_intercept=[True], 
    class_weight=['balanced'], 
    random_state=[RANDOM_SEED], 
    n_jobs=[-1], 
)

# %%
RUN_NAME = '05-LogRegression-hyperparams_tunning'
with mlflow.start_run(run_name=RUN_NAME, log_system_metrics=True):
    res = search_hyper_params_and_log(
        run_name=RUN_NAME,
        data_dict=data_dict,
        cols_to_use=COLS_TO_USE,
        target_name=TARGET_BIN,
        distributions=PARAMS,
        n_iter=50,
        model=MODEL,
        custom_params_updates=update_solver_by_penalty,
        tags={'features': len(COLS_TO_USE)}, 
        palette=PALETTE,
        test_name='df_test_same'
    )
# Out:
# 2024/05/24 14:57:10 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:57:10 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# The max_iter was reached which means the coef_ did not converge
# # 1 / 50
# 2024/05/24 14:57:10 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:57:10 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:57:21 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:57:21 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 2 / 50
# 2024/05/24 14:57:22 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/24 14:57:22 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:57:29 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:57:29 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 3 / 50
# 2024/05/24 14:57:30 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:57:30 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:57:38 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:57:38 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 4 / 50
# 2024/05/24 14:57:41 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:57:41 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:57:50 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:57:50 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 5 / 50
# 2024/05/24 14:57:51 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/24 14:57:51 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:57:59 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:57:59 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 6 / 50
# 2024/05/24 14:58:00 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:58:00 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:58:08 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:58:08 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 7 / 50
# 2024/05/24 14:58:08 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/24 14:58:08 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:58:17 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:58:17 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 8 / 50
# 2024/05/24 14:58:17 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:58:17 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:58:26 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:58:26 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 9 / 50
# 2024/05/24 14:58:26 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/24 14:58:26 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:58:34 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:58:34 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 10 / 50
# 2024/05/24 14:58:35 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:58:35 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:58:43 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:58:43 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 11 / 50
# 2024/05/24 14:58:43 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:58:43 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:58:51 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:58:51 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 12 / 50
# 2024/05/24 14:58:53 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:58:53 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:59:01 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:59:01 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 13 / 50
# 2024/05/24 14:59:01 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:59:01 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:59:10 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:59:10 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 14 / 50
# 2024/05/24 14:59:10 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:59:10 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:59:19 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:59:19 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 15 / 50
# 2024/05/24 14:59:19 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:59:19 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:59:28 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:59:28 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 16 / 50
# 2024/05/24 14:59:28 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:59:28 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:59:37 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:59:37 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 17 / 50
# 2024/05/24 14:59:37 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/24 14:59:37 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:59:46 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:59:46 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 18 / 50
# 2024/05/24 14:59:47 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:59:47 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 14:59:56 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 14:59:56 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 19 / 50
# 2024/05/24 14:59:57 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 14:59:57 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 15:00:05 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 15:00:05 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 20 / 50
# 2024/05/24 15:00:06 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/24 15:00:06 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 15:00:15 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 15:00:15 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 21 / 50
# 2024/05/24 15:00:15 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/24 15:00:15 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 15:00:24 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 15:00:24 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 22 / 50
# 2024/05/24 15:00:24 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/24 15:00:24 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# ...
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 15:04:45 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 15:04:45 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 49 / 50
# 2024/05/24 15:04:45 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# 2024/05/24 15:04:45 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 15:04:53 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 15:04:53 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 50 / 50
# The max_iter was reached which means the coef_ did not converge
# 2024/05/24 15:04:54 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/24 15:04:54 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/24 15:05:04 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 15:05:04 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# Best params:
#  {'penalty': 'l1', 'C': 4.246782213565523, 'fit_intercept': True, 'class_weight': 'balanced', 'random_state': 42, 'n_jobs': -1, 'solver': 'saga'}
# The max_iter was reached which means the coef_ did not converge
# Test-PR_AUC 0.10006443587822528
# Test-Gini 0.5478229386992892
# Not saved
# The option feature_dependence has been renamed to feature_perturbation!
# The feature_perturbation option is now deprecated in favor of using the appropriate masker (maskers.Independent, or maskers.Impute)
# .values =
# array([-3.56753327, -3.56753327,  4.17328813, ...,  2.72120637,
#         3.53021317, -2.806627  ])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([ 2.99474675,  2.99474675, -1.48385189, ..., -0.64372252,
#        -1.11178871,  2.55451004])
# .values =
# array([-0.13935359, -0.13935359,  0.91887639, ..., -0.13935359,
#        -0.13935359, -0.13935359])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([ 0.25783187,  0.25783187, -1.37849138, ...,  0.25783187,
#         0.25783187,  0.25783187])
# .values =
# array([-1.73527228, -0.79660649,  1.49809533, ..., -0.79660649,
#         1.49809533,  1.49809533])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([ 2.2584247 ,  1.43192539, -0.58856955, ...,  1.43192539,
#        -0.58856955, -0.58856955])
# .values =
# array([-0.25811009,  0.44369547, -0.57509317, ..., -0.57509317,
#        -0.12274984, -0.12274984])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([-0.07402703,  1.67999899, -0.86626434, ..., -0.86626434,
#         0.26427951,  0.26427951])
# .values =
# array([-0.05035689, -0.05035689, -0.09112123, ..., -0.1890826 ,
#        -0.1890826 ,  0.12974763])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([ 0.11437588,  0.11437588, -0.11903656, ..., -0.67995335,
#        -0.67995335,  1.14563599])
# .values =
# array([-0.07494758, -0.07494758,  0.06560684, ...,  0.06560684,
#         0.05109947, -0.01995642])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([ 2.24867633,  2.24867633, -1.00554946, ..., -1.00554946,
#        -0.66966358,  0.97547792])
# .values =
# array([-0.77784737, -0.14169809, -0.14169809, ...,  0.35383828,
#         0.35383828, -0.14169809])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([ 1.76910325,  0.46029847,  0.46029847, ..., -0.55921124,
#        -0.55921124,  0.46029847])
# .values =
# array([ 0.30624932,  0.30624932, -0.20850965, ...,  0.30624932,
#        -0.20850965,  0.30624932])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([ 0.88915064,  0.88915064, -0.13253725, ...,  0.88915064,
#        -0.13253725,  0.88915064])
# .values =
# array([-0.01714915,  0.11395814, -0.199998  , ..., -0.199998  ,
#        -0.01714915, -0.01714915])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([ 0.00824407,  0.71284345, -0.97442585, ..., -0.97442585,
#         0.00824407,  0.00824407])
# .values =
# array([-0.13478615, -0.2343367 ,  0.43145258, ...,  0.13477761,
#         0.13477761, -0.13478615])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([ 0.72895436,  1.11733109, -1.48011357, ..., -0.3226951 ,
#        -0.3226951 ,  0.72895436])
# .values =
# array([ 0.32826479, -0.8675044 , -0.1618828 , ...,  0.32826479,
#         0.32826479,  0.32826479])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([-0.32307254,  1.92487265,  0.59836358, ..., -0.32307254,
#        -0.32307254, -0.32307254])
# .values =
# array([ 0.43672619, -0.15321821, -0.37375299, ..., -0.37375299,
#        -0.19788904,  0.20094013])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([ 1.7260953 , -0.26225749, -1.00554946, ..., -1.00554946,
#        -0.41281637,  0.93140029])
# .values =
# array([ 0.02922097,  0.02922097, -0.0072286 , ..., -0.01430064,
#        -0.00948443, -0.01430064])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([ 1.82216229,  1.82216229, -0.17035703, ..., -0.55695098,
#        -0.29367241, -0.55695098])
# .values =
# array([ 0.14004833, -0.37955741,  0.14004833, ...,  0.14004833,
#        -0.37955741,  0.14004833])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([-0.22332692,  0.7066837 , -0.22332692, ..., -0.22332692,
#         0.7066837 , -0.22332692])
# .values =
# array([ 0.17442631,  0.17442631, -0.43639408, ...,  0.17442631,
#        -0.58120218,  0.17442631])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([ 0.62133384,  0.62133384, -0.64862661, ...,  0.62133384,
#        -0.94969801,  0.62133384])
# .values =
# array([-0.00809629, -0.00026078, -0.00809629, ..., -0.00809629,
#        -0.00809629, -0.00809629])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([-0.5840316 ,  0.25151281, -0.5840316 , ..., -0.5840316 ,
#        -0.5840316 , -0.5840316 ])
# .values =
# array([-0.25842197, -0.25842197,  0.12067789, ...,  0.12067789,
#         0.12067789,  0.06224039])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([ 0.79959541,  0.79959541, -0.22365204, ..., -0.22365204,
#        -0.22365204, -0.06592044])
# .values =
# array([-0.23224037, -0.23224037,  0.0421608 , ...,  0.15739462,
#         0.59881874, -0.23224037])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([ 0.58268625,  0.58268625,  0.07932923, ..., -0.13205379,
#        -0.94179494,  0.58268625])
# .values =
# array([-0.26807714, -0.02753242,  0.11582232, ..., -0.63453556,
#        -0.48785505,  0.11582232])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([-0.26007646,  0.09115383,  0.3004726 , ..., -0.79515906,
#        -0.58098418,  0.3004726 ])
# .values =
# array([-0.03810601, -0.03810601,  0.1811023 , ..., -0.03810601,
#         0.08824649, -0.03810601])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([ 0.43720996,  0.43720996, -1.31650893, ...,  0.43720996,
#        -0.5736402 ,  0.43720996])
# .values =
# array([-0.13010796, -0.53899349, -0.53899349, ...,  0.43223771,
#        -0.13010796,  0.21281779])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([ 0.32010486,  0.99260162,  0.99260162, ..., -0.6047888 ,
#         0.32010486, -0.24390739])
# .values =
# array([ 0.24277862,  0.24277862, -0.51590457, ..., -0.51590457,
#         0.24277862,  0.24277862])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([ 0.31746179,  0.31746179, -0.72582094, ..., -0.72582094,
#         0.31746179,  0.31746179])
# .values =
# array([-0.02422473,  0.12870798, -0.02422473, ..., -0.02422473,
#        -0.02422473, -0.02422473])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([-0.2105276 ,  2.14196943, -0.2105276 , ..., -0.2105276 ,
#        -0.2105276 , -0.2105276 ])
# .values =
# array([ 0.01552047,  0.02872009,  0.02872009, ..., -0.00437053,
#        -0.00437053,  0.02872009])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([0.489254  , 0.81392165, 0.81392165, ..., 0.        , 0.        ,
#        0.81392165])
# .values =
# array([ 0.02231496,  0.02231496, -0.20977829, ...,  0.02231496,
#         0.02231496,  0.02231496])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([ 0.33108872,  0.33108872, -1.37415297, ...,  0.33108872,
#         0.33108872,  0.33108872])
# .values =
# array([-0.25302213, -0.25302213,  0.68409687, ..., -0.25302213,
#         0.68409687, -0.25302213])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([ 0.25259013,  0.25259013, -0.49945757, ...,  0.25259013,
#        -0.49945757,  0.25259013])
# .values =
# array([-0.02315536,  0.06590373,  0.06590373, ..., -0.02315536,
#        -0.02315536, -0.02315536])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([-0.18718329,  0.8595552 ,  0.8595552 , ..., -0.18718329,
#        -0.18718329, -0.18718329])
# .values =
# array([-0.02698286, -0.02698286, -0.02698286, ..., -0.02698286,
#         0.04873072, -0.02698286])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([ 0.44177225,  0.44177225,  0.44177225, ...,  0.44177225,
#        -0.60684965,  0.44177225])
# .values =
# array([ 0.30530493,  0.09895308, -0.1872922 , ..., -0.1872922 ,
#        -0.1872922 ,  0.30530493])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([ 1.05380532,  0.42523164, -0.44670749, ..., -0.44670749,
#        -0.44670749,  1.05380532])
# .values =
# array([-0.15600596,  0.4217939 ,  0.4217939 , ..., -0.15600596,
#        -0.15600596, -0.15600596])
#
# .base_values =
# array([-3.70342413, -3.70342413, -3.70342413, ..., -3.70342413,
#        -3.70342413, -3.70342413])
#
# .data =
# array([-0.2006119 ,  0.92478913,  0.92478913, ..., -0.2006119 ,
#        -0.2006119 , -0.2006119 ])
# 2024/05/24 15:05:14 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/24 15:05:14 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!

# %%
pd.merge(
    pd.DataFrame(data_dict['df_test'][TARGET_BIN].value_counts()),
    pd.DataFrame(data_dict['df_test'][TARGET_BIN].value_counts(normalize=True)),
    how='outer', left_index=True, right_index=True
)
# Out:
#                       count  proportion
# _GB6_Flag_2Limit_bin
# 0                     10941    0.968401
# 1                       357    0.031599

# %%
pd.merge(
    pd.DataFrame(data_dict['df_val'][TARGET_BIN].value_counts()),
    pd.DataFrame(data_dict['df_val'][TARGET_BIN].value_counts(normalize=True)),
    how='outer', left_index=True, right_index=True
)
# Out:
#                       count  proportion
# _GB6_Flag_2Limit_bin
# 0                     12545    0.965297
# 1                       451    0.034703

# %%
pd.merge(
    pd.DataFrame(data_dict['df_train'][TARGET_BIN].value_counts()),
    pd.DataFrame(data_dict['df_train'][TARGET_BIN].value_counts(normalize=True)),
    how='outer', left_index=True, right_index=True
)
# Out:
#                       count  proportion
# _GB6_Flag_2Limit_bin
# 0                      2518    0.968462
# 1                        82    0.031538

# %%
pd.merge(
    pd.DataFrame(data_dict['df_train_val'][TARGET_BIN].value_counts()),
    pd.DataFrame(data_dict['df_train_val'][TARGET_BIN].value_counts(normalize=True)),
    how='outer', left_index=True, right_index=True
)
# Out:
#                       count  proportion
# _GB6_Flag_2Limit_bin
# 0                     15063    0.965825
# 1                       533    0.034175

# %%
res.sort_values('PR_AUC_val', ascending=False).head()
# Out:
#     iter  GINI_train  GINI_val  GINI_prcnt_chng  PR_AUC_train  PR_AUC_val  \
# 5      5    0.689736  0.676719        -1.887225      0.131612    0.177613
# 44    44    0.692119  0.688962        -0.456155      0.158685    0.176359
# 41    41    0.706358  0.660144        -6.542527      0.158773    0.172017
# 22    22    0.705147  0.686586        -2.632284      0.147794    0.169777
# 36    36    0.686705  0.669946        -2.440403      0.151169    0.169715
#
#     PR_AUC_prcnt_chng                                             params
# 5           34.952442  {'penalty': 'l1', 'C': 4.246782213565523, 'fit...
# 44          11.137995  {'penalty': 'elasticnet', 'C': 5.7950290582753...
# 41           8.341600  {'penalty': 'l2', 'C': 10.171413823294056, 'fi...
# 22          14.874327  {'penalty': 'elasticnet', 'C': 18.437484700462...
# 36          12.268380  {'penalty': 'elasticnet', 'C': 14.264895744459...

# %%
res.sort_values('GINI_val', ascending=False).head()
# Out:
#     iter  GINI_train  GINI_val  GINI_prcnt_chng  PR_AUC_train  PR_AUC_val  \
# 44    44    0.692119  0.688962        -0.456155      0.158685    0.176359
# 18    18    0.710814  0.687612        -3.264167      0.149358    0.165839
# 22    22    0.705147  0.686586        -2.632284      0.147794    0.169777
# 4      4    0.713468  0.681654        -4.459018      0.129344    0.154235
# 40    40    0.701127  0.681271        -2.832122      0.139157    0.152462
#
#     PR_AUC_prcnt_chng                                             params
# 44          11.137995  {'penalty': 'elasticnet', 'C': 5.7950290582753...
# 18          11.034385  {'penalty': 'l1', 'C': 8.503117489824895, 'fit...
# 22          14.874327  {'penalty': 'elasticnet', 'C': 18.437484700462...
# 4           19.243880  {'penalty': 'l1', 'C': 1.1282315805420051, 'fi...
# 40           9.560734  {'penalty': 'elasticnet', 'C': 0.6285837137346...

# %%
res[res.iter == 41].params.values[0]
# Out:
# {'penalty': 'l2',
#  'C': 10.171413823294056,
#  'fit_intercept': True,
#  'class_weight': 'balanced',
#  'random_state': 42,
#  'n_jobs': -1,
#  'solver': 'saga'}

# %%
params = copy.deepcopy(res[res.iter == 41].params.values[0])

# %%
params['max_iter'] = 50000

# %%
data_dict, model, scaler = train_pred(
    data_dict=data_dict,
    cols_to_use=COLS_TO_USE,
    target_name=TARGET_BIN,
    model=MODEL,
    params=params,
    alias='',
    test_name='df_test_same'
)
# Out:
# The max_iter was reached which means the coef_ did not converge

# %%
model.coef_
# Out:
# array([[-1.51443868, -0.39511039, -0.96684798, -0.13553581,  0.17332745,
#         -0.27400428, -0.1577618 , -0.05825538, -0.50146114, -0.14508147,
#         -0.22187913,  0.98460472, -0.45628492, -0.1599015 , -0.08937338,
#         -0.23382121,  0.61201894,  0.0862659 ,  0.11225166,  0.11581751,
#         -0.64119911, -0.16764744, -0.68429937, -0.21010329, -0.72113583,
#         -0.17773661,  0.1890333 ,  0.10696991,  0.28810874, -0.06061546]])

# %%
model.intercept_
# Out:
# array([-1.93937006])

# %%
df_coeff = pd.DataFrame(
    {
        'Feature': COLS_TO_USE + ['Intercept'],
        'Coeff': np.append(model.coef_[0], model.intercept_)
    }
)

# %%
df_coeff['Coeff_abs'] = df_coeff.Coeff.abs()
df_coeff['Importance (%)'] = df_coeff.Coeff_abs * 100 / df_coeff.Coeff_abs.sum()
df_coeff = df_coeff.sort_values('Coeff_abs', ascending=False)

# %%
def logit_pvalue(model, x):
    """ Calculate z-scores for scikit-learn LogisticRegression.
    parameters:
        model: fitted sklearn.linear_model.LogisticRegression with intercept and large C
        x:     matrix on which the model was fit
    This function uses asymtptics for maximum likelihood estimates.

 
    For a vector of maximum likelihood estimates theta, its variance-covariance matrix can be estimated as inverse(H), where H is the Hessian matrix of log-likelihood at theta.

 
    """
    from scipy.stats import norm
    p = model.predict_proba(x)
    n = len(p)
    m = len(model.coef_[0]) + 1
    coefs = np.concatenate([model.intercept_, model.coef_[0]])
    x_full = np.matrix(np.insert(np.array(x), 0, 1, axis = 1))
    ans = np.zeros((m, m))
    for i in range(n):
        ans = ans + np.dot(np.transpose(x_full[i, :]), x_full[i, :]) * p[i,1] * p[i, 0]
    vcov = np.linalg.inv(np.matrix(ans))
    se = np.sqrt(np.diag(vcov))
    t =  coefs/se  
    p = (1 - norm.cdf(abs(t))) * 2
    return p

# %%
df_p = pd.DataFrame(
    {
        'p-value': logit_pvalue(model, scaler.transform(data_dict['df_train_val'][COLS_TO_USE])), 
        'Feature': ['Intercept'] + COLS_TO_USE,
    }
)

# %%
df_coeff = pd.merge(df_coeff, df_p, on='Feature', how='outer')

# %%
p_value = 0.05

# %%
df_coeff
# Out:
#                       Feature     Coeff  Coeff_abs  Importance (%)  \
# 0           AFF_B_09_01OptBin  0.173327   0.173327        1.377773
# 1           AFF_E_07_01OptBin  0.106970   0.106970        0.850299
# 2   CLU_CLI_L6M_NPR_L6MOptBin -0.167647   0.167647        1.332623
# 3               E1_A_09OptBin -0.089373   0.089373        0.710425
# 4               E2_G_08OptBin -0.060615   0.060615        0.481830
# 5               E4_Q_17OptBin -0.058255   0.058255        0.463070
# 6              EA5_S_01OptBin -0.641199   0.641199        5.096866
# 7          G5_ND_SPECIIOptBin -0.395110   0.395110        3.140717
# 8       GEN11_SP_EDI_07OptBin  0.112252   0.112252        0.892284
# 9         GEN11_SP_K_80OptBin -0.210103   0.210103        1.670103
# 10        GEN11_SP_N_91OptBin  0.086266   0.086266        0.685724
# 11                  Intercept -1.939370   1.939370       15.415975
# 12       Marital_StatusOptBin -0.966848   0.966848        7.685436
# 13            ND_ECC_04OptBin -0.721136   0.721136        5.732280
# 14            ND_ERL_01OptBin -0.177737   0.177737        1.412821
# 15            ND_HAC_06OptBin  0.189033   0.189033        1.502618
# 16            ND_INC_03OptBin  0.612019   0.612019        4.864914
# 17       OPTIN_11SCN_MLOptBin -1.514439   1.514439       12.038212
# 18            SPA_F2_33OptBin -0.221879   0.221879        1.763708
# 19             SP_B2_18OptBin -0.145081   0.145081        1.153247
# 20            SP_EDI_24OptBin -0.157762   0.157762        1.254042
# 21             SP_F2_33OptBin -0.135536   0.135536        1.077369
# 22              SP_G_38OptBin -0.456285   0.456285        3.626990
# 23           SP_I_67_01OptBin -0.684299   0.684299        5.439468
# 24             TRD_B_18OptBin  0.115818   0.115818        0.920629
# 25             TRD_C_07OptBin -0.501461   0.501461        3.986094
# 26             TRD_O_05OptBin -0.159901   0.159901        1.271051
# 27             TRD_O_06OptBin  0.288109   0.288109        2.290165
# 28             TRD_O_07OptBin -0.233821   0.233821        1.858635
# 29       VM01_SP_VM2_14OptBin  0.984605   0.984605        7.826583
# 30       VM01_SP_VM2_15OptBin -0.274004   0.274004        2.178049
#
#          p-value
# 0   3.537057e-03
# 1   3.447935e-03
# 2   1.256408e-07
# 3   1.983107e-02
# 4   1.238941e-01
# 5   1.384912e-01
# 6   0.000000e+00
# 7   0.000000e+00
# 8   1.156071e-02
# 9   7.701630e-09
# 10  6.367687e-02
# 11  0.000000e+00
# 12  0.000000e+00
# 13  0.000000e+00
# 14  1.808370e-09
# 15  3.746292e-06
# 16  0.000000e+00
# 17  0.000000e+00
# 18  1.022363e-06
# 19  2.644554e-04
# 20  2.346599e-03
# 21  7.324347e-03
# 22  0.000000e+00
# 23  0.000000e+00
# 24  1.765799e-03
# 25  0.000000e+00
# 26  9.372193e-06
# 27  2.220446e-16
# 28  3.244205e-11
# 29  0.000000e+00
# 30  1.241930e-07

# %%
df_coeff[df_coeff['p-value'] >= p_value]
# Out:
#                 Feature     Coeff  Coeff_abs  Importance (%)   p-value
# 4         E2_G_08OptBin -0.060615   0.060615        0.481830  0.123894
# 5         E4_Q_17OptBin -0.058255   0.058255        0.463070  0.138491
# 10  GEN11_SP_N_91OptBin  0.086266   0.086266        0.685724  0.063677

# %%
for col in COLS_TO_USE:
    if col not in df_coeff[df_coeff['p-value'] > p_value].Feature.values:
        print(f'"{col}",')
# Out:
# "OPTIN_11SCN_MLOptBin",
# "G5_ND_SPECIIOptBin",
# "Marital_StatusOptBin",
# "SP_F2_33OptBin",
# "AFF_B_09_01OptBin",
# "VM01_SP_VM2_15OptBin",
# "SP_EDI_24OptBin",
# "TRD_C_07OptBin",
# "SP_B2_18OptBin",
# "SPA_F2_33OptBin",
# "VM01_SP_VM2_14OptBin",
# "SP_G_38OptBin",
# "TRD_O_05OptBin",
# "E1_A_09OptBin",
# "TRD_O_07OptBin",
# "ND_INC_03OptBin",
# "GEN11_SP_EDI_07OptBin",
# "TRD_B_18OptBin",
# "EA5_S_01OptBin",
# "CLU_CLI_L6M_NPR_L6MOptBin",
# "SP_I_67_01OptBin",
# "GEN11_SP_K_80OptBin",
# "ND_ECC_04OptBin",
# "ND_ERL_01OptBin",
# "ND_HAC_06OptBin",
# "AFF_E_07_01OptBin",
# "TRD_O_06OptBin",

# %%
roc_auc_train = roc_auc_score(data_dict['df_train_val'][TARGET_BIN], data_dict['df_train_val']['score'])
gini_train = 2 * roc_auc_train - 1

roc_auc_val = roc_auc_score(data_dict['df_test_same'][TARGET_BIN], data_dict['df_test_same']['score'])
gini_val = 2 * roc_auc_val - 1

print('Train+val: ', gini_train)
print('Test: ', gini_val)
# Out:
# Train+val:  0.6886212367095099
# Test:  0.6240482587592859

# %%
precision, recall, _ = precision_recall_curve(data_dict['df_train_val'][TARGET_BIN],  data_dict['df_train_val']['score'])
auc_train = auc(x=recall, y=precision)

precision, recall, _ = precision_recall_curve(data_dict['df_test_same'][TARGET_BIN], data_dict['df_test_same']['score'])
auc_values = auc(x=recall, y=precision)

print('Train+val: ', auc_train)
print('Test: ', auc_values)
# Out:
# Train+val:  0.16048919017960558
# Test:  0.1365184620736573

# %%
data_dict['df_test']['score'] = model.predict_proba(scaler.transform(data_dict['df_test'][COLS_TO_USE]))[:, 1]
data_dict['df_train_val']['score'] = model.predict_proba(scaler.transform(data_dict['df_train_val'][COLS_TO_USE]))[:, 1]

# %%
roc_auc_train = roc_auc_score(data_dict['df_train_val'][TARGET_BIN], data_dict['df_train_val']['score'])
gini_train = 2 * roc_auc_train - 1

roc_auc_val = roc_auc_score(data_dict['df_test'][TARGET_BIN], data_dict['df_test']['score'])
gini_val = 2 * roc_auc_val - 1

print('Train+val: ', gini_train)
print('Test: ', gini_val)
# Out:
# Train+val:  0.6886212367095099
# Test:  0.605405309916673

# %%
precision, recall, _ = precision_recall_curve(data_dict['df_train_val'][TARGET_BIN],  data_dict['df_train_val']['score'])
auc_train = auc(x=recall, y=precision)

precision, recall, _ = precision_recall_curve(data_dict['df_test'][TARGET_BIN], data_dict['df_test']['score'])
auc_values = auc(x=recall, y=precision)

print('Train+val: ', auc_train)
print('Test: ', auc_values)
# Out:
# Train+val:  0.16048919017960558
# Test:  0.11818783992603168

# %%
from sklearn.metrics import precision_score, recall_score

# %%
sns.histplot(x=data_dict['df_test']['score'], hue=data_dict['df_test'][TARGET_BIN], common_norm=False, stat='density')
# Out:
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# <Axes: xlabel='score', ylabel='Density'>

# %%
from utils.metrics_by_quantile import MetricsByQuantile

# %%
temp = pd.merge(
    pd.DataFrame(pd.qcut(data_dict['df_test']['score'].round(3).values, q=200, duplicates='drop').value_counts().sort_index(ascending=False).cumsum()),
    pd.DataFrame(pd.qcut(data_dict['df_test']['score'].round(3).values, q=200, duplicates='drop').value_counts().sort_index(ascending=False)),
    left_index=True, right_index=True
)
temp['%'] = (temp['count_x'] * 100 / data_dict['df_test'].shape[0]).round(2)
temp
# Out:
#                  count_x  count_y       %
# (0.998, 1.0]          51       51    0.45
# (0.997, 0.998]       101       50    0.89
# (0.996, 0.997]       146       45    1.29
# (0.994, 0.996]       206       60    1.82
# (0.992, 0.994]       264       58    2.34
# ...                  ...      ...     ...
# (0.004, 0.005]      9709      199   85.94
# (0.003, 0.004]      9927      218   87.87
# (0.002, 0.003]     10173      246   90.04
# (0.001, 0.002]     10476      303   92.72
# (-0.001, 0.001]    11298      822  100.00
#
# [164 rows x 3 columns]

# %%
m = MetricsByQuantile(metrics=["quantiles_analytics"])
r = m.compute(
    y_true=data_dict['df_test'][TARGET_BIN].reset_index(drop=True), 
    y_pred=data_dict['df_test']['score'].round(3).reset_index(drop=True), 
    list_of_metrics = [
        "cum_precision_by_quantile", "cum_recall_by_quantile", 
        "precision_by_quantile", "recall_by_quantile",
    ], 
    n_quantiles = 200
)
df_deciles = r["other"]["quantiles_analytics"]
df_deciles.head(50)
# Out:
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#     % of total population  Cumulative % of total population  Total  Bad  \
# 0                    0.45                              0.45     51   10
# 1                    0.44                              0.89     50   15
# 2                    0.40                              1.29     45    8
# 3                    0.53                              1.82     60    5
# 4                    0.51                              2.34     58   13
# 5                    0.63                              2.97     71   11
# 6                    0.50                              3.46     56   11
# 7                    0.46                              3.92     52    9
# 8                    0.53                              4.45     60    5
# 9                    0.47                              4.92     53    4
# 10                   0.43                              5.35     49    3
# 11                   0.51                              5.87     58    6
# 12                   0.64                              6.51     72    4
# 13                   0.40                              6.90     45    5
# 14                   0.46                              7.36     52    3
# 15                   0.57                              7.93     64    5
# 16                   0.46                              8.39     52    4
# 17                   0.53                              8.92     60    4
# 18                   0.53                              9.45     60    4
# 19                   0.54                              9.99     61    3
# 20                   0.41                             10.40     46    1
# 21                   0.60                             11.00     68    2
# 22                   0.46                             11.46     52    5
# 23                   0.54                             12.00     61    4
# 24                   0.44                             12.44     50    6
# 25                   0.50                             12.94     56    5
# 26                   0.48                             13.42     54    6
# 27                   0.56                             13.98     63    6
# 28                   0.49                             14.46     55    2
# 29                   0.54                             15.00     61    2
# 30                   0.49                             15.49     55    3
# 31                   0.50                             15.99     57    5
# 32                   0.46                             16.45     52    4
# 33                   0.54                             16.99     61    3
# 34                   0.45                             17.45     51    2
# 35                   0.56                             18.00     63    4
# 36                   0.47                             18.47     53    6
# 37                   0.50                             18.97     56    7
# 38                   0.52                             19.49     59    6
# 39                   0.47                             19.96     53    3
# 40                   0.52                             20.48     59    0
# 41                   0.50                             20.99     57    6
# 42                   0.49                             21.47     55    6
# 43                   0.53                             22.00     60   10
# 44                   0.49                             22.49     55    2
# 45                   0.50                             23.00     57    6
# 46                   0.44                             23.44     50    2
# 47                   0.53                             23.97     60    4
# 48                   0.47                             24.44     53    6
# 49                   0.55                             24.99     62    0
#
#     Cumulative Bad        Quantile  #Quantile  Cumulative Precision  \
# 0               10    (0.998, 1.0]        164             19.607843
# 1               25  (0.997, 0.998]        163             24.752475
# 2               33  (0.996, 0.997]        162             22.602740
# 3               38  (0.994, 0.996]        161             18.446602
# 4               51  (0.992, 0.994]        160             19.318182
# 5               62  (0.989, 0.992]        159             18.507463
# 6               73  (0.986, 0.989]        158             18.670077
# 7               82  (0.984, 0.986]        157             18.510158
# 8               87  (0.981, 0.984]        156             17.296223
# 9               91  (0.978, 0.981]        155             16.366906
# 10              94  (0.975, 0.978]        154             15.537190
# 11             100  (0.972, 0.975]        153             15.082956
# 12             104  (0.968, 0.972]        152             14.149660
# 13             109  (0.964, 0.968]        151             13.974359
# 14             112   (0.96, 0.964]        150             13.461538
# 15             117   (0.955, 0.96]        149             13.058036
# 16             121  (0.952, 0.955]        148             12.763713
# 17             125  (0.948, 0.952]        147             12.400794
# 18             129  (0.943, 0.948]        146             12.078652
# 19             132  (0.938, 0.943]        145             11.691763
# 20             133  (0.934, 0.938]        144             11.319149
# 21             135  (0.929, 0.934]        143             10.860821
# 22             140  (0.925, 0.929]        142             10.810811
# 23             144  (0.919, 0.925]        141             10.619469
# 24             150  (0.912, 0.919]        140             10.668563
# 25             155  (0.906, 0.912]        139             10.601915
# 26             161    (0.9, 0.906]        138             10.620053
# 27             167    (0.893, 0.9]        137             10.576314
# 28             169  (0.887, 0.893]        136             10.342717
# 29             171  (0.881, 0.887]        135             10.088496
# 30             174  (0.874, 0.881]        134              9.942857
# 31             179  (0.866, 0.874]        133              9.905921
# 32             183  (0.857, 0.866]        132              9.844002
# 33             186  (0.846, 0.857]        131              9.687500
# 34             188  (0.838, 0.846]        130              9.538305
# 35             192  (0.828, 0.838]        129              9.439528
# 36             198  (0.819, 0.828]        128              9.487302
# 37             205   (0.81, 0.819]        127              9.566029
# 38             211   (0.799, 0.81]        126              9.582198
# 39             214   (0.79, 0.799]        125              9.490022
# 40             214   (0.781, 0.79]        124              9.248055
# 41             220  (0.772, 0.781]        123              9.278785
# 42             226  (0.759, 0.772]        122              9.315746
# 43             236  (0.746, 0.759]        121              9.493162
# 44             238  (0.735, 0.746]        120              9.366391
# 45             244  (0.722, 0.735]        119              9.391840
# 46             246   (0.71, 0.722]        118              9.290030
# 47             250   (0.697, 0.71]        117              9.231905
# 48             256  (0.686, 0.697]        116              9.272003
# 49             256  (0.671, 0.686]        115              9.068367
#
#     Cumulative Recall  Precision    Recall        Scores
# 0            2.801120  19.607843  2.801120    0.998--1.0
# 1            7.002801  30.000000  4.201681  0.997--0.998
# 2            9.243697  17.777778  2.240896  0.996--0.997
# 3           10.644258   8.333333  1.400560  0.994--0.996
# 4           14.285714  22.413793  3.641457  0.992--0.994
# 5           17.366947  15.492958  3.081232  0.989--0.992
# 6           20.448179  19.642857  3.081232  0.986--0.989
# 7           22.969188  17.307692  2.521008  0.984--0.986
# 8           24.369748   8.333333  1.400560  0.981--0.984
# 9           25.490196   7.547170  1.120448  0.978--0.981
# 10          26.330532   6.122449  0.840336  0.975--0.978
# 11          28.011204  10.344828  1.680672  0.972--0.975
# 12          29.131653   5.555556  1.120448  0.968--0.972
# 13          30.532213  11.111111  1.400560  0.964--0.968
# 14          31.372549   5.769231  0.840336   0.96--0.964
# 15          32.773109   7.812500  1.400560   0.955--0.96
# 16          33.893557   7.692308  1.120448  0.952--0.955
# 17          35.014006   6.666667  1.120448  0.948--0.952
# 18          36.134454   6.666667  1.120448  0.943--0.948
# 19          36.974790   4.918033  0.840336  0.938--0.943
# 20          37.254902   2.173913  0.280112  0.934--0.938
# 21          37.815126   2.941176  0.560224  0.929--0.934
# 22          39.215686   9.615385  1.400560  0.925--0.929
# 23          40.336134   6.557377  1.120448  0.919--0.925
# 24          42.016807  12.000000  1.680672  0.912--0.919
# 25          43.417367   8.928571  1.400560  0.906--0.912
# 26          45.098039  11.111111  1.680672    0.9--0.906
# 27          46.778711   9.523810  1.680672    0.893--0.9
# 28          47.338936   3.636364  0.560224  0.887--0.893
# 29          47.899160   3.278689  0.560224  0.881--0.887
# 30          48.739496   5.454545  0.840336  0.874--0.881
# 31          50.140056   8.771930  1.400560  0.866--0.874
# 32          51.260504   7.692308  1.120448  0.857--0.866
# 33          52.100840   4.918033  0.840336  0.846--0.857
# 34          52.661064   3.921569  0.560224  0.838--0.846
# 35          53.781513   6.349206  1.120448  0.828--0.838
# 36          55.462185  11.320755  1.680672  0.819--0.828
# 37          57.422969  12.500000  1.960784   0.81--0.819
# 38          59.103641  10.169492  1.680672   0.799--0.81
# 39          59.943978   5.660377  0.840336   0.79--0.799
# 40          59.943978   0.000000  0.000000   0.781--0.79
# 41          61.624650  10.526316  1.680672  0.772--0.781
# 42          63.305322  10.909091  1.680672  0.759--0.772
# 43          66.106443  16.666667  2.801120  0.746--0.759
# 44          66.666667   3.636364  0.560224  0.735--0.746
# 45          68.347339  10.526316  1.680672  0.722--0.735
# 46          68.907563   4.000000  0.560224   0.71--0.722
# 47          70.028011   6.666667  1.120448   0.697--0.71
# 48          71.708683  11.320755  1.680672  0.686--0.697
# 49          71.708683   0.000000  0.000000  0.671--0.686
