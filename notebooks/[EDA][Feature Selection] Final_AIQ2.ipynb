# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import io
import os
import sys
from typing import (
    Dict, 
    List
)
import warnings


from datetime import datetime

import re
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
sys.path.append(os.path.join(os.getcwd(), '..'))

# %%
from utils.features_analysis_tools import mark_features_with_not_null_level_lower_than

# %%
# set constants
MIN_PRCNT_NOT_NULL: int = 100
MIN_N_UNIQUE_VALS: int = 2
MAX_N_UNIQUE_CONT_VALS: int = 40
MIN_IV: float = 0.01
CORR_PEARSON_CUT_OFF: float = 0.75


TARGET_NAME: str = 'GB6_Flag_2Limit'
PALETTE_TARGET: Dict[str, str] = {
    'G': 'green',
    'B': 'red',
    'I': 'black'
}
TARGET_BIN: str = f'_{TARGET_NAME}_bin'

DATA_PATH: str = os.path.join(os.getcwd(), '..')
DATA_PATH = os.path.join(DATA_PATH, 'data')

# %%
# read data
df_final: pd.DataFrame = pd.read_csv(os.path.join(DATA_PATH, 'Final_Dataset.csv'), low_memory=False)
df_aiq2: pd.DataFrame = pd.read_csv(os.path.join(DATA_PATH, 'AIQ2 Block - Cashplus.csv'))

# %%
print('Final; Number of rows: %.0f; columns: %.0f' % df_final.shape)
print('AIQ 2; Number of rows: %.0f; columns: %.0f' % df_aiq2.shape)
# Out:
# Final; Number of rows: 110462; columns: 1413
# AIQ 2; Number of rows: 110462; columns: 358

# %%
cols_inter: List[str] = list(set(df_aiq2.columns.tolist()).intersection(set(df_final.columns.tolist())))
print('AIQ 2 has common features with the final: ', len(cols_inter), '/', df_aiq2.shape[1])
print(cols_inter)
# Out:
# AIQ 2 has common features with the final:  23 / 358
# ['TRD_RAG_14', 'TRD_RAG_03', 'TRD_RAG_21', 'TRD_RAG_18', 'TRD_RAG_04', 'TRD_RAG_09', 'TRD_RAG_06', 'TRD_RAG_02', 'TRD_RAG_16', 'TRD_RAG_19', 'TRD_RAG_10', 'TRD_RAG_05', 'TRD_RAG_01', 'TRD_RAG_12', 'TRD_RAG_07', 'TRD_RAG_22', 'TRD_RAG_15', 'TRD_RAG_20', 'TRD_RAG_13', 'TRD_RAG_17', 'TRD_RAG_23', 'TRD_RAG_11', 'TRD_RAG_08']

# %%
# check if the duplicated columns have the same values 
df_final = df_final.set_index('UNIQUE_ID')
df_aiq2 = df_aiq2.set_index('UNIQUEID')

print('If the duplicated columns have the same values: ', df_final[cols_inter].equals(df_aiq2.loc[df_final.index, cols_inter]))
# Out:
# If the duplicated columns have the same values:  False

# %%
# check a random column
pd.concat(
    (
        df_final[['TRD_RAG_10']].rename(columns={'TRD_RAG_10': 'TRD_RAG_10_final'}),
        pd.DataFrame(df_final['TRD_RAG_10'] == df_aiq2.loc[df_final.index, 'TRD_RAG_10']).rename(columns={'TRD_RAG_10': 'IfEqual'}),
        df_aiq2.loc[df_final.index, ['TRD_RAG_10']].rename(columns={'TRD_RAG_10': 'TRD_RAG_10_AIQ2'})
    ), axis=1,
).reset_index().set_index(['IfEqual', 'UNIQUE_ID']).loc[False, :, :].head()
# Out:
#           TRD_RAG_10_final TRD_RAG_10_AIQ2
# UNIQUE_ID
# 30704244                 G               R
# 31914024                 A               G
# 22554724                 G               R
# 40853969                 A               R
# 41988140                 A               G

# %%
# rename columns in the AIQ2 dataset
aiq2_inter_cols: List[str] = [col + '_AIQ2' for col in cols_inter]
df_aiq2 = df_aiq2.rename(columns=dict(zip(cols_inter, aiq2_inter_cols)))

# %%
# check after renaming
cols_inter_check: List[str] = list(set(df_aiq2.columns.tolist()).intersection(set(df_final.columns.tolist())))
print('AIQ 2 has common features with the final: ', len(cols_inter_check), '/', df_aiq2.shape[1])
print(cols_inter_check)
# Out:
# AIQ 2 has common features with the final:  0 / 357
# []

# %%
# merge datasets
df_final = df_final.reset_index()
df_aiq2 = df_aiq2.reset_index()
df: pd.DataFrame = pd.merge(df_final, df_aiq2, left_on='UNIQUE_ID', right_on='UNIQUEID', how='outer', suffixes=('', '_AIQ2'))
del df_final, df_aiq2

# %%
# check stats after merge
print('Number of rows: %.0f; columns: %.0f' % df.shape)
print('Number of unique IDs: ', df.UNIQUE_ID.nunique())
# Out:
# Number of rows: 110462; columns: 1771
# Number of unique IDs:  110462

# %% [markdown]
# # Target

# %%
print('Column:', TARGET_NAME)
print('If any Nulls: ', df[TARGET_NAME].isnull().any())
# Out:
# Column: GB6_Flag_2Limit
# If any Nulls:  False

# %%
print('Distribution: ')
pd.merge(
    pd.DataFrame(df[TARGET_NAME].value_counts().rename('Target (counts)')),
    pd.DataFrame((df[TARGET_NAME].value_counts(normalize=True) * 100).round(3).rename('Target (%)')), 
    left_index=True, right_index=True
)
# Out:
# Distribution:
#                  Target (counts)  Target (%)
# GB6_Flag_2Limit
# G                          99444      90.026
# I                           6569       5.947
# B                           4449       4.028

# %%
# binarized target
df[f'{TARGET_BIN}'] = (df[TARGET_NAME] == 'B').astype(int)

# %%
print('Binarized target: ', TARGET_BIN)
print('Distribution: ')
pd.merge(
    pd.DataFrame(df[TARGET_BIN].value_counts().rename('Target (counts)')),
    pd.DataFrame((df[TARGET_BIN].value_counts(normalize=True) * 100).round(3).rename('Target (%)')), 
    left_index=True, right_index=True
)
# Out:
# Binarized target:  _GB6_Flag_2Limit_bin
# Distribution:
#                       Target (counts)  Target (%)
# _GB6_Flag_2Limit_bin
# 0                              106013      95.972
# 1                                4449       4.028

# %% [markdown]
# # RETRO_DATE

# %%
print('Date format:')
df.RETRO_DATE.head()
# Out:
# Date format:
# 0    13APR2022
# 1    26OCT2023
# 2    12MAR2023
# 3    04OCT2021
# 4    26AUG2023
# Name: RETRO_DATE, dtype: object

# %%
df['_RDATE'] = df.RETRO_DATE.apply(lambda x: datetime.strptime(x, '%d%b%Y').date()).values

# %%
print('Available date range:')
df['_RDATE'].agg(['min', 'max'])
# Out:
# Available date range:
# min    2021-06-30
# max    2023-11-30
# Name: _RDATE, dtype: object

# %%
print('Examples of unique dates: ')
df['_RDATE'].sort_values().unique()[:5]
# Out:
# Examples of unique dates:
# array([datetime.date(2021, 6, 30), datetime.date(2021, 7, 1),
#        datetime.date(2021, 7, 2), datetime.date(2021, 7, 3),
#        datetime.date(2021, 7, 4)], dtype=object)

# %%
# create end of month for aggregations:
df['_RDATE_EOM'] = pd.to_datetime(df['_RDATE'] + pd.tseries.offsets.MonthEnd(0)).dt.date

# %%
#  distributions 
# - number of observations per month
# - target as is, binary 
f, ax = plt.subplots(nrows=2, ncols=2, figsize=(20, 10))
plt.subplots_adjust(hspace=0.6)

_ = df['_RDATE_EOM'].value_counts(sort=False).sort_index().plot(kind='bar',  title='Number of observation per EoM (RETRO_DATE)', ax=ax[0, 0])

for date_val in ['2021-06-30', '2021-12-31', '2022-04-30', '2023-01-31','2023-08-31']: 
    _ = ax[0, 0].get_xticklabels()[np.where(np.sort(df['_RDATE_EOM'].unique()) == pd.to_datetime(date_val).date())[0][0]].set_color("red")

_ = pd.DataFrame(df.groupby(['_RDATE_EOM'])[TARGET_NAME].value_counts(sort=False).sort_index().rename('n')).reset_index()\
    .pivot(index='_RDATE_EOM', columns=TARGET_NAME, values='n')\
    .plot\
    .line(
        color=PALETTE_TARGET,
        title=f'Target ({TARGET_NAME}) per EoM (RETRO_DATE)', 
        rot=90, 
        xticks=np.sort(df._RDATE_EOM.unique()),
        ax=ax[0, 1]
    )
_ = ax[0, 1].get_xticklabels()[np.where(np.sort(df['_RDATE_EOM'].unique()) == pd.to_datetime('2023-01-31').date())[0][0]].set_color("red")
_ = ax[0, 1].get_xticklabels()[np.where(np.sort(df['_RDATE_EOM'].unique()) == pd.to_datetime('2023-08-31').date())[0][0]].set_color("red")


_ = pd.DataFrame((df.groupby(['_RDATE_EOM'])[TARGET_NAME].value_counts(normalize=True, sort=False) * 100).sort_index().rename('n')).reset_index()\
    .pivot(index='_RDATE_EOM', columns=TARGET_NAME, values='n')\
    .drop(columns=['G'])\
    .plot\
    .line(
        color=PALETTE_TARGET,
        title=f'Target ({TARGET_NAME}) per EoM (RETRO_DATE)', 
        rot=90, 
        xticks=np.sort(df._RDATE_EOM.unique()),
        ylabel='%', 
        xlabel = 'RETRO_DATE (EOM)', 
        ax=ax[1, 0]
    )
for date_value in ['2021-10-31', '2021-11-30', '2021-12-31', '2022-01-31', '2022-08-31', '2023-05-31', '2023-06-30']:
    _ = ax[1, 0].get_xticklabels()[np.where(np.sort(df['_RDATE_EOM'].unique()) == pd.to_datetime(date_value).date())[0][0]].set_color("red")

_ = ax[1, 0].hlines(y=df[TARGET_NAME].value_counts(normalize=True)['B'] * 100, xmin=pd.to_datetime('2021-06-30').date(), xmax=pd.to_datetime('2023-11-30').date(), color=PALETTE_TARGET['B'], label='B-Overall', linestyle='dashed')
_ = ax[1, 0].hlines(y=df[TARGET_NAME].value_counts(normalize=True)['I'] * 100, xmin=pd.to_datetime('2021-06-30').date(), xmax=pd.to_datetime('2023-11-30').date(), color=PALETTE_TARGET['I'], label='I-Overall', linestyle='dashed')
# _ = plt.legend()

_ = pd.DataFrame((df.groupby(['_RDATE_EOM'])[TARGET_BIN].value_counts(normalize=True, sort=False) * 100).sort_index().rename('n')).reset_index()\
    .pivot(index='_RDATE_EOM', columns=TARGET_BIN, values='n')\
    .drop(columns=[1])\
    .plot\
    .line(
        color={0: 'lightgreen', 1: 'red'},
        title=f'Target ({TARGET_BIN}) per EoM (RETRO_DATE)', 
        rot=90, 
        xticks=np.sort(df._RDATE_EOM.unique()),
        ylabel='%', 
        xlabel = 'RETRO_DATE (EOM)', 
        ax=ax[1, 1]
    )
_ = pd.DataFrame((df.groupby(['_RDATE_EOM'])[TARGET_NAME].value_counts(normalize=True, sort=False) * 100).sort_index().rename('n')).reset_index()\
    .pivot(index='_RDATE_EOM', columns=TARGET_NAME, values='n')\
    .drop(columns=['B', 'I'])\
    .plot\
    .line(
        color={'G': 'green'},
        title=f'Goods ({TARGET_BIN}, {TARGET_NAME}) per EoM (RETRO_DATE)', 
        rot=90, 
        xticks=np.sort(df._RDATE_EOM.unique()),
        ylabel='%', 
        xlabel = 'RETRO_DATE (EOM)', 
        ax=ax[1, 1]
    )
for date_value in ['2021-10-31', '2021-11-30', '2021-12-31', '2022-01-31', '2022-08-31', '2023-05-31', '2023-06-30']:
    _ = ax[1, 1].get_xticklabels()[np.where(np.sort(df['_RDATE_EOM'].unique()) == pd.to_datetime(date_value).date())[0][0]].set_color("red")

_ = ax[1, 1].hlines(y=df[TARGET_NAME].value_counts(normalize=True)['G'] * 100, xmin=pd.to_datetime('2021-06-30').date(), xmax=pd.to_datetime('2023-11-30').date(), color='green', label='G-Overall', linestyle='dashed')
_ = ax[1, 1].hlines(y=df[TARGET_BIN].value_counts(normalize=True)[0] * 100, xmin=pd.to_datetime('2021-06-30').date(), xmax=pd.to_datetime('2023-11-30').date(), color='lightgreen', label='0-Overall', linestyle='dashed')

# %%
print('Target population of the ends:')
pd.concat(
    (
        pd.DataFrame(df.groupby(['_RDATE_EOM'])[TARGET_NAME].value_counts(sort=False).sort_index().rename('n')).head(5),
        pd.DataFrame(df.groupby(['_RDATE_EOM'])[TARGET_NAME].value_counts(sort=False).sort_index().rename('n')).tail(6)
    )
)
# Out:
# Target population of the ends:
#                                n
# _RDATE_EOM GB6_Flag_2Limit
# 2021-06-30 G                   6
#            I                   1
# 2021-07-31 B                  65
#            G                2348
#            I                 123
# 2023-09-30 B                  18
#            G                3586
#            I                 166
# 2023-10-31 G                2842
#            I                  17
# 2023-11-30 G                1865

# %%
columns_final: List[str] = [
'UNIQUE_ID',
'RETRO_DATE',
'E1_A_01',
'E1_A_02',
'E1_A_03',
'E1_A_04',
'E1_A_05',
'E1_A_06',
'E1_A_07',
'E1_A_08',
'E1_A_09',
'E1_A_10',
'E1_A_11',
'E1_B_01',
'E1_B_02',
'E1_B_03',
'E1_B_04',
'E1_B_05',
'E1_B_06',
'E1_B_07',
'E1_B_08',
'E1_B_09',
'E1_B_10',
'E1_B_11',
'E1_B_12',
'E1_B_13',
'E1_C_01',
'E1_C_02',
'E1_C_03',
'E1_C_04',
'E1_C_05',
'E1_C_06',
'E1_D_01',
'E1_D_02',
'E1_D_03',
'E1_D_04',
'E1_E_01',
'E1_E_02',
'E2_G_01',
'E2_G_02',
'E2_G_03',
'E2_G_04',
'E2_G_05',
'GEN11_SP_K_70',
'GEN11_SP_K_71',
'GEN11_SP_K_72',
'GEN11_SP_K_73',
'GEN11_SP_K_74',
'GEN11_SP_K_75',
'GEN11_SP_K_76',
'GEN11_SP_K_77',
'GEN11_SP_K_78',
'GEN11_SP_K_79',
'GEN11_SP_K_80',
'GEN11_SP_L_78',
'GEN11_SP_L_79',
'GEN11_SP_L_80',
'GEN11_SP_L_81',
'GEN11_SP_L_82',
'GEN11_SP_L_83',
'GEN11_SP_L_84',
'GEN11_SP_L_85',
'GEN11_SP_M_86',
'GEN11_SP_M_88',
'CC_DATA_SUPPLIED',
'NO_MPM_NPR_L3M',
'PTBR_L3M_NPR_L3M',
'PTBR_L6M_NPR_L6M',
'NO_CA_L1M',
'NO_CA_L3M',
'NO_MLV_CA_L1M',
'NO_MLV_CA_L3M',
'CLU_CLI_L6M',
'CLU_CLI_L6M_NPR_L6M',
'CLU_NPR_L1M',
'NO_CLD_L3M',
'NO_ASB_NPR_L1M',
'PTSBR_L3M_NPR_L3M',
'PTSBR_L6M_NPR_L6M',
'HC_A_01',
'HC_A_02',
'HC_A_03',
'HC_A_04',
'HC_A_05',
'HC_A_06',
'HC_A_07',
'HC_A_08',
'HC_A_09',
'HC_A_10',
'HC_A_11',
'HC_A_12',
'HC_A_13',
'HC_A_14',
'HC_B_01',
'HC_B_02',
'HC_B_03',
'HC_B_04',
'HC_C_01',
'HC_C_02',
'HC_C_03',
'HC_C_04',
'HC_C_05',
'HC_D_01',
'HC_D_02',
'HC_E_01',
'HC_E_02',
'HC_E_03',
'HC_F_01',
'HC_F_02',
'HC_F_03',
'HC_F_04',
'HC_F_05',
'HC_F_06',
'HC_P_01',
'HC_P_02',
'HC_P_03',
'HC_P_04',
'HC_P_05',
'HC_P_06',
'HC_P_07',
'HC_P_08',
'PD_A_01',
'PD_A_02',
'PD_A_03',
'PD_A_04',
'PD_B_05',
'PD_B_06',
'PD_B_07',
'PD_B_08',
'PD_B_09',
'PD_B_10',
'PD_C_11',
'PD_C_12',
'PD_C_13',
'PD_D_14',
'PD_D_15',
'PD_D_16',
'PD_E_17',
'PD_E_18',
'PD_F_19',
'PD_F_20',
'PD_F_21',
'PD_F_22',
'PD_F_23',
'PD_F_24',
'PD_F_25',
'PD_F_26',
'PD_F_27',
'PD_F_28',
'TRD_STL_01',
'TRD_STL_02',
'TRD_STL_03',
'TRD_STL_04',
'TRD_STL_05',
'TRD_STL_06',
'TRD_STL_07',
'TRD_STL_08',
'TRD_STL_09',
'TRD_STL_10',
'TRD_STL_11',
'TRD_STL_12',
'TRD_STL_13',
'TRD_STL_14',
'TRD_STL_15',
'TRD_STL_16',
'TRD_STL_17',
'TRD_STL_18',
'TRD_STL_19',
'TRD_STL_20',
'TRD_STL_21',
'TRD_STL_22',
'TRD_STL_23',
'NDICH',
'NDSECARR',
'NDUNSECARR',
'NDCCJ',
'NDIVA',
'NDBANKRUPT',
'NDMAICH',
'NDMASECARR',
'NDMAUNSECARR',
'NDMACCJ',
'NDMAIVA',
'NDMABANKRUPT',
'NDJAICH',
'NDJASECARR',
'NDJAUNSECARR',
'NDJACCJ',
'NDJAIVA',
'NDJABANKRUPT',
'NUM_DELINQ_ACCS',
'VAL_DELINQ_ACCS',
'AGE_MOST_RECENT_DELINQ',
'NUM_ACTIVE_ACCS',
'TOT_BAL_ACTIVE_ACCS',
'AGE_MOST_RECENT',
'NUM_INACTIVE_ACCS',
'NUM_INACTIVE_ACCS_L12M',
'NUM_INACTIVE_ACCS_L24M',
'NUM_INACTIVE_ACCS_L36M',
'NUM_SETTLED_ACCS',
'NUM_SETTLED_ACCS_L12M',
'NUM_SETTLED_ACCS_L24M',
'NUM_SETTLED_ACCS_L36M',
'AGE_MOST_RECENT_SETTD',
'NPD_NUM_NPD_SP_L12M',
'NPD_BAL_NPD_SP_L12M',
'NPD_NUM_NPD_SP_L18M',
'NPD_BAL_NPD_SP_L18M',
'NPD_MIN_AGE_NPD_SP_L18M',
'NPD_NUM_EBAD_SP_L12M',
'NPD_BAL_EBAD_SP_L12M',
'NPD_NUM_EBAD_SP_L18M',
'NPD_BAL_EBAD_SP_L18M',
'NPD_MIN_AGE_EBAD_SP_L18M',
'NPD_MAX_AGE_EBAD_SP_L18M',
'NPD_NUM_NPD_SPA_L12M',
'NPD_BAL_NPD_SPA_L12M',
'NPD_NUM_NPD_SPA_L18M',
'NPD_BAL_NPD_SPA_L18M',
'NPD_MIN_AGE_NPD_SPA_L18M',
'NPD_NUM_EBAD_SPA_L12M',
'NPD_BAL_EBAD_SPA_L12M',
'NPD_NUM_EBAD_SPA_L18M',
'NPD_BAL_EBAD_SPA_L18M',
'NPD_MIN_AGE_EBAD_SPA_L18M',
'NPD_MAX_AGE_EBAD_SPA_L18M',
'VM01_SP_VM2_01',
'VM01_SP_VM2_02',
'VM01_SP_VM2_03',
'VM01_SP_VM2_04',
'VM01_SP_VM2_05',
'VM01_SP_VM2_06',
'VM01_SP_VM2_07',
'VM01_SP_VM2_08',
'VM01_SP_VM2_09',
'VM01_SP_VM2_10',
'VM01_SP_VM2_11',
'VM01_SP_VM2_12',
'VM01_SP_VM2_13',
'VM01_SP_VM2_14',
'VM01_SP_VM2_15',
'VM01_SP_VM2_16',
'VM01_SP_VM2_17',
'VM01_SP_VM2_18',
'VM01_SP_VM2_19',
'VM01_SP_VM2_20',
'VM01_SP_VM2_21',
'VM01_SP_VM2_22',
'VM01_SP_VM2_23',
'VM01_SP_VM2_24',
'VM01_SP_VM2_25',
'VM01_SP_VM2_26',
'VM01_SP_VM2_27',
'VM01_SP_VM2_28',
'VM01_SP_VM2_29',
'VM01_SP_VM2_30',
'VM01_SP_VM2_31',
'VM01_SP_VM2_32',
'VM01_SP_VM2_33',
'VM01_SP_VM2_34',
'VM01_SP_VM2_35',
'VM01_SP_VM2_36',
'VM01_SP_VM2_37',
'VM01_SP_VM2_38',
'VM01_SP_VM2_39',
'VM01_SP_VM2_40',
'VM01_SP_VM2_41',
'VM02_SP_VM1_01',
'AFF_T_46',
'AFF_T_47',
'AFF_T_48',
'AFF_T_49',
'AFF_T_50',
'AFF_T_51',
'AFF_T_52',
'AFF_T_53',
'AFF_T_54',
'AFF_T_55',
'AFF_T_56',
'AFF_T_57',
'AFF_T_58',
'AFF_T_59',
'AFF_T_60',
'AFF_T_61',
'AFF_T_62',
'AFF_T_63',
'AFF_T_64',
'AFF_T_65',
'AFF_T_66',
'AFF_T_67',
'AFF_T_68',
'AFF_T_69',
'AFF_T_70',
'AFF_T_71',
'AFF_T_72',
'AFF_T_73',
'AFF_T_74',
'AFF_T_75',
'AFF_T_76',
'AFF_T_77',
'AFF_T_78',
'AFF_T_79',
'AFF_T_80',
'AFF_T_81',
'AFF_T_82',
'AFF_T_83',
'AFF_T_84',
'AFF_S_01',
'AFF_S_02',
'AFF_S_03',
'AFF_S_04',
'AFF_S_05',
'AFF_S_06',
'AFF_S_07',
'AFF_S_08',
'AFF_S_09',
'AFF_S_10',
'AFF_S_11',
'AFF_S_12',
'AFF_C_01',
'AFF_C_02',
'AFF_C_03',
'AFF_C_04',
'AFF_C_05',
'AFF_C_06',
'AFF_C_07',
'AFF_C_08',
'AFF_C_09',
'AFF_C_10',
'AFF_C_11',
'AFF_C_12',
'AFF_C_13',
'AFF_C_14',
'AFF_C_15',
'AFF_C_16',
'AFF_C_17',
'AFF_C_18',
'AFF_B_01',
'AFF_B_02',
'AFF_B_03',
'AFF_B_04',
'AFF_B_05',
'AFF_B_06',
'AFF_B_07',
'AFF_B_08',
'AFF_B_09',
'AFF_D_01',
'AFF_D_02',
'AFF_D_03',
'AFF_D_04',
'OPTIN_11BFN',
'OPTOUT_11BFN',
'ALERT_11BFN',
'OPTIN_11RFN',
'OPTOUT_11RFN',
'ALERT_11RFN',
'OPTIN_11TFN',
'OPTOUT_11TFN',
'ALERT_11TFN',
'OPTIN_11SEN',
'OPTOUT_11SEN',
'ALERT_11SEN',
'OPTIN_11SFN',
'OPTOUT_11SFN',
'ALERT_11SFN',
'OPTIN_11BON',
'OPTOUT_11BON',
'ALERT_11BON',
'OPTIN_11BWN',
'OPTOUT_11BWN',
'ALERT_11BWN',
'OPTIN_11BBN',
'OPTOUT_11BBN',
'ALERT_11BBN',
'OPTIN_11BCN',
'OPTOUT_11BCN',
'ALERT_11BCN',
'OPTIN_11RWN',
'OPTOUT_11RWN',
'ALERT_11RWN',
'OPTIN_11RCN',
'OPTOUT_11RCN',
'ALERT_11RCN',
'OPTIN_11TCN',
'OPTOUT_11TCN',
'ALERT_11TCN',
'OPTIN_11SWN',
'OPTOUT_11SWN',
'ALERT_11SWN',
'OPTIN_11SBN',
'OPTOUT_11SBN',
'ALERT_11SBN',
'OPTIN_11SCN',
'OPTOUT_11SCN',
'ALERT_11SCN',
'OPTIN_11UCN',
'OPTOUT_11UCN',
'ALERT_11UCN',
'G5_ND_SPECII',
'G5_ND_SPCII_BDS',
'G5_ND_SPCII',
'G5_ND_SPACII',
'OPTIN_11BCN_ML',
'OPTIN_11BWN_ML',
'OPTIN_11RCN_ML',
'OPTIN_11RWN_ML',
'OPTIN_11SCN_ML',
'OPTIN_11SWN_ML',
'OPTOUT_11BCN_ML',
'OPTOUT_11BWN_ML',
'OPTOUT_11RCN_ML',
'OPTOUT_11RWN_ML',
'OPTOUT_11SCN_ML',
'OPTOUT_11SWN_ML',
'AGE_AT_APP',
'AGE_FMT',
'CREDIT_LIMIT',
'CREDIT_LIMIT_FMT',
'PI_Opening',
'PI_Settled',
'OPENDATE',
'CLOSEDATE',
'GROSS_INCOME_CAPS',
'GROSS_INCOME_COMBINED',
'GROSS_INCOME_COMBINED_FMT',
'GROSS_INCOME_FLAG',
'GB6_Flag_2Limit',
'GB12_Flag_2Limit',
'GB18_Flag_2Limit',
'GB6_Flag_3Limit',
'GB12_Flag_3Limit',
'GB18_Flag_3Limit',
'Weight',
'LAST_UPD_DATE',
'SI_STARTDATE',
'SI_ENDDATE',
'SI_FLAG',
'STATUS1_72',
'STAT1',
'STAT2',
'STAT3',
'STAT4',
'STAT5',
'STAT6',
'STAT7',
'STAT8',
'STAT9',
'STAT10',
'STAT11',
'STAT12',
'STAT13',
'STAT14',
'STAT15',
'STAT16',
'STAT17',
'STAT18',
'STAT19',
'STAT20',
'STAT21',
'STAT22',
'STAT23',
'STAT24',
'STAT25',
'STAT26',
'STAT27',
'STAT28',
'STAT29',
'STAT30',
'STAT31',
'STAT32',
'STAT33',
'STAT34',
'STAT35',
'STAT36',
'STAT37',
'STAT38',
'STAT39',
'STAT40',
'STAT41',
'STAT42',
'STAT43',
'STAT44',
'STAT45',
'STAT46',
'STAT47',
'STAT48',
'STAT49',
'STAT50',
'STAT51',
'STAT52',
'STAT53',
'STAT54',
'STAT55',
'STAT56',
'STAT57',
'STAT58',
'STAT59',
'STAT60',
'STAT61',
'STAT62',
'STAT63',
'STAT64',
'STAT65',
'STAT66',
'STAT67',
'STAT68',
'STAT69',
'STAT70',
'STAT71',
'STAT72',
'HIST_DATE_CHANGE1',
'HIST_DATE_CHANGE2',
'HIST_DATE_CHANGE3',
'HIST_DATE_CHANGE4',
'HIST_DATE_CHANGE5',
'HIST_DATE_CHANGE6',
'HIST_DATE_CHANGE7',
'HIST_DATE_CHANGE8',
'HIST_DATE_CHANGE9',
'HIST_DATE_CHANGE10',
'HIST_DATE_CHANGE11',
'HIST_DATE_CHANGE12',
'Dependants',
'Marital_Status',
'Employment_Type',
]

# %%
columns_final_types: List[str] = [
'Char (30)',
'Char (8)',
'Num (2)',
'Num (3)',
'Num (2)',
'Num (2)',
'Num (3)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (3)',
'Num (2)',
'Num (2)',
'Num (3)',
'Char (1)',
'Num (3)',
'Char (1)',
'Num (3)',
'Char (1)',
'Char (1)',
'Num (2)',
'Num (3)',
'Num (3)',
'Num (2)',
'Num (2)',
'Char (1)',
'Num (2)',
'Num (3)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (3)',
'Num (2)',
'Num (2)',
'Num (3)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (3)',
'Num (2)',
'Num (2)',
'Num (3)',
'Char (1)',
'Num (3)',
'Char (1)',
'Num (3)',
'Char (1)',
'Char (1)',
'Num (2)',
'Num (3)',
'Num (3)',
'Num (2)',
'Num (2)',
'Char (1)',
'Num (2)',
'Num (3)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Char (1)',
'Char (1)',
'Num (2)',
'Num (2)',
'Char (1)',
'Char (1)',
'Num (2)',
'Num (2)',
'Char (1)',
'Char (1)',
'Num (2)',
'Num (2)',
'Char (1)',
'Char (1)',
'Num (2)',
'Num (2)',
'Char (1)',
'Char (1)',
'Num (2)',
'Char (7)',
'Char (1)',
'Num (3)',
'Num (3)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (3)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Char (1)',
'Char (1)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (3)',
'Num (2)',
'Num (2)',
'Char (1)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (3)',
'Num (2)',
'Char (1)',
'Num (2)',
'Num (2)',
'Num (3)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (2)',
'Num (3)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (3)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (3)',
'Num (2)',
'Num (2)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (2)',
'Char (6)',
'Num (2)',
'Char (6)',
'Num (2)',
'Char (6)',
'Num (2)',
'Char (6)',
'Num (2)',
'Num (2)',
'Num (2)',
'Char (1)',
'Char (1)',
'Num (6)',
'Num (6)',
'Num (6)',
'Num (6)',
'Num (6)',
'Num (6)',
'Num (6)',
'Num (6)',
'Num (6)',
'Num (6)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (5)',
'Num (5)',
'Char (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (6)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (6)',
'Num (6)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (3)',
'Num (3)',
'Num (6)',
'Num (6)',
'Num (6)',
'Num (6)',
'Num (6)',
'Num (6)',
'Num (6)',
'Num (6)',
'Num (6)',
'Num (6)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (5)',
'Num (5)',
'Char (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (6)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (6)',
'Num (6)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (3)',
'Num (3)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (8)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (2)',
'Num (2)',
'Num (8)',
'Char (1)',
'Num (8)',
'Char (1)',
'Num (8)',
'Num (8)',
'Num (2)',
'Num (8)',
'Char (1)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Char (2)',
'Num (8)',
'Char (2)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Char (1)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Char (1)',
'Char (1)',
'Char (2)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (3)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (3)',
'Num (2)',
'Num (2)',
'Char (1)',
'Num (2)',
'Num (6)',
'Num (6)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (6)',
'Num (6)',
'Num (6)',
'Num (2)',
'Num (2)',
'Num (6)',
'Num (6)',
'Num (2)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (5)',
'Num (5)',
'Num (5)',
'Num (5)',
'Num (5)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Char (1)',
'Num (2)',
'Num (5)',
'Num (2)',
'Num (5)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (5)',
'Char (1)',
'Char (1)',
'Num (5)',
'Num (2)',
'Char (1)',
'Num (5)',
'Num (5)',
'Num (2)',
'Char (1)',
'Num (5)',
'Num (2)',
'Num (2)',
'Num (5)',
'Char (1)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Char (8)',
'Num (5)',
'Char (1)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (5)',
'Num (2)',
'Num (2)',
'Num (2)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (2)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (5)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (6)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (6)',
'Char (1)',
'Char (1)',
'Num (2)',
'Num (6)',
'Num (2)',
'Num (2)',
'Num (6)',
'Num (3)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (6)',
'Num (2)',
'Num (6)',
'Num (2)',
'Num (2)',
'Num (6)',
'Num (2)',
'Num (6)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (6)',
'Num (2)',
'Num (6)',
'Num (2)',
'Num (2)',
'Num (6)',
'Num (2)',
'Num (6)',
'Num (2)',
'Num (2)',
'Num (2)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (7)',
'Num (4)',
'Num (4)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Char (1)',
'Char (1)',
'Num (7)',
'Num (2)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Char (1)',
'Char (1)',
'Num (2)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (7)',
'Num (4)',
'Num (4)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Char (1)',
'Char (1)',
'Num (7)',
'Num (2)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Char (1)',
'Char (1)',
'Num (2)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Char (1)',
'Char (1)',
'Num (2)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Char (1)',
'Char (1)',
'Num (2)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Char (1)',
'Char (1)',
'Num (2)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (7)',
'Num (4)',
'Num (4)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Char (1)',
'Char (1)',
'Num (7)',
'Num (2)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Char (1)',
'Char (1)',
'Num (2)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (7)',
'Num (4)',
'Num (4)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Char (1)',
'Char (1)',
'Num (7)',
'Char (1)',
'Char (1)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (3)',
'Num (3)',
'Num (3)',
'Num (3)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (3)',
'Num (3)',
'Num (3)',
'Num (3)',
'Num (3)',
'Num (3)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (5)',
'Num (5)',
'Num (5)',
'Num (5)',
'Num (5)',
'Num (5)',
'Num (5)',
'Num (5)',
'Num (3)',
'Num (3)',
'Num (3)',
'Num (3)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (1)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (8)',
'Num (3)',
'Num (8)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (7)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Char (1)',
'Char (1)',
'Char (2)',
'Char (1)',
'Char (1)',
'Char (2)',
'Char (1)',
'Char (1)',
'Char (2)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Char (1)',
'Char (1)',
'Char (2)',
'Char (1)',
'Char (1)',
'Char (2)',
'Char (1)',
'Char (1)',
'Char (2)',
'Char (1)',
'Char (1)',
'Char (2)',
'Char (1)',
'Char (1)',
'Char (2)',
'Char (1)',
'Char (1)',
'Char (2)',
'Char (1)',
'Char (1)',
'Char (2)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Char (1)',
'Char (1)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num(8)',
'Char(20)',
'Num(8)',
'Char(18)',
'Char(22)',
'Char(22)',
'Char(10)',
'Char(10)',
'Char(32)',
'Char(20)',
'Num(1)',
'Num(1)',
'Char(3)',
'Char(3)',
'Char(3)',
'Char(3)',
'Char(3)',
'Char(3)',
'Num(8)',
'Num(8)',
'Char(12)',
'Char(12)',
'Char(1)',
'Char(32)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(1)',
'Char(9)',
'Char(12)',
'Char(12)',
'Char(12)',
'Char(12)',
'Char(12)',
'Char(12)',
'Char(12)',
'Char(12)',
'Char(12)',
'Char(12)',
'Char(1)',
'Char(3)',
'Char(1)',
'Char(1)',
]

# %%
columns_aiq2: List[str] = [
'UNIQUE_ID',
'AFF_V_01_01',
'AFF_V_02_01',
'AFF_V_03_01',
'AFF_V_04_01',
'AFF_V_05_01',
'AFF_V_06_01',
'AFF_V_07_01',
'AFF_V_08_01',
'AFF_V_09_01',
'AFF_V_10_01',
'AFF_V_11_01',
'AFF_V_12_01',
'AFF_V_13_01',
'AFF_V_14_01',
'AFF_V_15_01',
'AFF_V_16_01',
'AFF_V_17_01',
'AFF_V_18_01',
'AFF_V_19_01',
'AFF_V_20_01',
'AFF_V_21_01',
'AFF_V_22_01',
'AFF_E_01_01',
'AFF_E_02_01',
'AFF_E_03_01',
'AFF_E_04_01',
'AFF_E_05_01',
'AFF_E_06_01',
'AFF_E_07_01',
'AFF_E_08_01',
'AFF_E_09_01',
'AFF_E_10_01',
'AFF_E_11_01',
'AFF_E_12_01',
'AFF_E_13_01',
'AFF_E_14_01',
'AFF_E_15_01',
'AFF_E_16_01',
'AFF_E_17_01',
'AFF_E_18_01',
'AFF_E_19_01',
'AFF_E_20_01',
'AFF_E_21_01',
'AFF_E_22_01',
'AFF_E_23_01',
'AFF_E_24_01',
'AFF_E_25_01',
'AFF_E_26_01',
'AFF_E_27_01',
'AFF_E_28_01',
'AFF_E_29_01',
'AFF_E_30_01',
'AFF_E_31_01',
'AFF_E_32_01',
'AFF_E_33_01',
'AFF_E_34_01',
'AFF_E_35_01',
'AFF_E_36_01',
'AFF_T_01_01',
'AFF_T_02_01',
'AFF_T_03_01',
'AFF_T_04_01',
'AFF_T_05_01',
'AFF_T_06_01',
'AFF_T_07_01',
'TRD_RAG_06_AIQ2',
'TRD_RAG_07_AIQ2',
'TRD_RAG_08_AIQ2',
'TRD_RAG_09_AIQ2',
'TRD_RAG_10_AIQ2',
'TRD_RAG_11_AIQ2',
'TRD_RAG_12_AIQ2',
'TRD_RAG_13_AIQ2',
'TRD_RAG_14_AIQ2',
'TRD_RAG_15_AIQ2',
'TRD_RAG_16_AIQ2',
'TRD_RAG_17_AIQ2',
'TRD_RAG_18_AIQ2',
'TRD_RAG_19_AIQ2',
'TRD_RAG_20_AIQ2',
'TRD_RAG_21_AIQ2',
'TRD_RAG_22_AIQ2',
'TRD_RAG_23_AIQ2',
'TRD_RAG_24',
'TRD_RAG_25',
'TRD_RAG_26',
'TRD_RAG_27',
'TRD_RAG_28',
'TRD_RAG_29',
'TRD_RAG_30',
'TRD_RAG_31',
'TRD_RAG_32',
'TRD_RAG_33',
'TRD_RAG_34',
'TRD_RAG_35',
'TRD_RAG_36',
'TRD_RAG_37',
'TRD_RAG_38',
'TRD_RAG_39',
'TRD_RAG_40',
'TRD_RAG_41',
'TRD_RAG_42',
'TRD_RAG_43',
'TRD_RAG_44',
]

# %%
columns_aiq2_types: List[str] = [
'Char (30)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (2)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Char (1)',
'Char (1)',
'Char (2)',
'Char (1)',
'Char (1)',
'Char (2)',
'Char (1)',
'Char (1)',
'Char (2)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Char (1)',
'Char (1)',
'Char (2)',
'Char (1)',
'Char (1)',
'Char (2)',
'Char (1)',
'Char (1)',
'Char (2)',
'Char (1)',
'Char (1)',
'Char (2)',
'Char (1)',
'Char (1)',
'Char (2)',
'Char (1)',
'Char (1)',
'Char (2)',
'Char (1)',
'Char (1)',
'Char (2)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Char (1)',
'Char (1)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Char (2)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (8)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (4)',
'Num (2)',
'Num (2)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (1)',
'Num (8)',
'Num (1)',
'Num (8)',
'Num (1)',
'Num (8)',
'Num (1)',
'Num (1)',
'Num (1)',
'Num (2)',
'Num (2)',
'Num (7)',
'Char (1)',
'Num (7)',
'Char (1)',
'Num (2)',
'Num (7)',
'Char (1)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Char (1)',
'Char (1)',
'Char (2)',
'Num (8)',
'Char (2)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Num (7)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (8)',
'Num (1)',
'Num (7)',
'Num (7)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Char (1)',
'Num (1)',
'Num (1)',
'Num (1)',
'Num (1)',
'Num (1)',
'Num (1)',
'Num (1)',
'Num (1)',
'Num (1)',
'Num (1)',
'Num (1)',
'Num (1)',
'Num (1)',
'Num (1)',
'Num (1)',
'Num (1)',
'Num (1)',
'Num (1)',
'Num (1)',
'Num (1)',
'Num (1)',
]

# %%
# check lengths of types and names
assert len(columns_final) == len(columns_final_types)
assert len(columns_aiq2) == len(columns_aiq2_types)

# %%
# remove UNIQUE_ID from AIQ2's columns as there is no such feature
id_indx = columns_aiq2.index('UNIQUE_ID')

columns_aiq2.pop(id_indx)
columns_aiq2_types.pop(id_indx)
# Out:
# 'Char (30)'

# %%
print('Intersections of the AIQ2 and final columns provided in the data dict:', set(columns_final).intersection(columns_aiq2))
# Out:
# Intersections of the AIQ2 and final columns provided in the data dict: set()

# %%
# all names - together, all types - together;
columns = columns_final + columns_aiq2
columns_types = columns_final_types + columns_aiq2_types

# %%
print('# of listed columns\' types: ', len(columns_types))
print('# of listed columns\' names: ', len(columns))
assert len(columns) == len(columns_types)
# Out:
# # of listed columns' types:  1770
# # of listed columns' names:  1770

# %%
# compare with the columns given in the dataset
columns_init = df.columns
print('# of provided columns: ', len(columns_init))
# Out:
# # of provided columns:  1774

# %%
print('Provided extra columns: ', set(columns_init).difference(set(columns)))
# Out:
# Provided extra columns:  {'SP_EDI_02', 'SP_EDI_32', 'SP_EDI_35', 'SP_EDI_37', '_GB6_Flag_2Limit_bin', 'SP_EDI_21', 'SP_EDI_31', 'SP_EDI_29', 'SP_EDI_05', 'SP_EDI_22', 'SP_EDI_08', 'SP_EDI_19', 'SP_EDI_06', 'SP_EDI_09', 'SP_EDI_27', 'SP_EDI_18', 'SP_EDI_04', 'SP_EDI_03', 'UNIQUEID', '_RDATE', 'SP_EDI_30', 'SP_EDI_34', 'SP_EDI_07', 'SP_EDI_38', 'SP_EDI_13', 'SP_EDI_23', 'SP_EDI_26', 'SP_EDI_36', 'SP_EDI_12', 'SP_EDI_24', 'MARITAL_STATUS', 'SP_EDI_25', 'SP_EDI_01', 'SP_EDI_16', 'SP_EDI_15', '_RDATE_EOM', 'EMPLOYMENT_TYPE', 'SP_EDI_20', 'SP_EDI_33', 'SP_EDI_10', 'SP_EDI_11', 'SP_EDI_28', 'SP_EDI_17', 'DEPENDANTS'}

# %%
# rename columns which might mean the same
columns = [re.sub('_01$', '', col) if re.findall('^SP_EDI', col) != [] else col for col in columns]
columns_aiq2 = [re.sub('_01$', '', col) if re.findall('^SP_EDI', col) != [] else col for col in columns_aiq2]
columns_final = [re.sub('_01$', '', col) if re.findall('^SP_EDI', col) != [] else col for col in columns_final]

# %%
# # delete UNIQUEID, as there is already one
del df['UNIQUEID']

# %%
# rename columns to make them as in the documentation
df = df.rename(
    columns = { 
        'EMPLOYMENT_TYPE': 'Employment_Type',
        'DEPENDANTS': 'Dependants',
        'MARITAL_STATUS': 'Marital_Status',
    }
)

# %%
# check correspondence
columns_init = df.columns
print('In the data dict, not in the df: ', set(columns).difference(set(columns_init)))
print('In the data frame, not in the data dict:', set(columns_init).difference(set(columns)))
# Out:
# In the data dict, not in the df:  set()
# In the data frame, not in the data dict: {'_GB6_Flag_2Limit_bin', '_RDATE_EOM', '_RDATE'}

# %%
# generate standard info about a dataset

temp_file_path: str = 'df_info.txt'
buffer = io.StringIO()
df[columns].info(verbose=True, show_counts=True, buf=buffer)
s = buffer.getvalue()

with open(temp_file_path, "w", encoding="utf-8") as f:  
    f.write(s)
    
df_info = pd.read_table(temp_file_path, skiprows=5, sep='\\t', skipfooter=2, engine='python', header=None)[0]\
    .str.split(' +', expand=True)\
    .drop(columns=[0, 3])\
    .rename(columns={1: 'feature_name', 2: 'n_not_null', 4: 'dtype'})

df_info['feature_name'] = df_info['feature_name'].str.strip()
df_info['dtype'] = df_info['dtype'].str.strip()
df_info['n_not_null'] = df_info['n_not_null'].str.strip().astype(int)
df_info = df_info.set_index('feature_name')

os.remove(temp_file_path)

# %%
# create additional columns to filter out not useful features
df_info['AsFeature'] = None
df_info['Comment'] = ''

# %%
print('Shape of a dataset with info about the features: ', df_info.shape)
# Out:
# Shape of a dataset with info about the features:  (1770, 4)

# %% [markdown]
# # Null features

# %%
df_info.loc[df_info.n_not_null == 0, 'AsFeature'] = '-'
df_info.loc[df_info.n_not_null == 0, 'Comment'] = '; Non-nulls=0'

# %%
print("Number of columns with Nulls only: ", df_info[df_info.n_not_null == 0].shape[0])
# Out:
# Number of columns with Nulls only:  58

# %%
df_info['%_not_nulls'] = (df_info['n_not_null'] * 100) / df.shape[0]

# %%
df_info[(df_info['%_not_nulls'] > 0) & (df_info['%_not_nulls'] < 10)].sort_values(['n_not_null'])
# Out:
#                     n_not_null   dtype AsFeature Comment  %_not_nulls
# feature_name
# HIST_DATE_CHANGE10           2  object      None             0.001811
# HIST_DATE_CHANGE9            3  object      None             0.002716
# HIST_DATE_CHANGE8           14  object      None             0.012674
# HIST_DATE_CHANGE7           55  object      None             0.049791
# HIST_DATE_CHANGE6          156  object      None             0.141225
# GEN11_SP_J_64              349  object      None             0.315946
# SI_ENDDATE                 412  object      None             0.372979
# HIST_DATE_CHANGE5          539  object      None             0.487951
# STAT29                    1279  object      None             1.157864
# HIST_DATE_CHANGE4         1775  object      None             1.606887
# SI_STARTDATE              2205  object      None             1.996162
# SI_FLAG                   2205  object      None             1.996162
# PD_F_20                   2591  object      None             2.345603
# STAT28                    3344  object      None             3.027285
# EA2_L_04                  5620  object      None             5.087722
# HIST_DATE_CHANGE3         5631  object      None             5.097681
# STAT27                    5643  object      None             5.108544
# STAT26                    8541  object      None             7.732071

# %%
_ = plt.figure(figsize=(15, 5))
_ = sns.histplot(x='%_not_nulls', data=df_info)
_ = plt.title('Overall distribution of % of not null payments within each feature')
_ = plt.xlabel('% of not null values')
_ = plt.ylabel('# of features')

# %% [markdown]
# ## Example of a feature with huge number of nulls

# %% [markdown]
# ### EA2_L_04

# %%
col_name = 'EA2_L_04'
_ = sns.histplot(x=col_name, hue=TARGET_BIN, data=df, common_norm=False, stat='density')

# %%
temp = pd.merge(
    pd.DataFrame(df[~df[col_name].isnull() & ~df[col_name].isin(['M', 'I', 'R', 'C'])][TARGET_BIN].value_counts().rename('non_null')), 
    pd.DataFrame(df[TARGET_BIN].value_counts().rename('total')), 
    left_index=True, right_index=True
)
temp['% non-null'] = temp['non_null'] * 100 / temp['total']
temp
# Out:
#                       non_null   total  % non-null
# _GB6_Flag_2Limit_bin
# 0                         4852  106013    4.576797
# 1                          230    4449    5.169701

# %%
# Uncomment in case the feature is considered as an informative one
# df_info.loc[col_name, 'AsFeature'] = '+-'
# df_info.loc[col_name, 'Comment'] = '5% of binned target can be potentially distinguished'

# %%
mark_features_with_not_null_level_lower_than(df_info, not_null_level=MIN_PRCNT_NOT_NULL).sort_values('%_not_nulls')
# Out:
#               n_not_null    dtype AsFeature  \
# feature_name
# STAT36                 0  float64         -
# STAT44                 0  float64         -
# STAT43                 0  float64         -
# STAT42                 0  float64         -
# STAT41                 0  float64         -
# ...                  ...      ...       ...
# TRD_RAG_41        110462   object      None
# TRD_RAG_42        110462   object      None
# TRD_RAG_43        110462   object      None
# TRD_RAG_44        110462   object      None
# UNIQUE_ID         110462    int64      None
#
#                                                       Comment  %_not_nulls
# feature_name
# STAT36        ; Non-nulls=0; lower than 100% not null values;          0.0
# STAT44        ; Non-nulls=0; lower than 100% not null values;          0.0
# STAT43        ; Non-nulls=0; lower than 100% not null values;          0.0
# STAT42        ; Non-nulls=0; lower than 100% not null values;          0.0
# STAT41        ; Non-nulls=0; lower than 100% not null values;          0.0
# ...                                                       ...          ...
# TRD_RAG_41                                                           100.0
# TRD_RAG_42                                                           100.0
# TRD_RAG_43                                                           100.0
# TRD_RAG_44                                                           100.0
# UNIQUE_ID                                                            100.0
#
# [1770 rows x 5 columns]

# %% [markdown]
# # Number of unique values

# %%
df_info = pd.merge(
    df_info, 
    pd.DataFrame(df[columns].apply(lambda x: x.nunique(), axis=0).rename('n_unique_vals')), 
    left_index=True, right_index=True, how='outer'
)

# %%
df_info.loc[(df_info.n_unique_vals < MIN_N_UNIQUE_VALS) & (df_info.n_not_null == df.shape[0]), 'AsFeature'] = '-'
df_info.loc[(df_info.n_unique_vals < MIN_N_UNIQUE_VALS) & (df_info.n_not_null == df.shape[0]), 'Comment'] += '; Only one value presents'

# %%
print(f'Unique values of `AsFeature` for n_unique_vals < {MIN_N_UNIQUE_VALS}: ', df_info.loc[(df_info.n_unique_vals < MIN_N_UNIQUE_VALS)].AsFeature.unique())
# Out:
# Unique values of `AsFeature` for n_unique_vals < 2:  ['-']

# %% [markdown]
# # Definition of columns' types

# %%
# extradct types without lengths
columns_types = [elem.split('(')[0].strip() for elem in columns_types]

print('Unique initial types: ', pd.Series(columns_types).unique())
print('Unique types defined by Python: ', df_info['dtype'].unique())
# Out:
# Unique initial types:  ['Char' 'Num']
# Unique types defined by Python:  ['int64' 'object' 'float64']

# %%
# add theoretical columns' types to the df_info
df_info = pd.merge(
    df_info, 
    pd.DataFrame.from_records(zip(columns, columns_types), columns=['Feature', '_dtype_theoretical']).set_index('Feature'), 
    how='outer',
    left_index=True, right_index=True
)

# %%
print('Theoretical type vs. python\'s:')
df_info.groupby('_dtype_theoretical').dtype.unique()
# Out:
# Theoretical type vs. python's:
# _dtype_theoretical
# Char    [object, int64, float64]
# Num     [int64, float64, object]
# Name: dtype, dtype: object

# %% [markdown]
# ## Theoretically - Num, but objects - in real life

# %%
df_info[(df_info['_dtype_theoretical'] == 'Num') & (df_info.dtype == 'object')]
# Out:
#                            n_not_null   dtype AsFeature Comment  %_not_nulls  \
# GROSS_INCOME_COMBINED_FMT      110462  object      None                100.0
# LAST_UPD_DATE                  110462  object      None                100.0
# SP_EDI_26                      110462  object      None                100.0
# SP_EDI_37                      110462  object      None                100.0
# SP_EDI_38                      110462  object      None                100.0
# TRD_RAG_01                     110462  object      None                100.0
# TRD_RAG_01_AIQ2                110462  object      None                100.0
# TRD_RAG_24                     110462  object      None                100.0
# TRD_RAG_25                     110462  object      None                100.0
# TRD_RAG_26                     110462  object      None                100.0
# TRD_RAG_27                     110462  object      None                100.0
# TRD_RAG_28                     110462  object      None                100.0
# TRD_RAG_29                     110462  object      None                100.0
# TRD_RAG_30                     110462  object      None                100.0
# TRD_RAG_31                     110462  object      None                100.0
# TRD_RAG_32                     110462  object      None                100.0
# TRD_RAG_33                     110462  object      None                100.0
# TRD_RAG_34                     110462  object      None                100.0
# TRD_RAG_35                     110462  object      None                100.0
# TRD_RAG_36                     110462  object      None                100.0
# TRD_RAG_37                     110462  object      None                100.0
# TRD_RAG_38                     110462  object      None                100.0
# TRD_RAG_39                     110462  object      None                100.0
# TRD_RAG_40                     110462  object      None                100.0
# TRD_RAG_41                     110462  object      None                100.0
# TRD_RAG_42                     110462  object      None                100.0
# TRD_RAG_43                     110462  object      None                100.0
# TRD_RAG_44                     110462  object      None                100.0
#
#                            n_unique_vals _dtype_theoretical
# GROSS_INCOME_COMBINED_FMT             10                Num
# LAST_UPD_DATE                         56                Num
# SP_EDI_26                             11                Num
# SP_EDI_37                             11                Num
# SP_EDI_38                              6                Num
# TRD_RAG_01                            17                Num
# TRD_RAG_01_AIQ2                       17                Num
# TRD_RAG_24                             2                Num
# TRD_RAG_25                             2                Num
# TRD_RAG_26                             2                Num
# TRD_RAG_27                             2                Num
# TRD_RAG_28                             2                Num
# TRD_RAG_29                             2                Num
# TRD_RAG_30                             2                Num
# TRD_RAG_31                             2                Num
# TRD_RAG_32                             2                Num
# TRD_RAG_33                             2                Num
# TRD_RAG_34                             2                Num
# TRD_RAG_35                             2                Num
# TRD_RAG_36                             2                Num
# TRD_RAG_37                             2                Num
# TRD_RAG_38                             2                Num
# TRD_RAG_39                             2                Num
# TRD_RAG_40                             2                Num
# TRD_RAG_41                             2                Num
# TRD_RAG_42                             2                Num
# TRD_RAG_43                             2                Num
# TRD_RAG_44                             2                Num

# %% [markdown]
# ### aiq2

# %%
pot_numeric_cols  = []
print('Exceptions in case of converting the columns defined as Num in the data dict to float type')
for col in set(
        df_info[(df_info['_dtype_theoretical'] == 'Num') & (df_info.dtype == 'object')].index
    ).intersection(
        set(columns_aiq2)
):
    try:
        col_tr = df[col].astype(float)
        pot_numeric_cols += [col]
    except Exception as e:
        print(col, ': ', e)


print('Columns, which can be treated as floats: ', pot_numeric_cols)
# Out:
# Exceptions in case of converting the columns defined as Num in the data dict to float type
# TRD_RAG_34 :  could not convert string to float: 'X'
# TRD_RAG_41 :  could not convert string to float: 'X'
# SP_EDI_37 :  could not convert string to float: 'D'
# TRD_RAG_25 :  could not convert string to float: 'X'
# TRD_RAG_39 :  could not convert string to float: 'X'
# TRD_RAG_31 :  could not convert string to float: 'X'
# TRD_RAG_27 :  could not convert string to float: 'X'
# TRD_RAG_37 :  could not convert string to float: 'X'
# TRD_RAG_40 :  could not convert string to float: 'X'
# TRD_RAG_43 :  could not convert string to float: 'X'
# TRD_RAG_29 :  could not convert string to float: 'X'
# TRD_RAG_33 :  could not convert string to float: 'X'
# SP_EDI_38 :  could not convert string to float: 'B'
# TRD_RAG_30 :  could not convert string to float: 'X'
# TRD_RAG_44 :  could not convert string to float: 'X'
# SP_EDI_26 :  could not convert string to float: 'X'
# TRD_RAG_28 :  could not convert string to float: 'X'
# TRD_RAG_38 :  could not convert string to float: 'X'
# TRD_RAG_32 :  could not convert string to float: 'X'
# TRD_RAG_42 :  could not convert string to float: 'X'
# TRD_RAG_01_AIQ2 :  could not convert string to float: 'U'
# TRD_RAG_36 :  could not convert string to float: 'X'
# TRD_RAG_26 :  could not convert string to float: 'X'
# TRD_RAG_24 :  could not convert string to float: 'X'
# TRD_RAG_35 :  could not convert string to float: 'X'
# Columns, which can be treated as floats:  []

# %%
print(
    f"Number of columns with `Num` theoretical type and NOT `object` real type: ", 
    len(
        set(
            df_info[(df_info['_dtype_theoretical'] == 'Num') & (df_info.dtype != 'object')].index
        ).intersection(set(columns_aiq2))
    )
)
# Out:
# Number of columns with `Num` theoretical type and NOT `object` real type:  202

# %%
f, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 5))
_ = sns.histplot(df_info['n_unique_vals'], bins=100, ax = ax[0])
_ = ax[0].set_title('Full picture')
_ = plt.suptitle('Distribution of number of unique values of features')

_ = sns.histplot(df_info[df_info['n_unique_vals'] < 100]['n_unique_vals'].reset_index(drop=True), bins=100, ax = ax[1])
_ = plt.vlines(40, 0, 100, color='red', linestyle='dashed')
_ = plt.annotate('40 unique values', (41, 90), color='red')
_ = ax[1].set_xlim((-20, 200))
_ = ax[1].set_title('n_unique_vals < 100')

# %%
print(
    f"Number of columns with `Num` trheoretical type and NOT `object` real type and <= {MAX_N_UNIQUE_CONT_VALS} unique values: ", 
    len(
        set(
            df_info[(df_info['_dtype_theoretical'] == 'Num') & (df_info.dtype != 'object') & (df_info.n_unique_vals <= MAX_N_UNIQUE_CONT_VALS)].index
        ).intersection(set(columns_aiq2))
    )
)
# Out:
# Number of columns with `Num` trheoretical type and NOT `object` real type and <= 40 unique values:  88

# %%
CATEGORICAL_COLS: List[str] = list(
    set(
        df_info[
            (df_info['_dtype_theoretical'] == 'Num') & 
            (df_info.dtype != 'object') &
            (df_info.n_unique_vals <= MAX_N_UNIQUE_CONT_VALS)
        ].index
    ).intersection(set(columns_aiq2))
)
CATEGORICAL_COLS += list(
    set(
        df_info[
            (df_info['_dtype_theoretical'] == 'Num') & 
            (df_info.dtype == 'object')
        ].index
    ).intersection(set(columns_aiq2))
)

# %%
NUMERIC_COLS: List[str] = list(
    set(
        df_info[
            (df_info['_dtype_theoretical'] == 'Num') & 
            (df_info.dtype != 'object') &
            (df_info.n_unique_vals > MAX_N_UNIQUE_CONT_VALS)
        ].index
    ).intersection(set(columns_aiq2))
)

# %% [markdown]
# ### final

# %%
df.GROSS_INCOME_COMBINED_FMT.unique()
# Out:
# array(['20,001 - 30,000', '30,001 - 40,000', '1 - 10,000',
#        '10,001 - 20,000', '40,001 - 50,000', '60,001 - 70,000',
#        '50,001 - 60,000', '90,001 +', '70,001 - 80,000',
#        '80,001 - 90,000'], dtype=object)

# %%
df.LAST_UPD_DATE.unique()
# Out:
# array(['05NOV2023', '03DEC2023', '17DEC2023', '01JAN2023', '04JUN2023',
#        '03JUL2022', '09APR2023', '08OCT2023', '10SEP2023', '10OCT2021',
#        '12FEB2023', '06NOV2022', '07MAY2023', '05JUN2022', '16JUL2023',
#        '14AUG2022', '10APR2022', '31JUL2022', '19NOV2023', '13AUG2023',
#        '12MAR2023', '11SEP2022', '09OCT2022', '30JUL2023', '21MAY2023',
#        '04DEC2022', '02JUL2023', '08MAY2022', '13FEB2022', '18DEC2022',
#        '05DEC2021', '13MAR2022', '17JUL2022', '19JUN2022', '07NOV2021',
#        '20NOV2022', '18JUN2023', '02JAN2022', '20SEP2022', '12SEP2021',
#        '23APR2023', '21NOV2021', '15JAN2023', '15AUG2021', '01AUG2021',
#        '18SEP2023', '22DEC2022', '18OCT2023', '16JAN2022', '20OCT2022',
#        '19DEC2021', '22NOV2023', '18NOV2022', '16MAR2022', '22NOV2022',
#        '08AUG2023'], dtype=object)

# %%
df.TRD_RAG_01.unique()
# Out:
# array(['U', 'G', 'P', 'J', 'F', '1', '4', '3', 'A', 'B', '2', 'T', 'S',
#        '6', 'I', 'M', '5'], dtype=object)

# %% [markdown]
# -----------------------
# Should be objects

# %%
print(
    f"Number of columns with `Num` trheoretical type and NOT `object` real type: ", 
    len(
        set(
            df_info[
                (df_info['_dtype_theoretical'] == 'Num') & 
                (df_info.dtype != 'object')
            ].index
        ).intersection(set(columns_final))
    )
)
# Out:
# Number of columns with `Num` trheoretical type and NOT `object` real type:  1042

# %%
print(
    f"Number of columns with `Num` trheoretical type and NOT `object` real type and <= {MAX_N_UNIQUE_CONT_VALS} unique values: ", 
    len(
        set(
            df_info[
                (df_info['_dtype_theoretical'] == 'Num') & 
                (df_info.dtype != 'object') &
                (df_info.n_unique_vals <= MAX_N_UNIQUE_CONT_VALS)
            ].index
        ).intersection(set(columns_final))
    )
)
# Out:
# Number of columns with `Num` trheoretical type and NOT `object` real type and <= 40 unique values:  488

# %%
CATEGORICAL_COLS += list(
    set(
        df_info[
            (df_info['_dtype_theoretical'] == 'Num') & 
            (df_info.dtype != 'object') & 
            (df_info.n_unique_vals <= MAX_N_UNIQUE_CONT_VALS)
        ].index
    ).intersection(set(columns_final))
)
CATEGORICAL_COLS += list(
    set(
        df_info[
            (df_info['_dtype_theoretical'] == 'Num') & 
            (df_info.dtype == 'object')].index
    ).intersection(set(columns_final))
)

# %%
NUMERIC_COLS += list(
    set(
        df_info[
            (df_info['_dtype_theoretical'] == 'Num') & 
            (df_info.dtype != 'object') & 
            (df_info.n_unique_vals > MAX_N_UNIQUE_CONT_VALS)
        ].index
    ).intersection(set(columns_final))
)

# %% [markdown]
# ## Theoretically - objects, but int/floats - in real life

# %% [markdown]
# ### By types in real life

# %% [markdown]
# #### Int

# %%
cols_to_check = df_info[(df_info._dtype_theoretical == 'Char') & (df_info.dtype == 'int64')].index
for col in cols_to_check:
    print(col, ': ', df[col].unique())
# Out:
# Dependants :  [ 0  1  2  3  4  5 97  6]
# E4_Q_01 :  [1 3 4 2]
# E4_Q_02 :  [1 3 4 2]
# E4_Q_05 :  [5]
# E4_Q_06 :  [5]
# E4_Q_09 :  [5]
# E4_Q_10 :  [5]
# E4_Q_13 :  [5]
# E4_Q_14 :  [5]
# E4_Q_17 :  [2 6 4 3 5 8 1 7]
# E4_Q_18 :  [4 2 5 1 6 8 3 7]
# E5_S_01 :  [1]
# E5_S_02 :  [1 3 2]
# EA2_Q_01 :  [1 3 2 4]
# EA4_R_01_CJ :  [0]
# EA4_R_01_PJ :  [0]
# EA4_R_01_PM :  [0]
# GROSS_INCOME_CAPS :  [23000 33000 24000 ... 42771 49502 47880]
# GROSS_INCOME_COMBINED :  [23000 33000 24000 ... 42771 49502 47880]
# SP_EDI_10 :  [ 3  5  2 -1  4]
# SP_EDI_11 :  [  -2   -1  516  440  249 1039  490  457  408  524  564  378  354  385
#   625  404  597  676  467  548  352  501  580  497  232  550  398  450
#   895 1050  469  633  445  583  375  423  367  438  475  465  489  543
#   836  721  405  349  345  552  262  750  328  512  570  329  572  493
#   434  519  447  421  900  359 1036  428  495  506 1200  406  546  518
#   693 1400  474 1000 2500  507  427  995  417  462  588  402  876  957
#   476  503  553  441  432  628  372  379  214  614  658  470  381  737
#    90 1700 1030  591  722  559  577  725  321  532  416  401  810  389
#   395  578  316  424  306  850  420  453  334  303  500  673  464 2900
#  1300  350 1102  618  609  391  587  514  419 1450  292  108  185  905
#   365  380  530  460  646  778  368  270  414  547  505  430  950  451
#   800  448  206  491  555  361  700  585  735  975  386  305  496  407
#   335  563 1105  667  522  640 1350  595  369  590  526  492  604  344
#  1175  487  446  426  284 4400 3000  754  418  639  665  415   48  685
#   377  390  551  687  122  472  326  510  471  360  322  653  384  477
#   509  815  333  686  374  383 1500  556  866  545  498  965  795  403
#   325  124  296 1650  425  541  602  429  694  362  525  549  320  282
#   517  370  632 2400  576  663  645  705  412  521  387  422  484  743
#   508  586 1800 2686   66  875  259  644  297  433  409  400  594  592
#   302  527 1625  652  357  573  624  523   50  444  399  255  251  678
#   717  745  482  780  473  435  925  382  569  449  596  125  554  739
#   486  619 1575  437  747  131  376  692  312  364  481  394  816  574
#   666  439  466  712  622  531  538  660 1295  388  463  893  536  363
#   659  720 1395  770  332  668  997  584  978  480  483  891  582  147
#    63  626  279  568  635  223  634  669  601  485  338  742  431  809
#   478  479   68  709  825 1296  488  534  515  593  442  443  494  358
#   397  695  301  461  650  729  565  980  373  339  353  616  295  675
#   575   43  309  455 1054  938  608  454  468  540  600  674 1225  241
#  3361  641  528 1100 1634 1150  567  656  766  260  773 1600  691  293
#   662  337  845 1365  839  330  343  615  562  413  715  142  324  458
#   960  340  885  535  566  598 1192  939  459  393 2700  315 2000  169
#   620  760  970  348 1250  933  775   89  529  511  281   55  557  392
#   748  988  561  719  560  630  631  347  664  704  655  542    1  610
#   677  854  351  327 1130  796  971  410  355 1045  149  707 1109  436
#  1061  945  730  621 1020  243  166  699   19  724  299 1345  623  703
#  1550  696  289  744  920  539  371 1174 1462  756  319  606  711  680
#   308  613  269  396  280  841  790  642  102  915  603   33  636  612
#   504 1115  853  791  456 1425  286  797  298  452  792  120  882  318
#   826   99  219  176  661 2250  999 1040  366  599  942  158  520  710
#   154  537]
# UNIQUE_ID :  [      44      297      759 ... 46649356 46649909 46650007]

# %% [markdown]
# `GROSS_INCOME_CAPS`, `GROSS_INCOME_COMBINED`, `SP_EDI_11SP_EDI_11` - can be treated as numeric

# %%
for col in ['GROSS_INCOME_CAPS', 'GROSS_INCOME_COMBINED', 'SP_EDI_11']:
    NUMERIC_COLS += [col]

# %% [markdown]
# #### Float

# %%
cols_to_check = df_info[(df_info._dtype_theoretical == 'Char') & (df_info.dtype == 'float64')].index
#  606. 553. 619. 654. 537. 568. 604. 690. 389. 762. 637. 840. 635. 792.
#  633. 516. 613. 941. 699. 515. 896. 702. 454. 439. 682. 876. 746. 598.
#  396. 770. 743. 589. 909. 531. 549. 824. 473. 788. 583. 395. 906. 846.
#  388. 426. 703. 524. 744. 509. 467. 422. 675. 624. 585. 546. 354. 853.
#  691. 574. 413. 644. 680. 443. 711. 446. 522. 712. 567. 778. 437. 579.
#  886. 783. 867. 652. 812. 704. 620. 686. 573. 873. 492. 580. 672. 497.
#  822. 911. 923. 601. 529. 465. 705. 659. 605. 474. 423. 569. 543. 544.
#  507. 701. 766. 571. 729. 451. 559. 997. 661. 756. 470. 596. 790. 651.
#  563. 660. 458. 564. 753. 695. 831. 885. 555. 789. 710. 947. 523. 803.
#  572. 727. 666. 719. 924. 717. 415. 678. 656. 527. 418. 655. 636. 828.
#  587. 628. 971. 698. 657. 562. 934. 856.]
# STAT30 :  [nan]
# STAT31 :  [nan]
# STAT32 :  [nan]
# STAT33 :  [nan]
# STAT34 :  [nan]
# STAT35 :  [nan]
# STAT36 :  [nan]
# STAT37 :  [nan]
# STAT38 :  [nan]
# STAT39 :  [nan]
# STAT40 :  [nan]
# STAT41 :  [nan]
# STAT42 :  [nan]
# STAT43 :  [nan]
# STAT44 :  [nan]
# STAT45 :  [nan]
# STAT46 :  [nan]
# STAT47 :  [nan]
# STAT48 :  [nan]
# STAT49 :  [nan]
# STAT50 :  [nan]
# STAT51 :  [nan]
# STAT52 :  [nan]
# STAT53 :  [nan]
# STAT54 :  [nan]
# STAT55 :  [nan]
# STAT56 :  [nan]
# STAT57 :  [nan]
# STAT58 :  [nan]
# STAT59 :  [nan]
# STAT60 :  [nan]
# STAT61 :  [nan]
# STAT62 :  [nan]
# STAT63 :  [nan]
# STAT64 :  [nan]
# STAT65 :  [nan]
# STAT66 :  [nan]
# STAT67 :  [nan]
# STAT68 :  [nan]
# STAT69 :  [nan]
# STAT70 :  [nan]
# STAT71 :  [nan]
# STAT72 :  [nan]
# SUS_IND :  [nan]

# %% [markdown]
# ### By subsample

# %% [markdown]
# #### aiq2

# %%
print('AIQ2: Check if there are columns not from expenditure')
cols_to_check = set(df_info[(df_info._dtype_theoretical == 'Char') & (df_info.dtype == 'float64')].index).intersection(set(columns_aiq2))
for col in cols_to_check:
    if 'SP_EDI' not in col:
        print(col, ': ', df[col].unique())
# Out:
# AIQ2: Check if there are columns not from expenditure

# %% [markdown]
# Columns from expenditure cab be treated as numeric

# %%
NUMERIC_COLS += list(
    set(
        df_info[
            (df_info._dtype_theoretical.str.lower().str.strip() == 'char') & 
            (df_info.dtype.isin(['float64']))
        ].index
    ).intersection(set(columns_aiq2))
)

# %%
CATEGORICAL_COLS += list(
    set(
        df_info[
            (df_info._dtype_theoretical.str.lower().str.strip() == 'char') & 
            (df_info.dtype.isin(['int64', 'object']))
        ].index
    )
)

# %% [markdown]
# #### final

# %%
cols_to_check = df_info[(df_info._dtype_theoretical == 'Char') & (df_info.dtype == 'float64')].index
    
print(
    f'final: if all columns to check has NaNs < {MIN_PRCNT_NOT_NULL} : ', 
    len(set(cols_to_check).intersection(set(columns_final))) == len(
        set(
            df_info[
                (df_info._dtype_theoretical.str.lower().str.strip() == 'char') & 
                (df_info.dtype == 'float64') & 
                (df_info['%_not_nulls'] < MIN_PRCNT_NOT_NULL)
            ].index
        ).intersection(set(columns_final))
    )
)
# Out:
# final: if all columns to check has NaNs < 100 :  True

# %%
CATEGORICAL_COLS += list(
    set(
        df_info[
            (df_info._dtype_theoretical.str.lower().str.strip() == 'char') & 
            (df_info.dtype.isin(['int64', 'object']))
        ].index
    ).intersection(set(columns_final))
)

# %% [markdown]
# ## Columns with `date` in their names

# %%
print('Date columns: ')
print('in numeric: ', [col for col in NUMERIC_COLS if 'date' in col.lower()])
print('in categorical: ', [col for col in CATEGORICAL_COLS if 'date' in col.lower()])
# Out:
# Date columns:
# in numeric:  []
# in categorical:  ['LAST_UPD_DATE', 'HIST_DATE_CHANGE6', 'HIST_DATE_CHANGE2', 'SI_ENDDATE', 'HIST_DATE_CHANGE3', 'OPENDATE', 'SI_STARTDATE', 'HIST_DATE_CHANGE8', 'CLOSEDATE', 'HIST_DATE_CHANGE5', 'HIST_DATE_CHANGE9', 'HIST_DATE_CHANGE4', 'RETRO_DATE', 'HIST_DATE_CHANGE7', 'HIST_DATE_CHANGE10', 'HIST_DATE_CHANGE1', 'HIST_DATE_CHANGE6', 'HIST_DATE_CHANGE2', 'SI_ENDDATE', 'HIST_DATE_CHANGE3', 'OPENDATE', 'SI_STARTDATE', 'HIST_DATE_CHANGE8', 'CLOSEDATE', 'HIST_DATE_CHANGE5', 'HIST_DATE_CHANGE9', 'HIST_DATE_CHANGE4', 'RETRO_DATE', 'HIST_DATE_CHANGE7', 'HIST_DATE_CHANGE10', 'HIST_DATE_CHANGE1']

# %%
# check format of columns with 'date' in their names
for col in [col for col in CATEGORICAL_COLS if 'date' in col.lower()]:
    print(col, df[~df[col].isnull()][col].head(1).values)
# Out:
# LAST_UPD_DATE ['05NOV2023']
# HIST_DATE_CHANGE6 ['01JAN2022']
# HIST_DATE_CHANGE2 ['01MAY2022']
# SI_ENDDATE ['01SEP2023']
# HIST_DATE_CHANGE3 ['01JUL2022']
# OPENDATE ['13APR2022']
# SI_STARTDATE ['01NOV2023']
# HIST_DATE_CHANGE8 ['01NOV2021']
# CLOSEDATE ['31DEC2022']
# HIST_DATE_CHANGE5 ['01OCT2022']
# HIST_DATE_CHANGE9 ['01DEC2021']
# HIST_DATE_CHANGE4 ['01APR2022']
# RETRO_DATE ['13APR2022']
# HIST_DATE_CHANGE7 ['01SEP2021']
# HIST_DATE_CHANGE10 ['01AUG2021']
# HIST_DATE_CHANGE1 ['01DEC2022']
# HIST_DATE_CHANGE6 ['01JAN2022']
# HIST_DATE_CHANGE2 ['01MAY2022']
# SI_ENDDATE ['01SEP2023']
# HIST_DATE_CHANGE3 ['01JUL2022']
# OPENDATE ['13APR2022']
# SI_STARTDATE ['01NOV2023']
# HIST_DATE_CHANGE8 ['01NOV2021']
# CLOSEDATE ['31DEC2022']
# HIST_DATE_CHANGE5 ['01OCT2022']
# HIST_DATE_CHANGE9 ['01DEC2021']
# HIST_DATE_CHANGE4 ['01APR2022']
# RETRO_DATE ['13APR2022']
# HIST_DATE_CHANGE7 ['01SEP2021']
# HIST_DATE_CHANGE10 ['01AUG2021']
# HIST_DATE_CHANGE1 ['01DEC2022']

# %%
# remove columns with 'date' in their names:
for col in  [col for col in CATEGORICAL_COLS if 'date' in col.lower()]:
    df_info.loc[col, 'AsFeature'] = '-'
    df_info.loc[col, 'Comment'] = '; date column;'
    CATEGORICAL_COLS.remove(col)

# %%
# target/limits-related columns:
limits_related_cols = [col for col in df.columns if 'limit' in col.lower()]
print('Credit limits-related columns: ', limits_related_cols)

for col in limits_related_cols:
    if col in CATEGORICAL_COLS:
        df_info.loc[col, 'AsFeature'] = '-'
        df_info.loc[col, 'Comment'] = '; credit limits-related column;'
        CATEGORICAL_COLS.remove(col)
    if col in NUMERIC_COLS:
        df_info.loc[col, 'AsFeature'] = '-'
        df_info.loc[col, 'Comment'] = '; credit limits-related column;'
        NUMERIC_COLS.remove(col)
# Out:
# Credit limits-related columns:  ['CREDIT_LIMIT', 'CREDIT_LIMIT_FMT', 'GB6_Flag_2Limit', 'GB12_Flag_2Limit', 'GB18_Flag_2Limit', 'GB6_Flag_3Limit', 'GB12_Flag_3Limit', 'GB18_Flag_3Limit', '_GB6_Flag_2Limit_bin']

# %%
df_info.loc['UNIQUE_ID', :]
# Out:
# n_not_null            110462
# dtype                  int64
# AsFeature               None
# Comment
# %_not_nulls            100.0
# n_unique_vals         110462
# _dtype_theoretical      Char
# Name: UNIQUE_ID, dtype: object

# %%
# deduplication
CATEGORICAL_COLS = list(set(CATEGORICAL_COLS))
NUMERIC_COLS = list(set(NUMERIC_COLS))

# %%
df_info.loc['UNIQUE_ID', :]
# Out:
# n_not_null            110462
# dtype                  int64
# AsFeature               None
# Comment
# %_not_nulls            100.0
# n_unique_vals         110462
# _dtype_theoretical      Char
# Name: UNIQUE_ID, dtype: object

# %%
# remove auxiliary columns
for col in ['UNIQUE_ID', TARGET_NAME, 'UNIQUEID']:    
    if col in CATEGORICAL_COLS:
        df_info.loc[col, 'AsFeature'] = '-'
        df_info.loc[col, 'Comment'] = '; auxiliary column;'
        CATEGORICAL_COLS.remove(col)
    if col in NUMERIC_COLS:
        df_info.loc[col, 'AsFeature'] = '-'
        df_info.loc[col, 'Comment'] = '; auxiliary column;'
        NUMERIC_COLS.remove(col)

# %%
df_info.loc['UNIQUE_ID', :]
# Out:
# n_not_null                         110462
# dtype                               int64
# AsFeature                               -
# Comment               ; auxiliary column;
# %_not_nulls                         100.0
# n_unique_vals                      110462
# _dtype_theoretical                   Char
# Name: UNIQUE_ID, dtype: object

# %%
print('Intersection of Numerical and Categorical: ', set(CATEGORICAL_COLS).intersection(set(NUMERIC_COLS)))
# Out:
# Intersection of Numerical and Categorical:  {'GROSS_INCOME_CAPS', 'SP_EDI_11', 'GROSS_INCOME_COMBINED'}

# %%
# deduplication:
for col in ['GROSS_INCOME_CAPS', 'GROSS_INCOME_COMBINED', 'SP_EDI_11']:
    CATEGORICAL_COLS.remove(col)
print('Intersection: ', set(CATEGORICAL_COLS).intersection(set(NUMERIC_COLS)))
# Out:
# Intersection:  set()

# %%
# select only columns with at least 2 unique values
CATEGORICAL_COLS_AT_LEAST_2_VAl = [col for col in CATEGORICAL_COLS if df_info.loc[col, 'n_unique_vals'] > 1]
print('#categorical columns: ', len(CATEGORICAL_COLS))
print('#categorical columns with at least 2 values: ', len(CATEGORICAL_COLS_AT_LEAST_2_VAl))
# Out:
# #categorical columns:  1015
# #categorical columns with at least 2 values:  979

# %%
for col in set(CATEGORICAL_COLS).difference(set(CATEGORICAL_COLS_AT_LEAST_2_VAl)):
    df_info.loc[col, 'AsFeature'] = '-'
    df_info.loc[col, 'Comment'] += f'; Correlation cannot be computed'

# %%
# deduplicate columns in case somenthing was counted twice
CATEGORICAL_COLS_AT_LEAST_2_VAl = list(set(CATEGORICAL_COLS_AT_LEAST_2_VAl))
NUMERIC_COLS = list(set(NUMERIC_COLS))

# %%
print('Finally, #of columns in total: ', len(CATEGORICAL_COLS_AT_LEAST_2_VAl) + len(NUMERIC_COLS))
# Out:
# Finally, #of columns in total:  1656

# %%
# check not includeed columns, if anything was missed:
assert not df_info[~df_info.index.isin(CATEGORICAL_COLS_AT_LEAST_2_VAl + NUMERIC_COLS)].AsFeature.isna().any(), 'Missed a column without sign `AsFeature`'
assert not df_info[~df_info.index.isin(CATEGORICAL_COLS_AT_LEAST_2_VAl + NUMERIC_COLS)].Comment.isna().any(), 'Missed a column without a `Comment`'

# %%
print('Features of ignored columns:')
df_info[~df_info.index.isin(CATEGORICAL_COLS_AT_LEAST_2_VAl + NUMERIC_COLS)].head()
# Out:
# Features of ignored columns:
#               n_not_null   dtype AsFeature  \
# AFF_M_07_01       110462   int64         -
# AFF_M_08_01       110462   int64         -
# AFF_M_09_01       110462   int64         -
# CLOSEDATE          11542  object         -
# CREDIT_LIMIT      110462   int64         -
#
#                                                         Comment  %_not_nulls  \
# AFF_M_07_01   ; Only one value presents; Correlation cannot ...   100.000000
# AFF_M_08_01   ; Only one value presents; Correlation cannot ...   100.000000
# AFF_M_09_01   ; Only one value presents; Correlation cannot ...   100.000000
# CLOSEDATE                                        ; date column;    10.448842
# CREDIT_LIMIT                    ; credit limits-related column;   100.000000
#
#               n_unique_vals _dtype_theoretical
# AFF_M_07_01               1                Num
# AFF_M_08_01               1                Num
# AFF_M_09_01               1                Num
# CLOSEDATE               752               Char
# CREDIT_LIMIT            409                Num

# %%
df_info[~df_info.index.isin(CATEGORICAL_COLS_AT_LEAST_2_VAl + NUMERIC_COLS)]
# Out:
#               n_not_null    dtype AsFeature  \
# AFF_M_07_01       110462    int64         -
# AFF_M_08_01       110462    int64         -
# AFF_M_09_01       110462    int64         -
# CLOSEDATE          11542   object         -
# CREDIT_LIMIT      110462    int64         -
# ...                  ...      ...       ...
# STAT70                 0  float64         -
# STAT71                 0  float64         -
# STAT72                 0  float64         -
# SUS_IND                0  float64         -
# UNIQUE_ID         110462    int64         -
#
#                                                         Comment  %_not_nulls  \
# AFF_M_07_01   ; Only one value presents; Correlation cannot ...   100.000000
# AFF_M_08_01   ; Only one value presents; Correlation cannot ...   100.000000
# AFF_M_09_01   ; Only one value presents; Correlation cannot ...   100.000000
# CLOSEDATE                                        ; date column;    10.448842
# CREDIT_LIMIT                    ; credit limits-related column;   100.000000
# ...                                                         ...          ...
# STAT70          ; Non-nulls=0; lower than 100% not null values;     0.000000
# STAT71          ; Non-nulls=0; lower than 100% not null values;     0.000000
# STAT72          ; Non-nulls=0; lower than 100% not null values;     0.000000
# SUS_IND         ; Non-nulls=0; lower than 100% not null values;     0.000000
# UNIQUE_ID                                   ; auxiliary column;   100.000000
#
#               n_unique_vals _dtype_theoretical
# AFF_M_07_01               1                Num
# AFF_M_08_01               1                Num
# AFF_M_09_01               1                Num
# CLOSEDATE               752               Char
# CREDIT_LIMIT            409                Num
# ...                     ...                ...
# STAT70                    0               Char
# STAT71                    0               Char
# STAT72                    0               Char
# SUS_IND                   0               Char
# UNIQUE_ID            110462               Char
#
# [114 rows x 7 columns]

# %%
print('Ignored columns:')
for col in df_info[~df_info.index.isin(CATEGORICAL_COLS_AT_LEAST_2_VAl + NUMERIC_COLS)].index:
    print(col, ' - ', df_info.loc[col, 'Comment'])
# Out:
# Ignored columns:
# AFF_M_07_01  -  ; Only one value presents; Correlation cannot be computed
# AFF_M_08_01  -  ; Only one value presents; Correlation cannot be computed
# AFF_M_09_01  -  ; Only one value presents; Correlation cannot be computed
# CLOSEDATE  -  ; date column;
# CREDIT_LIMIT  -  ; credit limits-related column;
# E4_Q_05  -  ; Only one value presents; Correlation cannot be computed
# E4_Q_06  -  ; Only one value presents; Correlation cannot be computed
# E4_Q_09  -  ; Only one value presents; Correlation cannot be computed
# E4_Q_10  -  ; Only one value presents; Correlation cannot be computed
# E4_Q_13  -  ; Only one value presents; Correlation cannot be computed
# E4_Q_14  -  ; Only one value presents; Correlation cannot be computed
# E4_R_01  -  ; Non-nulls=0; lower than 100% not null values;; Correlation cannot be computed
# E4_R_03  -  ; Non-nulls=0; lower than 100% not null values;
# E5_S_01  -  ; Only one value presents; Correlation cannot be computed
# EA1_B_01  -  ; Only one value presents; Correlation cannot be computed
# EA1_C_02  -  ; Only one value presents; Correlation cannot be computed
# EA1_F_01  -  ; lower than 100% not null values;
# EA1_G_01  -  ; Only one value presents; Correlation cannot be computed
# EA1_G_02  -  ; Only one value presents; Correlation cannot be computed
# EA2_H_01  -  ; Only one value presents; Correlation cannot be computed
# EA2_I_02  -  ; Only one value presents; Correlation cannot be computed
# EA2_L_01  -  ; lower than 100% not null values;
# EA2_M_01  -  ; Only one value presents; Correlation cannot be computed
# EA2_M_02  -  ; Only one value presents; Correlation cannot be computed
# EA4_Q_03  -  ; Only one value presents; Correlation cannot be computed
# EA4_Q_07  -  ; Only one value presents; Correlation cannot be computed
# EA4_Q_08  -  ; Only one value presents; Correlation cannot be computed
# EA4_Q_10  -  ; Only one value presents; Correlation cannot be computed
# EA4_Q_11  -  ; Only one value presents; Correlation cannot be computed
# EA4_R_01_CJ  -  ; Only one value presents; Correlation cannot be computed
# EA4_R_01_PJ  -  ; Only one value presents; Correlation cannot be computed
# EA4_R_01_PM  -  ; Only one value presents; Correlation cannot be computed
# EA4_S_02  -  ; Non-nulls=0; lower than 100% not null values;
# EA4_S_04  -  ; Non-nulls=0; lower than 100% not null values;
# EA4_S_06  -  ; Non-nulls=0; lower than 100% not null values;
# EA4_S_08  -  ; Non-nulls=0; lower than 100% not null values;
# GB6_Flag_2Limit  -  ; auxiliary column;
# GEN11_SP_J_64  -  ; lower than 100% not null values;; Correlation cannot be computed
# HIST_DATE_CHANGE1  -  ; date column;
# HIST_DATE_CHANGE10  -  ; date column;
# HIST_DATE_CHANGE11  -  ; Non-nulls=0; lower than 100% not null values;
# HIST_DATE_CHANGE12  -  ; Non-nulls=0; lower than 100% not null values;
# HIST_DATE_CHANGE2  -  ; date column;
# HIST_DATE_CHANGE3  -  ; date column;
# HIST_DATE_CHANGE4  -  ; date column;
# HIST_DATE_CHANGE5  -  ; date column;
# HIST_DATE_CHANGE6  -  ; date column;
# HIST_DATE_CHANGE7  -  ; date column;
# HIST_DATE_CHANGE8  -  ; date column;
# HIST_DATE_CHANGE9  -  ; date column;
# LAST_UPD_DATE  -  ; date column;
# NDJABANKRUPT  -  ; Only one value presents; Correlation cannot be computed
# NDJACCJ  -  ; Only one value presents; Correlation cannot be computed
# NDJAICH  -  ; Only one value presents; Correlation cannot be computed
# NDJAIVA  -  ; Only one value presents; Correlation cannot be computed
# NDJASECARR  -  ; Only one value presents; Correlation cannot be computed
# NDJAUNSECARR  -  ; Only one value presents; Correlation cannot be computed
# ND_ERL_JACA  -  ; Non-nulls=0; lower than 100% not null values;
# ND_ERL_JAPA  -  ; Non-nulls=0; lower than 100% not null values;
# ND_ERL_MAPA  -  ; Non-nulls=0; lower than 100% not null values;
# ND_FCS_01  -  ; Non-nulls=0; lower than 100% not null values;
# ND_FCS_02  -  ; Non-nulls=0; lower than 100% not null values;
# ND_OPT_OUT  -  ; Only one value presents; Correlation cannot be computed
# ND_OPT_OUT_VALID  -  ; Non-nulls=0; lower than 100% not null values;
# ND_PSD_06  -  ; Only one value presents; Correlation cannot be computed
# OPENDATE  -  ; date column;
# RETRO_DATE  -  ; date column;
# SI_ENDDATE  -  ; date column;
# SI_STARTDATE  -  ; date column;
# STAT30  -  ; Non-nulls=0; lower than 100% not null values;
# STAT31  -  ; Non-nulls=0; lower than 100% not null values;
# STAT32  -  ; Non-nulls=0; lower than 100% not null values;
# STAT33  -  ; Non-nulls=0; lower than 100% not null values;
# STAT34  -  ; Non-nulls=0; lower than 100% not null values;
# STAT35  -  ; Non-nulls=0; lower than 100% not null values;
# STAT36  -  ; Non-nulls=0; lower than 100% not null values;
# STAT37  -  ; Non-nulls=0; lower than 100% not null values;
# STAT38  -  ; Non-nulls=0; lower than 100% not null values;
# STAT39  -  ; Non-nulls=0; lower than 100% not null values;
# STAT40  -  ; Non-nulls=0; lower than 100% not null values;
# STAT41  -  ; Non-nulls=0; lower than 100% not null values;
# STAT42  -  ; Non-nulls=0; lower than 100% not null values;
# STAT43  -  ; Non-nulls=0; lower than 100% not null values;
# STAT44  -  ; Non-nulls=0; lower than 100% not null values;
# STAT45  -  ; Non-nulls=0; lower than 100% not null values;
# STAT46  -  ; Non-nulls=0; lower than 100% not null values;
# STAT47  -  ; Non-nulls=0; lower than 100% not null values;
# STAT48  -  ; Non-nulls=0; lower than 100% not null values;
# STAT49  -  ; Non-nulls=0; lower than 100% not null values;
# STAT50  -  ; Non-nulls=0; lower than 100% not null values;
# STAT51  -  ; Non-nulls=0; lower than 100% not null values;
# STAT52  -  ; Non-nulls=0; lower than 100% not null values;
# STAT53  -  ; Non-nulls=0; lower than 100% not null values;
# STAT54  -  ; Non-nulls=0; lower than 100% not null values;
# STAT55  -  ; Non-nulls=0; lower than 100% not null values;
# STAT56  -  ; Non-nulls=0; lower than 100% not null values;
# STAT57  -  ; Non-nulls=0; lower than 100% not null values;
# STAT58  -  ; Non-nulls=0; lower than 100% not null values;
# STAT59  -  ; Non-nulls=0; lower than 100% not null values;
# STAT60  -  ; Non-nulls=0; lower than 100% not null values;
# STAT61  -  ; Non-nulls=0; lower than 100% not null values;
# STAT62  -  ; Non-nulls=0; lower than 100% not null values;
# STAT63  -  ; Non-nulls=0; lower than 100% not null values;
# STAT64  -  ; Non-nulls=0; lower than 100% not null values;
# STAT65  -  ; Non-nulls=0; lower than 100% not null values;
# STAT66  -  ; Non-nulls=0; lower than 100% not null values;
# STAT67  -  ; Non-nulls=0; lower than 100% not null values;
# STAT68  -  ; Non-nulls=0; lower than 100% not null values;
# STAT69  -  ; Non-nulls=0; lower than 100% not null values;
# STAT70  -  ; Non-nulls=0; lower than 100% not null values;
# STAT71  -  ; Non-nulls=0; lower than 100% not null values;
# STAT72  -  ; Non-nulls=0; lower than 100% not null values;
# SUS_IND  -  ; Non-nulls=0; lower than 100% not null values;
# UNIQUE_ID  -  ; auxiliary column;

# %%
cols_to_ignore = df_info[~df_info.index.isin(CATEGORICAL_COLS_AT_LEAST_2_VAl + NUMERIC_COLS)].index.tolist()

# %% [markdown]
# # IV

# %%
from utils.metrics import Metrics

# %% [markdown]
# ## Categorical

# %%
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)

cat_failed_cols = []
df_iv_categorical = pd.DataFrame()
for i, col in enumerate(CATEGORICAL_COLS_AT_LEAST_2_VAl):
    try:
        m = Metrics()
        df_iv_temp = m.iv_categorical(
            df_actual=df,
            feature_col=col,
            target_col=TARGET_BIN,
            positive_inf_offset=0.003,
            negative_inf_offset=0.003,
        )[0]
        df_iv_categorical = pd.concat((df_iv_categorical, df_iv_temp))
    except Exception as e:
        cat_failed_cols += [(col, e)]

# %%
print('Columns with failed computations: ', cat_failed_cols)
# Out:
# Columns with failed computations:  []

# %% [markdown]
# ## Numerical

# %%
numerical_failed_cols = []
df_iv_numeric = pd.DataFrame()
for i, col in enumerate(NUMERIC_COLS):
    try:
        m = Metrics()
        df_iv_temp = m.iv_numeric(
            df_actual=df,
            feature_col=col,
            target_col=TARGET_BIN,
            n_bins=10,
            positive_inf_offset=0.003,
            negative_inf_offset=0.003,
        )[0]
        df_iv_numeric = pd.concat((df_iv_numeric, df_iv_temp))
    except Exception as e:
        numerical_failed_cols += [(col, e)]

# %%
print('Columns with failed computations: ', numerical_failed_cols)
# Out:
# Columns with failed computations:  []

# %% [markdown]
# ## Add IV to the `df_info`

# %%
print('Shape of `df_info` before merge: ', df_info.shape)
# Out:
# Shape of `df_info` before merge:  (1770, 7)

# %%
df_iv_ignore = pd.DataFrame(
    {
        'Feature': cols_to_ignore,
        'IV': [np.nan] * len(cols_to_ignore)
    }
)

# %%
df_info = df_info.merge(
    pd.concat(
        (
            df_iv_categorical,
            df_iv_numeric,
            df_iv_ignore
        )
    ).set_index('Feature'),
    left_index=True, right_on='Feature', how='outer'
)

# %%
print('Shape of `df_info` after merge: ', df_info.shape)
# Out:
# Shape of `df_info` after merge:  (1770, 8)

# %% [markdown]
# ## Filtering out IV < 0.01

# %%
df_info.loc[df_info.IV < MIN_IV, 'AsFeature'] = '-'
df_info.loc[df_info.IV < MIN_IV, 'Comment'] += f'; IV < {MIN_IV}'

# %%
df_info
# Out:
#                 n_not_null    dtype AsFeature      Comment  %_not_nulls  \
# Feature
# AFF_B_01            110462    int64      None                     100.0
# AFF_B_01_01         110462    int64      None                     100.0
# AFF_B_02            110462    int64      None                     100.0
# AFF_B_02_01         110462    int64      None                     100.0
# AFF_B_03            110462    int64      None                     100.0
# ...                    ...      ...       ...          ...          ...
# VM10_SP_VM2_38      110462    int64         -  ; IV < 0.01        100.0
# VM10_SP_VM2_39      110462   object         -  ; IV < 0.01        100.0
# VM10_SP_VM2_40      110462   object         -  ; IV < 0.01        100.0
# VM10_SP_VM2_41      110462    int64         -  ; IV < 0.01        100.0
# Weight              110462  float64      None                     100.0
#
#                 n_unique_vals _dtype_theoretical        IV
# Feature
# AFF_B_01                36700                Num  0.517484
# AFF_B_01_01             36682                Num  0.516549
# AFF_B_02                28917                Num  0.516760
# AFF_B_02_01             29600                Num  0.518435
# AFF_B_03                 4062                Num  0.517217
# ...                       ...                ...       ...
# VM10_SP_VM2_38              3                Num  0.002136
# VM10_SP_VM2_39              2               Char  0.000827
# VM10_SP_VM2_40              2               Char  0.000827
# VM10_SP_VM2_41              3                Num  0.002136
# Weight                      2                Num  2.601039
#
# [1770 rows x 8 columns]

# %% [markdown]
# # Correlation

# %%
df_info.head()
# Out:
#              n_not_null  dtype AsFeature Comment  %_not_nulls  n_unique_vals  \
# Feature
# AFF_B_01         110462  int64      None                100.0          36700
# AFF_B_01_01      110462  int64      None                100.0          36682
# AFF_B_02         110462  int64      None                100.0          28917
# AFF_B_02_01      110462  int64      None                100.0          29600
# AFF_B_03         110462  int64      None                100.0           4062
#
#             _dtype_theoretical        IV
# Feature
# AFF_B_01                   Num  0.517484
# AFF_B_01_01                Num  0.516549
# AFF_B_02                   Num  0.516760
# AFF_B_02_01                Num  0.518435
# AFF_B_03                   Num  0.517217

# %% [markdown]
# ## Numeric + Categorical (WoE- based)

# %%
def woe(data, col_name, target_col, positive_inf_offset: float = 1.1,
                        negative_inf_offset: float = 1.1) -> float:
    data['_' + col_name] = data[col_name].copy()
    data['_' + col_name] = data['_' + col_name].fillna('Unknown')
    
    data_stats = data.groupby('_' + col_name)[target_col].sum().reset_index(name="n_positive")
    data_stats["n"] = data.groupby('_' + col_name)[target_col].count().values
    data_stats["n_negative"] = data_stats["n"] - data_stats["n_positive"]

    # compute number of positive and negative class in the input data
    n_positive_df = (data[target_col] == 1).sum()
    n_negative_df = (data[target_col] == 0).sum()

    # weight of evidence
    data_stats["woe"] = np.log(
        (data_stats["n_negative"] / n_negative_df) / (data_stats["n_positive"] / n_positive_df)
    )
    # woe smoothing
    try:
        max_woe = max(data_stats[~data_stats['woe'].isin([np.inf, -np.inf, np.nan])].woe)
        max_woe = max_woe * positive_inf_offset
        min_woe = min(data_stats[~data_stats['woe'].isin([np.inf, -np.inf, np.nan])].woe)
        min_woe = min_woe * negative_inf_offset
    except:
        max_woe = positive_inf_offset
        min_woe = negative_inf_offset

    # fill zero division

    data_stats['woe'] = data_stats.woe.replace(np.inf, max_woe).values
    data_stats['woe'] = data_stats.woe.replace(-np.inf, min_woe).values
    data_stats['woe'] = data_stats.woe.replace(np.nan, 0).values
    
    
    assert not data_stats.woe.isin([np.inf, -np.inf]).any(), data_stats[data_stats.woe.isin([np.inf, -np.inf])]
    assert not data_stats.woe.isin([np.nan]).any(), data_stats[data_stats.woe.isin([np.nan])]
    return pd.merge(data[['_' + col_name]], data_stats[['_' + col_name, 'woe']], on='_' + col_name, how='left')['woe'].values

# %%
warnings.filterwarnings("ignore", category=pd.errors.PerformanceWarning)
for col in CATEGORICAL_COLS_AT_LEAST_2_VAl:
    df[col + '_WoE'] = woe(df, col, TARGET_BIN)

# %%
print('If any Nulls in WoE columns: ', not df[[col + '_WoE' for col in CATEGORICAL_COLS_AT_LEAST_2_VAl]].isna().any()[df[[col + '_WoE' for col in CATEGORICAL_COLS_AT_LEAST_2_VAl]].isna().any()].empty)
# Out:
# If any Nulls in WoE columns:  False

# %%
print('If -+ inf in WoE: ', not df[[col + '_WoE' for col in CATEGORICAL_COLS_AT_LEAST_2_VAl]].isin([np.inf, -np.inf]).any()[df[[col + '_WoE' for col in CATEGORICAL_COLS_AT_LEAST_2_VAl]].isin([np.inf, -np.inf]).any()].empty)
# Out:
# If -+ inf in WoE:  False

# %%
print('If any duplicated features: ', not df_info[df_info.index.duplicated()].empty)
# Out:
# If any duplicated features:  False

# %%
for i, col_name in enumerate(CATEGORICAL_COLS_AT_LEAST_2_VAl + NUMERIC_COLS):
    if ('|Corr(' in df_info.loc[col_name, 'Comment']):
        continue
        
    if col_name in CATEGORICAL_COLS_AT_LEAST_2_VAl:
        col = col_name + '_WoE'
    else:
        col = col_name
        
    col_corr = df[
        [elem + '_WoE' for elem in CATEGORICAL_COLS_AT_LEAST_2_VAl] + NUMERIC_COLS
    ].corrwith(df[col], method='pearson', numeric_only=False)

    candidates = list(col_corr[col_corr.abs() >= CORR_PEARSON_CUT_OFF].index)
    woe_candidates = [c for c in candidates if '_WoE' in c]
    numeric_candidates = [c for c in candidates if '_WoE' not in c]
    
    canddidates_names = list(
        df_info.loc[
            [elem[:-4] for elem in woe_candidates] + numeric_candidates, 
            'IV'
        ].index
    )
    canddidates_values = df_info.loc[
        [elem[:-4] for elem in woe_candidates] + numeric_candidates, 
        'IV'
    ].values

    cand_indx = canddidates_values.argmax()

    df_info.loc[canddidates_names[cand_indx], 'AsFeature'] = '+' \
        if (df_info.loc[canddidates_names[cand_indx], 'AsFeature'] == '+') | \
            ((df_info.loc[canddidates_names[cand_indx], 'AsFeature'] is np.nan)) |\
            (df_info.loc[canddidates_names[cand_indx], 'AsFeature'] is None) \
        else '-'
        
    df_info.loc[canddidates_names[cand_indx], 'Comment'] = df_info.loc[canddidates_names[cand_indx], 'Comment'] + (
        '; Correlation checked;' \
            if ('; Correlation checked;' not in df_info.loc[canddidates_names[cand_indx], 'Comment']) & \
                ('|Corr(' not in df_info.loc[canddidates_names[cand_indx], 'Comment']) \
            else ''
    )

    canddidates_names.remove(canddidates_names[cand_indx])
    if len(canddidates_names) > 0:
        for name in canddidates_names:
            df_info.loc[name, 'AsFeature'] = '-'
            df_info.loc[name, 'Comment'] += f';  |Corr({col}, {name})| >= {CORR_PEARSON_CUT_OFF}'

# %%
# preview
df_info.head()
# Out:
#              n_not_null  dtype AsFeature  \
# Feature
# AFF_B_01         110462  int64         -
# AFF_B_01_01      110462  int64         -
# AFF_B_02         110462  int64         -
# AFF_B_02_01      110462  int64         -
# AFF_B_03         110462  int64         -
#
#                                                        Comment  %_not_nulls  \
# Feature
# AFF_B_01     ;  |Corr(AFF_B_02, AFF_B_01)| >= 0.75;  |Corr(...        100.0
# AFF_B_01_01  ;  |Corr(AFF_B_02, AFF_B_01_01)| >= 0.75;  |Co...        100.0
# AFF_B_02     ;  |Corr(AFF_B_02, AFF_B_02)| >= 0.75;  |Corr(...        100.0
# AFF_B_02_01  ;  |Corr(AFF_B_02, AFF_B_02_01)| >= 0.75;  |Co...        100.0
# AFF_B_03     ;  |Corr(AFF_B_02, AFF_B_03)| >= 0.75;  |Corr(...        100.0
#
#              n_unique_vals _dtype_theoretical        IV
# Feature
# AFF_B_01             36700                Num  0.517484
# AFF_B_01_01          36682                Num  0.516549
# AFF_B_02             28917                Num  0.516760
# AFF_B_02_01          29600                Num  0.518435
# AFF_B_03              4062                Num  0.517217

# %%
# reset index for further marging
df_info = df_info.reset_index()

# %%
# check duplication
df_info[df_info.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Feature, n_not_null, dtype, AsFeature, Comment, %_not_nulls, n_unique_vals, _dtype_theoretical, IV]
# Index: []

# %%
# read features with descriptions
df_dict = pd.read_csv(os.path.join(os.path.join('..', "data"), 'Experian - Data Analysis(Sheet1).csv'), encoding='cp1252')

# %%
df_dict[df_dict.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Block, Unnamed: 1, Variable, Label, Classification, Unnamed: 5, Unnamed: 6, Applicability for modelling from the definition, Variable.1, Feature, # not nulls, % not nulls , # unique values, dtype, IV, As Feature
# (based on IV, not null, #unique), Comment, _dtype_theoretical]
# Index: []

# %%
print('Data dict: If duplicates in Variable.1s: ', df_dict[['Variable.1']].duplicated().any(), '<->',df_dict['Variable.1'][df_dict['Variable.1'].duplicated()].values)
# Out:
# Data dict: If duplicates in Variable.1s:  True <-> ['UNIQUE_ID']

# %%
# rename Variable.1s which start with 'SP_EDI' and end with '_01' to merge our dataframe with the dictionary

df_dict['Variable.1'] = [re.sub('_01$', '', col) if re.findall('^SP_EDI', col) != [] else col for col in df_dict['Variable.1']]

# %%
df_dict = pd.merge(df_dict[['Variable.1']], df_info, left_on='Variable.1', right_on='Feature', how='left')

# %%
print('If any duplicated feature after merge: ', df_dict.duplicated().any())

# duplications
print('Duplications:')
pd.concat(
    (
        df_dict[df_dict.duplicated(keep='first')],
        df_dict[df_dict.duplicated(keep='last')]
    )
)
# Out:
# If any duplicated feature after merge:  True
# Duplications:
#      Variable.1    Feature  n_not_null  dtype AsFeature              Comment  \
# 1770  UNIQUE_ID  UNIQUE_ID    110462.0  int64         -  ; auxiliary column;
# 1768  UNIQUE_ID  UNIQUE_ID    110462.0  int64         -  ; auxiliary column;
#
#       %_not_nulls  n_unique_vals _dtype_theoretical  IV
# 1770        100.0       110462.0               Char NaN
# 1768        100.0       110462.0               Char NaN

# %%
# check unmerged features:
df_dict[df_dict.Feature.isna()]
# Out:
#                 Variable.1 Feature  n_not_null dtype AsFeature Comment  \
# 1771  _GB6_Flag_2Limit_bin     NaN         NaN   NaN       NaN     NaN
# 1772                _RDATE     NaN         NaN   NaN       NaN     NaN
# 1773            _RDATE_EOM     NaN         NaN   NaN       NaN     NaN
#
#       %_not_nulls  n_unique_vals _dtype_theoretical  IV
# 1771          NaN            NaN                NaN NaN
# 1772          NaN            NaN                NaN NaN
# 1773          NaN            NaN                NaN NaN

# %%
print('Check if all Variable.1s are processed:')
print('Unique comments with unprocessed `AsFeature:', df_dict[df_dict['AsFeature'].isna()].Comment.unique())
df_dict[
    df_dict['AsFeature'].isna() & 
    df_dict.Comment.isin([np.nan, ''])
]
# Out:
# Check if all Variable.1s are processed:
# Unique comments with unprocessed `AsFeature: [nan]
#                 Variable.1 Feature  n_not_null dtype AsFeature Comment  \
# 1771  _GB6_Flag_2Limit_bin     NaN         NaN   NaN       NaN     NaN
# 1772                _RDATE     NaN         NaN   NaN       NaN     NaN
# 1773            _RDATE_EOM     NaN         NaN   NaN       NaN     NaN
#
#       %_not_nulls  n_unique_vals _dtype_theoretical  IV
# 1771          NaN            NaN                NaN NaN
# 1772          NaN            NaN                NaN NaN
# 1773          NaN            NaN                NaN NaN

# %%
df_dict.to_csv(os.path.join(os.path.join('..', "data"), 'Experian - Data Analysis(Sheet1).csv'), encoding='cp1252')
