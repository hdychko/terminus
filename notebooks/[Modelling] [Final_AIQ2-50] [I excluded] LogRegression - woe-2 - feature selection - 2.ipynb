# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import copy
from typing import (
    Dict, 
    List,
    Any
)

import mlflow
from datetime import datetime


import numpy as np
import pandas as pd

from scipy.stats import uniform
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedShuffleSplit

from joblib import load, dump

import seaborn as sns
import matplotlib.pyplot as plt

# %%
sys.path.append(os.path.join(os.getcwd(), '..'))
from utils.metrics import Metrics
from utils.modelling_tools import (
    search_hyper_params_and_log, 
    update_solver_by_penalty, 
    evaluate_model
)
from utils.metrics_by_quantile import MetricsByQuantile
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %%
RUN_NAME: str = '02-LogRegression-hyperparams_tunning'

# %%
PROJECT_PATH: str = os.path.join(os.getcwd(), '..')
DATA_PATH: str = os.path.join(PROJECT_PATH, 'data')
OPT_BIN_PATH: str = os.path.join(os.path.join(PROJECT_PATH, 'objects'), 'optbinners')
MODELS_PATH: str = os.path.join(os.path.join(PROJECT_PATH, 'objects'), 'models')

# %%
TRAIN_FROM: datetime.date = pd.to_datetime('2021-12-01').date()
TRAIN_TO: datetime.date = pd.to_datetime('2022-01-01').date()

VAL_FROM: datetime.date = pd.to_datetime('2023-01-01').date()
VAL_TO: datetime.date = pd.to_datetime('2023-05-01').date()

TEST_FROM: datetime.date = pd.to_datetime('2023-05-01').date()
TEST_TO: datetime.date = pd.to_datetime('2023-08-01').date()

# %%
# set constants
COLS_TO_USE: List[str] = [
"TRD_A_20OptBin",
"E4_Q_17OptBin",
"TRD_B_20OptBin",
"SP_B2_18OptBin",
"TRD_B_18OptBin",
"ND_ECC_04OptBin",
"OPTIN_11SCN_MLOptBin",
"G5_ND_SPECIIOptBin",
"SP_F2_33OptBin",
"AFF_B_09_01OptBin",
"TRD_A_08OptBin",
"VM01_SP_VM2_15OptBin",
"GEN11_SP_N_92_NotABOptBin",
"GEN11_SP_N_92_IfSoleJointOtherAccOptBin",
"GEN11_SP_N_92_ByTurnoverOptBin",
"GEN11_SP_N_92_ByRPOptBin",
"SP_G_37OptBin",
"TRD_C_07OptBin",
"SPA_F2_33OptBin",
"VM01_SP_VM2_14OptBin",
"VM01_SP_VM2_24OptBin",
"TRD_O_05OptBin",
"E1_A_09OptBin",
"ND_INC_03OptBin",
"VM01_SP_VM2_17OptBin",
"GEN11_SP_N_91OptBin",
"GEN11_SP_EDI_07OptBin",
"ND_ECC_06OptBin",
"EA5_S_01OptBin",
"CLU_CLI_L6M_NPR_L6MOptBin",
"SP_I_63_01OptBin",
"E4_Q_04OptBin",
"EA1_D_02OptBin",
"TRD_O_06OptBin",
"AFF_T_07_01OptBin",
"VM02_SP_VM1_18OptBin",
]

# %%
TARGET_NAME: str = 'GB6_Flag_2Limit'
TARGET_VALS: List[int] = [0, 1]
TARGET_BIN: str = f'_{TARGET_NAME}_bin'
TARGET_BIN_0isB: str = f'_{TARGET_NAME}_bin_0isB'

PALETTE: Dict[str, str] = {
    TARGET_NAME: {
        'G': 'green',
        'B': 'red',
        'I': 'black'
    },
    TARGET_BIN: {0: 'green', 1: 'red'},
    'DataPart': {'Train+Val': 'black', 'Val': 'blue', 'Test': 'red', 'Train': 'orange'}
}

# %%
N_ITER: int = 100
RANDOM_SEED: int = 42
CONFIDENCE_LEVEL = 0.05

# %%
MODEL = LogisticRegression

# %%
PARAMS: Dict[str, Any] = dict(
    penalty=['l2', 'l1', 'elasticnet'], 
    C=uniform(loc=0, scale=20), 
    fit_intercept=[True], 
    class_weight=['balanced'], 
    random_state=[RANDOM_SEED], 
    n_jobs=[-1]
)

# %%
# read data
df: pd.DataFrame = pd.read_csv(os.path.join(DATA_PATH, 'final_aiq2_optbins_neg_sep_I_excl.csv'), low_memory=False)

# %%
print('Number of rows: %.0f; columns: %.0f' % df.shape)
# Out:
# Number of rows: 110462; columns: 2370

# %% [markdown]
# # Preprocessing

# %% [markdown]
# Convert dates to the corresponding types

# %%
for col in ['_RDATE_EOM', '_RDATE']:
    df[col] = pd.to_datetime(df[col]).dt.date

# %%
print('Available date range:')
df['_RDATE'].agg(['min', 'max'])
# Out:
# Available date range:
# min    2021-06-30
# max    2023-11-30
# Name: _RDATE, dtype: object

# %% [markdown]
# Generate Target, where `GB6_Flag_2Limit` in ('I','B') is '1' and GB6_Flag_2Limit in ('G') is '0'

# %%
df[f'_{TARGET_NAME}_bin_0isB'] = df[TARGET_NAME].replace(
    {
        'G': 0,
        'I': 1,
        'B': 1
    }
)
# Out:
# Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`

# %%
pd.merge(
    df[f'_{TARGET_NAME}_bin_0isB'].value_counts().reset_index(name='n'),
    (df[f'_{TARGET_NAME}_bin_0isB'].value_counts(normalize=True) * 100).reset_index(name='%'),
    on=f'_{TARGET_NAME}_bin_0isB', how='outer'
)
# Out:
#    _GB6_Flag_2Limit_bin_0isB      n          %
# 0                          0  99444  90.025529
# 1                          1  11018   9.974471

# %% [markdown]
# # Split data

# %%
df_train = df.loc[
    (df._RDATE >= TRAIN_FROM) &
    (df._RDATE < TRAIN_TO) & 
    (df[TARGET_NAME] != 'I'),
   :
].reset_index(drop=True)

df_train_val = df.loc[
    (df._RDATE >= TRAIN_FROM) &
    (df._RDATE < VAL_TO) &
    (df[TARGET_NAME] != 'I'),
    :
].reset_index(drop=True)

df_val = df.loc[
    (df._RDATE >= VAL_FROM) &
    (df._RDATE < VAL_TO) &
    (df[TARGET_NAME] != 'I'),
    :
].reset_index(drop=True)

df_test_same = df.loc[
    (df._RDATE >= TEST_FROM) &
    (df._RDATE < TEST_TO) &
    (df[TARGET_NAME] != 'I'),
    :
].reset_index(drop=True)

df_test = df.loc[
    (df._RDATE >= TEST_FROM) &
    (df._RDATE < TEST_TO),
    :
].reset_index(drop=True)

# %%
print(f'Distribution of _{TARGET_NAME}_bin_0isB on test')
pd.merge(
    df_test[f'_{TARGET_NAME}_bin_0isB'].value_counts().reset_index(name='n'),
    (df_test[f'_{TARGET_NAME}_bin_0isB'].value_counts(normalize=True) * 100).reset_index(name='%'),
    on=f'_{TARGET_NAME}_bin_0isB', how='outer'
)
# Out:
# Distribution of _GB6_Flag_2Limit_bin_0isB on test
#    _GB6_Flag_2Limit_bin_0isB      n          %
# 0                          0  13663  84.126593
# 1                          1   2578  15.873407

# %%
data_dict = {
    "df_train": df_train,
    "df_val": df_val,
    "df_train_val": df_train_val, 
    "df_test_same": df_test_same,
    "df_test": df_test
}

# %%
# randomly select N observations from test data
N = 10000
sss = StratifiedShuffleSplit(n_splits=1, train_size=N, random_state=RANDOM_SEED)
indx = sss.split(data_dict['df_test_same'].reset_index(drop=True), data_dict['df_test_same'][TARGET_BIN])
random_indx = list(indx)[0][0]

assert len(random_indx) == N, "Incorrect number of elements in the subsample"
test_sample = data_dict['df_test_same'].reset_index(drop=True).iloc[random_indx, :].reset_index(drop=True)

# %%
data_dict['df_test_same_sample'] = test_sample

# %% [markdown]
# # Run the experiment

# %%
mlflow.set_tracking_uri(uri="http://127.0.0.1:8800/")
mlflow.set_experiment("[Experian][Features 2.0]")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/562926978330189002', creation_time=1718121099087, experiment_id='562926978330189002', last_update_time=1718121099087, lifecycle_stage='active', name='[Experian][Features 2.0]', tags={}>

# %%
experiment_description = f"""
    'features': {len(COLS_TO_USE)},
    'target': {TARGET_BIN},
    'target_vals': '0==G, 1==B, 1=I',
    'model': {MODEL.__name__},
    'data_version': '22.05.2024', 
    'train_period': [{TRAIN_FROM.strftime('%Y-%m-%d') + ', ' + TRAIN_TO.strftime('%Y-%m-%d')}),
    'val_period': [{VAL_FROM.strftime('%Y-%m-%d') + ', ' + VAL_TO.strftime('%Y-%m-%d')}),
    'test_period': [{TEST_FROM.strftime('%Y-%m-%d') + ', ' + TEST_TO.strftime('%Y-%m-%d')}),
"""

# %%
print(experiment_description)
# Out:
#     'features': 36,
#     'target': _GB6_Flag_2Limit_bin,
#     'target_vals': '0==G, 1==B, 1=I',
#     'model': LogisticRegression,
#     'data_version': '22.05.2024',
#     'train_period': [2021-12-01, 2022-01-01),
#     'val_period': [2023-01-01, 2023-05-01),
#     'test_period': [2023-05-01, 2023-08-01),

# %%
with mlflow.start_run(run_name=RUN_NAME, log_system_metrics=True):
    res = search_hyper_params_and_log(
        run_name=RUN_NAME,
        data_dict=data_dict,
        cols_to_use=COLS_TO_USE,
        target_name=TARGET_BIN,
        distributions=PARAMS,
        n_iter=N_ITER,
        model=MODEL,
        custom_params_updates=update_solver_by_penalty,
        tags={'features': len(COLS_TO_USE)}, 
        palette=PALETTE['DataPart'],
        test_name='df_test_same',
        model_path=MODELS_PATH
    )
# Out:
# 2024/06/12 18:43:16 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/12 18:43:16 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# # 1 / 100
# # 2 / 100
# 2024/06/12 18:43:16 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/12 18:43:16 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:43:25 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:43:25 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 3 / 100
# # 4 / 100
# 2024/06/12 18:43:27 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/12 18:43:27 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:43:33 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:43:33 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 5 / 100
# # 6 / 100
# 2024/06/12 18:43:33 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# # 7 / 100
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/12 18:43:33 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:43:39 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:43:39 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 2024/06/12 18:43:39 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# # 8 / 100
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/12 18:43:39 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:43:45 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:43:45 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 2024/06/12 18:43:45 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# # 9 / 100
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/12 18:43:45 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:43:51 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:43:51 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 10 / 100
# # 11 / 100
# # 12 / 100
# 2024/06/12 18:43:52 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/12 18:43:52 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:43:58 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:43:58 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 13 / 100
# # 14 / 100
# 2024/06/12 18:43:58 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/12 18:43:58 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:44:04 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:44:04 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 15 / 100
# 2024/06/12 18:44:05 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/12 18:44:05 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:44:11 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:44:11 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 2024/06/12 18:44:11 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# # 16 / 100
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/12 18:44:11 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:44:17 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:44:17 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 17 / 100
# # 18 / 100
# # 19 / 100
# # 20 / 100
# 2024/06/12 18:44:17 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/12 18:44:17 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:44:23 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:44:23 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 21 / 100
# # 22 / 100
# # 23 / 100
# # 24 / 100
# 2024/06/12 18:44:24 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# # 25 / 100
# Exception in thread 2024/06/12 18:44:24 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:44:30 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:44:30 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 26 / 100
# # 27 / 100
# # 28 / 100
# 2024/06/12 18:44:31 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/12 18:44:31 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:44:37 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:44:37 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 29 / 100
# 2024/06/12 18:44:38 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/12 18:44:38 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:44:44 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:44:44 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 30 / 100
# # 31 / 100
# 2024/06/12 18:44:45 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/12 18:44:45 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:44:51 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:44:51 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 32 / 100
# # 33 / 100
# 2024/06/12 18:44:51 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/12 18:44:51 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:44:57 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:44:57 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 34 / 100
# # 35 / 100
# # 36 / 100
# # 37 / 100
# # 38 / 100
# # 39 / 100
# # 40 / 100
# 2024/06/12 18:44:59 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/12 18:44:59 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:45:05 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:45:05 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 41 / 100
# # 42 / 100
# # 43 / 100
# # 44 / 100
# # 45 / 100
# # 46 / 100
# # 47 / 100
# 2024/06/12 18:45:09 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/12 18:45:09 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:45:15 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:45:15 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 48 / 100
# # 49 / 100
# 2024/06/12 18:45:15 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/12 18:45:15 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:45:21 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:45:21 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 50 / 100
# # 51 / 100
# # 52 / 100
# # 53 / 100
# # 54 / 100
# # 55 / 100
# # 56 / 100
# # 57 / 100
# 2024/06/12 18:45:25 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/12 18:45:25 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:45:31 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:45:31 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 58 / 100
# 2024/06/12 18:45:31 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/12 18:45:31 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:45:37 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:45:37 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 59 / 100
# 2024/06/12 18:45:39 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/12 18:45:39 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:45:45 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:45:45 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 60 / 100
# # 61 / 100
# # 62 / 100
# # 63 / 100
# # 64 / 100
# # 65 / 100
# # 66 / 100
# # 67 / 100
# 2024/06/12 18:45:47 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/12 18:45:47 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:45:53 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:45:53 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 68 / 100
# # 69 / 100
# # 70 / 100
# # 71 / 100
# # 72 / 100
# 2024/06/12 18:45:55 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/12 18:45:55 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
# ...
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:46:35 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:46:35 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 88 / 100
# 2024/06/12 18:46:37 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/12 18:46:37 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:46:43 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:46:43 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 89 / 100
# # 90 / 100
# # 91 / 100
# # 92 / 100
# 2024/06/12 18:46:44 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/12 18:46:44 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:46:50 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:46:50 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 93 / 100
# # 94 / 100
# # 95 / 100
# 2024/06/12 18:46:51 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/12 18:46:51 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:46:57 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:46:57 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 96 / 100
# # 97 / 100
# 2024/06/12 18:46:57 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/12 18:46:57 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:47:03 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:47:03 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 98 / 100
# 2024/06/12 18:47:03 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/12 18:47:03 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:47:10 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:47:10 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 99 / 100
# 2024/06/12 18:47:10 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/12 18:47:10 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:47:16 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:47:16 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 100 / 100
# 2024/06/12 18:47:16 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/12 18:47:16 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/12 18:47:22 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:47:22 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# Best params:
#  {'penalty': 'l1', 'C': 13.926085456795768, 'fit_intercept': True, 'class_weight': 'balanced', 'random_state': 42, 'n_jobs': -1, 'solver': 'liblinear'}
# Val-PR_AUC:  0.1196669956341139
# Val-GINI:  0.4812272590287463
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# Not saved
# Test-PR_AUC 0.22226722127014278
# Test-Gini 0.568245629070117
# The option feature_dependence has been renamed to feature_perturbation!
# The feature_perturbation option is now deprecated in favor of using the appropriate masker (maskers.Independent, or maskers.Impute)
# 2024/06/12 18:47:46 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/12 18:47:46 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!

# %%
df_metrics, df_coeff, data_dict, model_obj, std_scaler = res

# %% [markdown]
# # Model's quality

# %% [markdown]
# ## Coefficients

# %%
df_coeff.sort_values('Importance(%)', ascending=False)
# Out:
#                                     Feature     Coeff  Importance(%)  \
# 19                     OPTIN_11SCN_MLOptBin -1.124315      22.655064
# 15                                Intercept -0.911466      18.366135
# 20                          SPA_F2_33OptBin -0.200578       4.041677
# 8                        G5_ND_SPECIIOptBin -0.198212       3.993987
# 24                         SP_I_63_01OptBin -0.164005       3.304712
# 17                          ND_ECC_06OptBin  0.163604       3.296641
# 29                           TRD_C_07OptBin -0.154986       3.122974
# 14                GEN11_SP_N_92_NotABOptBin -0.141919       2.859679
# 7                            EA5_S_01OptBin -0.129521       2.609861
# 9                     GEN11_SP_EDI_07OptBin  0.123257       2.483647
# 32                     VM01_SP_VM2_14OptBin  0.114815       2.313528
# 23                            SP_G_37OptBin -0.114668       2.310575
# 34                     VM01_SP_VM2_17OptBin -0.104741       2.110538
# 16                          ND_ECC_04OptBin -0.102947       2.074387
# 22                           SP_F2_33OptBin  0.094337       1.900905
# 10                      GEN11_SP_N_91OptBin -0.092345       1.860758
# 31                           TRD_O_06OptBin  0.089661       1.806678
# 33                     VM01_SP_VM2_15OptBin -0.082453       1.661427
# 12           GEN11_SP_N_92_ByTurnoverOptBin  0.074167       1.494463
# 27                           TRD_B_18OptBin  0.063879       1.287167
# 3                             E1_A_09OptBin  0.061867       1.246617
# 21                           SP_B2_18OptBin -0.059317       1.195249
# 30                           TRD_O_05OptBin -0.058231       1.173361
# 5                             E4_Q_17OptBin  0.055984       1.128075
# 0                         AFF_B_09_01OptBin -0.052047       1.048762
# 11                 GEN11_SP_N_92_ByRPOptBin  0.051630       1.040347
# 1                         AFF_T_07_01OptBin  0.048306       0.973369
# 4                             E4_Q_04OptBin -0.044658       0.899864
# 25                           TRD_A_08OptBin -0.038687       0.779549
# 13  GEN11_SP_N_92_IfSoleJointOtherAccOptBin -0.035418       0.713681
# 18                          ND_INC_03OptBin  0.031972       0.644240
# 2                 CLU_CLI_L6M_NPR_L6MOptBin -0.031727       0.639303
# 35                     VM01_SP_VM2_24OptBin -0.031196       0.628608
# 6                            EA1_D_02OptBin -0.030529       0.615161
# 36                     VM02_SP_VM1_18OptBin -0.029342       0.591254
# 28                           TRD_B_20OptBin  0.028943       0.583198
# 26                           TRD_A_20OptBin -0.027025       0.544559
#
#          p-value  Importance(SHAP)  Importance(SHAP, %)
# 19  0.000000e+00          1.441414            49.152222
# 15  0.000000e+00               NaN                  NaN
# 20  0.000000e+00          0.127190             4.337181
# 8   0.000000e+00          0.232997             7.945199
# 24  0.000000e+00          0.057845             1.972527
# 17  0.000000e+00          0.097036             3.308916
# 29  0.000000e+00          0.084585             2.884353
# 14  0.000000e+00          0.037408             1.275620
# 7   0.000000e+00          0.062713             2.138512
# 9   1.811218e-12          0.060978             2.079351
# 32  0.000000e+00          0.061628             2.101532
# 23  0.000000e+00          0.088798             3.028028
# 34  5.975258e-10          0.061785             2.106884
# 16  0.000000e+00          0.011138             0.379817
# 22  4.152919e-07          0.085719             2.923029
# 10  6.344059e-07          0.055870             1.905175
# 31  1.010303e-13          0.022419             0.764484
# 33  1.052592e-06          0.079200             2.700704
# 12  1.527750e-09          0.004780             0.162986
# 27  1.713745e-07          0.017408             0.593629
# 3   1.985267e-07          0.025858             0.881750
# 21  2.741984e-05          0.024599             0.838821
# 30  2.197779e-06          0.005814             0.198242
# 5   3.936732e-07          0.002029             0.069200
# 0   1.290714e-02          0.053330             1.818568
# 11  4.018963e-04          0.001204             0.041067
# 1   4.112700e-05          0.011489             0.391764
# 4   7.736401e-04          0.017860             0.609023
# 25  4.398758e-03          0.033865             1.154801
# 13  3.573721e-03          0.004083             0.139232
# 18  1.634284e-02          0.017662             0.602274
# 2   1.126909e-03          0.000751             0.025615
# 35  2.008398e-02          0.013773             0.469650
# 6   3.043610e-03          0.006289             0.214441
# 36  1.460723e-02          0.010281             0.350566
# 28  1.896217e-02          0.011861             0.404465
# 26  4.495534e-03          0.000891             0.030374

# %%
# features with 0 coefficients
df_coeff[df_coeff.Coeff == 0]
# Out:
# Empty DataFrame
# Columns: [Feature, Coeff, Importance(%), p-value, Importance(SHAP), Importance(SHAP, %)]
# Index: []

# %%
# features with high p-value
df_coeff[df_coeff['p-value'] > CONFIDENCE_LEVEL]
# Out:
# Empty DataFrame
# Columns: [Feature, Coeff, Importance(%), p-value, Importance(SHAP), Importance(SHAP, %)]
# Index: []

# %%
model_obj
# Out:
# LogisticRegression(C=13.926085456795768, class_weight='balanced', n_jobs=-1,
#                    penalty='l1', random_state=42, solver='liblinear')

# %%
with open(os.path.join(MODELS_PATH, '[Model][Modelling] [Final_AIQ2-50] [I excluded] LogRegression - woe-2 - feature selection - 2 (final).jblb'), 'wb') as f:
    dump(model_obj, f)

# %%
with open(os.path.join(MODELS_PATH, '[StdScaler][Modelling] [Final_AIQ2-50] [I excluded] LogRegression - woe-2 - feature selection - 2 (final).jblb'), 'wb') as f:
    dump(std_scaler, f)

# %% [markdown]
# ## GINI, AU PRC

# %% [markdown]
# ## Test-same

# %%
evaluate_model(
    data=data_dict['df_test_same'], 
    cols_to_use=COLS_TO_USE,
    std_scaler=std_scaler,
    target_name=TARGET_BIN,
    model_obj=model_obj
)
# Out:
# Test-PR_AUC 0.22226722127014278
# Test-Gini 0.568245629070117

# %% [markdown]
# ## Test-full

# %% [markdown]
# ### 'I' is 0

# %%
evaluate_model(
    data=data_dict['df_test'], 
    cols_to_use=COLS_TO_USE,
    std_scaler=std_scaler,
    target_name=TARGET_BIN,
    model_obj=model_obj
)
# Out:
# Test-PR_AUC 0.18897241666707676
# Test-Gini 0.5318380757296939

# %% [markdown]
# ### 'I' is 1

# %%
evaluate_model(
    data=data_dict['df_test'], 
    cols_to_use=COLS_TO_USE,
    std_scaler=std_scaler,
    target_name=TARGET_BIN_0isB,
    model_obj=model_obj
)
# Out:
# Test-PR_AUC 0.3266541506844922
# Test-Gini 0.5119091914780975

# %% [markdown]
# ## Outcomes distributions

# %%
data_dict['df_test']['score'] = model_obj.predict_proba(
    std_scaler.transform(data_dict['df_test'][COLS_TO_USE])
)[:, 1]
data_dict['df_test_same']['score'] = model_obj.predict_proba(
    std_scaler.transform(data_dict['df_test_same'][COLS_TO_USE])
)[:, 1]

# %% [markdown]
# ### Test-same

# %%
sns.histplot(x=data_dict['df_test_same']['score'], hue=data_dict['df_test_same'][TARGET_BIN], common_norm=False, stat='density')
# Out:
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# <Axes: xlabel='score', ylabel='Density'>

# %% [markdown]
# ### Test-full

# %% [markdown]
# ### 'I' is 0

# %%
sns.histplot(x=data_dict['df_test']['score'], hue=data_dict['df_test'][TARGET_BIN], common_norm=False, stat='density')
# Out:
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# <Axes: xlabel='score', ylabel='Density'>

# %% [markdown]
# ### 'I' is 1

# %%
sns.histplot(x=data_dict['df_test']['score'], hue=data_dict['df_test'][TARGET_BIN_0isB], common_norm=False, stat='density')
# Out:
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# <Axes: xlabel='score', ylabel='Density'>

# %% [markdown]
# ## Precision, Recall By Quantile

# %% [markdown]
# ### Test-same

# %%
m = MetricsByQuantile(metrics=["quantiles_analytics"])
r = m.compute(
    y_true=data_dict['df_test_same'][TARGET_BIN].reset_index(drop=True), 
    y_pred=data_dict['df_test_same']['score'].round(3).reset_index(drop=True), 
    list_of_metrics = [
        "cum_precision_by_quantile", "cum_recall_by_quantile", 
        "precision_by_quantile", "recall_by_quantile",
    ], 
    n_quantiles = 200
)
df_deciles = r["other"]["quantiles_analytics"]
df_deciles.head(50)
# Out:
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#     % of total population  Cumulative % of total population  Total  Bad  \
# 0                    0.49                              0.49     74   23
# 1                    0.44                              0.93     66   24
# 2                    0.52                              1.45     78   18
# 3                    0.52                              1.97     78   18
# 4                    0.47                              2.45     71   26
# 5                    0.53                              2.97     79   22
# 6                    0.47                              3.44     70   18
# 7                    0.47                              3.91     70   16
# 8                    0.47                              4.38     71   18
# 9                    0.52                              4.90     78   22
# 10                   0.52                              5.42     78   14
# 11                   0.57                              5.99     85   23
# 12                   0.39                              6.38     59   20
# 13                   0.51                              6.89     77   17
# 14                   0.45                              7.35     68    9
# 15                   0.59                              7.94     89   35
# 16                   0.45                              8.39     67   12
# 17                   0.45                              8.84     68   20
# 18                   0.55                              9.40     83   23
# 19                   0.51                              9.91     77   16
# 20                   0.52                             10.43     78   14
# 21                   0.57                             11.00     85   22
# 22                   0.49                             11.48     73   11
# 23                   0.47                             11.96     71   15
# 24                   0.43                             12.39     65    8
# 25                   0.50                             12.89     75   12
# 26                   0.61                             13.50     91   16
# 27                   0.42                             13.92     63   11
# 28                   0.50                             14.42     75   12
# 29                   0.51                             14.92     76   10
# 30                   0.44                             15.36     66   12
# 31                   0.64                             16.00     96   20
# 32                   0.43                             16.44     65   13
# 33                   0.55                             16.98     82   13
# 34                   0.51                             17.50     77   17
# 35                   0.41                             17.90     61   12
# 36                   0.47                             18.38     71   14
# 37                   0.53                             18.91     80   12
# 38                   0.53                             19.44     79   15
# 39                   0.55                             19.98     82   17
# 40                   0.42                             20.40     63   10
# 41                   0.59                             20.99     88   13
# 42                   0.41                             21.40     61   12
# 43                   0.60                             22.00     90    8
# 44                   0.49                             22.48     73   13
# 45                   0.46                             22.94     69    8
# 46                   0.47                             23.41     70    5
# 47                   0.58                             23.99     87   15
# 48                   0.48                             24.47     72    7
# 49                   0.49                             24.96     74   12
#
#     Cumulative Bad        Quantile  #Quantile  Cumulative Precision  \
# 0               23   (0.89, 0.938]        200             31.081081
# 1               47   (0.877, 0.89]        199             33.571429
# 2               65  (0.869, 0.877]        198             29.816514
# 3               83  (0.862, 0.869]        197             28.040541
# 4              109  (0.856, 0.862]        196             29.700272
# 5              131  (0.849, 0.856]        195             29.372197
# 6              149  (0.845, 0.849]        194             28.875969
# 7              165   (0.84, 0.845]        193             28.156997
# 8              183   (0.836, 0.84]        192             27.853881
# 9              205  (0.832, 0.836]        191             27.891156
# 10             219  (0.828, 0.832]        190             26.937269
# 11             242  (0.824, 0.828]        189             26.948775
# 12             262  (0.821, 0.824]        188             27.377220
# 13             279  (0.817, 0.821]        187             26.982592
# 14             288  (0.813, 0.817]        186             26.134301
# 15             323  (0.809, 0.813]        185             27.120067
# 16             335  (0.806, 0.809]        184             26.629571
# 17             355  (0.803, 0.806]        183             26.772247
# 18             378    (0.8, 0.803]        182             26.827537
# 19             394    (0.796, 0.8]        181             26.514132
# 20             408  (0.793, 0.796]        180             26.086957
# 21             430  (0.788, 0.793]        179             26.076410
# 22             441  (0.784, 0.788]        178             25.609756
# 23             456  (0.781, 0.784]        177             25.432236
# 24             464  (0.778, 0.781]        176             24.973089
# 25             476  (0.774, 0.778]        175             24.624935
# 26             492   (0.77, 0.774]        174             24.308300
# 27             503   (0.767, 0.77]        173             24.101581
# 28             515  (0.764, 0.767]        172             23.820537
# 29             525  (0.761, 0.764]        171             23.458445
# 30             537  (0.758, 0.761]        170             23.307292
# 31             557  (0.755, 0.758]        169             23.208333
# 32             570  (0.751, 0.755]        168             23.123732
# 33             583  (0.747, 0.751]        167             22.889674
# 34             600  (0.743, 0.747]        166             22.865854
# 35             612   (0.74, 0.743]        165             22.793296
# 36             626   (0.736, 0.74]        164             22.714078
# 37             638  (0.732, 0.736]        163             22.496474
# 38             653  (0.728, 0.732]        162             22.401372
# 39             670  (0.724, 0.728]        161             22.355689
# 40             680  (0.721, 0.724]        160             22.222222
# 41             693  (0.716, 0.721]        159             22.013977
# 42             705  (0.713, 0.716]        158             21.969461
# 43             713  (0.708, 0.713]        157             21.612610
# 44             726  (0.704, 0.708]        156             21.530249
# 45             734  (0.699, 0.704]        155             21.331008
# 46             739  (0.694, 0.699]        154             21.048134
# 47             754  (0.689, 0.694]        153             20.956087
# 48             761  (0.684, 0.689]        152             20.735695
# 49             773  (0.679, 0.684]        151             20.646368
#
#     Cumulative Recall  Precision    Recall        Scores
# 0            1.724138  31.081081  1.724138   0.89--0.938
# 1            3.523238  36.363636  1.799100   0.877--0.89
# 2            4.872564  23.076923  1.349325  0.869--0.877
# 3            6.221889  23.076923  1.349325  0.862--0.869
# 4            8.170915  36.619718  1.949025  0.856--0.862
# 5            9.820090  27.848101  1.649175  0.849--0.856
# 6           11.169415  25.714286  1.349325  0.845--0.849
# 7           12.368816  22.857143  1.199400   0.84--0.845
# 8           13.718141  25.352113  1.349325   0.836--0.84
# 9           15.367316  28.205128  1.649175  0.832--0.836
# 10          16.416792  17.948718  1.049475  0.828--0.832
# 11          18.140930  27.058824  1.724138  0.824--0.828
# 12          19.640180  33.898305  1.499250  0.821--0.824
# 13          20.914543  22.077922  1.274363  0.817--0.821
# 14          21.589205  13.235294  0.674663  0.813--0.817
# 15          24.212894  39.325843  2.623688  0.809--0.813
# 16          25.112444  17.910448  0.899550  0.806--0.809
# 17          26.611694  29.411765  1.499250  0.803--0.806
# 18          28.335832  27.710843  1.724138    0.8--0.803
# 19          29.535232  20.779221  1.199400    0.796--0.8
# 20          30.584708  17.948718  1.049475  0.793--0.796
# 21          32.233883  25.882353  1.649175  0.788--0.793
# 22          33.058471  15.068493  0.824588  0.784--0.788
# 23          34.182909  21.126761  1.124438  0.781--0.784
# 24          34.782609  12.307692  0.599700  0.778--0.781
# 25          35.682159  16.000000  0.899550  0.774--0.778
# 26          36.881559  17.582418  1.199400   0.77--0.774
# 27          37.706147  17.460317  0.824588   0.767--0.77
# 28          38.605697  16.000000  0.899550  0.764--0.767
# 29          39.355322  13.157895  0.749625  0.761--0.764
# 30          40.254873  18.181818  0.899550  0.758--0.761
# 31          41.754123  20.833333  1.499250  0.755--0.758
# 32          42.728636  20.000000  0.974513  0.751--0.755
# 33          43.703148  15.853659  0.974513  0.747--0.751
# 34          44.977511  22.077922  1.274363  0.743--0.747
# 35          45.877061  19.672131  0.899550   0.74--0.743
# 36          46.926537  19.718310  1.049475   0.736--0.74
# 37          47.826087  15.000000  0.899550  0.732--0.736
# 38          48.950525  18.987342  1.124438  0.728--0.732
# 39          50.224888  20.731707  1.274363  0.724--0.728
# 40          50.974513  15.873016  0.749625  0.721--0.724
# 41          51.949025  14.772727  0.974513  0.716--0.721
# 42          52.848576  19.672131  0.899550  0.713--0.716
# 43          53.448276   8.888889  0.599700  0.708--0.713
# 44          54.422789  17.808219  0.974513  0.704--0.708
# 45          55.022489  11.594203  0.599700  0.699--0.704
# 46          55.397301   7.142857  0.374813  0.694--0.699
# 47          56.521739  17.241379  1.124438  0.689--0.694
# 48          57.046477   9.722222  0.524738  0.684--0.689
# 49          57.946027  16.216216  0.899550  0.679--0.684

# %%
df_deciles.to_csv('lr_metrics_by_quantile_test_same.csv')

# %% [markdown]
# ### Test-full

# %% [markdown]
# ### 'I' is 0

# %%
m = MetricsByQuantile(metrics=["quantiles_analytics"])
r = m.compute(
    y_true=data_dict['df_test'][TARGET_BIN].reset_index(drop=True), 
    y_pred=data_dict['df_test']['score'].round(3).reset_index(drop=True), 
    list_of_metrics = [
        "cum_precision_by_quantile", "cum_recall_by_quantile", 
        "precision_by_quantile", "recall_by_quantile",
    ], 
    n_quantiles = 200
)
df_deciles = r["other"]["quantiles_analytics"]
df_deciles.head(50)
# Out:
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#     % of total population  Cumulative % of total population  Total  Bad  \
# 0                    0.50                              0.50     81   22
# 1                    0.50                              1.00     82   25
# 2                    0.46                              1.47     75   15
# 3                    0.50                              1.96     81   15
# 4                    0.54                              2.50     87   16
# 5                    0.49                              2.99     80   23
# 6                    0.48                              3.47     78   22
# 7                    0.53                              4.00     86   13
# 8                    0.44                              4.45     72   14
# 9                    0.50                              4.94     81   18
# 10                   0.46                              5.41     75   16
# 11                   0.55                              5.96     90   18
# 12                   0.44                              6.40     72   12
# 13                   0.60                              7.00     97   26
# 14                   0.49                              7.49     80   21
# 15                   0.42                              7.91     68    7
# 16                   0.57                              8.48     93   23
# 17                   0.47                              8.96     77   21
# 18                   0.47                              9.43     76   16
# 19                   0.53                              9.96     86   20
# 20                   0.39                             10.35     64   15
# 21                   0.57                             10.92     92   16
# 22                   0.55                             11.47     90   14
# 23                   0.49                             11.96     80   18
# 24                   0.42                             12.38     68   10
# 25                   0.60                             12.98     97   18
# 26                   0.49                             13.47     79    5
# 27                   0.39                             13.86     64   11
# 28                   0.58                             14.44     94   14
# 29                   0.49                             14.93     79   13
# 30                   0.48                             15.41     78   10
# 31                   0.49                             15.89     79   10
# 32                   0.59                             16.48     96   13
# 33                   0.46                             16.94     75   12
# 34                   0.53                             17.47     86   15
# 35                   0.46                             17.93     74   13
# 36                   0.56                             18.49     91   13
# 37                   0.42                             18.92     69   17
# 38                   0.55                             19.46     89   12
# 39                   0.49                             19.96     80   14
# 40                   0.55                             20.50     89   12
# 41                   0.40                             20.90     65   13
# 42                   0.54                             21.44     87   15
# 43                   0.38                             21.82     62   10
# 44                   0.61                             22.43     99   11
# 45                   0.51                             22.94     83   14
# 46                   0.55                             23.50     90    8
# 47                   0.49                             23.98     79    8
# 48                   0.47                             24.45     76   13
# 49                   0.53                             24.98     86    5
#
#     Cumulative Bad        Quantile  #Quantile  Cumulative Precision  \
# 0               22  (0.891, 0.938]        200             27.160494
# 1               47  (0.878, 0.891]        199             28.834356
# 2               62  (0.871, 0.878]        198             26.050420
# 3               77  (0.865, 0.871]        197             24.137931
# 4               93  (0.859, 0.865]        196             22.906404
# 5              116  (0.853, 0.859]        195             23.868313
# 6              138  (0.848, 0.853]        194             24.468085
# 7              151  (0.844, 0.848]        193             23.230769
# 8              165   (0.84, 0.844]        192             22.853186
# 9              183   (0.836, 0.84]        191             22.789539
# 10             199  (0.833, 0.836]        190             22.665148
# 11             217  (0.829, 0.833]        189             22.417355
# 12             229  (0.826, 0.829]        188             22.019231
# 13             255  (0.822, 0.826]        187             22.427441
# 14             276  (0.818, 0.822]        186             22.678718
# 15             283  (0.815, 0.818]        185             22.023346
# 16             306  (0.811, 0.815]        184             22.206096
# 17             327  (0.808, 0.811]        183             22.474227
# 18             343  (0.805, 0.808]        182             22.403658
# 19             363  (0.802, 0.805]        181             22.448980
# 20             378    (0.8, 0.802]        180             22.486615
# 21             394    (0.796, 0.8]        179             22.222222
# 22             408  (0.793, 0.796]        178             21.900161
# 23             426  (0.789, 0.793]        177             21.924858
# 24             436  (0.786, 0.789]        176             21.680756
# 25             454  (0.782, 0.786]        175             21.537002
# 26             459  (0.779, 0.782]        174             20.987654
# 27             470  (0.776, 0.779]        173             20.879609
# 28             484  (0.772, 0.776]        172             20.639659
# 29             497  (0.769, 0.772]        171             20.503300
# 30             507  (0.766, 0.769]        170             20.263789
# 31             517  (0.763, 0.766]        169             20.030996
# 32             530   (0.76, 0.763]        168             19.798282
# 33             542   (0.757, 0.76]        167             19.694767
# 34             557  (0.754, 0.757]        166             19.626498
# 35             570  (0.751, 0.754]        165             19.574176
# 36             583  (0.747, 0.751]        164             19.413919
# 37             600  (0.744, 0.747]        163             19.531250
# 38             612   (0.74, 0.744]        162             19.360962
# 39             626   (0.736, 0.74]        161             19.315026
# 40             638  (0.733, 0.736]        160             19.159159
# 41             651  (0.729, 0.733]        159             19.175258
# 42             666  (0.725, 0.729]        158             19.126939
# 43             676  (0.722, 0.725]        157             19.074492
# 44             687  (0.718, 0.722]        156             18.858084
# 45             701  (0.714, 0.718]        155             18.813741
# 46             709   (0.71, 0.714]        154             18.579665
# 47             717   (0.706, 0.71]        153             18.408216
# 48             730  (0.702, 0.706]        152             18.383279
# 49             735  (0.696, 0.702]        151             18.116835
#
#     Cumulative Recall  Precision    Recall        Scores
# 0            1.649175  27.160494  1.649175  0.891--0.938
# 1            3.523238  30.487805  1.874063  0.878--0.891
# 2            4.647676  20.000000  1.124438  0.871--0.878
# 3            5.772114  18.518519  1.124438  0.865--0.871
# 4            6.971514  18.390805  1.199400  0.859--0.865
# 5            8.695652  28.750000  1.724138  0.853--0.859
# 6           10.344828  28.205128  1.649175  0.848--0.853
# 7           11.319340  15.116279  0.974513  0.844--0.848
# 8           12.368816  19.444444  1.049475   0.84--0.844
# 9           13.718141  22.222222  1.349325   0.836--0.84
# 10          14.917541  21.333333  1.199400  0.833--0.836
# 11          16.266867  20.000000  1.349325  0.829--0.833
# 12          17.166417  16.666667  0.899550  0.826--0.829
# 13          19.115442  26.804124  1.949025  0.822--0.826
# 14          20.689655  26.250000  1.574213  0.818--0.822
# 15          21.214393  10.294118  0.524738  0.815--0.818
# 16          22.938531  24.731183  1.724138  0.811--0.815
# 17          24.512744  27.272727  1.574213  0.808--0.811
# 18          25.712144  21.052632  1.199400  0.805--0.808
# 19          27.211394  23.255814  1.499250  0.802--0.805
# 20          28.335832  23.437500  1.124438    0.8--0.802
# 21          29.535232  17.391304  1.199400    0.796--0.8
# 22          30.584708  15.555556  1.049475  0.793--0.796
# 23          31.934033  22.500000  1.349325  0.789--0.793
# 24          32.683658  14.705882  0.749625  0.786--0.789
# 25          34.032984  18.556701  1.349325  0.782--0.786
# 26          34.407796   6.329114  0.374813  0.779--0.782
# 27          35.232384  17.187500  0.824588  0.776--0.779
# 28          36.281859  14.893617  1.049475  0.772--0.776
# 29          37.256372  16.455696  0.974513  0.769--0.772
# 30          38.005997  12.820513  0.749625  0.766--0.769
# 31          38.755622  12.658228  0.749625  0.763--0.766
# 32          39.730135  13.541667  0.974513   0.76--0.763
# 33          40.629685  16.000000  0.899550   0.757--0.76
# 34          41.754123  17.441860  1.124438  0.754--0.757
# 35          42.728636  17.567568  0.974513  0.751--0.754
# 36          43.703148  14.285714  0.974513  0.747--0.751
# 37          44.977511  24.637681  1.274363  0.744--0.747
# 38          45.877061  13.483146  0.899550   0.74--0.744
# 39          46.926537  17.500000  1.049475   0.736--0.74
# 40          47.826087  13.483146  0.899550  0.733--0.736
# 41          48.800600  20.000000  0.974513  0.729--0.733
# 42          49.925037  17.241379  1.124438  0.725--0.729
# 43          50.674663  16.129032  0.749625  0.722--0.725
# 44          51.499250  11.111111  0.824588  0.718--0.722
# 45          52.548726  16.867470  1.049475  0.714--0.718
# 46          53.148426   8.888889  0.599700   0.71--0.714
# 47          53.748126  10.126582  0.599700   0.706--0.71
# 48          54.722639  17.105263  0.974513  0.702--0.706
# 49          55.097451   5.813953  0.374813  0.696--0.702

# %%
df_deciles.to_csv('lr_metrics_by_quantile_test_Iis0).csv')

# %% [markdown]
# ### 'I' is 1

# %%
m = MetricsByQuantile(metrics=["quantiles_analytics"])
r = m.compute(
    y_true=data_dict['df_test'][TARGET_BIN_0isB].reset_index(drop=True), 
    y_pred=data_dict['df_test']['score'].round(3).reset_index(drop=True), 
    list_of_metrics = [
        "cum_precision_by_quantile", "cum_recall_by_quantile", 
        "precision_by_quantile", "recall_by_quantile",
    ], 
    n_quantiles = 200
)
df_deciles = r["other"]["quantiles_analytics"]
df_deciles.head(50)
# Out:
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#     % of total population  Cumulative % of total population  Total  Bad  \
# 0                    0.50                              0.50     81   34
# 1                    0.50                              1.00     82   36
# 2                    0.46                              1.47     75   34
# 3                    0.50                              1.96     81   29
# 4                    0.54                              2.50     87   38
# 5                    0.49                              2.99     80   34
# 6                    0.48                              3.47     78   38
# 7                    0.53                              4.00     86   29
# 8                    0.44                              4.45     72   29
# 9                    0.50                              4.94     81   28
# 10                   0.46                              5.41     75   33
# 11                   0.55                              5.96     90   26
# 12                   0.44                              6.40     72   19
# 13                   0.60                              7.00     97   44
# 14                   0.49                              7.49     80   31
# 15                   0.42                              7.91     68   18
# 16                   0.57                              8.48     93   38
# 17                   0.47                              8.96     77   28
# 18                   0.47                              9.43     76   27
# 19                   0.53                              9.96     86   35
# 20                   0.39                             10.35     64   22
# 21                   0.57                             10.92     92   31
# 22                   0.55                             11.47     90   26
# 23                   0.49                             11.96     80   31
# 24                   0.42                             12.38     68   20
# 25                   0.60                             12.98     97   34
# 26                   0.49                             13.47     79   14
# 27                   0.39                             13.86     64   24
# 28                   0.58                             14.44     94   26
# 29                   0.49                             14.93     79   17
# 30                   0.48                             15.41     78   24
# 31                   0.49                             15.89     79   21
# 32                   0.59                             16.48     96   24
# 33                   0.46                             16.94     75   24
# 34                   0.53                             17.47     86   29
# 35                   0.46                             17.93     74   22
# 36                   0.56                             18.49     91   22
# 37                   0.42                             18.92     69   26
# 38                   0.55                             19.46     89   23
# 39                   0.49                             19.96     80   23
# 40                   0.55                             20.50     89   21
# 41                   0.40                             20.90     65   17
# 42                   0.54                             21.44     87   23
# 43                   0.38                             21.82     62   19
# 44                   0.61                             22.43     99   21
# 45                   0.51                             22.94     83   28
# 46                   0.55                             23.50     90   20
# 47                   0.49                             23.98     79   19
# 48                   0.47                             24.45     76   20
# 49                   0.53                             24.98     86   14
#
#     Cumulative Bad        Quantile  #Quantile  Cumulative Precision  \
# 0               34  (0.891, 0.938]        200             41.975309
# 1               70  (0.878, 0.891]        199             42.944785
# 2              104  (0.871, 0.878]        198             43.697479
# 3              133  (0.865, 0.871]        197             41.692790
# 4              171  (0.859, 0.865]        196             42.118227
# 5              205  (0.853, 0.859]        195             42.181070
# 6              243  (0.848, 0.853]        194             43.085106
# 7              272  (0.844, 0.848]        193             41.846154
# 8              301   (0.84, 0.844]        192             41.689751
# 9              329   (0.836, 0.84]        191             40.971357
# 10             362  (0.833, 0.836]        190             41.230068
# 11             388  (0.829, 0.833]        189             40.082645
# 12             407  (0.826, 0.829]        188             39.134615
# 13             451  (0.822, 0.826]        187             39.665787
# 14             482  (0.818, 0.822]        186             39.605588
# 15             500  (0.815, 0.818]        185             38.910506
# 16             538  (0.811, 0.815]        184             39.042090
# 17             566  (0.808, 0.811]        183             38.900344
# 18             593  (0.805, 0.808]        182             38.732854
# 19             628  (0.802, 0.805]        181             38.837353
# 20             650    (0.8, 0.802]        180             38.667460
# 21             681    (0.796, 0.8]        179             38.409475
# 22             707  (0.793, 0.796]        178             37.949544
# 23             738  (0.789, 0.793]        177             37.982501
# 24             758  (0.786, 0.789]        176             37.692690
# 25             792  (0.782, 0.786]        175             37.571157
# 26             806  (0.779, 0.782]        174             36.854138
# 27             830  (0.776, 0.779]        173             36.872501
# 28             856  (0.772, 0.776]        172             36.503198
# 29             873  (0.769, 0.772]        171             36.014851
# 30             897  (0.766, 0.769]        170             35.851319
# 31             918  (0.763, 0.766]        169             35.567609
# 32             942   (0.76, 0.763]        168             35.188644
# 33             966   (0.757, 0.76]        167             35.101744
# 34             995  (0.754, 0.757]        166             35.059901
# 35            1017  (0.751, 0.754]        165             34.924451
# 36            1039  (0.747, 0.751]        164             34.598735
# 37            1065  (0.744, 0.747]        163             34.667969
# 38            1088   (0.74, 0.744]        162             34.419488
# 39            1111   (0.736, 0.74]        161             34.279543
# 40            1132  (0.733, 0.736]        160             33.993994
# 41            1149  (0.729, 0.733]        159             33.843888
# 42            1172  (0.725, 0.729]        158             33.658817
# 43            1191  (0.722, 0.725]        157             33.606095
# 44            1212  (0.718, 0.722]        156             33.269284
# 45            1240  (0.714, 0.718]        155             33.279656
# 46            1260   (0.71, 0.714]        154             33.018868
# 47            1279   (0.706, 0.71]        153             32.836970
# 48            1299  (0.702, 0.706]        152             32.712163
# 49            1313  (0.696, 0.702]        151             32.363816
#
#     Cumulative Recall  Precision    Recall        Scores
# 0            1.318852  41.975309  1.318852  0.891--0.938
# 1            2.715283  43.902439  1.396431  0.878--0.891
# 2            4.034135  45.333333  1.318852  0.871--0.878
# 3            5.159038  35.802469  1.124903  0.865--0.871
# 4            6.633049  43.678161  1.474011  0.859--0.865
# 5            7.951901  42.500000  1.318852  0.853--0.859
# 6            9.425912  48.717949  1.474011  0.848--0.853
# 7           10.550815  33.720930  1.124903  0.844--0.848
# 8           11.675718  40.277778  1.124903   0.84--0.844
# 9           12.761831  34.567901  1.086113   0.836--0.84
# 10          14.041893  44.000000  1.280062  0.833--0.836
# 11          15.050427  28.888889  1.008534  0.829--0.833
# 12          15.787432  26.388889  0.737005  0.826--0.829
# 13          17.494182  45.360825  1.706749  0.822--0.826
# 14          18.696664  38.750000  1.202483  0.818--0.822
# 15          19.394880  26.470588  0.698216  0.815--0.818
# 16          20.868891  40.860215  1.474011  0.811--0.815
# 17          21.955004  36.363636  1.086113  0.808--0.811
# 18          23.002327  35.526316  1.047324  0.805--0.808
# 19          24.359969  40.697674  1.357642  0.802--0.805
# 20          25.213344  34.375000  0.853375    0.8--0.802
# 21          26.415826  33.695652  1.202483    0.796--0.8
# 22          27.424360  28.888889  1.008534  0.793--0.796
# 23          28.626843  38.750000  1.202483  0.789--0.793
# 24          29.402638  29.411765  0.775795  0.786--0.789
# 25          30.721490  35.051546  1.318852  0.782--0.786
# 26          31.264546  17.721519  0.543057  0.779--0.782
# 27          32.195500  37.500000  0.930954  0.776--0.779
# 28          33.204034  27.659574  1.008534  0.772--0.776
# 29          33.863460  21.518987  0.659426  0.769--0.772
# 30          34.794414  30.769231  0.930954  0.766--0.769
# 31          35.608999  26.582278  0.814585  0.763--0.766
# 32          36.539953  25.000000  0.930954   0.76--0.763
# 33          37.470908  32.000000  0.930954   0.757--0.76
# 34          38.595811  33.720930  1.124903  0.754--0.757
# 35          39.449185  29.729730  0.853375  0.751--0.754
# 36          40.302560  24.175824  0.853375  0.747--0.751
# 37          41.311094  37.681159  1.008534  0.744--0.747
# 38          42.203258  25.842697  0.892164   0.74--0.744
# 39          43.095423  28.750000  0.892164   0.736--0.74
# 40          43.910008  23.595506  0.814585  0.733--0.736
# 41          44.569434  26.153846  0.659426  0.729--0.733
# 42          45.461598  26.436782  0.892164  0.725--0.729
# 43          46.198604  30.645161  0.737005  0.722--0.725
# 44          47.013189  21.212121  0.814585  0.718--0.722
# 45          48.099302  33.734940  1.086113  0.714--0.718
# 46          48.875097  22.222222  0.775795   0.71--0.714
# 47          49.612102  24.050633  0.737005   0.706--0.71
# 48          50.387898  26.315789  0.775795  0.702--0.706
# 49          50.930954  16.279070  0.543057  0.696--0.702

# %%
df_deciles.to_csv('lr_metrics_by_quantile_test_Iis1.csv')

# %%
data_dict['df_test']
# Out:
#        Unnamed: 0.1  Unnamed: 0  UNIQUE_ID  E1_A_01  E1_A_02  E1_A_03  \
# 0                 8           8       2569        0        0        0
# 1                11          11       4014        0        0        0
# 2                28          28       9969        0        0        0
# 3                34          34      12659        0        0        0
# 4                35          35      13384        0        0        0
# ...             ...         ...        ...      ...      ...      ...
# 16236        110425      110425   46638131        0        0        0
# 16237        110426      110426   46638528        0        0        0
# 16238        110439      110439   46642883        0        0        0
# 16239        110443      110443   46643968        1      999       55
# 16240        110461      110461   46650007        0        0        0
#
#        E1_A_04  E1_A_05  E1_A_06  E1_A_07  ...  GEN11_SP_N_92_ByRP  \
# 0            0        0        0        3  ...                 SNR
# 1            0        0        0        1  ...                  SR
# 2            0        0        0        2  ...               Other
# 3            0        0        0        5  ...               Other
# 4            0        0        0        0  ...               Other
# ...        ...      ...      ...      ...  ...                 ...
# 16236        0        0        0        9  ...               Other
# 16237        0        0        0        1  ...                  SR
# 16238        0        0        0        9  ...               Other
# 16239        5      150       55        9  ...               Other
# 16240        0        0        0        9  ...                 SNR
#
#        GEN11_SP_N_92_ByRPOptBin  BinGEN11_SP_N_92_ByRP  GEN11_SP_K_80_NotJS  \
# 0                      0.000000              [SR, SNR]                 Sole
# 1                      0.000000              [SR, SNR]                 Sole
# 2                      0.046651              ['Other']                Joint
# 3                      0.046651              ['Other']                   XX
# 4                      0.046651              ['Other']                   XX
# ...                         ...                    ...                  ...
# 16236                  0.046651              ['Other']                   XX
# 16237                  0.000000              [SR, SNR]                 Sole
# 16238                  0.046651              ['Other']                 Sole
# 16239                  0.046651              ['Other']                 Sole
# 16240                  0.000000              [SR, SNR]                 Sole
#
#        GEN11_SP_K_80_TO  GEN11_SP_K_80_TOOptBin BinGEN11_SP_K_80_TO  \
# 0                     G                0.000000        [G, F, S, U]
# 1                     S                0.000000        [G, F, S, U]
# 2                  1234                0.788473            ['1234']
# 3                    XX                0.000000                  XX
# 4                    XX                0.000000                  XX
# ...                 ...                     ...                 ...
# 16236                XX                0.000000                  XX
# 16237                 I               -0.302803           ['J' 'I']
# 16238                 G                0.000000        [G, F, S, U]
# 16239                 G                0.000000        [G, F, S, U]
# 16240                 G                0.000000        [G, F, S, U]
#
#        GEN11_SP_K_80_PR _GB6_Flag_2Limit_bin_0isB     score
# 0                     G                         0  0.129904
# 1                     S                         0  0.301749
# 2                   135                         0  0.184723
# 3                    XX                         0  0.680418
# 4                    XX                         0  0.661145
# ...                 ...                       ...       ...
# 16236                XX                         0  0.096430
# 16237                 I                         0  0.532865
# 16238                 G                         0  0.340390
# 16239                 G                         0  0.655663
# 16240                 G                         0  0.030194
#
# [16241 rows x 2372 columns]

# %%
# PROJECT_PATH: str = os.path.join(os.getcwd(), '..')
# DATA_PATH: str = os.path.join(PROJECT_PATH, 'data')
# OPT_BIN_PATH: str = os.path.join(os.path.join(PROJECT_PATH, 'objects'), 'optbinners')
# MODELS_PATH: str = os.path.join(os.path.join(PROJECT_PATH, 'objects'), 'models')

# %%
import pickle
with open(os.path.join(DATA_PATH, 'data_dict.pckl'), 'wb') as f:
    pickle.dump(data_dict, f)

# %%
df_corr = df[COLS_TO_USE].corr().abs()

# %%
df_most_corr = pd.DataFrame()
for col in df_corr.columns:
    temp_col_list =  [c for c in df_corr.columns if c != col]
    max_ind = df_corr.loc[col, temp_col_list].abs().argmax()
    max_val = df_corr.loc[col, temp_col_list].abs().max()
    max_col = temp_col_list[max_ind]
    df_most_corr = pd.concat((df_most_corr, pd.DataFrame({'Feature': [col], 'Max_abs_corr': [max_val], 'Max_abs_corr_feat': [max_col]})))
df_most_corr
# Out:
#                                    Feature  Max_abs_corr  \
# 0                           TRD_A_20OptBin      0.123575
# 0                            E4_Q_17OptBin      0.437595
# 0                           TRD_B_20OptBin      0.471358
# 0                           SP_B2_18OptBin      0.492740
# 0                           TRD_B_18OptBin      0.436151
# 0                          ND_ECC_04OptBin      0.263325
# 0                     OPTIN_11SCN_MLOptBin      0.823863
# 0                       G5_ND_SPECIIOptBin      0.823863
# 0                           SP_F2_33OptBin      0.626299
# 0                        AFF_B_09_01OptBin      0.719229
# 0                           TRD_A_08OptBin      0.558356
# 0                     VM01_SP_VM2_15OptBin      0.583490
# 0                GEN11_SP_N_92_NotABOptBin      0.577880
# 0  GEN11_SP_N_92_IfSoleJointOtherAccOptBin      0.259940
# 0           GEN11_SP_N_92_ByTurnoverOptBin      0.480815
# 0                 GEN11_SP_N_92_ByRPOptBin      0.480815
# 0                            SP_G_37OptBin      0.453546
# 0                           TRD_C_07OptBin      0.398730
# 0                          SPA_F2_33OptBin      0.526088
# 0                     VM01_SP_VM2_14OptBin      0.558106
# 0                     VM01_SP_VM2_24OptBin      0.397568
# 0                           TRD_O_05OptBin      0.239046
# 0                            E1_A_09OptBin      0.502131
# 0                          ND_INC_03OptBin      0.500016
# 0                     VM01_SP_VM2_17OptBin      0.615742
# 0                      GEN11_SP_N_91OptBin      0.676169
# 0                    GEN11_SP_EDI_07OptBin      0.719229
# 0                          ND_ECC_06OptBin      0.730342
# 0                           EA5_S_01OptBin      0.429770
# 0                CLU_CLI_L6M_NPR_L6MOptBin      0.082184
# 0                         SP_I_63_01OptBin      0.730342
# 0                            E4_Q_04OptBin      0.437595
# 0                           EA1_D_02OptBin      0.421151
# 0                           TRD_O_06OptBin      0.335081
# 0                        AFF_T_07_01OptBin      0.577880
# 0                     VM02_SP_VM1_18OptBin      0.267737
#
#                 Max_abs_corr_feat
# 0                   E1_A_09OptBin
# 0                   E4_Q_04OptBin
# 0            VM01_SP_VM2_15OptBin
# 0                  SP_F2_33OptBin
# 0                  SP_B2_18OptBin
# 0                SP_I_63_01OptBin
# 0              G5_ND_SPECIIOptBin
# 0            OPTIN_11SCN_MLOptBin
# 0            OPTIN_11SCN_MLOptBin
# 0           GEN11_SP_EDI_07OptBin
# 0            VM01_SP_VM2_15OptBin
# 0                  SP_F2_33OptBin
# 0               AFF_T_07_01OptBin
# 0       GEN11_SP_N_92_NotABOptBin
# 0        GEN11_SP_N_92_ByRPOptBin
# 0  GEN11_SP_N_92_ByTurnoverOptBin
# 0            OPTIN_11SCN_MLOptBin
# 0                  SP_B2_18OptBin
# 0               AFF_B_09_01OptBin
# 0            VM01_SP_VM2_15OptBin
# 0                 ND_INC_03OptBin
# 0            VM01_SP_VM2_17OptBin
# 0            OPTIN_11SCN_MLOptBin
# 0               AFF_B_09_01OptBin
# 0                  SP_F2_33OptBin
# 0               AFF_B_09_01OptBin
# 0               AFF_B_09_01OptBin
# 0                SP_I_63_01OptBin
# 0                   SP_G_37OptBin
# 0              G5_ND_SPECIIOptBin
# 0                 ND_ECC_06OptBin
# 0                   E4_Q_17OptBin
# 0                   E1_A_09OptBin
# 0                  SP_B2_18OptBin
# 0       GEN11_SP_N_92_NotABOptBin
# 0                 ND_INC_03OptBin

# %%
df_most_corr[df_most_corr['Max_abs_corr'] >= 0.75]
# Out:
#                 Feature  Max_abs_corr     Max_abs_corr_feat
# 0  OPTIN_11SCN_MLOptBin      0.823863    G5_ND_SPECIIOptBin
# 0    G5_ND_SPECIIOptBin      0.823863  OPTIN_11SCN_MLOptBin
