# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import copy
from typing import (
    Dict, 
    List,
    Any
)

import mlflow
from datetime import datetime


import numpy as np
import pandas as pd

from scipy.stats import uniform
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedShuffleSplit

from joblib import load, dump

import seaborn as sns
import matplotlib.pyplot as plt

# %%
sys.path.append(os.path.join(os.getcwd(), '..'))
from utils.metrics import Metrics
from utils.modelling_tools import (
    search_hyper_params_and_log, 
    update_solver_by_penalty, 
    evaluate_model
)
from utils.metrics_by_quantile import MetricsByQuantile
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %%
RUN_NAME: str = '02-LogRegression-hyperparams_tunning'

# %%
PROJECT_PATH: str = os.path.join(os.getcwd(), '..')
DATA_PATH: str = os.path.join(PROJECT_PATH, 'data')
OPT_BIN_PATH: str = os.path.join(os.path.join(PROJECT_PATH, 'objects'), 'optbinners')
MODELS_PATH: str = os.path.join(os.path.join(PROJECT_PATH, 'objects'), 'models')

# %%
TRAIN_FROM: datetime.date = pd.to_datetime('2021-12-01').date()
TRAIN_TO: datetime.date = pd.to_datetime('2022-01-01').date()

VAL_FROM: datetime.date = pd.to_datetime('2023-01-01').date()
VAL_TO: datetime.date = pd.to_datetime('2023-05-01').date()

TEST_FROM: datetime.date = pd.to_datetime('2023-05-01').date()
TEST_TO: datetime.date = pd.to_datetime('2023-08-01').date()

# %%
# set constants
COLS_TO_USE: List[str] = [
"OPTIN_11SCN_MLOptBin",
"AFF_B_09_01OptBin",
"TRD_A_20OptBin",
"VM01_SP_VM2_15OptBin",
"SP_G_37OptBin",
"E4_Q_17OptBin",
"TRD_C_07OptBin",
"TRD_B_20OptBin",
"SP_B2_18OptBin",
"SPA_F2_33OptBin",
"VM01_SP_VM2_14OptBin",
"VM01_SP_VM2_24OptBin",
"SP_G_38OptBin",
"SP_B1_14OptBin",
"GEN11_SP_N_91OptBin",
"GEN11_SP_EDI_07OptBin",
"ND_ECC_06OptBin",
"TRD_B_18OptBin",
"TRD_B_08OptBin",
"EA5_S_01OptBin",
"CLU_CLI_L6M_NPR_L6MOptBin",
"SP_I_63_01OptBin",
"VM08_SP_VM2_20OptBin",
"EA1_D_02OptBin",
"TRD_O_06OptBin",
"AFF_T_07_01OptBin",
"VM02_SP_VM1_18OptBin",
"GEN11_SP_K_80_TOOptBin",
"GEN11_SP_N_92_ABOtherOptBin",
]

# %%
TARGET_NAME: str = 'GB6_Flag_2Limit'
TARGET_VALS: List[int] = [0, 1]
TARGET_BIN: str = f'_{TARGET_NAME}_bin'
TARGET_BIN_0isB: str = f'_{TARGET_NAME}_bin_0isB'

PALETTE: Dict[str, str] = {
    TARGET_NAME: {
        'G': 'green',
        'B': 'red',
        'I': 'black'
    },
    TARGET_BIN: {0: 'green', 1: 'red'},
    'DataPart': {'Train+Val': 'black', 'Val': 'blue', 'Test': 'red', 'Train': 'orange'}
}

# %%
N_ITER: int = 100
RANDOM_SEED: int = 42
CONFIDENCE_LEVEL = 0.05

# %%
MODEL = LogisticRegression

# %%
PARAMS: Dict[str, Any] = dict(
    penalty=['l2', 'l1', 'elasticnet'], 
    C=uniform(loc=0, scale=20), 
    fit_intercept=[True], 
    class_weight=['balanced'], 
    random_state=[RANDOM_SEED], 
    n_jobs=[-1]
)

# %%
# read data
df: pd.DataFrame = pd.read_csv(os.path.join(DATA_PATH, 'final_aiq2_s_neg_sep_I_excl.csv'), low_memory=False)

# %%
print('Number of rows: %.0f; columns: %.0f' % df.shape)
# Out:
# Number of rows: 110462; columns: 1866

# %% [markdown]
# # Preprocessing

# %% [markdown]
# Convert dates to the corresponding types

# %%
for col in ['_RDATE_EOM', '_RDATE']:
    df[col] = pd.to_datetime(df[col]).dt.date

# %%
print('Available date range:')
df['_RDATE'].agg(['min', 'max'])
# Out:
# Available date range:
# min    2021-06-30
# max    2023-11-30
# Name: _RDATE, dtype: object

# %% [markdown]
# Generate Target, where `GB6_Flag_2Limit` in ('I','B') is '1' and GB6_Flag_2Limit in ('G') is '0'

# %%
df[f'_{TARGET_NAME}_bin_0isB'] = df[TARGET_NAME].replace(
    {
        'G': 0,
        'I': 1,
        'B': 1
    }
)
# Out:
# Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`

# %%
pd.merge(
    df[f'_{TARGET_NAME}_bin_0isB'].value_counts().reset_index(name='n'),
    (df[f'_{TARGET_NAME}_bin_0isB'].value_counts(normalize=True) * 100).reset_index(name='%'),
    on=f'_{TARGET_NAME}_bin_0isB', how='outer'
)
# Out:
#    _GB6_Flag_2Limit_bin_0isB      n          %
# 0                          0  99444  90.025529
# 1                          1  11018   9.974471

# %% [markdown]
# # Split data

# %%
df_train = df.loc[
    (df._RDATE >= TRAIN_FROM) &
    (df._RDATE < TRAIN_TO) & 
    (df[TARGET_NAME] != 'I'),
   :
].reset_index(drop=True)

df_train_val = df.loc[
    (df._RDATE >= TRAIN_FROM) &
    (df._RDATE < VAL_TO) &
    (df[TARGET_NAME] != 'I'),
    :
].reset_index(drop=True)

df_val = df.loc[
    (df._RDATE >= VAL_FROM) &
    (df._RDATE < VAL_TO) &
    (df[TARGET_NAME] != 'I'),
    :
].reset_index(drop=True)

df_test_same = df.loc[
    (df._RDATE >= TEST_FROM) &
    (df._RDATE < TEST_TO) &
    (df[TARGET_NAME] != 'I'),
    :
].reset_index(drop=True)

df_test = df.loc[
    (df._RDATE >= TEST_FROM) &
    (df._RDATE < TEST_TO),
    :
].reset_index(drop=True)

# %%
print(f'Distribution of _{TARGET_NAME}_bin_0isB on test')
pd.merge(
    df_test[f'_{TARGET_NAME}_bin_0isB'].value_counts().reset_index(name='n'),
    (df_test[f'_{TARGET_NAME}_bin_0isB'].value_counts(normalize=True) * 100).reset_index(name='%'),
    on=f'_{TARGET_NAME}_bin_0isB', how='outer'
)
# Out:
# Distribution of _GB6_Flag_2Limit_bin_0isB on test
#    _GB6_Flag_2Limit_bin_0isB      n          %
# 0                          0  13663  84.126593
# 1                          1   2578  15.873407

# %%
data_dict = {
    "df_train": df_train,
    "df_val": df_val,
    "df_train_val": df_train_val, 
    "df_test_same": df_test_same,
    "df_test": df_test
}

# %%
# randomly select N observations from test data
N = 10000
sss = StratifiedShuffleSplit(n_splits=1, train_size=N, random_state=RANDOM_SEED)
indx = sss.split(data_dict['df_test_same'].reset_index(drop=True), data_dict['df_test_same'][TARGET_BIN])
random_indx = list(indx)[0][0]

assert len(random_indx) == N, "Incorrect number of elements in the subsample"
test_sample = data_dict['df_test_same'].reset_index(drop=True).iloc[random_indx, :].reset_index(drop=True)

# %%
data_dict['df_test_same_sample'] = test_sample

# %% [markdown]
# # Run the experiment

# %%
mlflow.set_tracking_uri(uri="http://127.0.0.1:8800/")
mlflow.set_experiment("[Experian][Features 2.0]")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/562926978330189002', creation_time=1718121099087, experiment_id='562926978330189002', last_update_time=1718121099087, lifecycle_stage='active', name='[Experian][Features 2.0]', tags={}>

# %%
experiment_description = f"""
    'features': {len(COLS_TO_USE)},
    'target': {TARGET_BIN},
    'target_vals': '0==G, 1==B, 1=I',
    'model': {MODEL.__name__},
    'data_version': '22.05.2024', 
    'train_period': [{TRAIN_FROM.strftime('%Y-%m-%d') + ', ' + TRAIN_TO.strftime('%Y-%m-%d')}),
    'val_period': [{VAL_FROM.strftime('%Y-%m-%d') + ', ' + VAL_TO.strftime('%Y-%m-%d')}),
    'test_period': [{TEST_FROM.strftime('%Y-%m-%d') + ', ' + TEST_TO.strftime('%Y-%m-%d')}),
"""

# %%
print(experiment_description)
# Out:
#     'features': 29,
#     'target': _GB6_Flag_2Limit_bin,
#     'target_vals': '0==G, 1==B, 1=I',
#     'model': LogisticRegression,
#     'data_version': '22.05.2024',
#     'train_period': [2021-12-01, 2022-01-01),
#     'val_period': [2023-01-01, 2023-05-01),
#     'test_period': [2023-05-01, 2023-08-01),

# %%
with mlflow.start_run(run_name=RUN_NAME, log_system_metrics=True):
    res = search_hyper_params_and_log(
        run_name=RUN_NAME,
        data_dict=data_dict,
        cols_to_use=COLS_TO_USE,
        target_name=TARGET_BIN,
        distributions=PARAMS,
        n_iter=N_ITER,
        model=MODEL,
        custom_params_updates=update_solver_by_penalty,
        tags={'features': len(COLS_TO_USE)}, 
        palette=PALETTE['DataPart'],
        test_name='df_test_same',
        model_path=MODELS_PATH
    )
# Out:
# 2024/06/19 11:34:19 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/19 11:34:19 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# # 1 / 100
# # 2 / 100
# 2024/06/19 11:34:20 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/19 11:34:20 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:34:29 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:34:29 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 3 / 100
# # 4 / 100
# 2024/06/19 11:34:31 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/19 11:34:31 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:34:37 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:34:37 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 5 / 100
# # 6 / 100
# # 7 / 100
# 2024/06/19 11:34:38 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/19 11:34:38 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:34:44 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:34:44 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 8 / 100
# 2024/06/19 11:34:44 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/19 11:34:44 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:34:50 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:34:50 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 9 / 100
# 2024/06/19 11:34:51 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/19 11:34:51 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:34:57 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:34:57 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 10 / 100
# # 11 / 100
# # 12 / 100
# 2024/06/19 11:34:58 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/19 11:34:58 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:35:04 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:35:04 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 13 / 100
# # 14 / 100
# 2024/06/19 11:35:05 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/19 11:35:05 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:35:11 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:35:11 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 15 / 100
# 2024/06/19 11:35:11 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/19 11:35:11 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:35:17 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:35:17 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 16 / 100
# 2024/06/19 11:35:17 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/19 11:35:17 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:35:24 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:35:24 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 17 / 100
# # 18 / 100
# # 19 / 100
# # 20 / 100
# 2024/06/19 11:35:25 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/19 11:35:25 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:35:31 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:35:31 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 21 / 100
# # 22 / 100
# # 23 / 100
# # 24 / 100
# # 25 / 100
# 2024/06/19 11:35:32 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/19 11:35:32 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:35:39 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:35:39 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 26 / 100
# # 27 / 100
# # 28 / 100
# 2024/06/19 11:35:41 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/19 11:35:41 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:35:48 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:35:48 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 29 / 100
# 2024/06/19 11:35:49 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/19 11:35:49 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:35:55 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:35:55 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 30 / 100
# # 31 / 100
# 2024/06/19 11:35:55 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/19 11:35:55 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:36:01 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:36:01 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 32 / 100
# # 33 / 100
# 2024/06/19 11:36:01 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/19 11:36:01 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:36:07 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:36:07 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 34 / 100
# # 35 / 100
# # 36 / 100
# # 37 / 100
# # 38 / 100
# # 39 / 100
# # 40 / 100
# 2024/06/19 11:36:08 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/19 11:36:08 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:36:14 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:36:14 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 41 / 100
# # 42 / 100
# # 43 / 100
# # 44 / 100
# # 45 / 100
# # 46 / 100
# # 47 / 100
# 2024/06/19 11:36:16 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/19 11:36:16 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:36:22 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:36:22 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 48 / 100
# # 49 / 100
# 2024/06/19 11:36:22 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/19 11:36:22 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:36:29 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:36:29 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 50 / 100
# # 51 / 100
# # 52 / 100
# # 53 / 100
# # 54 / 100
# # 55 / 100
# # 56 / 100
# # 57 / 100
# 2024/06/19 11:36:31 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/19 11:36:31 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:36:40 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:36:40 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 58 / 100
# 2024/06/19 11:36:40 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/19 11:36:40 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:36:48 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:36:48 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 59 / 100
# 2024/06/19 11:36:49 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/19 11:36:49 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:36:55 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:36:55 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 60 / 100
# # 61 / 100
# # 62 / 100
# # 63 / 100
# # 64 / 100
# # 65 / 100
# # 66 / 100
# # 67 / 100
# 2024/06/19 11:36:57 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/19 11:36:57 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:37:03 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:37:03 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 68 / 100
# # 69 / 100
# # 70 / 100
# # 71 / 100
# # 72 / 100
# 2024/06/19 11:37:04 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
# 2024/06/19 11:37:04 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self._target(*self._args, **self._kwargs)
# ...
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:37:46 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:37:46 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 88 / 100
# 2024/06/19 11:37:47 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/19 11:37:47 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:37:53 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:37:53 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 89 / 100
# # 90 / 100
# # 91 / 100
# # 92 / 100
# 2024/06/19 11:37:54 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/19 11:37:54 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:38:00 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:38:00 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 93 / 100
# # 94 / 100
# # 95 / 100
# 2024/06/19 11:38:00 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/19 11:38:00 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:38:06 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:38:06 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 96 / 100
# # 97 / 100
# 2024/06/19 11:38:07 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/19 11:38:07 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:38:13 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:38:13 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 98 / 100
# 2024/06/19 11:38:13 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/19 11:38:13 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:38:19 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:38:19 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 99 / 100
# 2024/06/19 11:38:20 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
# 2024/06/19 11:38:20 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:38:26 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:38:26 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 100 / 100
# 2024/06/19 11:38:26 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/19 11:38:26 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/19 11:38:33 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:38:33 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# Best params:
#  {'penalty': 'l2', 'C': 0.3127281348238786, 'fit_intercept': True, 'class_weight': 'balanced', 'random_state': 42, 'n_jobs': -1, 'solver': 'lbfgs'}
# Val-PR_AUC:  0.11881450638652283
# Val-GINI:  0.5014752327958596
# Not saved
# Test-PR_AUC 0.23249433741978948
# Test-Gini 0.5715752421673965
# The option feature_dependence has been renamed to feature_perturbation!
# The feature_perturbation option is now deprecated in favor of using the appropriate masker (maskers.Independent, or maskers.Impute)
# 2024/06/19 11:38:53 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/19 11:38:53 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!

# %%
df_metrics, df_coeff, data_dict, model_obj, std_scaler = res

# %% [markdown]
# # Model's quality

# %% [markdown]
# ## Coefficients

# %%
df_coeff.sort_values('Importance(%)', ascending=False)
# Out:
#                         Feature     Coeff  Importance(%)       p-value  \
# 12         OPTIN_11SCN_MLOptBin -1.237363      27.251994  0.000000e+00
# 10                    Intercept -0.889346      19.587177  0.000000e+00
# 13              SPA_F2_33OptBin -0.199697       4.398179  0.000000e+00
# 11              ND_ECC_06OptBin  0.178006       3.920440  0.000000e+00
# 18             SP_I_63_01OptBin -0.171372       3.774343  0.000000e+00
# 25         VM01_SP_VM2_14OptBin  0.165627       3.647818  0.000000e+00
# 23               TRD_C_07OptBin -0.147748       3.254045  0.000000e+00
# 5                EA5_S_01OptBin -0.134837       2.969683  0.000000e+00
# 6         GEN11_SP_EDI_07OptBin  0.108485       2.389311  2.657030e-11
# 2     CLU_CLI_L6M_NPR_L6MOptBin -0.106699       2.349967  1.356693e-13
# 24               TRD_O_06OptBin  0.101547       2.236490  2.220446e-15
# 8           GEN11_SP_N_91OptBin -0.091484       2.014868  2.939811e-09
# 16                SP_G_37OptBin -0.089530       1.971835  3.520446e-08
# 15               SP_B2_18OptBin -0.086826       1.912283  4.647545e-07
# 9   GEN11_SP_N_92_ABOtherOptBin -0.081663       1.798568  2.672445e-08
# 3                 E4_Q_17OptBin  0.077340       1.703351  3.280443e-10
# 17                SP_G_38OptBin -0.063899       1.407325  2.219308e-04
# 20               TRD_B_08OptBin  0.062005       1.365618  6.429106e-07
# 21               TRD_B_18OptBin  0.061472       1.353867  5.817994e-05
# 19               TRD_A_20OptBin -0.059703       1.314922  2.686993e-05
# 0             AFF_B_09_01OptBin -0.056934       1.253931  5.922663e-03
# 27         VM01_SP_VM2_24OptBin  0.056063       1.234748  1.070982e-04
# 26         VM01_SP_VM2_15OptBin -0.054449       1.199209  1.884025e-03
# 14               SP_B1_14OptBin -0.049436       1.088793  8.270328e-04
# 22               TRD_B_20OptBin -0.049272       1.085170  1.356068e-03
# 28         VM02_SP_VM1_18OptBin -0.038584       0.849792  1.101733e-03
# 7        GEN11_SP_K_80_TOOptBin -0.036187       0.796983  4.438539e-03
# 1             AFF_T_07_01OptBin  0.034515       0.760157  1.533665e-03
# 4                EA1_D_02OptBin -0.028173       0.620482  5.257804e-03
# 29         VM08_SP_VM2_20OptBin  0.022187       0.488651  4.647007e-02
#
#     Importance(SHAP)  Importance(SHAP, %)
# 12          1.586346            52.292227
# 10               NaN                  NaN
# 13          0.151903             5.007311
# 11          0.105577             3.480245
# 18          0.060444             1.992469
# 25          0.108668             3.582140
# 23          0.091578             3.018758
# 5           0.065287             2.152115
# 6           0.053670             1.769179
# 2           0.063499             2.093169
# 24          0.047288             1.558786
# 8           0.055349             1.824537
# 16          0.069332             2.285448
# 15          0.053971             1.779094
# 9           0.061947             2.042007
# 3           0.055837             1.840615
# 17          0.043917             1.447674
# 20          0.021533             0.709813
# 21          0.027790             0.916063
# 19          0.054842             1.807822
# 0           0.058338             1.923035
# 27          0.027329             0.900873
# 26          0.057587             1.898297
# 14          0.021498             0.708666
# 22          0.034854             1.148937
# 28          0.015144             0.499214
# 7           0.012554             0.413843
# 1           0.012143             0.400280
# 4           0.005803             0.191297
# 29          0.009589             0.316086

# %%
# features with 0 coefficients
df_coeff[df_coeff.Coeff == 0]
# Out:
# Empty DataFrame
# Columns: [Feature, Coeff, Importance(%), p-value, Importance(SHAP), Importance(SHAP, %)]
# Index: []

# %%
# features with high p-value
df_coeff[df_coeff['p-value'] > CONFIDENCE_LEVEL]
# Out:
# Empty DataFrame
# Columns: [Feature, Coeff, Importance(%), p-value, Importance(SHAP), Importance(SHAP, %)]
# Index: []

# %%
# features with p-values low than the confident level
for col in COLS_TO_USE:
    if col not in df_coeff[df_coeff['p-value'] > CONFIDENCE_LEVEL].Feature.values:
        print(f'"{col}",')
# Out:
# "OPTIN_11SCN_MLOptBin",
# "AFF_B_09_01OptBin",
# "TRD_A_20OptBin",
# "VM01_SP_VM2_15OptBin",
# "SP_G_37OptBin",
# "E4_Q_17OptBin",
# "TRD_C_07OptBin",
# "TRD_B_20OptBin",
# "SP_B2_18OptBin",
# "SPA_F2_33OptBin",
# "VM01_SP_VM2_14OptBin",
# "VM01_SP_VM2_24OptBin",
# "SP_G_38OptBin",
# "SP_B1_14OptBin",
# "GEN11_SP_N_91OptBin",
# "GEN11_SP_EDI_07OptBin",
# "ND_ECC_06OptBin",
# "TRD_B_18OptBin",
# "TRD_B_08OptBin",
# "EA5_S_01OptBin",
# "CLU_CLI_L6M_NPR_L6MOptBin",
# "SP_I_63_01OptBin",
# "VM08_SP_VM2_20OptBin",
# "EA1_D_02OptBin",
# "TRD_O_06OptBin",
# "AFF_T_07_01OptBin",
# "VM02_SP_VM1_18OptBin",
# "GEN11_SP_K_80_TOOptBin",
# "GEN11_SP_N_92_ABOtherOptBin",

# %%
model_obj
# Out:
# LogisticRegression(C=0.3127281348238786, class_weight='balanced', n_jobs=-1,
#                    random_state=42)

# %%
with open(os.path.join(MODELS_PATH, '[Model][Modelling] [Final_AIQ2-50] [I excluded] LogRegression - woe-2 - feature selection - 2 (final).jblb'), 'wb') as f:
    dump(model_obj, f)

# %%
with open(os.path.join(MODELS_PATH, '[StdScaler][Modelling] [Final_AIQ2-50] [I excluded] LogRegression - woe-2 - feature selection - 2 (final).jblb'), 'wb') as f:
    dump(std_scaler, f)

# %% [markdown]
# ## GINI, AU PRC

# %% [markdown]
# ## Test-same

# %%
evaluate_model(
    data=data_dict['df_test_same'], 
    cols_to_use=COLS_TO_USE,
    std_scaler=std_scaler,
    target_name=TARGET_BIN,
    model_obj=model_obj
)
# Out:
# PR_AUC 0.23249433741978948
# Gini 0.5715752421673965
# (0.23249433741978948, 0.5715752421673965)

# %% [markdown]
# ## Test-full

# %% [markdown]
# ### 'I' is 0

# %%
evaluate_model(
    data=data_dict['df_test'], 
    cols_to_use=COLS_TO_USE,
    std_scaler=std_scaler,
    target_name=TARGET_BIN,
    model_obj=model_obj
)
# Out:
# PR_AUC 0.19694460273694167
# Gini 0.5350918825151725
# (0.19694460273694167, 0.5350918825151725)

# %% [markdown]
# ### 'I' is 1

# %%
evaluate_model(
    data=data_dict['df_test'], 
    cols_to_use=COLS_TO_USE,
    std_scaler=std_scaler,
    target_name=TARGET_BIN_0isB,
    model_obj=model_obj
)
# Out:
# PR_AUC 0.33514716967200486
# Gini 0.5144540472655335
# (0.33514716967200486, 0.5144540472655335)

# %% [markdown]
# ## Outcomes distributions

# %%
data_dict['df_test']['score'] = model_obj.predict_proba(
    std_scaler.transform(data_dict['df_test'][COLS_TO_USE])
)[:, 1]
data_dict['df_test_same']['score'] = model_obj.predict_proba(
    std_scaler.transform(data_dict['df_test_same'][COLS_TO_USE])
)[:, 1]

# %% [markdown]
# ### Test-same

# %%
sns.histplot(x=data_dict['df_test_same']['score'], hue=data_dict['df_test_same'][TARGET_BIN], common_norm=False, stat='density')
# Out:
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# <Axes: xlabel='score', ylabel='Density'>

# %% [markdown]
# ### Test-full

# %% [markdown]
# ### 'I' is 0

# %%
sns.histplot(x=data_dict['df_test']['score'], hue=data_dict['df_test'][TARGET_BIN], common_norm=False, stat='density')
# Out:
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# <Axes: xlabel='score', ylabel='Density'>

# %% [markdown]
# ### 'I' is 1

# %%
sns.histplot(x=data_dict['df_test']['score'], hue=data_dict['df_test'][TARGET_BIN_0isB], common_norm=False, stat='density')
# Out:
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# <Axes: xlabel='score', ylabel='Density'>

# %% [markdown]
# ## Precision, Recall By Quantile

# %% [markdown]
# ### Test-same

# %%
m = MetricsByQuantile(metrics=["quantiles_analytics"])
r = m.compute(
    y_true=data_dict['df_test_same'][TARGET_BIN].reset_index(drop=True), 
    y_pred=data_dict['df_test_same']['score'].round(3).reset_index(drop=True), 
    list_of_metrics = [
        "cum_precision_by_quantile", "cum_recall_by_quantile", 
        "precision_by_quantile", "recall_by_quantile",
    ], 
    n_quantiles = 200
)
df_deciles = r["other"]["quantiles_analytics"]
df_deciles.head(50)
# Out:
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#     % of total population  Cumulative % of total population  Total  Bad  \
# 0                    0.47                              0.47     71   28
# 1                    0.49                              0.96     73   30
# 2                    0.53                              1.49     79   16
# 3                    0.43                              1.91     64   21
# 4                    0.49                              2.41     74   23
# 5                    0.51                              2.91     76   18
# 6                    0.53                              3.45     80   21
# 7                    0.55                              4.00     83   16
# 8                    0.47                              4.47     70   22
# 9                    0.45                              4.91     67   26
# 10                   0.55                              5.47     83   18
# 11                   0.52                              5.99     78   24
# 12                   0.43                              6.42     65   19
# 13                   0.45                              6.87     68   13
# 14                   0.59                              7.46     88   23
# 15                   0.51                              7.97     77   11
# 16                   0.47                              8.45     71   15
# 17                   0.55                              9.00     82   13
# 18                   0.29                              9.29     44   11
# 19                   0.64                              9.93     96   21
# 20                   0.41                             10.34     62    9
# 21                   0.62                             10.96     93   29
# 22                   0.53                             11.49     79   19
# 23                   0.41                             11.90     62   11
# 24                   0.47                             12.38     71   21
# 25                   0.59                             12.97     89   15
# 26                   0.50                             13.47     75   14
# 27                   0.53                             14.00     80   10
# 28                   0.44                             14.44     66   19
# 29                   0.51                             14.96     77   10
# 30                   0.55                             15.50     82   11
# 31                   0.39                             15.89     58   10
# 32                   0.57                             16.46     86   20
# 33                   0.47                             16.93     70    8
# 34                   0.48                             17.41     72   20
# 35                   0.59                             18.00     89   14
# 36                   0.42                             18.42     63    9
# 37                   0.51                             18.94     77    6
# 38                   0.52                             19.46     78    7
# 39                   0.51                             19.97     77   13
# 40                   0.47                             20.44     71   11
# 41                   0.45                             20.89     67   13
# 42                   0.53                             21.42     80   16
# 43                   0.55                             21.98     83    9
# 44                   0.42                             22.40     63    7
# 45                   0.55                             22.95     83   11
# 46                   0.47                             23.42     71   15
# 47                   0.57                             24.00     86   12
# 48                   0.41                             24.41     62    5
# 49                   0.55                             24.96     83   18
#
#     Cumulative Bad        Quantile  #Quantile  Cumulative Precision  \
# 0               28  (0.885, 0.931]        200             39.436620
# 1               58  (0.876, 0.885]        199             40.277778
# 2               74  (0.869, 0.876]        198             33.183857
# 3               95  (0.863, 0.869]        197             33.101045
# 4              118  (0.858, 0.863]        196             32.686981
# 5              136  (0.853, 0.858]        195             31.121281
# 6              157  (0.849, 0.853]        194             30.367505
# 7              173  (0.844, 0.849]        193             28.833333
# 8              195   (0.84, 0.844]        192             29.104478
# 9              221   (0.836, 0.84]        191             29.986431
# 10             239  (0.832, 0.836]        190             29.146341
# 11             263  (0.828, 0.832]        189             29.287305
# 12             282  (0.824, 0.828]        188             29.283489
# 13             295  (0.821, 0.824]        187             28.612997
# 14             318  (0.816, 0.821]        186             28.418231
# 15             329  (0.812, 0.816]        185             27.508361
# 16             344  (0.809, 0.812]        184             27.150750
# 17             357  (0.805, 0.809]        183             26.464047
# 18             368  (0.803, 0.805]        182             26.417803
# 19             389    (0.8, 0.803]        181             26.124916
# 20             398    (0.797, 0.8]        180             25.660864
# 21             427  (0.793, 0.797]        179             25.973236
# 22             446  (0.789, 0.793]        178             25.885084
# 23             457  (0.786, 0.789]        177             25.602241
# 24             478  (0.782, 0.786]        176             25.754310
# 25             493  (0.778, 0.782]        175             25.347044
# 26             507  (0.774, 0.778]        174             25.099010
# 27             517  (0.771, 0.774]        173             24.619048
# 28             536  (0.767, 0.771]        172             24.746076
# 29             546  (0.763, 0.767]        171             24.342399
# 30             557   (0.76, 0.763]        170             23.956989
# 31             567   (0.756, 0.76]        169             23.793538
# 32             587  (0.751, 0.756]        168             23.774808
# 33             595  (0.747, 0.751]        167             23.434423
# 34             615  (0.743, 0.747]        166             23.554194
# 35             629  (0.739, 0.743]        165             23.296296
# 36             638  (0.735, 0.739]        164             23.090843
# 37             644  (0.731, 0.735]        163             22.676056
# 38             651  (0.725, 0.731]        162             22.309801
# 39             664  (0.721, 0.725]        161             22.170284
# 40             675  (0.718, 0.721]        160             22.015656
# 41             688  (0.714, 0.718]        159             21.959783
# 42             704   (0.71, 0.714]        158             21.910987
# 43             713   (0.705, 0.71]        157             21.632282
# 44             720  (0.701, 0.705]        156             21.434951
# 45             731  (0.697, 0.701]        155             21.237653
# 46             746  (0.693, 0.697]        154             21.235411
# 47             758  (0.688, 0.693]        153             21.061406
# 48             763  (0.684, 0.688]        152             20.841300
# 49             781  (0.678, 0.684]        151             20.860043
#
#     Cumulative Recall  Precision    Recall        Scores
# 0            2.098951  39.436620  2.098951  0.885--0.931
# 1            4.347826  41.095890  2.248876  0.876--0.885
# 2            5.547226  20.253165  1.199400  0.869--0.876
# 3            7.121439  32.812500  1.574213  0.863--0.869
# 4            8.845577  31.081081  1.724138  0.858--0.863
# 5           10.194903  23.684211  1.349325  0.853--0.858
# 6           11.769115  26.250000  1.574213  0.849--0.853
# 7           12.968516  19.277108  1.199400  0.844--0.849
# 8           14.617691  31.428571  1.649175   0.84--0.844
# 9           16.566717  38.805970  1.949025   0.836--0.84
# 10          17.916042  21.686747  1.349325  0.832--0.836
# 11          19.715142  30.769231  1.799100  0.828--0.832
# 12          21.139430  29.230769  1.424288  0.824--0.828
# 13          22.113943  19.117647  0.974513  0.821--0.824
# 14          23.838081  26.136364  1.724138  0.816--0.821
# 15          24.662669  14.285714  0.824588  0.812--0.816
# 16          25.787106  21.126761  1.124438  0.809--0.812
# 17          26.761619  15.853659  0.974513  0.805--0.809
# 18          27.586207  25.000000  0.824588  0.803--0.805
# 19          29.160420  21.875000  1.574213    0.8--0.803
# 20          29.835082  14.516129  0.674663    0.797--0.8
# 21          32.008996  31.182796  2.173913  0.793--0.797
# 22          33.433283  24.050633  1.424288  0.789--0.793
# 23          34.257871  17.741935  0.824588  0.786--0.789
# 24          35.832084  29.577465  1.574213  0.782--0.786
# 25          36.956522  16.853933  1.124438  0.778--0.782
# 26          38.005997  18.666667  1.049475  0.774--0.778
# 27          38.755622  12.500000  0.749625  0.771--0.774
# 28          40.179910  28.787879  1.424288  0.767--0.771
# 29          40.929535  12.987013  0.749625  0.763--0.767
# 30          41.754123  13.414634  0.824588   0.76--0.763
# 31          42.503748  17.241379  0.749625   0.756--0.76
# 32          44.002999  23.255814  1.499250  0.751--0.756
# 33          44.602699  11.428571  0.599700  0.747--0.751
# 34          46.101949  27.777778  1.499250  0.743--0.747
# 35          47.151424  15.730337  1.049475  0.739--0.743
# 36          47.826087  14.285714  0.674663  0.735--0.739
# 37          48.275862   7.792208  0.449775  0.731--0.735
# 38          48.800600   8.974359  0.524738  0.725--0.731
# 39          49.775112  16.883117  0.974513  0.721--0.725
# 40          50.599700  15.492958  0.824588  0.718--0.721
# 41          51.574213  19.402985  0.974513  0.714--0.718
# 42          52.773613  20.000000  1.199400   0.71--0.714
# 43          53.448276  10.843373  0.674663   0.705--0.71
# 44          53.973013  11.111111  0.524738  0.701--0.705
# 45          54.797601  13.253012  0.824588  0.697--0.701
# 46          55.922039  21.126761  1.124438  0.693--0.697
# 47          56.821589  13.953488  0.899550  0.688--0.693
# 48          57.196402   8.064516  0.374813  0.684--0.688
# 49          58.545727  21.686747  1.349325  0.678--0.684

# %%
df_deciles.to_csv('lr_metrics_by_quantile_test_same.csv')

# %% [markdown]
# ### Test-full

# %% [markdown]
# ### 'I' is 0

# %%
m = MetricsByQuantile(metrics=["quantiles_analytics"])
r = m.compute(
    y_true=data_dict['df_test'][TARGET_BIN].reset_index(drop=True), 
    y_pred=data_dict['df_test']['score'].round(3).reset_index(drop=True), 
    list_of_metrics = [
        "cum_precision_by_quantile", "cum_recall_by_quantile", 
        "precision_by_quantile", "recall_by_quantile",
    ], 
    n_quantiles = 200
)
df_deciles = r["other"]["quantiles_analytics"]
df_deciles.head(50)
# Out:
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#     % of total population  Cumulative % of total population  Total  Bad  \
# 0                    0.50                              0.50     82   26
# 1                    0.50                              1.00     81   31
# 2                    0.49                              1.50     80   15
# 3                    0.46                              1.95     74   15
# 4                    0.54                              2.49     87   22
# 5                    0.45                              2.94     73   20
# 6                    0.41                              3.34     66    8
# 7                    0.61                              3.95     99   24
# 8                    0.52                              4.47     84   12
# 9                    0.40                              4.87     65   14
# 10                   0.51                              5.38     83   30
# 11                   0.57                              5.95     93   17
# 12                   0.52                              6.47     84   23
# 13                   0.49                              6.96     79   18
# 14                   0.51                              7.47     83   18
# 15                   0.54                              8.00     87   16
# 16                   0.40                              8.40     65   10
# 17                   0.48                              8.88     78   10
# 18                   0.51                              9.40     83   15
# 19                   0.45                              9.85     73    9
# 20                   0.47                             10.32     77   15
# 21                   0.68                             11.00    111   21
# 22                   0.45                             11.45     73    9
# 23                   0.53                             11.98     86   21
# 24                   0.45                             12.43     73   18
# 25                   0.56                             12.99     91   16
# 26                   0.44                             13.44     72   18
# 27                   0.51                             13.95     83   12
# 28                   0.46                             14.41     75   14
# 29                   0.52                             14.93     84   10
# 30                   0.55                             15.48     90   15
# 31                   0.47                             15.95     76   17
# 32                   0.52                             16.47     85   12
# 33                   0.46                             16.93     74    6
# 34                   0.45                             17.38     73   10
# 35                   0.54                             17.91     87   15
# 36                   0.55                             18.46     89   13
# 37                   0.49                             18.95     79   15
# 38                   0.47                             19.42     77   14
# 39                   0.55                             19.97     89   11
# 40                   0.50                             20.47     82    8
# 41                   0.48                             20.95     78    5
# 42                   0.50                             21.45     81   11
# 43                   0.41                             21.86     67    6
# 44                   0.58                             22.45     95   18
# 45                   0.51                             22.96     83   11
# 46                   0.53                             23.49     86   17
# 47                   0.44                             23.93     71    3
# 48                   0.56                             24.49     91   14
# 49                   0.49                             24.98     80    9
#
#     Cumulative Bad        Quantile  #Quantile  Cumulative Precision  \
# 0               26  (0.888, 0.931]        200             31.707317
# 1               57  (0.878, 0.888]        199             34.969325
# 2               72  (0.871, 0.878]        198             29.629630
# 3               87  (0.865, 0.871]        197             27.444795
# 4              109   (0.86, 0.865]        196             26.980198
# 5              129   (0.856, 0.86]        195             27.044025
# 6              137  (0.852, 0.856]        194             25.230203
# 7              161  (0.848, 0.852]        193             25.077882
# 8              173  (0.844, 0.848]        192             23.829201
# 9              187  (0.841, 0.844]        191             23.640961
# 10             217  (0.837, 0.841]        190             24.828375
# 11             234  (0.833, 0.837]        189             24.198552
# 12             257   (0.83, 0.833]        188             24.452902
# 13             275   (0.826, 0.83]        187             24.336283
# 14             293  (0.822, 0.826]        186             24.154988
# 15             309  (0.819, 0.822]        185             23.769231
# 16             319  (0.815, 0.819]        184             23.369963
# 17             329  (0.812, 0.815]        183             22.799723
# 18             344  (0.809, 0.812]        182             22.542595
# 19             353  (0.806, 0.809]        181             22.076298
# 20             368  (0.803, 0.806]        180             21.957041
# 21             389  (0.801, 0.803]        179             21.768327
# 22             398  (0.797, 0.801]        178             21.397849
# 23             419  (0.794, 0.797]        177             21.531346
# 24             437  (0.791, 0.794]        176             21.644378
# 25             453  (0.787, 0.791]        175             21.469194
# 26             471  (0.784, 0.787]        174             21.585701
# 27             483   (0.78, 0.784]        173             21.324503
# 28             497   (0.777, 0.78]        172             21.239316
# 29             507  (0.773, 0.777]        171             20.915842
# 30             522  (0.769, 0.773]        170             20.763723
# 31             539  (0.766, 0.769]        169             20.810811
# 32             551  (0.762, 0.766]        168             20.598131
# 33             557  (0.759, 0.762]        167             20.261913
# 34             567  (0.756, 0.759]        166             20.092133
# 35             582  (0.752, 0.756]        165             20.006875
# 36             595  (0.748, 0.752]        164             19.846564
# 37             610  (0.744, 0.748]        163             19.824504
# 38             624   (0.74, 0.744]        162             19.784401
# 39             635   (0.736, 0.74]        161             19.580635
# 40             643  (0.732, 0.736]        160             19.338346
# 41             648  (0.727, 0.732]        159             19.042022
# 42             659  (0.723, 0.727]        158             18.915040
# 43             665   (0.72, 0.723]        157             18.727119
# 44             683   (0.716, 0.72]        156             18.732858
# 45             694  (0.712, 0.716]        155             18.610888
# 46             711  (0.708, 0.712]        154             18.636959
# 47             714  (0.704, 0.708]        153             18.373649
# 48             728  (0.699, 0.704]        152             18.305255
# 49             737  (0.695, 0.699]        151             18.166133
#
#     Cumulative Recall  Precision    Recall        Scores
# 0            1.949025  31.707317  1.949025  0.888--0.931
# 1            4.272864  38.271605  2.323838  0.878--0.888
# 2            5.397301  18.750000  1.124438  0.871--0.878
# 3            6.521739  20.270270  1.124438  0.865--0.871
# 4            8.170915  25.287356  1.649175   0.86--0.865
# 5            9.670165  27.397260  1.499250   0.856--0.86
# 6           10.269865  12.121212  0.599700  0.852--0.856
# 7           12.068966  24.242424  1.799100  0.848--0.852
# 8           12.968516  14.285714  0.899550  0.844--0.848
# 9           14.017991  21.538462  1.049475  0.841--0.844
# 10          16.266867  36.144578  2.248876  0.837--0.841
# 11          17.541229  18.279570  1.274363  0.833--0.837
# 12          19.265367  27.380952  1.724138   0.83--0.833
# 13          20.614693  22.784810  1.349325   0.826--0.83
# 14          21.964018  21.686747  1.349325  0.822--0.826
# 15          23.163418  18.390805  1.199400  0.819--0.822
# 16          23.913043  15.384615  0.749625  0.815--0.819
# 17          24.662669  12.820513  0.749625  0.812--0.815
# 18          25.787106  18.072289  1.124438  0.809--0.812
# 19          26.461769  12.328767  0.674663  0.806--0.809
# 20          27.586207  19.480519  1.124438  0.803--0.806
# 21          29.160420  18.918919  1.574213  0.801--0.803
# 22          29.835082  12.328767  0.674663  0.797--0.801
# 23          31.409295  24.418605  1.574213  0.794--0.797
# 24          32.758621  24.657534  1.349325  0.791--0.794
# 25          33.958021  17.582418  1.199400  0.787--0.791
# 26          35.307346  25.000000  1.349325  0.784--0.787
# 27          36.206897  14.457831  0.899550   0.78--0.784
# 28          37.256372  18.666667  1.049475   0.777--0.78
# 29          38.005997  11.904762  0.749625  0.773--0.777
# 30          39.130435  16.666667  1.124438  0.769--0.773
# 31          40.404798  22.368421  1.274363  0.766--0.769
# 32          41.304348  14.117647  0.899550  0.762--0.766
# 33          41.754123   8.108108  0.449775  0.759--0.762
# 34          42.503748  13.698630  0.749625  0.756--0.759
# 35          43.628186  17.241379  1.124438  0.752--0.756
# 36          44.602699  14.606742  0.974513  0.748--0.752
# 37          45.727136  18.987342  1.124438  0.744--0.748
# 38          46.776612  18.181818  1.049475   0.74--0.744
# 39          47.601199  12.359551  0.824588   0.736--0.74
# 40          48.200900   9.756098  0.599700  0.732--0.736
# 41          48.575712   6.410256  0.374813  0.727--0.732
# 42          49.400300  13.580247  0.824588  0.723--0.727
# 43          49.850075   8.955224  0.449775   0.72--0.723
# 44          51.199400  18.947368  1.349325   0.716--0.72
# 45          52.023988  13.253012  0.824588  0.712--0.716
# 46          53.298351  19.767442  1.274363  0.708--0.712
# 47          53.523238   4.225352  0.224888  0.704--0.708
# 48          54.572714  15.384615  1.049475  0.699--0.704
# 49          55.247376  11.250000  0.674663  0.695--0.699

# %%
df_deciles.to_csv('lr_metrics_by_quantile_test_Iis0).csv')

# %% [markdown]
# ### 'I' is 1

# %%
m = MetricsByQuantile(metrics=["quantiles_analytics"])
r = m.compute(
    y_true=data_dict['df_test'][TARGET_BIN_0isB].reset_index(drop=True), 
    y_pred=data_dict['df_test']['score'].round(3).reset_index(drop=True), 
    list_of_metrics = [
        "cum_precision_by_quantile", "cum_recall_by_quantile", 
        "precision_by_quantile", "recall_by_quantile",
    ], 
    n_quantiles = 200
)
df_deciles = r["other"]["quantiles_analytics"]
df_deciles.head(50)
# Out:
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#     % of total population  Cumulative % of total population  Total  Bad  \
# 0                    0.50                              0.50     82   41
# 1                    0.50                              1.00     81   46
# 2                    0.49                              1.50     80   30
# 3                    0.46                              1.95     74   26
# 4                    0.54                              2.49     87   38
# 5                    0.45                              2.94     73   32
# 6                    0.41                              3.34     66   16
# 7                    0.61                              3.95     99   41
# 8                    0.52                              4.47     84   29
# 9                    0.40                              4.87     65   28
# 10                   0.51                              5.38     83   49
# 11                   0.57                              5.95     93   29
# 12                   0.52                              6.47     84   35
# 13                   0.49                              6.96     79   27
# 14                   0.51                              7.47     83   29
# 15                   0.54                              8.00     87   35
# 16                   0.40                              8.40     65   21
# 17                   0.48                              8.88     78   24
# 18                   0.51                              9.40     83   27
# 19                   0.45                              9.85     73   22
# 20                   0.47                             10.32     77   26
# 21                   0.68                             11.00    111   36
# 22                   0.45                             11.45     73   20
# 23                   0.53                             11.98     86   34
# 24                   0.45                             12.43     73   31
# 25                   0.56                             12.99     91   25
# 26                   0.44                             13.44     72   29
# 27                   0.51                             13.95     83   23
# 28                   0.46                             14.41     75   20
# 29                   0.52                             14.93     84   21
# 30                   0.55                             15.48     90   28
# 31                   0.47                             15.95     76   27
# 32                   0.52                             16.47     85   23
# 33                   0.46                             16.93     74   13
# 34                   0.45                             17.38     73   25
# 35                   0.54                             17.91     87   31
# 36                   0.55                             18.46     89   29
# 37                   0.49                             18.95     79   23
# 38                   0.47                             19.42     77   27
# 39                   0.55                             19.97     89   22
# 40                   0.50                             20.47     82   16
# 41                   0.48                             20.95     78   14
# 42                   0.50                             21.45     81   17
# 43                   0.41                             21.86     67   13
# 44                   0.58                             22.45     95   26
# 45                   0.51                             22.96     83   22
# 46                   0.53                             23.49     86   26
# 47                   0.44                             23.93     71   10
# 48                   0.56                             24.49     91   24
# 49                   0.49                             24.98     80   18
#
#     Cumulative Bad        Quantile  #Quantile  Cumulative Precision  \
# 0               41  (0.888, 0.931]        200             50.000000
# 1               87  (0.878, 0.888]        199             53.374233
# 2              117  (0.871, 0.878]        198             48.148148
# 3              143  (0.865, 0.871]        197             45.110410
# 4              181   (0.86, 0.865]        196             44.801980
# 5              213   (0.856, 0.86]        195             44.654088
# 6              229  (0.852, 0.856]        194             42.173112
# 7              270  (0.848, 0.852]        193             42.056075
# 8              299  (0.844, 0.848]        192             41.184573
# 9              327  (0.841, 0.844]        191             41.340076
# 10             376  (0.837, 0.841]        190             43.020595
# 11             405  (0.833, 0.837]        189             41.882110
# 12             440   (0.83, 0.833]        188             41.864891
# 13             467   (0.826, 0.83]        187             41.327434
# 14             496  (0.822, 0.826]        186             40.890354
# 15             531  (0.819, 0.822]        185             40.846154
# 16             552  (0.815, 0.819]        184             40.439560
# 17             576  (0.812, 0.815]        183             39.916840
# 18             603  (0.809, 0.812]        182             39.515072
# 19             625  (0.806, 0.809]        181             39.086929
# 20             651  (0.803, 0.806]        180             38.842482
# 21             687  (0.801, 0.803]        179             38.444320
# 22             707  (0.797, 0.801]        178             38.010753
# 23             741  (0.794, 0.797]        177             38.078109
# 24             772  (0.791, 0.794]        176             38.236751
# 25             797  (0.787, 0.791]        175             37.772512
# 26             826  (0.784, 0.787]        174             37.855179
# 27             849   (0.78, 0.784]        173             37.483444
# 28             869   (0.777, 0.78]        172             37.136752
# 29             890  (0.773, 0.777]        171             36.716172
# 30             918  (0.769, 0.773]        170             36.515513
# 31             945  (0.766, 0.769]        169             36.486486
# 32             968  (0.762, 0.766]        168             36.186916
# 33             981  (0.759, 0.762]        167             35.685704
# 34            1006  (0.756, 0.759]        166             35.648476
# 35            1037  (0.752, 0.756]        165             35.647989
# 36            1066  (0.748, 0.752]        164             35.557038
# 37            1089  (0.744, 0.748]        163             35.391615
# 38            1116   (0.74, 0.744]        162             35.383640
# 39            1138   (0.736, 0.74]        161             35.090965
# 40            1154  (0.732, 0.736]        160             34.706767
# 41            1168  (0.727, 0.732]        159             34.322656
# 42            1185  (0.723, 0.727]        158             34.012629
# 43            1198   (0.72, 0.723]        157             33.736975
# 44            1224   (0.716, 0.72]        156             33.571037
# 45            1246  (0.712, 0.716]        155             33.413784
# 46            1272  (0.708, 0.712]        154             33.342071
# 47            1282  (0.704, 0.708]        153             32.990221
# 48            1306  (0.699, 0.704]        152             32.838823
# 49            1324  (0.695, 0.699]        151             32.634952
#
#     Cumulative Recall  Precision    Recall        Scores
# 0            1.590380  50.000000  1.590380  0.888--0.931
# 1            3.374709  56.790123  1.784329  0.878--0.888
# 2            4.538402  37.500000  1.163693  0.871--0.878
# 3            5.546936  35.135135  1.008534  0.865--0.871
# 4            7.020946  43.678161  1.474011   0.86--0.865
# 5            8.262219  43.835616  1.241272   0.856--0.86
# 6            8.882855  24.242424  0.620636  0.852--0.856
# 7           10.473235  41.414141  1.590380  0.848--0.852
# 8           11.598138  34.523810  1.124903  0.844--0.848
# 9           12.684251  43.076923  1.086113  0.841--0.844
# 10          14.584950  59.036145  1.900698  0.837--0.841
# 11          15.709853  31.182796  1.124903  0.833--0.837
# 12          17.067494  41.666667  1.357642   0.83--0.833
# 13          18.114818  34.177215  1.047324   0.826--0.83
# 14          19.239721  34.939759  1.124903  0.822--0.826
# 15          20.597362  40.229885  1.357642  0.819--0.822
# 16          21.411947  32.307692  0.814585  0.815--0.819
# 17          22.342901  30.769231  0.930954  0.812--0.815
# 18          23.390225  32.530120  1.047324  0.809--0.812
# 19          24.243600  30.136986  0.853375  0.806--0.809
# 20          25.252133  33.766234  1.008534  0.803--0.806
# 21          26.648565  32.432432  1.396431  0.801--0.803
# 22          27.424360  27.397260  0.775795  0.797--0.801
# 23          28.743212  39.534884  1.318852  0.794--0.797
# 24          29.945694  42.465753  1.202483  0.791--0.794
# 25          30.915438  27.472527  0.969744  0.787--0.791
# 26          32.040341  40.277778  1.124903  0.784--0.787
# 27          32.932506  27.710843  0.892164   0.78--0.784
# 28          33.708301  26.666667  0.775795   0.777--0.78
# 29          34.522886  25.000000  0.814585  0.773--0.777
# 30          35.608999  31.111111  1.086113  0.769--0.773
# 31          36.656323  35.526316  1.047324  0.766--0.769
# 32          37.548487  27.058824  0.892164  0.762--0.766
# 33          38.052754  17.567568  0.504267  0.759--0.762
# 34          39.022498  34.246575  0.969744  0.756--0.759
# 35          40.224981  35.632184  1.202483  0.752--0.756
# 36          41.349884  32.584270  1.124903  0.748--0.752
# 37          42.242048  29.113924  0.892164  0.744--0.748
# 38          43.289372  35.064935  1.047324   0.74--0.744
# 39          44.142746  24.719101  0.853375   0.736--0.74
# 40          44.763382  19.512195  0.620636  0.732--0.736
# 41          45.306439  17.948718  0.543057  0.727--0.732
# 42          45.965865  20.987654  0.659426  0.723--0.727
# 43          46.470132  19.402985  0.504267   0.72--0.723
# 44          47.478666  27.368421  1.008534   0.716--0.72
# 45          48.332040  26.506024  0.853375  0.712--0.716
# 46          49.340574  30.232558  1.008534  0.708--0.712
# 47          49.728472  14.084507  0.387898  0.704--0.708
# 48          50.659426  26.373626  0.930954  0.699--0.704
# 49          51.357642  22.500000  0.698216  0.695--0.699

# %%
df_deciles.to_csv('lr_metrics_by_quantile_test_Iis1.csv')

# %%
data_dict['df_test']
# Out:
#        Unnamed: 0.1  Unnamed: 0  UNIQUE_ID  E1_A_01  E1_A_02  E1_A_03  \
# 0                 8           8       2569        0        0        0
# 1                11          11       4014        0        0        0
# 2                28          28       9969        0        0        0
# 3                34          34      12659        0        0        0
# 4                35          35      13384        0        0        0
# ...             ...         ...        ...      ...      ...      ...
# 16236        110425      110425   46638131        0        0        0
# 16237        110426      110426   46638528        0        0        0
# 16238        110439      110439   46642883        0        0        0
# 16239        110443      110443   46643968        1      999       55
# 16240        110461      110461   46650007        0        0        0
#
#        E1_A_04  E1_A_05  E1_A_06  E1_A_07  ...  GEN11_SP_N_92_ABOther  \
# 0            0        0        0        3  ...                      B
# 1            0        0        0        1  ...                      B
# 2            0        0        0        2  ...                      B
# 3            0        0        0        5  ...                  Other
# 4            0        0        0        0  ...                      A
# ...        ...      ...      ...      ...  ...                    ...
# 16236        0        0        0        9  ...                      B
# 16237        0        0        0        1  ...                  Other
# 16238        0        0        0        9  ...                      B
# 16239        5      150       55        9  ...                      B
# 16240        0        0        0        9  ...                      B
#
#        GEN11_SP_N_92_ABOtherOptBin  BinGEN11_SP_N_92_ABOther  \
# 0                         0.883575                     {'B'}
# 1                         0.883575                     {'B'}
# 2                         0.883575                     {'B'}
# 3                        -0.592210                 {'Other'}
# 4                        -0.956089                     {'A'}
# ...                            ...                       ...
# 16236                     0.883575                     {'B'}
# 16237                    -0.592210                 {'Other'}
# 16238                     0.883575                     {'B'}
# 16239                     0.883575                     {'B'}
# 16240                     0.883575                     {'B'}
#
#        GEN11_SP_K_80_JSOther  GEN11_SP_K_80_TO  GEN11_SP_K_80_TOOptBin  \
# 0                       Sole                 G               -0.213474
# 1                       Sole                 S               -0.213474
# 2      (Joint)OR(Sole&Joint)              1234                0.788473
# 3                         XX                XX               -0.093103
# 4                         XX                XX               -0.093103
# ...                      ...               ...                     ...
# 16236                     XX                XX               -0.093103
# 16237                   Sole                 I               -0.213474
# 16238                   Sole                 G               -0.213474
# 16239                   Sole                 G               -0.213474
# 16240                   Sole                 G               -0.213474
#
#       BinGEN11_SP_K_80_TO  GEN11_SP_K_80_PR _GB6_Flag_2Limit_bin_0isB  \
# 0      [J, I, S, U, G, F]                 G                         0
# 1      [J, I, S, U, G, F]                 S                         0
# 2            {1, 2, 3, 4}               135                         0
# 3                  {'XX'}                XX                         0
# 4                  {'XX'}                XX                         0
# ...                   ...               ...                       ...
# 16236              {'XX'}                XX                         0
# 16237  [J, I, S, U, G, F]                 I                         0
# 16238  [J, I, S, U, G, F]                 G                         0
# 16239  [J, I, S, U, G, F]                 G                         0
# 16240  [J, I, S, U, G, F]                 G                         0
#
#           score
# 0      0.170002
# 1      0.292642
# 2      0.198095
# 3      0.664965
# 4      0.750884
# ...         ...
# 16236  0.097377
# 16237  0.512568
# 16238  0.416491
# 16239  0.641962
# 16240  0.037530
#
# [16241 rows x 1868 columns]
