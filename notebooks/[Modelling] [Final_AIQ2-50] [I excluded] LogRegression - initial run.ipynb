# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys
import copy
from typing import (
    Dict, 
    List,
    Any
)


import mlflow
import warnings
from datetime import datetime

from tqdm.autonotebook import tqdm

import numpy as np
import pandas as pd

from scipy.stats import uniform

import shap

import seaborn as sns
import matplotlib.pyplot as plt

# %%
sys.path.append(os.path.join(os.getcwd(), '..'))
from utils.modelling_tools import *

# %%
TRAIN_FROM: datetime.date = pd.to_datetime('2021-12-01').date()
TRAIN_TO: datetime.date = pd.to_datetime('2022-01-01').date()

VAL_FROM: datetime.date = pd.to_datetime('2022-01-01').date()
VAL_TO: datetime.date = pd.to_datetime('2022-05-01').date()

TEST_FROM: datetime.date = pd.to_datetime('2022-05-01').date()
TEST_TO: datetime.date = pd.to_datetime('2022-08-01').date()

# %%
# set constants
COLS_TO_USE: List[str] = [
"OPTIN_11SCN_MLOptBin",
"G5_ND_SPECIIOptBin",
"Marital_StatusOptBin",
"SP_F2_33OptBin",
"AFF_B_09_01OptBin",
"TRD_A_20OptBin",
"TRD_A_08OptBin",
"VM01_SP_VM2_15OptBin",
"GEN11_SP_N_92OptBin",
"SP_EDI_24OptBin",
"SP_G_37OptBin",
"E4_Q_17OptBin",
"TRD_C_07OptBin",
"TRD_B_20OptBin",
"SP_B2_18OptBin",
"SPA_F2_33OptBin",
"VM01_SP_VM2_14OptBin",
"VM01_SP_VM2_24OptBin",
"SP_G_38OptBin",
"TRD_O_05OptBin",
"E1_A_09OptBin",
"TRD_O_07OptBin",
"ND_INC_03OptBin",
"VM01_SP_VM2_17OptBin",
"SP_B1_14OptBin",
"GEN11_SP_N_91OptBin",
"GEN11_SP_EDI_07OptBin",
"ND_ECC_06OptBin",
"TRD_B_18OptBin",
"TRD_B_08OptBin",
"EA5_S_01OptBin",
"CLU_CLI_L6M_NPR_L6MOptBin",
"E1_B_06OptBin",
"SP_I_67_01OptBin",
"GEN11_SP_K_80OptBin",
"E4_Q_04OptBin",
"ND_ECC_04OptBin",
"VM08_SP_VM2_15OptBin",
"VAL_DELINQ_ACCSOptBin",
"ND_ERL_01OptBin",
"EA1_D_02OptBin",
"ND_HAC_06OptBin",
"AFF_E_07_01OptBin",
"TRD_O_06OptBin",
"E2_G_08OptBin",
"AFF_T_07_01OptBin",
"VM02_SP_VM1_18OptBin",
] 

TARGET_NAME: str = 'GB6_Flag_2Limit'
TARGET_VALS: List[int] = [0, 1]
TARGET_BIN: str = f'_{TARGET_NAME}_bin'

PALETTE: Dict[str, str] = {
    TARGET_NAME: {
        'G': 'green',
        'B': 'red',
        'I': 'black'
    },
    TARGET_BIN: {0: 'green', 1: 'red'},
    'DataPart': {'Train-val': 'orange', 'Val': 'blue', 'Test': 'black'}
    # 'Test-OOT': 'black'
}

PROJECT_PATH: str = os.path.join(os.getcwd(), '..')
DATA_PATH: str = os.path.join(PROJECT_PATH, 'data')
OPT_BIN_PATH: str = os.path.join(os.path.join(PROJECT_PATH, 'objects'), 'optbinners')
MODELS_PATH: str = os.path.join(os.path.join(PROJECT_PATH, 'objects'), 'models')

# %%
N_ITER: int = 20
RANDOM_SEED: int = 42

# %%
# read data
df: pd.DataFrame = pd.read_csv(os.path.join(DATA_PATH, 'final_aiq2_optbins.csv'), low_memory=False)

# %%
print('Number of rows: %.0f; columns: %.0f' % df.shape)
# Out:
# Number of rows: 110462; columns: 2069

# %% [markdown]
# # Preprocessing

# %% [markdown]
# # Convert dates to the corresponding types

# %%
for col in ['_RDATE_EOM', '_RDATE']:
    df[col] = pd.to_datetime(df[col]).dt.date

# %%
print('Available date range:')
df['_RDATE'].agg(['min', 'max'])
# Out:
# Available date range:
# min    2021-06-30
# max    2023-11-30
# Name: _RDATE, dtype: object

# %%
pd.merge(
    pd.DataFrame(df.groupby([TARGET_NAME])[TARGET_BIN].value_counts()),
    pd.DataFrame(df[TARGET_NAME].value_counts(normalize=True)),
    how='outer', left_index=True, right_index=True
)
# Out:
#                                       count  proportion
# GB6_Flag_2Limit _GB6_Flag_2Limit_bin
# B               1                      4449    0.040276
# G               0                     99444    0.900255
# I               0                      6569    0.059468

# %%
df_train = df.loc[
    (df._RDATE >= TRAIN_FROM) &
    (df._RDATE < TRAIN_TO) & 
    (df[TARGET_NAME] != 'I'),
    COLS_TO_USE + [TARGET_NAME, TARGET_BIN, '_RDATE']
].reset_index(drop=True)

df_train_val = df.loc[
    (df._RDATE >= TRAIN_FROM) &
    (df._RDATE < VAL_TO) &
    (df[TARGET_NAME] != 'I'),
    COLS_TO_USE + [TARGET_NAME, TARGET_BIN, '_RDATE']
].reset_index(drop=True)

df_val = df.loc[
    (df._RDATE >= VAL_FROM) &
    (df._RDATE < VAL_TO) &
    (df[TARGET_NAME] != 'I'),
    COLS_TO_USE + [TARGET_NAME, TARGET_BIN, '_RDATE']
].reset_index(drop=True)

df_test_same = df.loc[
    (df._RDATE >= TEST_FROM) &
    (df._RDATE < TEST_TO) &
    (df[TARGET_NAME] != 'I'),
    COLS_TO_USE + [TARGET_NAME, TARGET_BIN, '_RDATE']
].reset_index(drop=True)

df_test = df.loc[
    (df._RDATE >= TEST_FROM) &
    (df._RDATE < TEST_TO),
    COLS_TO_USE + [TARGET_NAME, TARGET_BIN, '_RDATE']
].reset_index(drop=True)

# %%
data_dict = {
    "df_train": df_train,
    "df_val": df_val,
    "df_train_val": df_train_val, 
    "df_test_same": df_test_same,
    "df_test": df_test
}

# %%
# randomly select N observations from test data
N = 10000
sss = StratifiedShuffleSplit(n_splits=1, train_size=N, random_state=RANDOM_SEED)
indx = sss.split(data_dict['df_test_same'].reset_index(drop=True), data_dict['df_test_same'][TARGET_BIN])
random_indx = list(indx)[0][0]

assert len(random_indx) == N, "Incorrect number of elements in the subsample"
test_sample = data_dict['df_test'].reset_index(drop=True).iloc[random_indx, :].reset_index(drop=True)

# %%
data_dict['df_test_same_sample'] = test_sample

# %%
mlflow.set_tracking_uri(uri="http://127.0.0.1:5000/")
mlflow.set_experiment("[Experian]")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/696858428304145414', creation_time=1716463645799, experiment_id='696858428304145414', last_update_time=1716463645799, lifecycle_stage='active', name='[Experian]', tags={}>

# %%
MODEL = LogisticRegression

# %%
experiment_description = f"""
    'features': {len(COLS_TO_USE)},
    'target': {TARGET_BIN},
    'target_vals': '0==G, 1==B',
    'model': {MODEL.__name__},
    'data_version': '22.05.2024', 
    'train_period': [{TRAIN_FROM.strftime('%Y-%m-%d') + ', ' + TRAIN_TO.strftime('%Y-%m-%d')}),
    'val_period': [{VAL_FROM.strftime('%Y-%m-%d') + ', ' + VAL_TO.strftime('%Y-%m-%d')}),
    'test_period': [{TEST_FROM.strftime('%Y-%m-%d') + ', ' + TEST_TO.strftime('%Y-%m-%d')}),
"""

# %%
print(experiment_description)
# Out:
#     'features': 47,
#     'target': _GB6_Flag_2Limit_bin,
#     'target_vals': '0==G, 1==B',
#     'model': LogisticRegression,
#     'data_version': '22.05.2024',
#     'train_period': [2021-12-01, 2022-01-01),
#     'val_period': [2022-01-01, 2022-05-01),
#     'test_period': [2022-05-01, 2022-08-01),

# %%
PARAMS = dict(
    penalty=['l2', 'l1', 'elasticnet'], 
    C=uniform(loc=0, scale=20), 
    fit_intercept=[True], 
    class_weight=['balanced'], 
    random_state=[RANDOM_SEED], 
    n_jobs=[-1], 
)

# %%
RUN_NAME = '03-LogRegression-hyperparams_tunning'
with mlflow.start_run(run_name=RUN_NAME, log_system_metrics=True):
    res = search_hyper_params_and_log(
        run_name=RUN_NAME,
        data_dict=data_dict,
        cols_to_use=COLS_TO_USE,
        target_name=TARGET_BIN,
        distributions=PARAMS,
        n_iter=100,
        model=MODEL,
        custom_params_updates=update_solver_by_penalty,
        tags={'features': len(COLS_TO_USE)}, 
        palette=PALETTE,
        test_name='df_test_same'
    )
# Out:
# 2024/05/23 22:08:36 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/23 22:08:36 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# # 1 / 100
# The max_iter was reached which means the coef_ did not converge
# 2024/05/23 22:08:37 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/23 22:08:37 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:08:45 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:08:45 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 2 / 100
# 2024/05/23 22:08:46 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/23 22:08:46 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:08:53 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:08:53 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 3 / 100
# 2024/05/23 22:08:54 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/23 22:08:54 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:09:00 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:09:00 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 4 / 100
# 2024/05/23 22:09:02 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/23 22:09:02 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:09:09 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:09:09 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 5 / 100
# 2024/05/23 22:09:09 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/23 22:09:09 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:09:16 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:09:16 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 6 / 100
# The max_iter was reached which means the coef_ did not converge
# 2024/05/23 22:09:16 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/23 22:09:16 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:09:23 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:09:23 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 7 / 100
# 2024/05/23 22:09:23 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/23 22:09:23 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:09:30 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:09:30 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 8 / 100
# 2024/05/23 22:09:30 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/23 22:09:30 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:09:36 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:09:36 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 9 / 100
# 2024/05/23 22:09:36 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/23 22:09:36 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:09:43 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:09:43 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 10 / 100
# 2024/05/23 22:09:43 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/23 22:09:43 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:09:50 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:09:50 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 11 / 100
# The max_iter was reached which means the coef_ did not converge
# 2024/05/23 22:09:51 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
# 2024/05/23 22:09:51 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:09:57 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:09:57 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 12 / 100
# 2024/05/23 22:09:58 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
# 2024/05/23 22:09:58 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:10:05 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:10:05 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 13 / 100
# The max_iter was reached which means the coef_ did not converge
# 2024/05/23 22:10:05 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/23 22:10:05 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:10:12 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:10:12 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 14 / 100
# 2024/05/23 22:10:12 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/23 22:10:12 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:10:18 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:10:18 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 15 / 100
# 2024/05/23 22:10:19 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/23 22:10:19 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:10:26 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:10:26 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 16 / 100
# 2024/05/23 22:10:26 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/23 22:10:26 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:10:32 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:10:32 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 17 / 100
# 2024/05/23 22:10:33 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
# 2024/05/23 22:10:33 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:10:40 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:10:40 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 18 / 100
# 2024/05/23 22:10:40 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
# 2024/05/23 22:10:40 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:10:46 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:10:46 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 19 / 100
# 2024/05/23 22:10:47 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/23 22:10:47 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:10:54 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:10:54 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 20 / 100
# 2024/05/23 22:10:54 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/23 22:10:54 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:11:00 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:11:00 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 21 / 100
# 2024/05/23 22:11:00 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/23 22:11:00 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:11:06 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:11:06 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 22 / 100
# 2024/05/23 22:11:07 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/23 22:11:07 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# ...
# Test-PR_AUC 0.10289058443334112
# Test-Gini 0.6042019528899998
# Not saved
# The option feature_dependence has been renamed to feature_perturbation!
# The feature_perturbation option is now deprecated in favor of using the appropriate masker (maskers.Independent, or maskers.Impute)
# .values =
# array([-3.93939522, -3.93939522,  4.60829095, ...,  3.0048514 ,
#         3.89818506, -3.09917585])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 2.99474675,  2.99474675, -1.48385189, ..., -0.64372252,
#        -1.11178871,  2.55451004])
# .values =
# array([-0.03773259, -0.03773259,  0.24880292, ..., -0.03773259,
#        -0.03773259, -0.03773259])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 0.25783187,  0.25783187, -1.37849138, ...,  0.25783187,
#         0.25783187,  0.25783187])
# .values =
# array([-1.7128872 , -0.78633024,  1.47876984, ..., -0.78633024,
#         1.47876984,  1.47876984])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 2.2584247 ,  1.43192539, -0.58856955, ...,  1.43192539,
#        -0.58856955, -0.58856955])
# .values =
# array([-0.2125198 ,  0.36532502, -0.47351378, ..., -0.47351378,
#        -0.10106839, -0.10106839])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([-0.07402703,  1.67999899, -0.86626434, ..., -0.86626434,
#         0.26427951,  0.26427951])
# .values =
# array([-0.02942888, -0.02942888, -0.05325182, ..., -0.11050105,
#        -0.11050105,  0.07582533])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 0.11437588,  0.11437588, -0.11903656, ..., -0.67995335,
#        -0.67995335,  1.14563599])
# .values =
# array([ 0.16874704,  0.16874704, -0.10788745, ..., -0.10788745,
#         0.16874704, -0.10788745])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 1.42155037,  1.42155037, -0.45645552, ..., -0.45645552,
#         1.42155037, -0.45645552])
# .values =
# array([-0.72579726, -1.16211925,  0.81178656, ...,  0.81178656,
#         0.51256252,  0.17879543])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 1.49761241,  2.15021933, -0.8021521 , ..., -0.8021521 ,
#        -0.35460263,  0.1446129 ])
# .values =
# array([-0.19127189, -0.19127189,  0.16743362, ...,  0.16743362,
#         0.13040972, -0.05093028])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 2.24867633,  2.24867633, -1.00554946, ..., -1.00554946,
#        -0.66966358,  0.97547792])
# .values =
# array([ 0.07530412,  0.07530412, -0.08225829, ..., -0.08225829,
#        -0.06096766,  0.0467589 ])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 1.49620257,  1.49620257, -1.07338141, ..., -1.07338141,
#        -0.72616619,  1.03067702])
# .values =
# array([-1.06012823, -0.19312033, -0.19312033, ...,  0.48224621,
#         0.48224621, -0.19312033])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 1.76910325,  0.46029847,  0.46029847, ..., -0.55921124,
#        -0.55921124,  0.46029847])
# .values =
# array([ 0.07411496,  0.07411496, -0.05662381, ..., -0.05662381,
#         0.02186455, -0.05662381])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 1.67314853,  1.67314853, -0.7508588 , ..., -0.7508588 ,
#         0.70438177, -0.7508588 ])
# .values =
# array([-0.13363292, -0.13363292,  0.09098388, ..., -0.13363292,
#         0.09098388, -0.13363292])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 0.88915064,  0.88915064, -0.13253725, ...,  0.88915064,
#        -0.13253725,  0.88915064])
# .values =
# array([ 0.03072123, -0.20414625,  0.3582793 , ...,  0.3582793 ,
#         0.03072123,  0.03072123])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 0.00824407,  0.71284345, -0.97442585, ..., -0.97442585,
#         0.00824407,  0.00824407])
# .values =
# array([ 0.21642787,  0.15402192, -0.51653166, ..., -0.51653166,
#        -0.51653166,  0.21642787])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 0.82287761,  0.65599878, -1.13711868, ..., -1.13711868,
#        -1.13711868,  0.82287761])
# .values =
# array([-0.15139702, -0.26321606,  0.48462425, ...,  0.15138743,
#         0.15138743, -0.15139702])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 0.72895436,  1.11733109, -1.48011357, ..., -0.3226951 ,
#        -0.3226951 ,  0.72895436])
# .values =
# array([ 0.18599049, -0.49151652, -0.09172065, ...,  0.18599049,
#         0.18599049,  0.18599049])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([-0.32307254,  1.92487265,  0.59836358, ..., -0.32307254,
#        -0.32307254, -0.32307254])
# .values =
# array([ 0.62487345, -0.21922659, -0.53477059, ..., -0.53477059,
#        -0.28314219,  0.28750772])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 1.7260953 , -0.26225749, -1.00554946, ..., -1.00554946,
#        -0.41281637,  0.93140029])
# .values =
# array([ 0.00683732, -0.0246846 ,  0.02290737, ...,  0.02290737,
#         0.00683732, -0.0051011 ])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([-0.13347962,  1.57711311, -1.00554946, ..., -1.00554946,
#        -0.13347962,  0.5143796 ])
# .values =
# array([-0.26314191, -0.26314191,  0.06509528, ...,  0.12878074,
#         0.08540961,  0.12878074])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 1.82216229,  1.82216229, -0.17035703, ..., -0.55695098,
#        -0.29367241, -0.55695098])
# .values =
# array([ 0.15025509, -0.40721967,  0.15025509, ...,  0.15025509,
#        -0.40721967,  0.15025509])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([-0.22332692,  0.7066837 , -0.22332692, ..., -0.22332692,
#         0.7066837 , -0.22332692])
# .values =
# array([-0.06208177, -0.06208177,  0.15532126, ..., -0.06208177,
#         0.20686132, -0.06208177])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 0.62133384,  0.62133384, -0.64862661, ...,  0.62133384,
#        -0.94969801,  0.62133384])
# .values =
# array([-0.49350333, -0.01589566, -0.49350333, ..., -0.49350333,
#        -0.49350333, -0.49350333])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([-0.5840316 ,  0.25151281, -0.5840316 , ..., -0.5840316 ,
#        -0.5840316 , -0.5840316 ])
# .values =
# array([-0.49041724, -0.49041724,  0.22901503, ...,  0.22901503,
#         0.22901503,  0.11811596])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 0.79959541,  0.79959541, -0.22365204, ..., -0.22365204,
#        -0.22365204, -0.06592044])
# .values =
# array([ 0.08578375, -0.40357152,  0.33239635, ...,  0.33239635,
#         0.12093299, -0.13083025])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([-0.10043523,  1.69558986, -1.00554946, ..., -1.00554946,
#        -0.22943949,  0.69457856])
# .values =
# array([ 0.3910399 ,  0.3910399 , -1.00947995, ..., -0.24140258,
#         0.15553993,  0.15553993])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 0.80769208,  0.80769208, -1.48011357, ..., -0.22542822,
#         0.42299338,  0.42299338])
# .values =
# array([-0.20186519, -0.20186519,  0.03664651, ...,  0.13680866,
#         0.52049805, -0.20186519])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 0.58268625,  0.58268625,  0.07932923, ..., -0.13205379,
#        -0.94179494,  0.58268625])
# .values =
# array([-0.04690077, -0.00481687,  0.02026341, ..., -0.11101359,
#        -0.08535147,  0.02026341])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([-0.26007646,  0.09115383,  0.3004726 , ..., -0.79515906,
#        -0.58098418,  0.3004726 ])
# .values =
# array([ 0.06391192,  0.52374433, -0.31910446, ..., -0.18085161,
#        -0.00183803, -0.00183803])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 0.3026651 ,  1.74210988, -0.89631721, ..., -0.46353487,
#         0.09684355,  0.09684355])
# .values =
# array([ 0.00145572,  0.00145572, -0.00691844, ...,  0.00145572,
#        -0.00337118,  0.00145572])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 0.43720996,  0.43720996, -1.31650893, ...,  0.43720996,
#        -0.5736402 ,  0.43720996])
# .values =
# array([-0.00905824, -0.00905824, -0.00905824, ..., -0.00905824,
#         0.03961481, -0.00905824])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 0.28643024,  0.28643024,  0.28643024, ...,  0.28643024,
#        -0.78689034,  0.28643024])
# .values =
# array([-0.07544522, -0.31254415, -0.31254415, ...,  0.25064007,
#        -0.07544522,  0.12340586])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 0.32010486,  0.99260162,  0.99260162, ..., -0.6047888 ,
#         0.32010486, -0.24390739])
# .values =
# array([ 0.17658883,  0.17658883, -0.37525126, ..., -0.37525126,
#         0.17658883,  0.17658883])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 0.31746179,  0.31746179, -0.72582094, ..., -0.72582094,
#         0.31746179,  0.31746179])
# .values =
# array([ 0.07537191,  0.08755061, -0.10733809, ..., -0.10733809,
#         0.01241514,  0.01241514])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 0.43307072,  0.50093817, -0.58510547, ..., -0.58510547,
#         0.08223558,  0.08223558])
# .values =
# array([ 0.05857367, -0.31120675,  0.05857367, ...,  0.05857367,
#         0.05857367,  0.05857367])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([-0.2105276 ,  2.14196943, -0.2105276 , ..., -0.2105276 ,
#        -0.2105276 , -0.2105276 ])
# .values =
# array([-0.15118174, -0.27975646, -0.27975646, ...,  0.04257238,
#         0.04257238, -0.27975646])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([0.489254  , 0.81392165, 0.81392165, ..., 0.        , 0.        ,
#        0.81392165])
# .values =
# array([-0.03421164, -0.00612705,  0.06707189, ..., -0.03421164,
#         0.06707189,  0.03571421])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 0.32592608,  0.11896768, -0.42044324, ...,  0.32592608,
#        -0.42044324, -0.18936508])
# .values =
# array([-0.03674253, -0.03674253,  0.34540899, ..., -0.03674253,
#        -0.03674253, -0.03674253])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 0.33108872,  0.33108872, -1.37415297, ...,  0.33108872,
#         0.33108872,  0.33108872])
# .values =
# array([ 0.0241409 ,  0.0241409 ,  0.0241409 , ...,  0.0241409 ,
#        -0.02654173, -0.02654173])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 0.48476763,  0.48476763,  0.48476763, ...,  0.48476763,
#        -0.2885318 , -0.2885318 ])
# .values =
# array([ 0.00316879,  0.00316879, -0.02692211, ...,  0.00316879,
#        -0.01807979,  0.00316879])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 0.26462064,  0.26462064, -1.38204197, ...,  0.26462064,
#        -0.89816386,  0.26462064])
# .values =
# array([-0.1245302 , -0.1245302 ,  0.33669277, ..., -0.1245302 ,
#         0.33669277, -0.1245302 ])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 0.25259013,  0.25259013, -0.49945757, ...,  0.25259013,
#        -0.49945757,  0.25259013])
# .values =
# array([0.0250219, 0.0250219, 0.0250219, ..., 0.0250219, 0.0250219,
#        0.0250219])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([0.27008795, 0.27008795, 0.27008795, ..., 0.27008795, 0.27008795,
#        0.27008795])
# .values =
# array([-0.06794356,  0.19337782,  0.19337782, ..., -0.06794356,
#        -0.06794356, -0.06794356])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([-0.18718329,  0.8595552 ,  0.8595552 , ..., -0.18718329,
#        -0.18718329, -0.18718329])
# .values =
# array([-0.12307478, -0.12307478, -0.12307478, ..., -0.12307478,
#         0.22227156, -0.12307478])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 0.44177225,  0.44177225,  0.44177225, ...,  0.44177225,
#        -0.60684965,  0.44177225])
# .values =
# array([ 0.44262799,  0.14346117, -0.27153434, ..., -0.27153434,
#        -0.27153434,  0.44262799])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 1.05380532,  0.42523164, -0.44670749, ..., -0.44670749,
#        -0.44670749,  1.05380532])
# .values =
# array([-0.04725646,  0.12776748,  0.12776748, ..., -0.04725646,
#        -0.04725646, -0.04725646])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([-0.2006119 ,  0.92478913,  0.92478913, ..., -0.2006119 ,
#        -0.2006119 , -0.2006119 ])
# .values =
# array([-0.04448914, -0.04448914, -0.04448914, ..., -0.04448914,
#         0.13462481, -0.04448914])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([ 0.28199654,  0.28199654,  0.28199654, ...,  0.28199654,
#        -0.81172408,  0.28199654])
# .values =
# array([-0.03414013, -0.03414013, -0.03414013, ..., -0.03414013,
#        -0.03414013, -0.03414013])
#
# .base_values =
# array([-4.91120521, -4.91120521, -4.91120521, ..., -4.91120521,
#        -4.91120521, -4.91120521])
#
# .data =
# array([-0.15241742, -0.15241742, -0.15241742, ..., -0.15241742,
#        -0.15241742, -0.15241742])
# 2024/05/23 22:20:29 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:20:29 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!

# %%
pd.merge(
    pd.DataFrame(data_dict['df_test'][TARGET_BIN].value_counts()),
    pd.DataFrame(data_dict['df_test'][TARGET_BIN].value_counts(normalize=True)),
    how='outer', left_index=True, right_index=True
)
# Out:
#                       count  proportion
# _GB6_Flag_2Limit_bin
# 0                     10941    0.968401
# 1                       357    0.031599

# %%
pd.merge(
    pd.DataFrame(data_dict['df_val'][TARGET_BIN].value_counts()),
    pd.DataFrame(data_dict['df_val'][TARGET_BIN].value_counts(normalize=True)),
    how='outer', left_index=True, right_index=True
)
# Out:
#                       count  proportion
# _GB6_Flag_2Limit_bin
# 0                     12545    0.965297
# 1                       451    0.034703

# %%
pd.merge(
    pd.DataFrame(data_dict['df_train'][TARGET_BIN].value_counts()),
    pd.DataFrame(data_dict['df_train'][TARGET_BIN].value_counts(normalize=True)),
    how='outer', left_index=True, right_index=True
)
# Out:
#                       count  proportion
# _GB6_Flag_2Limit_bin
# 0                      2518    0.968462
# 1                        82    0.031538

# %%
pd.merge(
    pd.DataFrame(data_dict['df_train_val'][TARGET_BIN].value_counts()),
    pd.DataFrame(data_dict['df_train_val'][TARGET_BIN].value_counts(normalize=True)),
    how='outer', left_index=True, right_index=True
)
# Out:
#                       count  proportion
# _GB6_Flag_2Limit_bin
# 0                     15063    0.965825
# 1                       533    0.034175

# %%
res.sort_values('PR_AUC_val', ascending=False).head()
# Out:
#     iter  GINI_train  GINI_val  GINI_prcnt_chng  PR_AUC_train  PR_AUC_val  \
# 47    47    0.700004  0.663616        -5.198221      0.142432    0.175001
# 61    61    0.720151  0.664134        -7.778522      0.162069    0.173205
# 38    38    0.696371  0.651576        -6.432686      0.141196    0.172191
# 67    67    0.720752  0.660822        -8.314918      0.174926    0.170289
# 20    20    0.706988  0.650247        -8.025709      0.138451    0.169174
#
#     PR_AUC_prcnt_chng                                             params
# 47          22.865898  {'penalty': 'l1', 'C': 17.665605178377366, 'fi...
# 61           6.870993  {'penalty': 'l2', 'C': 12.687026894027277, 'fi...
# 38          21.951788  {'penalty': 'elasticnet', 'C': 0.8086717907686...
# 67          -2.650837  {'penalty': 'elasticnet', 'C': 1.8057954010881...
# 20          22.190243  {'penalty': 'elasticnet', 'C': 16.845695491899...

# %%
res.sort_values('GINI_val', ascending=False).head()
# Out:
#     iter  GINI_train  GINI_val  GINI_prcnt_chng  PR_AUC_train  PR_AUC_val  \
# 79    79    0.726409  0.672620        -7.404719      0.165275    0.163727
# 64    64    0.750877  0.668993       -10.905052      0.154846    0.158242
# 61    61    0.720151  0.664134        -7.778522      0.162069    0.173205
# 47    47    0.700004  0.663616        -5.198221      0.142432    0.175001
# 67    67    0.720752  0.660822        -8.314918      0.174926    0.170289
#
#     PR_AUC_prcnt_chng                                             params
# 79          -0.936633  {'penalty': 'elasticnet', 'C': 17.126485837561...
# 64           2.193305  {'penalty': 'elasticnet', 'C': 15.232392306574...
# 61           6.870993  {'penalty': 'l2', 'C': 12.687026894027277, 'fi...
# 47          22.865898  {'penalty': 'l1', 'C': 17.665605178377366, 'fi...
# 67          -2.650837  {'penalty': 'elasticnet', 'C': 1.8057954010881...

# %%
res[res.iter == 61].params.values[0]
# Out:
# {'penalty': 'l2',
#  'C': 12.687026894027277,
#  'fit_intercept': True,
#  'class_weight': 'balanced',
#  'random_state': 42,
#  'n_jobs': -1,
#  'solver': 'saga'}

# %%
params = copy.deepcopy(res[res.iter == 61].params.values[0])

# %%
params['max_iter'] = 50000

# %%
data_dict, model, scaler = train_pred(
    data_dict=data_dict,
    cols_to_use=COLS_TO_USE,
    target_name=TARGET_BIN,
    model=MODEL,
    params=params,
    alias='',
    test_name='df_test_same'
)
# Out:
# The max_iter was reached which means the coef_ did not converge

# %%
model.coef_
# Out:
# array([[-2.03592562, -0.9676529 , -1.51509728,  0.01801525,  0.04701541,
#         -0.26635257, -0.02645267, -0.68675356, -0.029077  , -0.42484534,
#          0.10069831,  0.37043116, -0.42403341, -0.3608146 , -0.40280074,
#         -0.55660159,  0.05919786, -0.25080745, -0.43682218, -0.37450186,
#          0.61053062,  0.04176241,  0.17599621, -0.77793417, -0.45411426,
#         -0.46315259,  0.57443472, -0.19784605, -0.08792534,  0.72560217,
#         -0.50565845, -0.16812243,  0.65723251, -0.44098143, -0.22902211,
#         -0.26235533, -0.43386194, -0.0071487 , -0.89920155, -0.47769139,
#         -0.3397506 ,  0.2160366 , -0.04227093,  0.35117463,  0.10197084,
#          0.0570693 , -0.27078198]])

# %%
model.intercept_
# Out:
# array([-2.06818996])

# %%
df_coeff = pd.DataFrame(
    {
        'Feature': COLS_TO_USE + ['Intercept'],
        'Coeff': np.append(model.coef_[0], model.intercept_)
    }
)

# %%
df_coeff['Coeff_abs'] = df_coeff.Coeff.abs()
df_coeff['Importance (%)'] = df_coeff.Coeff_abs * 100 / df_coeff.Coeff_abs.sum()
df_coeff = df_coeff.sort_values('Coeff_abs', ascending=False)

# %%
def logit_pvalue(model, x):
    """ Calculate z-scores for scikit-learn LogisticRegression.
    parameters:
        model: fitted sklearn.linear_model.LogisticRegression with intercept and large C
        x:     matrix on which the model was fit
    This function uses asymtptics for maximum likelihood estimates.

 
    For a vector of maximum likelihood estimates theta, its variance-covariance matrix can be estimated as inverse(H), where H is the Hessian matrix of log-likelihood at theta.

 
    """
    from scipy.stats import norm
    p = model.predict_proba(x)
    n = len(p)
    m = len(model.coef_[0]) + 1
    coefs = np.concatenate([model.intercept_, model.coef_[0]])
    x_full = np.matrix(np.insert(np.array(x), 0, 1, axis = 1))
    ans = np.zeros((m, m))
    for i in range(n):
        ans = ans + np.dot(np.transpose(x_full[i, :]), x_full[i, :]) * p[i,1] * p[i, 0]
    vcov = np.linalg.inv(np.matrix(ans))
    se = np.sqrt(np.diag(vcov))
    t =  coefs/se  
    p = (1 - norm.cdf(abs(t))) * 2
    return p

# %%
df_p = pd.DataFrame(
    {
        'p-value': logit_pvalue(model, data_dict['df_train_val'][COLS_TO_USE]), 
        'Feature': ['Intercept'] + COLS_TO_USE,
    }
)
# Out:
# X has feature names, but LogisticRegression was fitted without feature names

# %%
df_coeff = pd.merge(df_coeff, df_p, on='Feature', how='outer')
df_coeff
# Out:
#                       Feature     Coeff  Coeff_abs  Importance (%)  \
# 0           AFF_B_09_01OptBin  0.047015   0.047015        0.223971
# 1           AFF_E_07_01OptBin -0.042271   0.042271        0.201370
# 2           AFF_T_07_01OptBin  0.057069   0.057069        0.271866
# 3   CLU_CLI_L6M_NPR_L6MOptBin -0.168122   0.168122        0.800899
# 4               E1_A_09OptBin  0.610531   0.610531        2.908436
# 5               E1_B_06OptBin  0.657233   0.657233        3.130914
# 6               E2_G_08OptBin  0.101971   0.101971        0.485767
# 7               E4_Q_04OptBin -0.262355   0.262355        1.249804
# 8               E4_Q_17OptBin  0.370431   0.370431        1.764654
# 9              EA1_D_02OptBin -0.339751   0.339751        1.618498
# 10             EA5_S_01OptBin -0.505658   0.505658        2.408848
# 11         G5_ND_SPECIIOptBin -0.967653   0.967653        4.609689
# 12      GEN11_SP_EDI_07OptBin  0.574435   0.574435        2.736483
# 13        GEN11_SP_K_80OptBin -0.229022   0.229022        1.091012
# 14        GEN11_SP_N_91OptBin -0.463153   0.463153        2.206359
# 15        GEN11_SP_N_92OptBin -0.029077   0.029077        0.138517
# 16                  Intercept -2.068190   2.068190        9.852410
# 17       Marital_StatusOptBin -1.515097   1.515097        7.217596
# 18            ND_ECC_04OptBin -0.433862   0.433862        2.066825
# 19            ND_ECC_06OptBin -0.197846   0.197846        0.942496
# 20            ND_ERL_01OptBin -0.477691   0.477691        2.275619
# 21            ND_HAC_06OptBin  0.216037   0.216037        1.029152
# 22            ND_INC_03OptBin  0.175996   0.175996        0.838408
# 23       OPTIN_11SCN_MLOptBin -2.035926   2.035926        9.698710
# 24            SPA_F2_33OptBin -0.556602   0.556602        2.651530
# 25             SP_B1_14OptBin -0.454114   0.454114        2.163302
# 26             SP_B2_18OptBin -0.402801   0.402801        1.918856
# 27            SP_EDI_24OptBin -0.424845   0.424845        2.023871
# 28             SP_F2_33OptBin  0.018015   0.018015        0.085821
# 29              SP_G_37OptBin  0.100698   0.100698        0.479705
# 30              SP_G_38OptBin -0.436822   0.436822        2.080926
# 31           SP_I_67_01OptBin -0.440981   0.440981        2.100740
# 32             TRD_A_08OptBin -0.026453   0.026453        0.126015
# 33             TRD_A_20OptBin -0.266353   0.266353        1.268846
# 34             TRD_B_08OptBin  0.725602   0.725602        3.456612
# 35             TRD_B_18OptBin -0.087925   0.087925        0.418857
# 36             TRD_B_20OptBin -0.360815   0.360815        1.718843
# 37             TRD_C_07OptBin -0.424033   0.424033        2.020004
# 38             TRD_O_05OptBin -0.374502   0.374502        1.784046
# 39             TRD_O_06OptBin  0.351175   0.351175        1.672920
# 40             TRD_O_07OptBin  0.041762   0.041762        0.198947
# 41      VAL_DELINQ_ACCSOptBin -0.899202   0.899202        4.283602
# 42       VM01_SP_VM2_14OptBin  0.059198   0.059198        0.282006
# 43       VM01_SP_VM2_15OptBin -0.686754   0.686754        3.271546
# 44       VM01_SP_VM2_17OptBin -0.777934   0.777934        3.705910
# 45       VM01_SP_VM2_24OptBin -0.250807   0.250807        1.194793
# 46       VM02_SP_VM1_18OptBin -0.270782   0.270782        1.289947
# 47       VM08_SP_VM2_15OptBin -0.007149   0.007149        0.034055
#
#          p-value
# 0   6.409588e-01
# 1   7.649862e-01
# 2   6.498307e-01
# 3   1.912305e-01
# 4   1.350660e-09
# 5   1.375288e-06
# 6   5.099673e-01
# 7   5.563509e-02
# 8   2.673164e-06
# 9   1.176445e-04
# 10  2.160805e-08
# 11  2.220446e-16
# 12  2.113368e-06
# 13  3.174506e-01
# 14  2.355750e-05
# 15  7.109000e-01
# 16  0.000000e+00
# 17  0.000000e+00
# 18  7.755298e-04
# 19  1.082004e-01
# 20  4.118380e-03
# 21  2.298334e-01
# 22  9.256061e-02
# 23  0.000000e+00
# 24  8.343492e-06
# 25  4.519610e-03
# 26  3.452371e-04
# 27  3.393271e-03
# 28  8.751690e-01
# 29  2.302491e-01
# 30  3.654158e-06
# 31  2.146691e-05
# 32  7.092158e-01
# 33  5.156049e-03
# 34  5.159375e-10
# 35  3.771981e-01
# 36  9.675172e-06
# 37  8.016741e-03
# 38  3.335095e-02
# 39  3.112243e-03
# 40  6.399766e-01
# 41  0.000000e+00
# 42  5.937221e-01
# 43  5.966760e-11
# 44  2.397144e-06
# 45  3.807208e-02
# 46  1.028220e-02
# 47  9.432499e-01

# %%
p_level = 0.05

# %%
for col in COLS_TO_USE:
    if col not in df_coeff[df_coeff['p-value'] > p_level].Feature.values:
        print(f'"{col}",')
# Out:
# "OPTIN_11SCN_MLOptBin",
# "G5_ND_SPECIIOptBin",
# "Marital_StatusOptBin",
# "TRD_A_20OptBin",
# "VM01_SP_VM2_15OptBin",
# "SP_EDI_24OptBin",
# "E4_Q_17OptBin",
# "TRD_C_07OptBin",
# "TRD_B_20OptBin",
# "SP_B2_18OptBin",
# "SPA_F2_33OptBin",
# "VM01_SP_VM2_24OptBin",
# "SP_G_38OptBin",
# "TRD_O_05OptBin",
# "E1_A_09OptBin",
# "VM01_SP_VM2_17OptBin",
# "SP_B1_14OptBin",
# "GEN11_SP_N_91OptBin",
# "GEN11_SP_EDI_07OptBin",
# "TRD_B_08OptBin",
# "EA5_S_01OptBin",
# "E1_B_06OptBin",
# "SP_I_67_01OptBin",
# "ND_ECC_04OptBin",
# "VAL_DELINQ_ACCSOptBin",
# "ND_ERL_01OptBin",
# "EA1_D_02OptBin",
# "TRD_O_06OptBin",
# "VM02_SP_VM1_18OptBin",

# %%
len([
   "OPTIN_11SCN_MLOptBin",
"G5_ND_SPECIIOptBin",
"Marital_StatusOptBin",
"SP_F2_33OptBin",
"AFF_B_09_01OptBin",
"TRD_A_20OptBin",
"VM01_SP_VM2_15OptBin",
"SP_EDI_24OptBin",
"E4_Q_17OptBin",
"TRD_C_07OptBin",
"SP_B2_18OptBin",
"SPA_F2_33OptBin",
"VM01_SP_VM2_14OptBin",
"SP_G_38OptBin",
"TRD_O_05OptBin",
"E1_A_09OptBin",
"TRD_O_07OptBin",
"ND_INC_03OptBin",
"VM01_SP_VM2_17OptBin",
"GEN11_SP_N_91OptBin",
"GEN11_SP_EDI_07OptBin",
"TRD_B_18OptBin",
"EA5_S_01OptBin",
"CLU_CLI_L6M_NPR_L6MOptBin",
"SP_I_67_01OptBin",
"GEN11_SP_K_80OptBin",
"ND_ECC_04OptBin",
"ND_ERL_01OptBin",
"ND_HAC_06OptBin",
"AFF_E_07_01OptBin",
"TRD_O_06OptBin",
"E2_G_08OptBin",
"AFF_T_07_01OptBin", 
])
# Out:
# 33

# %%
from sklearn.metrics import precision_score, recall_score

# %%
sns.histplot(x=data_dict['df_test']['score'], hue=data_dict['df_test'][TARGET_BIN], common_norm=False, stat='density')
# Out:
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# <Axes: xlabel='score', ylabel='Density'>

# %%
from utils.metrics_by_quantile import MetricsByQuantile

# %%
temp = pd.merge(
    pd.DataFrame(pd.qcut(data_dict['df_test']['score'].round(3).values, q=200, duplicates='drop').value_counts().sort_index(ascending=False).cumsum()),
    pd.DataFrame(pd.qcut(data_dict['df_test']['score'].round(3).values, q=200, duplicates='drop').value_counts().sort_index(ascending=False)),
    left_index=True, right_index=True
)
temp['%'] = (temp['count_x'] * 100 / data_dict['df_test'].shape[0]).round(2)
temp
# Out:
#                  count_x  count_y       %
# (0.932, 0.968]        56       56    0.50
# (0.921, 0.932]       113       57    1.00
# (0.912, 0.921]       164       51    1.45
# (0.903, 0.912]       222       58    1.96
# (0.898, 0.903]       278       56    2.46
# ...                  ...      ...     ...
# (0.007, 0.008]     10989       91   97.27
# (0.006, 0.007]     11078       89   98.05
# (0.005, 0.006]     11148       70   98.67
# (0.004, 0.005]     11217       69   99.28
# (0.0009, 0.004]    11298       81  100.00
#
# [192 rows x 3 columns]

# %%
m = MetricsByQuantile(metrics=["quantiles_analytics"])
r = m.compute(
    y_true=data_dict['df_test'][TARGET_BIN].reset_index(drop=True), 
    y_pred=data_dict['df_test']['score'].round(3).reset_index(drop=True), 
    list_of_metrics = [
        "cum_precision_by_quantile", "cum_recall_by_quantile", 
        "precision_by_quantile", "recall_by_quantile",
    ], 
    n_quantiles = 200
)
df_deciles = r["other"]["quantiles_analytics"]
df_deciles.head(50)
# Out:
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#     % of total population  Cumulative % of total population  Total  Bad  \
# 0                    0.50                              0.50     56    8
# 1                    0.50                              1.00     57   14
# 2                    0.45                              1.45     51   10
# 3                    0.51                              1.96     58    5
# 4                    0.50                              2.46     56   11
# 5                    0.54                              3.00     61    8
# 6                    0.48                              3.48     54   10
# 7                    0.48                              3.96     54   11
# 8                    0.55                              4.51     62   12
# 9                    0.49                              4.99     55    4
# 10                   0.42                              5.41     47    8
# 11                   0.50                              5.91     57    2
# 12                   0.52                              6.43     59    4
# 13                   0.56                              6.99     63    6
# 14                   0.42                              7.41     47    7
# 15                   0.55                              7.96     62    5
# 16                   0.55                              8.51     62    5
# 17                   0.45                              8.96     51    3
# 18                   0.44                              9.40     50    2
# 19                   0.55                              9.95     62    6
# 20                   0.50                             10.44     56    2
# 21                   0.49                             10.93     55    3
# 22                   0.54                             11.47     61    8
# 23                   0.52                             11.99     59    7
# 24                   0.50                             12.50     57    6
# 25                   0.48                             12.98     54    7
# 26                   0.51                             13.49     58    2
# 27                   0.51                             14.00     58    8
# 28                   0.44                             14.45     50    3
# 29                   0.53                             14.98     60    5
# 30                   0.51                             15.49     58    4
# 31                   0.50                             15.99     57    3
# 32                   0.46                             16.45     52    2
# 33                   0.50                             16.95     56    3
# 34                   0.50                             17.45     56    7
# 35                   0.50                             17.94     56    4
# 36                   0.49                             18.43     55    7
# 37                   0.56                             18.99     63    2
# 38                   0.50                             19.49     57    2
# 39                   0.50                             19.99     56    5
# 40                   0.46                             20.45     52    4
# 41                   0.56                             21.00     63    5
# 42                   0.43                             21.44     49    3
# 43                   0.48                             21.92     54    3
# 44                   0.57                             22.48     64    2
# 45                   0.48                             22.96     54    4
# 46                   0.50                             23.46     56    2
# 47                   0.54                             24.00     61    5
# 48                   0.45                             24.45     51    4
# 49                   0.49                             24.93     55    3
#
#     Cumulative Bad         Quantile  #Quantile  Cumulative Precision  \
# 0                8   (0.932, 0.968]        192             14.285714
# 1               22   (0.921, 0.932]        191             19.469027
# 2               32   (0.912, 0.921]        190             19.512195
# 3               37   (0.903, 0.912]        189             16.666667
# 4               48   (0.898, 0.903]        188             17.266187
# 5               56  (0.8911, 0.898]        187             16.519174
# 6               66  (0.884, 0.8911]        186             16.793893
# 7               77   (0.877, 0.884]        185             17.225951
# 8               89  (0.8686, 0.877]        184             17.485265
# 9               93   (0.86, 0.8686]        183             16.489362
# 10             101    (0.855, 0.86]        182             16.530278
# 11             103   (0.848, 0.855]        181             15.419162
# 12             107   (0.842, 0.848]        180             14.718019
# 13             113   (0.835, 0.842]        179             14.303797
# 14             120   (0.828, 0.835]        178             14.336918
# 15             125   (0.822, 0.828]        177             13.904338
# 16             130  (0.8168, 0.822]        176             13.527575
# 17             133   (0.81, 0.8168]        175             13.142292
# 18             135    (0.804, 0.81]        174             12.711864
# 19             141   (0.798, 0.804]        173             12.544484
# 20             143   (0.791, 0.798]        172             12.118644
# 21             146   (0.784, 0.791]        171             11.821862
# 22             154   (0.777, 0.784]        170             11.882716
# 23             161   (0.768, 0.777]        169             11.881919
# 24             167   (0.761, 0.768]        168             11.827195
# 25             174   (0.754, 0.761]        167             11.869031
# 26             176   (0.748, 0.754]        166             11.548556
# 27             184  (0.7414, 0.748]        165             11.630847
# 28             187  (0.735, 0.7414]        164             11.458333
# 29             192   (0.728, 0.735]        163             11.347518
# 30             196    (0.72, 0.728]        162             11.200000
# 31             199    (0.713, 0.72]        161             11.012728
# 32             201   (0.705, 0.713]        160             10.812265
# 33             204   (0.696, 0.705]        159             10.652742
# 34             211   (0.688, 0.696]        158             10.705226
# 35             215    (0.68, 0.688]        157             10.606808
# 36             222    (0.673, 0.68]        156             10.662824
# 37             224   (0.666, 0.673]        155             10.442890
# 38             226    (0.66, 0.666]        154             10.263397
# 39             231    (0.653, 0.66]        153             10.230292
# 40             235   (0.646, 0.653]        152             10.173160
# 41             240  (0.6376, 0.646]        151             10.113780
# 42             243  (0.629, 0.6376]        150             10.033031
# 43             246   (0.622, 0.629]        149              9.935380
# 44             248   (0.611, 0.622]        148              9.763780
# 45             252   (0.604, 0.611]        147              9.714726
# 46             254   (0.596, 0.604]        146              9.584906
# 47             259   (0.589, 0.596]        145              9.553670
# 48             263    (0.58, 0.589]        144              9.522085
# 49             266     (0.57, 0.58]        143              9.442670
#
#     Cumulative Recall  Precision    Recall         Scores
# 0            2.240896  14.285714  2.240896   0.932--0.968
# 1            6.162465  24.561404  3.921569   0.921--0.932
# 2            8.963585  19.607843  2.801120   0.912--0.921
# 3           10.364146   8.620690  1.400560   0.903--0.912
# 4           13.445378  19.642857  3.081232   0.898--0.903
# 5           15.686275  13.114754  2.240896  0.8911--0.898
# 6           18.487395  18.518519  2.801120  0.884--0.8911
# 7           21.568627  20.370370  3.081232   0.877--0.884
# 8           24.929972  19.354839  3.361345  0.8686--0.877
# 9           26.050420   7.272727  1.120448   0.86--0.8686
# 10          28.291317  17.021277  2.240896    0.855--0.86
# 11          28.851541   3.508772  0.560224   0.848--0.855
# 12          29.971989   6.779661  1.120448   0.842--0.848
# 13          31.652661   9.523810  1.680672   0.835--0.842
# 14          33.613445  14.893617  1.960784   0.828--0.835
# 15          35.014006   8.064516  1.400560   0.822--0.828
# 16          36.414566   8.064516  1.400560  0.8168--0.822
# 17          37.254902   5.882353  0.840336   0.81--0.8168
# 18          37.815126   4.000000  0.560224    0.804--0.81
# 19          39.495798   9.677419  1.680672   0.798--0.804
# 20          40.056022   3.571429  0.560224   0.791--0.798
# 21          40.896359   5.454545  0.840336   0.784--0.791
# 22          43.137255  13.114754  2.240896   0.777--0.784
# 23          45.098039  11.864407  1.960784   0.768--0.777
# 24          46.778711  10.526316  1.680672   0.761--0.768
# 25          48.739496  12.962963  1.960784   0.754--0.761
# 26          49.299720   3.448276  0.560224   0.748--0.754
# 27          51.540616  13.793103  2.240896  0.7414--0.748
# 28          52.380952   6.000000  0.840336  0.735--0.7414
# 29          53.781513   8.333333  1.400560   0.728--0.735
# 30          54.901961   6.896552  1.120448    0.72--0.728
# 31          55.742297   5.263158  0.840336    0.713--0.72
# 32          56.302521   3.846154  0.560224   0.705--0.713
# 33          57.142857   5.357143  0.840336   0.696--0.705
# 34          59.103641  12.500000  1.960784   0.688--0.696
# 35          60.224090   7.142857  1.120448    0.68--0.688
# 36          62.184874  12.727273  1.960784    0.673--0.68
# 37          62.745098   3.174603  0.560224   0.666--0.673
# 38          63.305322   3.508772  0.560224    0.66--0.666
# 39          64.705882   8.928571  1.400560    0.653--0.66
# 40          65.826331   7.692308  1.120448   0.646--0.653
# 41          67.226891   7.936508  1.400560  0.6376--0.646
# 42          68.067227   6.122449  0.840336  0.629--0.6376
# 43          68.907563   5.555556  0.840336   0.622--0.629
# 44          69.467787   3.125000  0.560224   0.611--0.622
# 45          70.588235   7.407407  1.120448   0.604--0.611
# 46          71.148459   3.571429  0.560224   0.596--0.604
# 47          72.549020   8.196721  1.400560   0.589--0.596
# 48          73.669468   7.843137  1.120448    0.58--0.589
# 49          74.509804   5.454545  0.840336     0.57--0.58
