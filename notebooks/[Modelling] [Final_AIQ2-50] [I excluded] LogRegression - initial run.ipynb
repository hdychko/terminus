# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys
import copy
from typing import (
    Dict, 
    List,
    Any
)

import mlflow
from datetime import datetime


import numpy as np
import pandas as pd

from scipy.stats import uniform
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedShuffleSplit

from joblib import load, dump

import seaborn as sns
import matplotlib.pyplot as plt

# %%
sys.path.append(os.path.join(os.getcwd(), '..'))
from utils.metrics import Metrics
from utils.modelling_tools import (
    search_hyper_params_and_log, 
    update_solver_by_penalty, 
    evaluate_model
)
from utils.metrics_by_quantile import MetricsByQuantile

# %%
RUN_NAME: str = '02-LogRegression-hyperparams_tunning'

# %%
PROJECT_PATH: str = os.path.join(os.getcwd(), '..')
DATA_PATH: str = os.path.join(PROJECT_PATH, 'data')
OPT_BIN_PATH: str = os.path.join(os.path.join(PROJECT_PATH, 'objects'), 'optbinners')
MODELS_PATH: str = os.path.join(os.path.join(PROJECT_PATH, 'objects'), 'models')

# %%
TRAIN_FROM: datetime.date = pd.to_datetime('2021-12-01').date()
TRAIN_TO: datetime.date = pd.to_datetime('2022-01-01').date()

VAL_FROM: datetime.date = pd.to_datetime('2022-01-01').date()
VAL_TO: datetime.date = pd.to_datetime('2022-05-01').date()

TEST_FROM: datetime.date = pd.to_datetime('2022-05-01').date()
TEST_TO: datetime.date = pd.to_datetime('2022-08-01').date()

# %%
# set constants
COLS_TO_USE: List[str] = [
'OPTIN_11SCN_MLOptBin',
'G5_ND_SPECIIOptBin',
'Marital_StatusOptBin',
'SP_F2_33OptBin',
'AFF_B_09_01OptBin',
'TRD_A_20OptBin',
'TRD_A_08OptBin',
'VM01_SP_VM2_15OptBin',
'GEN11_SP_N_92OptBin',
'SP_EDI_24OptBin',
'SP_G_37OptBin',
'E4_Q_17OptBin',
'TRD_C_07OptBin',
'TRD_B_20OptBin',
'SP_B2_18OptBin',
'SPA_F2_33OptBin',
'VM01_SP_VM2_14OptBin',
'VM01_SP_VM2_24OptBin',
'SP_G_38OptBin',
'TRD_O_05OptBin',
'E1_A_09OptBin',
'TRD_O_07OptBin',
'ND_INC_03OptBin',
'VM01_SP_VM2_17OptBin',
'SP_B1_14OptBin',
'GEN11_SP_N_91OptBin',
'GEN11_SP_EDI_07OptBin',
'ND_ECC_06OptBin',
'TRD_B_18OptBin',
'TRD_B_08OptBin',
'EA5_S_01OptBin',
'CLU_CLI_L6M_NPR_L6MOptBin',
'E1_B_06OptBin',
'SP_I_67_01OptBin',
'GEN11_SP_K_80OptBin',
'SP_I_63_01OptBin',
'E4_Q_04OptBin',
'ND_ECC_04OptBin',
'VM08_SP_VM2_15OptBin',
'VAL_DELINQ_ACCSOptBin',
'ND_ERL_01OptBin',
'VM08_SP_VM2_20OptBin',
'EA1_D_02OptBin',
'ND_HAC_06OptBin',
'AFF_E_07_01OptBin',
'TRD_O_06OptBin',
'E2_G_08OptBin',
'AFF_T_07_01OptBin',
'VM02_SP_VM1_18OptBin'
]

# %%
TARGET_NAME: str = 'GB6_Flag_2Limit'
TARGET_VALS: List[int] = [0, 1]
TARGET_BIN: str = f'_{TARGET_NAME}_bin'

PALETTE: Dict[str, str] = {
    TARGET_NAME: {
        'G': 'green',
        'B': 'red',
        'I': 'black'
    },
    TARGET_BIN: {0: 'green', 1: 'red'},
    'DataPart': {'Train+Val': 'black', 'Val': 'blue', 'Test': 'red', 'Train': 'orange'}
}

# %%
N_ITER: int = 100
RANDOM_SEED: int = 42
CONFIDENCE_LEVEL: float = 0.05

# %%
MODEL = LogisticRegression

# %%
PARAMS: Dict[str, Any] = dict(
    penalty=['l2', 'l1', 'elasticnet'], 
    C=uniform(loc=0, scale=20), 
    fit_intercept=[True], 
    class_weight=['balanced'], 
    random_state=[RANDOM_SEED], 
    n_jobs=[-1]
)

# %%
# read data
df: pd.DataFrame = pd.read_csv(os.path.join(DATA_PATH, 'final_aiq2_optbins.csv'), low_memory=False)

# %%
print('Number of rows: %.0f; columns: %.0f' % df.shape)
# Out:
# Number of rows: 110462; columns: 2069

# %% [markdown]
# # Preprocessing

# %% [markdown]
# Convert dates to the corresponding types

# %%
for col in ['_RDATE_EOM', '_RDATE']:
    df[col] = pd.to_datetime(df[col]).dt.date

# %%
print('Available date range:')
df['_RDATE'].agg(['min', 'max'])
# Out:
# Available date range:
# min    2021-06-30
# max    2023-11-30
# Name: _RDATE, dtype: object

# %% [markdown]
# # Split data

# %%
df_train = df.loc[
    (df._RDATE >= TRAIN_FROM) &
    (df._RDATE < TRAIN_TO) & 
    (df[TARGET_NAME] != 'I'),
    COLS_TO_USE + [TARGET_NAME, TARGET_BIN, '_RDATE']
].reset_index(drop=True)

df_train_val = df.loc[
    (df._RDATE >= TRAIN_FROM) &
    (df._RDATE < VAL_TO) &
    (df[TARGET_NAME] != 'I'),
    COLS_TO_USE + [TARGET_NAME, TARGET_BIN, '_RDATE']
].reset_index(drop=True)

df_val = df.loc[
    (df._RDATE >= VAL_FROM) &
    (df._RDATE < VAL_TO) &
    (df[TARGET_NAME] != 'I'),
    COLS_TO_USE + [TARGET_NAME, TARGET_BIN, '_RDATE']
].reset_index(drop=True)

df_test_same = df.loc[
    (df._RDATE >= TEST_FROM) &
    (df._RDATE < TEST_TO) &
    (df[TARGET_NAME] != 'I'),
    COLS_TO_USE + [TARGET_NAME, TARGET_BIN, '_RDATE']
].reset_index(drop=True)

df_test = df.loc[
    (df._RDATE >= TEST_FROM) &
    (df._RDATE < TEST_TO),
    COLS_TO_USE + [TARGET_NAME, TARGET_BIN, '_RDATE']
].reset_index(drop=True)

# %%
data_dict = {
    "df_train": df_train,
    "df_val": df_val,
    "df_train_val": df_train_val, 
    "df_test_same": df_test_same,
    "df_test": df_test
}

# %%
print('Target distribution')
print('Train:')
pd.merge(
    pd.DataFrame(data_dict['df_train'][TARGET_BIN].value_counts()),
    pd.DataFrame(data_dict['df_train'][TARGET_BIN].value_counts(normalize=True)),
    how='outer', left_index=True, right_index=True
)
# Out:
# Target distribution
# Train:
#                       count  proportion
# _GB6_Flag_2Limit_bin
# 0                      2518    0.968462
# 1                        82    0.031538

# %%
print('Validation:')
pd.merge(
    pd.DataFrame(data_dict['df_val'][TARGET_BIN].value_counts()),
    pd.DataFrame(data_dict['df_val'][TARGET_BIN].value_counts(normalize=True)),
    how='outer', left_index=True, right_index=True
)
# Out:
# Validation:
#                       count  proportion
# _GB6_Flag_2Limit_bin
# 0                     12545    0.965297
# 1                       451    0.034703

# %%
print('Train+Validation:')
pd.merge(
    pd.DataFrame(data_dict['df_train_val'][TARGET_BIN].value_counts()),
    pd.DataFrame(data_dict['df_train_val'][TARGET_BIN].value_counts(normalize=True)),
    how='outer', left_index=True, right_index=True
)
# Out:
# Train+Validation:
#                       count  proportion
# _GB6_Flag_2Limit_bin
# 0                     15063    0.965825
# 1                       533    0.034175

# %%
print('Test-same')
pd.merge(
    pd.DataFrame(data_dict['df_test_same'][TARGET_BIN].value_counts()),
    pd.DataFrame(data_dict['df_test_same'][TARGET_BIN].value_counts(normalize=True)),
    how='outer', left_index=True, right_index=True
)
# Out:
# Test-same
#                       count  proportion
# _GB6_Flag_2Limit_bin
# 0                     10290    0.966469
# 1                       357    0.033531

# %%
print('Test')
pd.merge(
    pd.DataFrame(data_dict['df_test'][TARGET_BIN].value_counts()),
    pd.DataFrame(data_dict['df_test'][TARGET_BIN].value_counts(normalize=True)),
    how='outer', left_index=True, right_index=True
)
# Out:
# Test
#                       count  proportion
# _GB6_Flag_2Limit_bin
# 0                     10941    0.968401
# 1                       357    0.031599

# %%
# randomly select N observations from test data
N = 10000
sss = StratifiedShuffleSplit(n_splits=1, train_size=N, random_state=RANDOM_SEED)
indx = sss.split(data_dict['df_test_same'].reset_index(drop=True), data_dict['df_test_same'][TARGET_BIN])
random_indx = list(indx)[0][0]

assert len(random_indx) == N, "Incorrect number of elements in the subsample"
test_sample = data_dict['df_test_same'].reset_index(drop=True).iloc[random_indx, :].reset_index(drop=True)

# %%
data_dict['df_test_same_sample'] = test_sample

# %% [markdown]
# # Run the experiment

# %%
mlflow.set_tracking_uri(uri="http://127.0.0.1:5000/")
mlflow.set_experiment("[Experian][Initial]")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/778824721878270035', creation_time=1716819596783, experiment_id='778824721878270035', last_update_time=1716819596783, lifecycle_stage='active', name='[Experian][Initial]', tags={}>

# %%
experiment_description = f"""
    'features': {len(COLS_TO_USE)},
    'target': {TARGET_BIN},
    'target_vals': '0==G, 1==B',
    'model': {MODEL.__name__},
    'data_version': '22.05.2024', 
    'train_period': [{TRAIN_FROM.strftime('%Y-%m-%d') + ', ' + TRAIN_TO.strftime('%Y-%m-%d')}),
    'val_period': [{VAL_FROM.strftime('%Y-%m-%d') + ', ' + VAL_TO.strftime('%Y-%m-%d')}),
    'test_period': [{TEST_FROM.strftime('%Y-%m-%d') + ', ' + TEST_TO.strftime('%Y-%m-%d')}),
"""

# %%
print(experiment_description)
# Out:
#     'features': 49,
#     'target': _GB6_Flag_2Limit_bin,
#     'target_vals': '0==G, 1==B',
#     'model': LogisticRegression,
#     'data_version': '22.05.2024',
#     'train_period': [2021-12-01, 2022-01-01),
#     'val_period': [2022-01-01, 2022-05-01),
#     'test_period': [2022-05-01, 2022-08-01),

# %%
with mlflow.start_run(run_name=RUN_NAME, log_system_metrics=True):
    res = search_hyper_params_and_log(
        run_name=RUN_NAME,
        data_dict=data_dict,
        cols_to_use=COLS_TO_USE,
        target_name=TARGET_BIN,
        distributions=PARAMS,
        n_iter=N_ITER,
        model=MODEL,
        custom_params_updates=update_solver_by_penalty,
        tags={'features': len(COLS_TO_USE)}, 
        palette=PALETTE['DataPart'],
        test_name='df_test_same',
        model_path=MODELS_PATH
    )
# Out:
# 2024/05/27 19:50:57 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024
WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/27 19:53:10 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# # 58 / 100
# 2024/05/27 19:53:16 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/27 19:53:16 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 59 / 100
# 2024/05/27 19:53:17 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/27 19:53:17 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/27 19:53:23 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/27 19:53:23 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 60 / 100
# # 61 / 100
# # 62 / 100
# # 63 / 100
# # 64 / 100
# # 65 / 100
# # 66 / 100
# # 67 / 100
# 2024/05/27 19:53:24 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/27 19:53:24 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/27 19:53:30 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/27 19:53:30 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 68 / 100
# # 69 / 100
# # 70 / 100
# # 71 / 100
# 2024/05/27 19:53:31 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/27 19:53:31 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
# ...
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/27 19:54:08 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/27 19:54:08 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 88 / 100
# 2024/05/27 19:54:09 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/27 19:54:09 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/27 19:54:15 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/27 19:54:15 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 89 / 100
# # 90 / 100
# # 91 / 100
# 2024/05/27 19:54:16 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/27 19:54:16 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# # 92 / 100
# 2024/05/27 19:54:22 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/27 19:54:22 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 93 / 100
# # 94 / 100
# 2024/05/27 19:54:22 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/27 19:54:22 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# # 95 / 100
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/27 19:54:28 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/27 19:54:28 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 96 / 100
# # 97 / 100
# 2024/05/27 19:54:29 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/27 19:54:29 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/27 19:54:35 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/27 19:54:35 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 2024/05/27 19:54:35 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/27 19:54:35 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# # 98 / 100
# 2024/05/27 19:54:41 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/27 19:54:41 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 2024/05/27 19:54:41 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/27 19:54:41 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# # 99 / 100
# 2024/05/27 19:54:47 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/27 19:54:47 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 100 / 100
# 2024/05/27 19:54:47 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/27 19:54:47 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/27 19:54:53 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/27 19:54:53 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# Best params:
#  {'penalty': 'l1', 'C': 0.14132610439434812, 'fit_intercept': True, 'class_weight': 'balanced', 'random_state': 42, 'n_jobs': -1, 'solver': 'liblinear'}
# Val-PR_AUC:  0.14382866151225446
# Val-GINI:  0.6601935913195864
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# Not saved
# Test-PR_AUC 0.14041193335398405
# Test-Gini 0.6630439931074468
# The option feature_dependence has been renamed to feature_perturbation!
# The feature_perturbation option is now deprecated in favor of using the appropriate masker (maskers.Independent, or maskers.Impute)
# 2024/05/27 19:55:07 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/27 19:55:07 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!

# %%
df_metrics, df_coeff, data_dict, model_obj, std_scaler = res

# %% [markdown]
# # Model's quality

# %% [markdown]
# ## Coefficients

# %%
df_coeff.sort_values('Importance(%)', ascending=False)
# Out:
#                       Feature     Coeff  Importance(%)       p-value  \
# 16                  Intercept -1.449260      18.118633  0.000000e+00
# 23       OPTIN_11SCN_MLOptBin -1.110205      13.879780  0.000000e+00
# 17       Marital_StatusOptBin -0.736444       9.207021  0.000000e+00
# 14        GEN11_SP_N_91OptBin -0.227491       2.844096  4.964489e-09
# 39             TRD_O_05OptBin -0.226122       2.826977  1.552092e-13
# 27            SP_EDI_24OptBin -0.216151       2.702316  4.879101e-06
# 38             TRD_C_07OptBin -0.210522       2.631941  1.122086e-06
# 10             EA5_S_01OptBin -0.204145       2.552223  5.351275e-14
# 24            SPA_F2_33OptBin -0.202486       2.531483  2.675054e-07
# 40             TRD_O_06OptBin  0.187659       2.346118  2.677898e-10
# 0           AFF_B_09_01OptBin  0.178671       2.233747  6.149386e-04
# 12      GEN11_SP_EDI_07OptBin  0.178249       2.228462  3.709419e-06
# 11         G5_ND_SPECIIOptBin -0.164646       2.058407  4.786682e-09
# 43       VM01_SP_VM2_14OptBin  0.164577       2.057539  3.452861e-05
# 30              SP_G_38OptBin -0.163699       2.046569  4.852471e-05
# 44       VM01_SP_VM2_15OptBin -0.157710       1.971688  3.047487e-04
# 6               E2_G_08OptBin  0.155883       1.948850  2.556616e-06
# 26             SP_B2_18OptBin -0.154874       1.936229  2.952837e-05
# 22            ND_INC_03OptBin -0.144911       1.811671  1.015970e-05
# 36             TRD_B_18OptBin  0.141014       1.762954  2.208912e-05
# 1           AFF_E_07_01OptBin -0.115634       1.445653  8.861682e-04
# 18            ND_ECC_04OptBin -0.113767       1.422316  4.740703e-04
# 13        GEN11_SP_K_80OptBin -0.102255       1.278387  5.287511e-04
# 21            ND_HAC_06OptBin  0.097454       1.218368  4.934457e-03
# 32           SP_I_67_01OptBin -0.094113       1.176600  3.977126e-03
# 28             SP_F2_33OptBin  0.092041       1.150697  5.690713e-02
# 3   CLU_CLI_L6M_NPR_L6MOptBin  0.089788       1.122532  2.075516e-03
# 4               E1_A_09OptBin  0.089406       1.117757  1.119496e-02
# 45       VM01_SP_VM2_17OptBin -0.078781       0.984922  1.329776e-01
# 8               E4_Q_17OptBin  0.077523       0.969197  2.115032e-02
# 34             TRD_A_20OptBin -0.072277       0.903610  3.595829e-02
# 41             TRD_O_07OptBin  0.067130       0.839257  2.715155e-02
# 20            ND_ERL_01OptBin -0.066159       0.827124  2.719308e-02
# 29              SP_G_37OptBin  0.056784       0.709912  1.353984e-01
# 2           AFF_T_07_01OptBin -0.054871       0.686002  4.579608e-02
# 19            ND_ECC_06OptBin  0.046415       0.580280  3.231847e-01
# 35             TRD_B_08OptBin  0.036460       0.455822  1.844157e-01
# 46       VM01_SP_VM2_24OptBin  0.036189       0.452439  3.355807e-01
# 25             SP_B1_14OptBin  0.035048       0.438167  4.540640e-01
# 48       VM08_SP_VM2_15OptBin  0.034532       0.431719  2.007655e-01
# 7               E4_Q_04OptBin  0.031719       0.396554  3.555855e-01
# 5               E1_B_06OptBin  0.023257       0.290760  5.570785e-01
# 37             TRD_B_20OptBin -0.022459       0.280780  5.204833e-01
# 9              EA1_D_02OptBin -0.021399       0.267531  3.465767e-01
# 33             TRD_A_08OptBin -0.021210       0.265165  5.535220e-01
# 47       VM02_SP_VM1_18OptBin  0.020691       0.258675  4.351162e-01
# 15        GEN11_SP_N_92OptBin  0.009957       0.124477  7.882782e-01
# 42      VAL_DELINQ_ACCSOptBin -0.009461       0.118280  6.895700e-01
# 31           SP_I_63_01OptBin  0.007224       0.090313  8.761053e-01
# 49       VM08_SP_VM2_20OptBin  0.000000       0.000000  1.000000e+00
#
#     Importance(SHAP)  Importance(SHAP, %)
# 16               NaN                  NaN
# 23          1.436258            28.766927
# 17          0.904504            18.116386
# 14          0.136320             2.730357
# 39          0.084000             1.682445
# 27          0.135498             2.713905
# 38          0.094184             1.886421
# 10          0.095571             1.914192
# 24          0.153651             3.077493
# 40          0.096118             1.925162
# 0           0.178729             3.579778
# 12          0.088474             1.772047
# 11          0.034277             0.686545
# 43          0.117802             2.359459
# 30          0.109785             2.198883
# 44          0.171576             3.436505
# 6           0.068382             1.369621
# 26          0.104498             2.092992
# 22          0.077939             1.561037
# 36          0.056723             1.136119
# 1           0.049156             0.984558
# 18          0.035415             0.709330
# 13          0.021818             0.437000
# 21          0.035405             0.709129
# 32          0.059765             1.197039
# 28          0.097837             1.959590
# 3           0.033109             0.663137
# 4           0.045814             0.917608
# 45          0.055369             1.108995
# 8           0.052892             1.059371
# 34          0.065873             1.319381
# 41          0.043541             0.872087
# 20          0.019327             0.387107
# 29          0.041751             0.836235
# 2           0.016202             0.324510
# 19          0.026625             0.533284
# 35          0.011072             0.221763
# 46          0.022286             0.446365
# 25          0.016475             0.329985
# 48          0.015316             0.306767
# 7           0.012246             0.245284
# 5           0.011211             0.224539
# 37          0.014666             0.293751
# 9           0.004571             0.091545
# 33          0.019837             0.397308
# 47          0.008683             0.173915
# 15          0.007755             0.155334
# 42          0.001917             0.038405
# 31          0.002517             0.050404
# 49          0.000000             0.000000

# %%
# features with 0 coefficients
df_coeff[df_coeff.Coeff == 0]
# Out:
#                  Feature  Coeff  Importance(%)  p-value  Importance(SHAP)  \
# 49  VM08_SP_VM2_20OptBin    0.0            0.0      1.0               0.0
#
#     Importance(SHAP, %)
# 49                  0.0

# %%
# features with high p-value
df_coeff[df_coeff['p-value'] > CONFIDENCE_LEVEL]
# Out:
#                   Feature     Coeff  Importance(%)   p-value  \
# 5           E1_B_06OptBin  0.023257       0.290760  0.557078
# 7           E4_Q_04OptBin  0.031719       0.396554  0.355586
# 9          EA1_D_02OptBin -0.021399       0.267531  0.346577
# 15    GEN11_SP_N_92OptBin  0.009957       0.124477  0.788278
# 19        ND_ECC_06OptBin  0.046415       0.580280  0.323185
# 25         SP_B1_14OptBin  0.035048       0.438167  0.454064
# 28         SP_F2_33OptBin  0.092041       1.150697  0.056907
# 29          SP_G_37OptBin  0.056784       0.709912  0.135398
# 31       SP_I_63_01OptBin  0.007224       0.090313  0.876105
# 33         TRD_A_08OptBin -0.021210       0.265165  0.553522
# 35         TRD_B_08OptBin  0.036460       0.455822  0.184416
# 37         TRD_B_20OptBin -0.022459       0.280780  0.520483
# 42  VAL_DELINQ_ACCSOptBin -0.009461       0.118280  0.689570
# 45   VM01_SP_VM2_17OptBin -0.078781       0.984922  0.132978
# 46   VM01_SP_VM2_24OptBin  0.036189       0.452439  0.335581
# 47   VM02_SP_VM1_18OptBin  0.020691       0.258675  0.435116
# 48   VM08_SP_VM2_15OptBin  0.034532       0.431719  0.200765
# 49   VM08_SP_VM2_20OptBin  0.000000       0.000000  1.000000
#
#     Importance(SHAP)  Importance(SHAP, %)
# 5           0.011211             0.224539
# 7           0.012246             0.245284
# 9           0.004571             0.091545
# 15          0.007755             0.155334
# 19          0.026625             0.533284
# 25          0.016475             0.329985
# 28          0.097837             1.959590
# 29          0.041751             0.836235
# 31          0.002517             0.050404
# 33          0.019837             0.397308
# 35          0.011072             0.221763
# 37          0.014666             0.293751
# 42          0.001917             0.038405
# 45          0.055369             1.108995
# 46          0.022286             0.446365
# 47          0.008683             0.173915
# 48          0.015316             0.306767
# 49          0.000000             0.000000

# %%
# features with not 0 coefficients
for col in COLS_TO_USE:
    if col not in df_coeff[df_coeff.Coeff == 0].Feature.values:
        print(f'"{col}",')
# Out:
# "OPTIN_11SCN_MLOptBin",
# "G5_ND_SPECIIOptBin",
# "Marital_StatusOptBin",
# "AFF_B_09_01OptBin",
# "TRD_A_20OptBin",
# "VM01_SP_VM2_15OptBin",
# "SP_EDI_24OptBin",
# "E4_Q_17OptBin",
# "TRD_C_07OptBin",
# "SP_B2_18OptBin",
# "SPA_F2_33OptBin",
# "VM01_SP_VM2_14OptBin",
# "SP_G_38OptBin",
# "TRD_O_05OptBin",
# "E1_A_09OptBin",
# "TRD_O_07OptBin",
# "ND_INC_03OptBin",
# "GEN11_SP_N_91OptBin",
# "GEN11_SP_EDI_07OptBin",
# "TRD_B_18OptBin",
# "EA5_S_01OptBin",
# "CLU_CLI_L6M_NPR_L6MOptBin",
# "SP_I_67_01OptBin",
# "GEN11_SP_K_80OptBin",
# "ND_ECC_04OptBin",
# "ND_ERL_01OptBin",
# "ND_HAC_06OptBin",
# "AFF_E_07_01OptBin",
# "TRD_O_06OptBin",
# "E2_G_08OptBin",
# "AFF_T_07_01OptBin",

# %% [markdown]
# ## GINI, AU PRC

# %% [markdown]
# ## Test-same

# %%
evaluate_model(
    data=data_dict['df_test_same'], 
    cols_to_use=COLS_TO_USE,
    std_scaler=std_scaler,
    target_name=TARGET_BIN,
    model_obj=model_obj
)
# Out:
# Test-PR_AUC 0.14041193335398405
# Test-Gini 0.6630439931074468

# %% [markdown]
# ## Test-full

# %%
evaluate_model(
    data=data_dict['df_test'], 
    cols_to_use=COLS_TO_USE,
    std_scaler=std_scaler,
    target_name=TARGET_BIN,
    model_obj=model_obj
)
# Out:
# Test-PR_AUC 0.12131131301108525
# Test-Gini 0.6443040427943412

# %% [markdown]
# ## Outcomes distributions

# %%
data_dict['df_test']['score'] = model_obj.predict_proba(
    std_scaler.transform(data_dict['df_test'][COLS_TO_USE])
)[:, 1]

# %% [markdown]
# ### Test-same

# %%
sns.histplot(x=data_dict['df_test_same']['score'], hue=data_dict['df_test_same'][TARGET_BIN], common_norm=False, stat='density')
# Out:
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# <Axes: xlabel='score', ylabel='Density'>

# %% [markdown]
# ### Test-full

# %%
sns.histplot(x=data_dict['df_test']['score'], hue=data_dict['df_test'][TARGET_BIN], common_norm=False, stat='density')
# Out:
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# <Axes: xlabel='score', ylabel='Density'>

# %% [markdown]
# ## Precision, Recall By Quantile

# %% [markdown]
# ### Test-same

# %%
m = MetricsByQuantile(metrics=["quantiles_analytics"])
r = m.compute(
    y_true=data_dict['df_test_same'][TARGET_BIN].reset_index(drop=True), 
    y_pred=data_dict['df_test_same']['score'].round(3).reset_index(drop=True), 
    list_of_metrics = [
        "cum_precision_by_quantile", "cum_recall_by_quantile", 
        "precision_by_quantile", "recall_by_quantile",
    ], 
    n_quantiles = 200
)
df_deciles = r["other"]["quantiles_analytics"]
df_deciles.head(50)
# Out:
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#     % of total population  Cumulative % of total population  Total  Bad  \
# 0                    0.50                              0.50     53   11
# 1                    0.51                              1.00     54   15
# 2                    0.50                              1.50     53   11
# 3                    0.47                              1.97     50    8
# 4                    0.50                              2.47     53    9
# 5                    0.51                              2.98     54   10
# 6                    0.53                              3.50     56   13
# 7                    0.50                              4.00     53    8
# 8                    0.46                              4.46     49    8
# 9                    0.54                              5.01     58    9
# 10                   0.42                              5.43     45    1
# 11                   0.48                              5.91     51    5
# 12                   0.56                              6.47     60    5
# 13                   0.53                              7.00     56   10
# 14                   0.41                              7.41     44    3
# 15                   0.52                              7.93     55    7
# 16                   0.57                              8.50     61    4
# 17                   0.40                              8.90     43    4
# 18                   0.56                              9.47     60    2
# 19                   0.51                              9.97     54    7
# 20                   0.49                             10.46     52    4
# 21                   0.54                             11.01     58    6
# 22                   0.50                             11.51     53    6
# 23                   0.46                             11.97     49    5
# 24                   0.53                             12.49     56    9
# 25                   0.47                             12.96     50    7
# 26                   0.49                             13.45     52    1
# 27                   0.55                             14.00     59    7
# 28                   0.44                             14.45     47    2
# 29                   0.48                             14.92     51    4
# 30                   0.56                             15.49     60    3
# 31                   0.49                             15.98     52    5
# 32                   0.53                             16.50     56    5
# 33                   0.50                             17.00     53    8
# 34                   0.44                             17.44     47    1
# 35                   0.52                             17.96     55    2
# 36                   0.49                             18.45     52    5
# 37                   0.53                             18.97     56    4
# 38                   0.41                             19.39     44    6
# 39                   0.59                             19.98     63    0
# 40                   0.52                             20.49     55    3
# 41                   0.47                             20.96     50    4
# 42                   0.46                             21.42     49    3
# 43                   0.55                             21.98     59    4
# 44                   0.51                             22.49     54    4
# 45                   0.46                             22.95     49    2
# 46                   0.53                             23.47     56    2
# 47                   0.49                             23.96     52    3
# 48                   0.50                             24.46     53    2
# 49                   0.54                             24.99     57    3
#
#     Cumulative Bad        Quantile  #Quantile  Cumulative Precision  \
# 0               11  (0.927, 0.966]        193             20.754717
# 1               26  (0.915, 0.927]        192             24.299065
# 2               37  (0.904, 0.915]        191             23.125000
# 3               45  (0.897, 0.904]        190             21.428571
# 4               54  (0.891, 0.897]        189             20.532319
# 5               64  (0.883, 0.891]        188             20.189274
# 6               77  (0.875, 0.883]        187             20.643432
# 7               85  (0.867, 0.875]        186             19.953052
# 8               93  (0.858, 0.867]        185             19.578947
# 9              102  (0.852, 0.858]        184             19.136961
# 10             103  (0.845, 0.852]        183             17.820069
# 11             108  (0.838, 0.845]        182             17.170111
# 12             113   (0.83, 0.838]        181             16.400581
# 13             123   (0.823, 0.83]        180             16.510067
# 14             126  (0.818, 0.823]        179             15.969582
# 15             133  (0.811, 0.818]        178             15.758294
# 16             137  (0.804, 0.811]        177             15.138122
# 17             141  (0.798, 0.804]        176             14.873418
# 18             143  (0.791, 0.798]        175             14.186508
# 19             150  (0.784, 0.791]        174             14.124294
# 20             154  (0.777, 0.784]        173             13.824057
# 21             160  (0.768, 0.777]        172             13.651877
# 22             166   (0.76, 0.768]        171             13.551020
# 23             171   (0.753, 0.76]        170             13.422292
# 24             180  (0.745, 0.753]        169             13.533835
# 25             187  (0.739, 0.745]        168             13.550725
# 26             188  (0.733, 0.739]        167             13.128492
# 37          65.546218   7.142857  1.120448   0.65--0.656
# 38          67.226891  13.636364  1.680672   0.642--0.65
# 39          67.226891   0.000000  0.000000  0.634--0.642
# 40          68.067227   5.454545  0.840336  0.625--0.634
# 41          69.187675   8.000000  1.120448  0.618--0.625
# 42          70.028011   6.122449  0.840336  0.609--0.618
# 43          71.148459   6.779661  1.120448  0.602--0.609
# 44          72.268908   7.407407  1.120448  0.592--0.602
# 45          72.829132   4.081633  0.560224  0.584--0.592
# 46          73.389356   3.571429  0.560224  0.575--0.584
# 47          74.229692   5.769231  0.840336  0.567--0.575
# 48          74.789916   3.773585  0.560224  0.559--0.567
# 49          75.630252   5.263158  0.840336   0.55--0.559

# %% [markdown]
# ### Test-full

# %%
m = MetricsByQuantile(metrics=["quantiles_analytics"])
r = m.compute(
    y_true=data_dict['df_test'][TARGET_BIN].reset_index(drop=True), 
    y_pred=data_dict['df_test']['score'].round(3).reset_index(drop=True), 
    list_of_metrics = [
        "cum_precision_by_quantile", "cum_recall_by_quantile", 
        "precision_by_quantile", "recall_by_quantile",
    ], 
    n_quantiles = 200
)
df_deciles = r["other"]["quantiles_analytics"]
df_deciles.head(50)
# Out:
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#     % of total population  Cumulative % of total population  Total  Bad  \
# 0                    0.50                              0.50     57    8
# 1                    0.47                              0.97     53   14
# 2                    0.43                              1.41     49    9
# 3                    0.53                              1.94     60    7
# 4                    0.52                              2.46     59   11
# 5                    0.48                              2.94     54    7
# 6                    0.52                              3.46     59   11
# 7                    0.50                              3.96     56   12
# 8                    0.48                              4.43     54    8
# 9                    0.50                              4.93     56    6
# 10                   0.53                              5.46     60    9
# 11                   0.47                              5.93     53    1
# 12                   0.53                              6.46     60    5
# 13                   0.53                              6.99     60    4
# 14                   0.48                              7.47     54    8
# 15                   0.51                              7.98     58    6
# 16                   0.48                              8.46     54    4
# 17                   0.47                              8.93     53    5
# 18                   0.53                              9.46     60    3
# 19                   0.54                             10.00     61    3
# 20                   0.49                             10.49     55    4
# 21                   0.43                             10.92     49    7
# 22                   0.56                             11.48     63    4
# 23                   0.50                             11.98     56    3
# 24                   0.46                             12.44     52    6
# 25                   0.57                             13.00     64    6
# 26                   0.48                             13.48     54    6
# 27                   0.43                             13.91     49    9
# 28                   0.53                             14.45     60    2
# 29                   0.54                             14.98     61    7
# 30                   0.51                             15.50     58    2
# 31                   0.47                             15.97     53    3
# 32                   0.54                             16.51     61    3
# 33                   0.46                             16.97     52    3
# 34                   0.50                             17.46     56    8
# 35                   0.48                             17.94     54    3
# 36                   0.53                             18.47     60    5
# 37                   0.53                             19.00     60    3
# 38                   0.48                             19.48     54    4
# 39                   0.42                             19.91     48    1
# 40                   0.59                             20.50     67    7
# 41                   0.43                             20.93     49    3
# 42                   0.56                             21.49     63    0
# 43                   0.48                             21.97     54    4
# 44                   0.42                             22.38     47    3
# 45                   0.57                             22.95     64    3
# 46                   0.55                             23.50     62    7
# 47                   0.43                             23.93     49    2
# 48                   0.52                             24.46     59    3
# 49                   0.50                             24.95     56    1
#
#     Cumulative Bad        Quantile  #Quantile  Cumulative Precision  \
# 0                8   (0.93, 0.966]        193             14.035088
# 1               22   (0.918, 0.93]        192             20.000000
# 2               31  (0.908, 0.918]        191             19.496855
# 3               38  (0.901, 0.908]        190             17.351598
# 4               49  (0.895, 0.901]        189             17.625899
# 5               56  (0.888, 0.895]        188             16.867470
# 6               67   (0.88, 0.888]        187             17.135550
# 7               79   (0.874, 0.88]        186             17.673378
# 8               87  (0.866, 0.874]        185             17.365269
# 9               93  (0.858, 0.866]        184             16.696589
# 10             102  (0.851, 0.858]        183             16.531605
# 11             103  (0.845, 0.851]        182             15.373134
# 12             108  (0.838, 0.845]        181             14.794521
# 13             112  (0.831, 0.838]        180             14.177215
# 14             120  (0.825, 0.831]        179             14.218009
# 15             126  (0.819, 0.825]        178             13.968958
# 16             130  (0.814, 0.819]        177             13.598326
# 17             135  (0.808, 0.814]        176             13.379584
# 18             138  (0.802, 0.808]        175             12.909261
# 19             141  (0.795, 0.802]        174             12.477876
# 20             145  (0.789, 0.795]        173             12.236287
# 21             152  (0.783, 0.789]        172             12.317666
# 22             156  (0.775, 0.783]        171             12.027756
# 23             159  (0.768, 0.775]        170             11.751663
# 24             165   (0.76, 0.768]        169             11.743772
# 25             171   (0.753, 0.76]        168             11.640572
# 26             177  (0.746, 0.753]        167             11.621799
# 27             186   (0.74, 0.746]        166             11.832061
# 28             188   (0.734, 0.74]        165             11.519608
# 29             195  (0.726, 0.734]        164             11.518015
# 30             197  (0.719, 0.726]        163             11.250714
# 31             200  (0.711, 0.719]        162             11.086475
# 32             203  (0.704, 0.711]        161             10.884718
# 33             206  (0.697, 0.704]        160             10.745957
# 34             214  (0.689, 0.697]        159             10.846427
# 35             217  (0.681, 0.689]        158             10.705476
# 36             222  (0.673, 0.681]        157             10.637278
# 37             225  (0.667, 0.673]        156             10.479739
# 38             229  (0.659, 0.667]        155             10.404362
# 39             230  (0.653, 0.659]        154             10.226767
# 40             237  (0.645, 0.653]        153             10.233161
# 41             240  (0.638, 0.645]        152             10.147992
# 42             240   (0.63, 0.638]        151              9.884679
# 43             244   (0.622, 0.63]        150              9.830782
# 44             247  (0.614, 0.622]        149              9.766706
# 45             250  (0.606, 0.614]        148              9.641342
# 46             257  (0.597, 0.606]        147              9.679849
# 47             259  (0.589, 0.597]        146              9.578402
# 48             262  (0.581, 0.589]        145              9.482447
# 49             263  (0.572, 0.581]        144              9.329549
#
#     Cumulative Recall  Precision    Recall        Scores
# 0            2.240896  14.035088  2.240896   0.93--0.966
# 1            6.162465  26.415094  3.921569   0.918--0.93
# 2            8.683473  18.367347  2.521008  0.908--0.918
# 3           10.644258  11.666667  1.960784  0.901--0.908
# 4           13.725490  18.644068  3.081232  0.895--0.901
# 5           15.686275  12.962963  1.960784  0.888--0.895
# 6           18.767507  18.644068  3.081232   0.88--0.888
# 7           22.128852  21.428571  3.361345   0.874--0.88
# 8           24.369748  14.814815  2.240896  0.866--0.874
# 9           26.050420  10.714286  1.680672  0.858--0.866
# 10          28.571429  15.000000  2.521008  0.851--0.858
# 11          28.851541   1.886792  0.280112  0.845--0.851
# 12          30.252101   8.333333  1.400560  0.838--0.845
