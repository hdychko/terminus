# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import copy
from typing import (
    Dict, 
    List,
    Any
)


import mlflow
import warnings
from datetime import datetime

from tqdm.autonotebook import tqdm

import numpy as np
import pandas as pd

from scipy.stats import uniform

import shap

import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\hdychko\AppData\Local\Temp\ipykernel_16016\243224794.py:15: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
sys.path.append(os.path.join(os.getcwd(), '..'))
from utils.modelling_tools import *

# %%
TRAIN_FROM: datetime.date = pd.to_datetime('2021-12-01').date()
TRAIN_TO: datetime.date = pd.to_datetime('2022-01-01').date()

VAL_FROM: datetime.date = pd.to_datetime('2022-01-01').date()
VAL_TO: datetime.date = pd.to_datetime('2022-05-01').date()

TEST_FROM: datetime.date = pd.to_datetime('2022-05-01').date()
TEST_TO: datetime.date = pd.to_datetime('2022-08-01').date()

# %%
# set constants
COLS_TO_USE: List[str] = [
"OPTIN_11SCN_MLOptBin",
"G5_ND_SPECIIOptBin",
"Marital_StatusOptBin",
"SP_F2_33OptBin",
"AFF_B_09_01OptBin",
"TRD_A_20OptBin",
"TRD_A_08OptBin",
"VM01_SP_VM2_15OptBin",
"GEN11_SP_N_92OptBin",
"SP_EDI_24OptBin",
"SP_G_37OptBin",
"E4_Q_17OptBin",
"TRD_C_07OptBin",
"TRD_B_20OptBin",
"SP_B2_18OptBin",
"SPA_F2_33OptBin",
"VM01_SP_VM2_14OptBin",
"VM01_SP_VM2_24OptBin",
"SP_G_38OptBin",
"TRD_O_05OptBin",
"E1_A_09OptBin",
"TRD_O_07OptBin",
"ND_INC_03OptBin",
"VM01_SP_VM2_17OptBin",
"SP_B1_14OptBin",
"GEN11_SP_N_91OptBin",
"GEN11_SP_EDI_07OptBin",
"ND_ECC_06OptBin",
"TRD_B_18OptBin",
"TRD_B_08OptBin",
"EA5_S_01OptBin",
"CLU_CLI_L6M_NPR_L6MOptBin",
"E1_B_06OptBin",
"SP_I_67_01OptBin",
"GEN11_SP_K_80OptBin",
"E4_Q_04OptBin",
"ND_ECC_04OptBin",
"VM08_SP_VM2_15OptBin",
"VAL_DELINQ_ACCSOptBin",
"ND_ERL_01OptBin",
"EA1_D_02OptBin",
"ND_HAC_06OptBin",
"AFF_E_07_01OptBin",
"TRD_O_06OptBin",
"E2_G_08OptBin",
"AFF_T_07_01OptBin",
"VM02_SP_VM1_18OptBin",
] 

TARGET_NAME: str = 'GB6_Flag_2Limit'
TARGET_VALS: List[int] = [0, 1]
TARGET_BIN: str = f'_{TARGET_NAME}_bin'

PALETTE: Dict[str, str] = {
    TARGET_NAME: {
        'G': 'green',
        'B': 'red',
        'I': 'black'
    },
    TARGET_BIN: {0: 'green', 1: 'red'},
    'DataPart': {'Train-val': 'orange', 'Val': 'blue', 'Test': 'black'}
    # 'Test-OOT': 'black'
}

PROJECT_PATH: str = os.path.join(os.getcwd(), '..')
DATA_PATH: str = os.path.join(PROJECT_PATH, 'data')
OPT_BIN_PATH: str = os.path.join(os.path.join(PROJECT_PATH, 'objects'), 'optbinners')
MODELS_PATH: str = os.path.join(os.path.join(PROJECT_PATH, 'objects'), 'models')

# %%
N_ITER: int = 20
RANDOM_SEED: int = 42

# %%
# read data
df: pd.DataFrame = pd.read_csv(os.path.join(DATA_PATH, 'final_aiq2_optbins.csv'), low_memory=False)

# %%
print('Number of rows: %.0f; columns: %.0f' % df.shape)
# Out:
# Number of rows: 110462; columns: 2069

# %% [markdown]
# # Preprocessing

# %% [markdown]
# # Convert dates to the corresponding types

# %%
for col in ['_RDATE_EOM', '_RDATE']:
    df[col] = pd.to_datetime(df[col]).dt.date

# %%
print('Available date range:')
df['_RDATE'].agg(['min', 'max'])
# Out:
# Available date range:
# min    2021-06-30
# max    2023-11-30
# Name: _RDATE, dtype: object

# %%
df_train = df.loc[
    (df._RDATE >= TRAIN_FROM) &
    (df._RDATE < TRAIN_TO),
    COLS_TO_USE + [TARGET_NAME, TARGET_BIN, '_RDATE']
].reset_index(drop=True)

df_train_val = df.loc[
    (df._RDATE >= TRAIN_FROM) &
    (df._RDATE < VAL_TO),
    COLS_TO_USE + [TARGET_NAME, TARGET_BIN, '_RDATE']
].reset_index(drop=True)

df_val = df.loc[
    (df._RDATE >= VAL_FROM) &
    (df._RDATE < VAL_TO),
    COLS_TO_USE + [TARGET_NAME, TARGET_BIN, '_RDATE']
].reset_index(drop=True)

df_test = df.loc[
    (df._RDATE >= TEST_FROM) &
    (df._RDATE < TEST_TO),
    COLS_TO_USE + [TARGET_NAME, TARGET_BIN, '_RDATE']
].reset_index(drop=True)

# %%
data_dict = {
    "df_train": df_train,
    "df_val": df_val,
    "df_train_val": df_train_val, 
    "df_test": df_test
}

# %%
# randomly select N observations from test data
N = 10000
sss = StratifiedShuffleSplit(n_splits=1, train_size=N, random_state=RANDOM_SEED)
indx = sss.split(data_dict['df_test'].reset_index(drop=True), data_dict['df_test'][TARGET_BIN])
random_indx = list(indx)[0][0]

assert len(random_indx) == N, "Incorrect number of elements in the subsample"
test_sample = data_dict['df_test'].reset_index(drop=True).iloc[random_indx, :].reset_index(drop=True)

# %%
data_dict['df_test_sample'] = test_sample

# %%
mlflow.set_tracking_uri(uri="http://127.0.0.1:5000/")
mlflow.set_experiment("[Experian]")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/696858428304145414', creation_time=1716463645799, experiment_id='696858428304145414', last_update_time=1716463645799, lifecycle_stage='active', name='[Experian]', tags={}>

# %%
MODEL = LogisticRegression

# %%
experiment_description = f"""
    'features': {len(COLS_TO_USE)},
    'target': {TARGET_BIN},
    'target_vals': '0, 1',
    'model': {MODEL.__name__},
    'data_version': '22.05.2024', 
    'train_period': [{TRAIN_FROM.strftime('%Y-%m-%d') + ', ' + TRAIN_TO.strftime('%Y-%m-%d')}),
    'val_period': [{VAL_FROM.strftime('%Y-%m-%d') + ', ' + VAL_TO.strftime('%Y-%m-%d')}),
    'test_period': [{TEST_FROM.strftime('%Y-%m-%d') + ', ' + TEST_TO.strftime('%Y-%m-%d')}),
"""

# %%
print(experiment_description)
# Out:
#     'features': 47,
#     'target': _GB6_Flag_2Limit_bin,
#     'target_vals': '0, 1',
#     'model': LogisticRegression,
#     'data_version': '22.05.2024',
#     'train_period': [2021-12-01, 2022-01-01),
#     'val_period': [2022-01-01, 2022-05-01),
#     'test_period': [2022-05-01, 2022-08-01),

# %%
PARAMS = dict(
    penalty=['l2', 'l1', 'elasticnet'], 
    C=uniform(loc=0, scale=20), 
    fit_intercept=[True], 
    class_weight=['balanced'], 
    random_state=[RANDOM_SEED], 
    n_jobs=[-1], 
)

# %%
RUN_NAME = '02-LogRegression-hyperparams_tunning'
with mlflow.start_run(run_name=RUN_NAME, log_system_metrics=True):
    res = search_hyper_params_and_log(
        run_name=RUN_NAME,
        data_dict=data_dict,
        cols_to_use=COLS_TO_USE,
        target_name=TARGET_BIN,
        distributions=PARAMS,
        n_iter=100,
        model=MODEL,
        custom_params_updates=update_solver_by_penalty,
        palette=PALETTE,
        tags={'features': len(COLS_TO_USE)}
    )
# Out:
# 2024/05/23 22:08:27 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/23 22:08:27 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# The max_iter was reached which means the coef_ did not converge
# # 1 / 100
# 2024/05/23 22:08:28 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/23 22:08:28 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:08:37 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:08:37 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 2 / 100
# 2024/05/23 22:08:37 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/23 22:08:37 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:08:43 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:08:43 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 3 / 100
# The max_iter was reached which means the coef_ did not converge
# 2024/05/23 22:08:44 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/23 22:08:44 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:08:51 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:08:51 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 4 / 100
# 2024/05/23 22:08:53 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# 2024/05/23 22:08:53 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:08:59 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:08:59 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 5 / 100
# 2024/05/23 22:09:00 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/23 22:09:00 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:09:07 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:09:07 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 6 / 100
# The max_iter was reached which means the coef_ did not converge
# 2024/05/23 22:09:07 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/23 22:09:07 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:09:14 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:09:14 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 7 / 100
# 2024/05/23 22:09:14 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/23 22:09:14 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:09:21 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:09:21 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 8 / 100
# 2024/05/23 22:09:21 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/23 22:09:21 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:09:28 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:09:28 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 9 / 100
# 2024/05/23 22:09:28 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
# 2024/05/23 22:09:28 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:09:34 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:09:34 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 10 / 100
# 2024/05/23 22:09:34 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/23 22:09:34 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:09:41 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:09:41 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 11 / 100
# The max_iter was reached which means the coef_ did not converge
# 2024/05/23 22:09:41 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
# 2024/05/23 22:09:41 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:09:48 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:09:48 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 12 / 100
# 2024/05/23 22:09:49 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/23 22:09:49 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:09:56 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:09:56 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 13 / 100
# 2024/05/23 22:09:56 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/23 22:09:56 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:10:03 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:10:03 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 14 / 100
# 2024/05/23 22:10:03 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/23 22:10:03 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:10:10 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:10:10 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 15 / 100
# 2024/05/23 22:10:10 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/23 22:10:10 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:10:17 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:10:17 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 16 / 100
# 2024/05/23 22:10:17 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/23 22:10:17 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:10:24 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:10:24 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 17 / 100
# The max_iter was reached which means the coef_ did not converge
# 2024/05/23 22:10:24 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/23 22:10:24 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:10:30 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:10:30 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 18 / 100
# 2024/05/23 22:10:31 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/23 22:10:31 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:10:38 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:10:38 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 19 / 100
# The max_iter was reached which means the coef_ did not converge
# 2024/05/23 22:10:38 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/23 22:10:38 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:10:45 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:10:45 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 20 / 100
# 2024/05/23 22:10:45 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/23 22:10:45 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:10:51 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:10:51 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 21 / 100
# The max_iter was reached which means the coef_ did not converge
# 2024/05/23 22:10:52 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/05/23 22:10:52 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/05/23 22:10:58 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:10:58 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# The max_iter was reached which means the coef_ did not converge
# # 22 / 100
# 2024/05/23 22:10:59 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/05/23 22:10:59 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# ...
# The max_iter was reached which means the coef_ did not converge
# Test-PR_AUC 0.07686222593978012
# Test-Gini 0.5300963635614195
# Not saved
# The option feature_dependence has been renamed to feature_perturbation!
# The feature_perturbation option is now deprecated in favor of using the appropriate masker (maskers.Independent, or maskers.Impute)
# .values =
# array([ -6.40761916,  -2.85268528,   1.04986052, ...,  14.10115848,
#        -12.85300138,   1.04986052])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([ 1.58884142,  1.0562294 ,  0.471537  , ..., -1.48385189,
#         2.55451004,  0.471537  ])
# .values =
# array([0.0126739, 0.0126739, 0.0126739, ..., 0.0126739, 0.0126739,
#        0.0126739])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([0.25783187, 0.25783187, 0.25783187, ..., 0.25783187, 0.25783187,
#        0.25783187])
# .values =
# array([-5.50240495, -5.50240495,  3.92389771, ...,  3.92389771,
#        -2.7658934 , -2.7658934 ])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([ 2.2584247 ,  2.2584247 , -0.58856955, ..., -0.58856955,
#         1.43192539,  1.43192539])
# .values =
# array([-0.34938881, -0.15217243, -0.15217243, ..., -0.81122491,
#         0.64693856,  0.64693856])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([-0.07402703,  0.26427951,  0.26427951, ..., -0.86626434,
#         1.63508082,  1.63508082])
# .values =
# array([ 3.0500519 ,  1.60947226,  1.30259236, ..., -0.16649494,
#         1.60947226, -0.49900393])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([ 2.37230598,  1.36105749,  1.14563599, ...,  0.11437588,
#         1.36105749, -0.11903656])
# .values =
# array([ 0.60148765, -1.11704849, -1.11704849, ...,  0.60148765,
#        -1.11704849,  0.60148765])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([-0.45645552,  1.42155037,  1.42155037, ..., -0.45645552,
#         1.42155037, -0.45645552])
# .values =
# array([ 0.00581213,  0.01808042, -0.04347591, ...,  0.02907901,
#        -0.01361256, -0.01361256])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([ 0.1446129 , -0.35460263,  2.15021933, ..., -0.8021521 ,
#         0.93503366,  0.93503366])
# .values =
# array([-0.12470568,  0.65175465, -3.23502532, ..., -1.08812014,
#        -3.23502532,  0.65175465])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([ 0.40413561, -0.05633562,  2.24867633, ...,  0.97547792,
#         2.24867633, -0.05633562])
# .values =
# array([-1.2005467 , -0.36223046, -1.88523297, ..., -1.88523297,
#         1.13839263,  1.53293157])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([ 1.03067702,  0.46069679,  1.49620257, ...,  1.49620257,
#        -0.55959299, -0.82784426])
# .values =
# array([-3.52981808, -3.52981808, -0.62978367, ..., -0.62978367,
#         1.62923408,  1.62923408])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([ 1.76910325,  1.76910325,  0.46029847, ...,  0.46029847,
#        -0.55921124, -0.55921124])
# .values =
# array([-0.32166763,  1.0477535 ,  0.26115685, ...,  0.26115685,
#        -0.0098768 , -0.0098768 ])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([-0.01342065,  1.67314853,  0.70438177, ...,  0.70438177,
#         0.37057869,  0.37057869])
# .values =
# array([-0.50143316,  0.24603662, -0.50143316, ...,  0.8404019 ,
#        -0.50143316, -0.50143316])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([ 0.88915064, -0.13253725,  0.88915064, ..., -0.94495243,
#         0.88915064,  0.88915064])
# .values =
# array([ 0.19122677, -0.85577686, -0.85577686, ...,  0.19122677,
#         0.19122677,  0.19122677])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([0.00824407, 0.71284345, 0.71284345, ..., 0.00824407, 0.00824407,
#        0.00824407])
# .values =
# array([-0.23368108,  0.31670532, -0.33243283, ..., -0.33243283,
#        -0.33243283, -0.33243283])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([ 0.65599878, -0.27408943,  0.82287761, ...,  0.82287761,
#         0.82287761,  0.82287761])
# .values =
# array([-0.01828006,  0.02481233,  0.02481233, ...,  0.02481233,
#        -0.01828006, -0.01828006])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([-0.3226951 ,  0.72895436,  0.72895436, ...,  0.72895436,
#        -0.3226951 , -0.3226951 ])
# .values =
# array([-0.36602223, -1.63122255, -0.87356235, ...,  0.51282685,
#         0.51282685,  0.51282685])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([ 0.59836358,  1.92487265,  1.13049795, ..., -0.32307254,
#        -0.32307254, -0.32307254])
# .values =
# array([-0.84517164, -0.63195271,  0.75891961, ...,  1.05848514,
#        -0.63195271, -0.63195271])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([-0.41281637, -0.26225749,  0.71987005, ...,  0.93140029,
#        -0.26225749, -0.26225749])
# .values =
# array([-0.03527977,  0.02334104, -0.03527977, ..., -0.03527977,
#        -0.03527977,  0.06704155])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([-0.13347962,  0.5143796 , -0.13347962, ..., -0.13347962,
#        -0.13347962,  0.99734418])
# .values =
# array([ 0.27338585, -0.80593196,  0.27338585, ...,  0.3739908 ,
#         0.3739908 ,  0.58878254])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([-0.17035703,  1.15260466, -0.17035703, ..., -0.29367241,
#        -0.29367241, -0.55695098])
# .values =
# array([ 0.39651612, -1.24777762,  0.65589562, ...,  0.65589562,
#         0.39651612, -1.24777762])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([-0.09661101,  0.7066837 , -0.22332692, ..., -0.22332692,
#        -0.09661101,  0.7066837 ])
# .values =
# array([ 0.17529628,  0.17529628,  0.17529628, ..., -0.30114108,
#         0.17529628, -0.30114108])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([ 0.62133384,  0.62133384,  0.62133384, ..., -0.64862661,
#         0.62133384, -0.64862661])
# .values =
# array([ 0.24703844, -0.30103361, -0.30103361, ...,  0.24703844,
#         0.24703844, -0.01766021])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([-0.5840316 ,  1.14600574,  1.14600574, ..., -0.5840316 ,
#        -0.5840316 ,  0.25151281])
# .values =
# array([ 0.15669279,  0.15669279,  0.15669279, ...,  0.15669279,
#        -0.06994115, -0.05609388])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([ 0.79959541,  0.79959541,  0.79959541, ...,  0.79959541,
#        -0.06592044, -0.01303768])
# .values =
# array([ 0.48828531, -0.41952173, -0.41952173, ...,  0.48828531,
#        -0.41952173, -1.40297125])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([-0.22943949,  0.69457856,  0.69457856, ..., -0.22943949,
#         0.69457856,  1.69558986])
# .values =
# array([ 0.14945719, -0.21424228, -0.21424228, ..., -0.07881302,
#        -0.07881302, -0.21424228])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([-0.22542822,  0.80769208,  0.80769208, ...,  0.42299338,
#         0.42299338,  0.80769208])
# .values =
# array([ 0.0926801 , -0.90648871, -0.90648871, ..., -0.8417344 ,
#        -2.45261749,  0.0926801 ])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([0.07932923, 0.61756856, 0.61756856, ..., 0.58268625, 1.45044814,
#        0.07932923])
# .values =
# array([ 0.91872627,  0.29483797,  0.29483797, ...,  0.14664494,
#         0.91872627, -0.08431218])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([1.14563599, 0.46269298, 0.46269298, ..., 0.3004726 , 1.14563599,
#        0.04765402])
# .values =
# array([0.61924127, 0.61924127, 0.61924127, ..., 0.42666136, 0.1618605 ,
#        0.61924127])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([0.81806631, 0.81806631, 0.81806631, ..., 0.63297718, 0.37847627,
#        0.81806631])
# .values =
# array([ 0.71393122,  0.71393122,  0.71393122, ...,  0.71393122,
#        -1.39363186,  0.71393122])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([ 0.43720996,  0.43720996,  0.43720996, ...,  0.43720996,
#        -0.5736402 ,  0.43720996])
# .values =
# array([0.45311375, 0.45311375, 0.45311375, ..., 0.45311375, 0.45311375,
#        0.45311375])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([0.28643024, 0.28643024, 0.28643024, ..., 0.28643024, 0.28643024,
#        0.28643024])
# .values =
# array([0.37377649, 0.37377649, 0.65152048, ..., 0.65152048, 0.65152048,
#        0.65152048])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([-0.08102823, -0.08102823, -0.24390739, ..., -0.24390739,
#        -0.24390739, -0.24390739])
# .values =
# array([0.07225366, 0.07225366, 0.07225366, ..., 0.07225366, 0.07225366,
#        0.07225366])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([0.31746179, 0.31746179, 0.31746179, ..., 0.31746179, 0.31746179,
#        0.31746179])
# .values =
# array([-0.7657694 , -0.05890171,  1.69597873, ...,  0.73991325,
#         0.61043344,  0.73991325])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([-0.28827242,  0.08223558,  1.00206435, ...,  0.50093817,
#         0.43307072,  0.50093817])
# .values =
# array([-0.04891244, -0.0320694 , -0.04891244, ..., -0.04891244,
#        -0.04891244, -0.04891244])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([-0.2105276 , -0.09376725, -0.2105276 , ..., -0.2105276 ,
#        -0.2105276 , -0.2105276 ])
# .values =
# array([-0.85915051,  0.18622778,  0.18622778, ...,  0.18622778,
#         0.18622778,  0.18622778])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([0.81392165, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ])
# .values =
# array([ 0.10047284, -0.1412368 ,  0.05478581, ...,  0.05478581,
#        -0.08054762,  0.00043131])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([ 0.49988257, -0.42044324,  0.32592608, ...,  0.32592608,
#        -0.18936508,  0.11896768])
# .values =
# array([ 0.21374777,  0.21374777,  0.21374777, ...,  0.21374777,
#         0.21374777, -0.62472519])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([ 0.33108872,  0.33108872,  0.33108872, ...,  0.33108872,
#         0.33108872, -0.43939296])
# .values =
# array([ 0.76006599,  1.33758921, -0.6190583 , ..., -0.6190583 ,
#        -0.6190583 , -0.6190583 ])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([-0.2885318 , -0.6123593 ,  0.48476763, ...,  0.48476763,
#         0.48476763,  0.48476763])
# .values =
# array([0.23496544, 0.23496544, 0.23496544, ..., 0.23496544, 0.23496544,
#        0.23496544])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([0.26462064, 0.26462064, 0.26462064, ..., 0.26462064, 0.26462064,
#        0.26462064])
# .values =
# array([-0.25536423,  0.62520207, -0.25536423, ..., -0.25536423,
#        -0.25536423, -0.25536423])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([ 0.25259013, -0.49945757,  0.25259013, ...,  0.25259013,
#         0.25259013,  0.25259013])
# .values =
# array([0.06411371, 0.06411371, 0.06411371, ..., 0.06411371, 0.06411371,
#        0.06411371])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([0.27008795, 0.27008795, 0.27008795, ..., 0.27008795, 0.27008795,
#        0.27008795])
# .values =
# array([-0.95434584, -0.95434584, -0.95434584, ...,  0.25368687,
#         0.25368687,  0.25368687])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([ 0.8595552 ,  0.8595552 ,  0.8595552 , ..., -0.18718329,
#        -0.18718329, -0.18718329])
# .values =
# array([-0.09750663,  0.051613  , -0.09750663, ..., -0.09750663,
#        -0.09750663,  0.13847814])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([ 0.44177225, -0.22085575,  0.44177225, ...,  0.44177225,
#         0.44177225, -0.60684965])
# .values =
# array([ 0.31773578,  0.31773578,  0.31773578, ...,  0.72304762,
#        -0.41251773,  0.31773578])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([ 0.42523164,  0.42523164,  0.42523164, ...,  0.90918311,
#        -0.44670749,  0.42523164])
# .values =
# array([-0.42582722, -0.42582722, -0.42582722, ..., -0.42582722,
#         0.19131368,  0.19131368])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([ 0.92478913,  0.92478913,  0.92478913, ...,  0.92478913,
#        -0.2006119 , -0.2006119 ])
# .values =
# array([0.07002634, 0.07002634, 0.07002634, ..., 0.07002634, 0.07002634,
#        0.07002634])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([0.28199654, 0.28199654, 0.28199654, ..., 0.28199654, 0.28199654,
#        0.28199654])
# .values =
# array([-0.08999174, -0.08999174, -0.08999174, ..., -0.08999174,
#        -0.08999174,  0.24153121])
#
# .base_values =
# array([-12.6731138, -12.6731138, -12.6731138, ..., -12.6731138,
#        -12.6731138, -12.6731138])
#
# .data =
# array([-0.15241742, -0.15241742, -0.15241742, ..., -0.15241742,
#        -0.15241742,  0.79444051])
# 2024/05/23 22:20:20 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/05/23 22:20:20 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!

# %%
pd.merge(
    pd.DataFrame(data_dict['df_train'][TARGET_BIN].value_counts()),
    pd.DataFrame(data_dict['df_train'][TARGET_BIN].value_counts(normalize=True)),
    how='outer', left_index=True, right_index=True
)

# %%
pd.merge(
    pd.DataFrame(data_dict['df_val'][TARGET_BIN].value_counts()),
    pd.DataFrame(data_dict['df_val'][TARGET_BIN].value_counts(normalize=True)),
    how='outer', left_index=True, right_index=True
)

# %%
pd.merge(
    pd.DataFrame(data_dict['df_train_val'][TARGET_BIN].value_counts()),
    pd.DataFrame(data_dict['df_train_val'][TARGET_BIN].value_counts(normalize=True)),
    how='outer', left_index=True, right_index=True
)

# %%
pd.merge(
    pd.DataFrame(data_dict['df_test'][TARGET_BIN].value_counts()),
    pd.DataFrame(data_dict['df_test'][TARGET_BIN].value_counts(normalize=True)),
    how='outer', left_index=True, right_index=True
)

# %%
res.sort_values('PR_AUC_val', ascending=False).head()

# %%
res.sort_values('GINI', ascending=False).head()
# Out:
#                                                params    PR_AUC      GINI
# 20  {'penalty': 'elasticnet', 'C': 16.845695491899...  0.144337  0.651358
# 67  {'penalty': 'elasticnet', 'C': 1.8057954010881...  0.136809  0.650685
# 47  {'penalty': 'l1', 'C': 17.665605178377366, 'fi...  0.132347  0.650495
# 33  {'penalty': 'l2', 'C': 1.2711670057204727, 'fi...  0.132091  0.643441
# 81  {'penalty': 'l2', 'C': 3.2325742818922754, 'fi...  0.151033  0.642824

# %%
df_res = compute_train_val_diff(
    data_dict=data_dict,
    cols_to_use=COLS_TO_USE,
    target_name=TARGET_BIN,
    cv_res=res,
    model=MODEL
)
# Out:
# # 1 / 99
# # 2 / 99
# # 3 / 99
# The max_iter was reached which means the coef_ did not converge
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# The max_iter was reached which means the coef_ did not converge
# # 4 / 99
# # 5 / 99
# The max_iter was reached which means the coef_ did not converge
# # 6 / 99
# The max_iter was reached which means the coef_ did not converge
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 7 / 99
# # 8 / 99
# # 9 / 99
# # 10 / 99
# The max_iter was reached which means the coef_ did not converge
# # 11 / 99
# The max_iter was reached which means the coef_ did not converge
# # 12 / 99
# # 13 / 99
# # 14 / 99
# # 15 / 99
# The max_iter was reached which means the coef_ did not converge
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 16 / 99
# # 17 / 99
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# # 18 / 99
# # 19 / 99
# The max_iter was reached which means the coef_ did not converge
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 20 / 99
# # 21 / 99
# The max_iter was reached which means the coef_ did not converge
# # 22 / 99
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# # 23 / 99
# # 24 / 99
# The max_iter was reached which means the coef_ did not converge
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# The max_iter was reached which means the coef_ did not converge
# # 25 / 99
# # 26 / 99
# # 27 / 99
# The max_iter was reached which means the coef_ did not converge
# # 28 / 99
# # 29 / 99
# # 30 / 99
# # 31 / 99
# The max_iter was reached which means the coef_ did not converge
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 32 / 99
# The max_iter was reached which means the coef_ did not converge
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# The max_iter was reached which means the coef_ did not converge
# # 33 / 99
# # 34 / 99
# # 35 / 99
# # 36 / 99
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# # 37 / 99
# # 38 / 99
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# # 39 / 99
# The max_iter was reached which means the coef_ did not converge
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# The max_iter was reached which means the coef_ did not converge
# # 40 / 99
# # 41 / 99
# # 42 / 99
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# # 43 / 99
# # 44 / 99
# The max_iter was reached which means the coef_ did not converge
# # 45 / 99
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# # 46 / 99
# # 47 / 99
# # 48 / 99
# The max_iter was reached which means the coef_ did not converge
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 49 / 99
# # 50 / 99
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# # 51 / 99
# # 52 / 99
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# # 53 / 99
# # 54 / 99
# The max_iter was reached which means the coef_ did not converge
# # 55 / 99
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# # 56 / 99
# # 57 / 99
# # 58 / 99
# # 59 / 99
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 60 / 99
# # 61 / 99
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# # 62 / 99
# # 63 / 99
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# # 64 / 99
# # 65 / 99
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# # 66 / 99
# # 67 / 99
# The max_iter was reached which means the coef_ did not converge
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# The max_iter was reached which means the coef_ did not converge
# # 68 / 99
# # 69 / 99
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# # 70 / 99
# # 71 / 99
# The max_iter was reached which means the coef_ did not converge
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 72 / 99
# # 73 / 99
# # 74 / 99
# # 75 / 99
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# # 76 / 99
# # 77 / 99
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# # 78 / 99
# # 79 / 99
# # 80 / 99
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# # 81 / 99
# # 82 / 99
# # 83 / 99
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# # 84 / 99
# # 85 / 99
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# # 86 / 99
# # 87 / 99
# The max_iter was reached which means the coef_ did not converge
# # 88 / 99
# # 89 / 99
# # 90 / 99
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# # 91 / 99
# # 92 / 99
# The max_iter was reached which means the coef_ did not converge
# # 93 / 99
# # 94 / 99
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# # 95 / 99
# # 96 / 99
# The max_iter was reached which means the coef_ did not converge
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
# # 97 / 99
# # 98 / 99
# # 99 / 99
# # 100 / 99
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.

# %%
df_res.sort_values('PR_AUC_val', ascending=False).head(10)
# Out:
#    iter  GINI_train  GINI_val  GINI_prcnt_chng  PR_AUC_train  PR_AUC_val  \
# 0    26    0.707413  0.628212       -11.195792      0.137821    0.163632
# 0    81    0.692380  0.642824        -7.157293      0.119386    0.151033
# 0    61    0.680317  0.621439        -8.654367      0.127550    0.150776
# 0    84    0.679287  0.640147        -5.761961      0.132242    0.148457
# 0    20    0.702812  0.651358        -7.321047      0.134094    0.144337
# 0    31    0.707431  0.622968       -11.939432      0.134748    0.143433
# 0    74    0.670677  0.586763       -12.511813      0.127425    0.140987
# 0    69    0.686676  0.627615        -8.600964      0.144883    0.138584
# 0    73    0.669365  0.591533       -11.627740      0.119023    0.138201
# 0    93    0.707112  0.642699        -9.109373      0.147416    0.137670
#
#    PR_AUC_prcnt_chng                                             params
# 0          18.727910  {'penalty': 'l2', 'C': 2.818484499495253, 'fit...
# 0          26.508022  {'penalty': 'l2', 'C': 3.2325742818922754, 'fi...
# 0          18.209102  {'penalty': 'l2', 'C': 12.687026894027277, 'fi...
# 0          12.261469  {'penalty': 'l1', 'C': 3.216161028349973, 'fit...
# 0           7.638234  {'penalty': 'elasticnet', 'C': 16.845695491899...
# 0           6.445195  {'penalty': 'elasticnet', 'C': 13.021540510038...
# 0          10.643340  {'penalty': 'l1', 'C': 5.158832554303112, 'fit...
# 0          -4.347696  {'penalty': 'elasticnet', 'C': 4.4048209513109...
# 0          16.113293  {'penalty': 'l2', 'C': 4.181432414754274, 'fit...
# 0          -6.610871  {'penalty': 'elasticnet', 'C': 9.8503538763772...

# %%
df_res.sort_values('GINI_val', ascending=False).head(20)
# Out:
#    iter  GINI_train  GINI_val  GINI_prcnt_chng  PR_AUC_train  PR_AUC_val  \
# 0    20    0.702812  0.651358        -7.321047      0.134094    0.144337
# 0    67    0.701509  0.650685        -7.244926      0.133760    0.136809
# 0    47    0.699003  0.650495        -6.939626      0.125358    0.132347
# 0    33    0.706511  0.643441        -8.926922      0.135146    0.132091
# 0    81    0.692380  0.642824        -7.157293      0.119386    0.151033
# 0    93    0.707112  0.642699        -9.109373      0.147416    0.137670
# 0     7    0.755100  0.641562       -15.036116      0.142715    0.124796
# 0    84    0.679287  0.640147        -5.761961      0.132242    0.148457
# 0    39    0.756977  0.628794       -16.933474      0.138662    0.118798
# 0    78    0.675697  0.628786        -6.942594      0.101709    0.124942
# 0    26    0.707413  0.628212       -11.195792      0.137821    0.163632
# 0    69    0.686676  0.627615        -8.600964      0.144883    0.138584
# 0    27    0.757851  0.627009       -17.264865      0.139092    0.118409
# 0     5    0.709663  0.626925       -11.658780      0.121039    0.128994
# 0    11    0.757241  0.624305       -17.555300      0.137543    0.116885
# 0    48    0.757013  0.624267       -17.535468      0.137348    0.116823
# 0    46    0.757068  0.623474       -17.646188      0.137235    0.116483
# 0    14    0.756959  0.623361       -17.649261      0.136979    0.116416
# 0    97    0.756931  0.623253       -17.660596      0.136957    0.116377
# 0    58    0.757113  0.623159       -17.692826      0.137286    0.116381
#
#    PR_AUC_prcnt_chng                                             params
# 0           7.638234  {'penalty': 'elasticnet', 'C': 16.845695491899...
# 0           2.278990  {'penalty': 'elasticnet', 'C': 1.8057954010881...
# 0           5.575496  {'penalty': 'l1', 'C': 17.665605178377366, 'fi...
# 0          -2.260355  {'penalty': 'l2', 'C': 1.2711670057204727, 'fi...
# 0          26.508022  {'penalty': 'l2', 'C': 3.2325742818922754, 'fi...
# 0          -6.610871  {'penalty': 'elasticnet', 'C': 9.8503538763772...
# 0         -12.556155  {'penalty': 'l1', 'C': 0.14132610439434812, 'f...
# 0          12.261469  {'penalty': 'l1', 'C': 3.216161028349973, 'fit...
# 0         -14.324907  {'penalty': 'l1', 'C': 0.5083825348819038, 'fi...
# 0          22.843105  {'penalty': 'elasticnet', 'C': 6.7805958209740...
# 0          18.727910  {'penalty': 'l2', 'C': 2.818484499495253, 'fit...
# 0          -4.347696  {'penalty': 'elasticnet', 'C': 4.4048209513109...
# 0         -14.869804  {'penalty': 'l2', 'C': 0.3127281348238786, 'fi...
# 0           6.572277  {'penalty': 'l1', 'C': 4.246782213565523, 'fit...
# 0         -15.018962  {'penalty': 'l2', 'C': 0.9290082543999545, 'fi...
# 0         -14.943912  {'penalty': 'l1', 'C': 2.441759094013467, 'fit...
# 0         -15.121272  {'penalty': 'l2', 'C': 2.109885196605412, 'fit...
# 0         -15.012016  {'penalty': 'l1', 'C': 6.092275383467413, 'fit...
# 0         -15.026423  {'penalty': 'l1', 'C': 7.4031740051088875, 'fi...
# 0         -15.227336  {'penalty': 'l2', 'C': 2.961738599067998, 'fit...

# %%
df_res[df_res.iter == 20].params[0]
# Out:
# {'penalty': 'elasticnet',
#  'C': 16.84569549189997,
#  'fit_intercept': True,
#  'class_weight': 'balanced',
#  'random_state': 42,
#  'n_jobs': -1,
#  'solver': 'saga',
#  'l1_ratio': 0.44975413336976566}

# %%
params = copy.deepcopy(df_res[df_res.iter == 20].params[0])

# %%
params['max_iter'] = 50000

# %%
data_dict, model = train_pred(
    data_dict=data_dict,
    cols_to_use=COLS_TO_USE,
    target_name=TARGET_BIN,
    model=MODEL,
    params=params,
    alias=''
)
# Out:
# The max_iter was reached which means the coef_ did not converge

# %%
params = copy.deepcopy(df_res[df_res.iter == 93].params[0])
params['max_iter'] = 50000
data_dict, model = train_pred(
    data_dict=data_dict,
    cols_to_use=COLS_TO_USE,
    target_name=TARGET_BIN,
    model=MODEL,
    params=params,
    alias=''
)
# Out:
# The max_iter was reached which means the coef_ did not converge

# %%
params = copy.deepcopy(df_res[df_res.iter == 74].params[0])
# params['max_iter'] = 50000
data_dict, model = train_pred(
    data_dict=data_dict,
    cols_to_use=COLS_TO_USE,
    target_name=TARGET_BIN,
    model=MODEL,
    params=params,
    alias=''
)
# Out:
# The max_iter was reached which means the coef_ did not converge

# %%
params = copy.deepcopy(df_res[df_res.iter == 7].params[0])
# params['max_iter'] = 50000
data_dict, model = train_pred(
    data_dict=data_dict,
    cols_to_use=COLS_TO_USE,
    target_name=TARGET_BIN,
    model=MODEL,
    params=params,
    alias=''
)
# Out:
# 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.

# %%
df_res[df_res.iter == 7]
# Out:
#    iter  GINI_train  GINI_val  GINI_prcnt_chng  PR_AUC_train  PR_AUC_val  \
# 0     7      0.7551  0.641562       -15.036116      0.142715    0.124796
#
#    PR_AUC_prcnt_chng                                             params
# 0         -12.556155  {'penalty': 'l1', 'C': 0.14132610439434812, 'f...

# %%
model.coef_
# Out:
# array([[-0.69944248, -0.4284628 , -0.5780283 ,  0.07225909,  0.16658237,
#         -0.0767708 , -0.01332875, -0.13853262,  0.0222269 , -0.29743332,
#          0.04935381,  0.08247774, -0.32564275, -0.03374324, -0.18562533,
#         -0.23184774,  0.174464  ,  0.03949082, -0.17005844, -0.47704015,
#          0.16581389,  0.096621  , -0.23287065, -0.08675505,  0.04130686,
#         -0.30969918,  0.26857132,  0.06616298,  0.25186073,  0.08068184,
#         -0.31085959,  0.17360754,  0.01623709, -0.11025578, -0.31515578,
#          0.        ,  0.        ,  0.01766439, -0.23876721,  0.05461848,
#         -0.00300952, -0.14571043,  0.        , -0.05101561,  0.17611797,
#         -0.22539618,  0.33944555,  0.30392309, -0.14939079,  0.03764574]])

# %%
model.intercept_
# Out:
# array([0.03541165])

# %%
df_coeff = pd.DataFrame(
    {
        'Feature': COLS_TO_USE + ['Intercept'],
        'Coeff': np.append(model.coef_[0], model.intercept_)
    }
)
df_coeff
# Out:
#                       Feature     Coeff
# 0        OPTIN_11SCN_MLOptBin -0.699442
# 1          G5_ND_SPECIIOptBin -0.428463
# 2        Marital_StatusOptBin -0.578028
# 3              SP_F2_33OptBin  0.072259
# 4           AFF_B_09_01OptBin  0.166582
# 5              TRD_A_20OptBin -0.076771
# 6              TRD_A_08OptBin -0.013329
# 7        VM01_SP_VM2_15OptBin -0.138533
# 8         GEN11_SP_N_92OptBin  0.022227
# 9             SP_EDI_24OptBin -0.297433
# 10              SP_G_37OptBin  0.049354
# 11              E4_Q_17OptBin  0.082478
# 12             TRD_C_07OptBin -0.325643
# 13             TRD_B_20OptBin -0.033743
# 14             SP_B2_18OptBin -0.185625
# 15            SPA_F2_33OptBin -0.231848
# 16       VM01_SP_VM2_14OptBin  0.174464
# 17       VM01_SP_VM2_24OptBin  0.039491
# 18              SP_G_38OptBin -0.170058
# 19             TRD_O_05OptBin -0.477040
# 20              E1_A_09OptBin  0.165814
# 21             TRD_O_07OptBin  0.096621
# 22            ND_INC_03OptBin -0.232871
# 23       VM01_SP_VM2_17OptBin -0.086755
# 24             SP_B1_14OptBin  0.041307
# 25        GEN11_SP_N_91OptBin -0.309699
# 26      GEN11_SP_EDI_07OptBin  0.268571
# 27            ND_ECC_06OptBin  0.066163
# 28             TRD_B_18OptBin  0.251861
# 29             TRD_B_08OptBin  0.080682
# 30             EA5_S_01OptBin -0.310860
# 31  CLU_CLI_L6M_NPR_L6MOptBin  0.173608
# 32              E1_B_06OptBin  0.016237
# 33           SP_I_67_01OptBin -0.110256
# 34        GEN11_SP_K_80OptBin -0.315156
# 35           SP_I_63_01OptBin  0.000000
# 36             SP_B2_20OptBin  0.000000
# 37              E4_Q_04OptBin  0.017664
# 38            ND_ECC_04OptBin -0.238767
# 39       VM08_SP_VM2_15OptBin  0.054618
# 40      VAL_DELINQ_ACCSOptBin -0.003010
# 41            ND_ERL_01OptBin -0.145710
# 42       VM08_SP_VM2_20OptBin  0.000000
# 43             EA1_D_02OptBin -0.051016
# 44            ND_HAC_06OptBin  0.176118
# 45          AFF_E_07_01OptBin -0.225396
# 46             TRD_O_06OptBin  0.339446
# 47              E2_G_08OptBin  0.303923
# 48          AFF_T_07_01OptBin -0.149391
# 49       VM02_SP_VM1_18OptBin  0.037646
# 50                  Intercept  0.035412

# %%
df_coeff[df_coeff.Coeff == 0]
# Out:
#                  Feature  Coeff
# 35      SP_I_63_01OptBin    0.0
# 36        SP_B2_20OptBin    0.0
# 42  VM08_SP_VM2_20OptBin    0.0

# %%
for col in COLS_TO_USE:
    if col not in df_coeff[df_coeff.Coeff == 0].Feature:
        print(f'"{col}",')
# Out:
# "OPTIN_11SCN_MLOptBin",
# "G5_ND_SPECIIOptBin",
# "Marital_StatusOptBin",
# "SP_F2_33OptBin",
# "AFF_B_09_01OptBin",
# "TRD_A_20OptBin",
# "TRD_A_08OptBin",
# "VM01_SP_VM2_15OptBin",
# "GEN11_SP_N_92OptBin",
# "SP_EDI_24OptBin",
# "SP_G_37OptBin",
# "E4_Q_17OptBin",
# "TRD_C_07OptBin",
# "TRD_B_20OptBin",
# "SP_B2_18OptBin",
# "SPA_F2_33OptBin",
# "VM01_SP_VM2_14OptBin",
# "VM01_SP_VM2_24OptBin",
# "SP_G_38OptBin",
# "TRD_O_05OptBin",
# "E1_A_09OptBin",
# "TRD_O_07OptBin",
# "ND_INC_03OptBin",
# "VM01_SP_VM2_17OptBin",
# "SP_B1_14OptBin",
# "GEN11_SP_N_91OptBin",
# "GEN11_SP_EDI_07OptBin",
# "ND_ECC_06OptBin",
# "TRD_B_18OptBin",
# "TRD_B_08OptBin",
# "EA5_S_01OptBin",
# "CLU_CLI_L6M_NPR_L6MOptBin",
# "E1_B_06OptBin",
# "SP_I_67_01OptBin",
# "GEN11_SP_K_80OptBin",
# "SP_I_63_01OptBin",
# "SP_B2_20OptBin",
# "E4_Q_04OptBin",
# "ND_ECC_04OptBin",
# "VM08_SP_VM2_15OptBin",
# "VAL_DELINQ_ACCSOptBin",
# "ND_ERL_01OptBin",
# "VM08_SP_VM2_20OptBin",
# "EA1_D_02OptBin",
# "ND_HAC_06OptBin",
# "AFF_E_07_01OptBin",
# "TRD_O_06OptBin",
# "E2_G_08OptBin",
# "AFF_T_07_01OptBin",
# "VM02_SP_VM1_18OptBin",

# %%
from sklearn.metrics import precision_score, recall_score

# %%
sns.histplot(x=data_dict['df_test']['score'], hue=data_dict['df_test'][TARGET_BIN], common_norm=False, stat='density')
# Out:
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# <Axes: xlabel='score', ylabel='Density'>

# %%
from utils.metrics_by_quantile import MetricsByQuantile

# %%
temp = pd.merge(
    pd.DataFrame(pd.qcut(data_dict['df_test']['score'].round(3).values, q=200, duplicates='drop').value_counts().sort_index(ascending=False).cumsum()),
    pd.DataFrame(pd.qcut(data_dict['df_test']['score'].round(3).values, q=200, duplicates='drop').value_counts().sort_index(ascending=False)),
    left_index=True, right_index=True
)
temp['%'] = (temp['count_x'] * 100 / data_dict['df_test'].shape[0]).round(2)
temp
# Out:
#                 count_x  count_y       %
# (0.92, 0.96]         55       55    0.49
# (0.907, 0.92]       112       57    0.99
# (0.898, 0.907]      170       58    1.50
# (0.891, 0.898]      220       50    1.95
# (0.884, 0.891]      274       54    2.43
# ...                 ...      ...     ...
# (0.008, 0.009]    11064       93   97.93
# (0.007, 0.008]    11122       58   98.44
# (0.006, 0.007]    11180       58   98.96
# (0.005, 0.006]    11235       55   99.44
# (0.001, 0.005]    11298       63  100.00
#
# [195 rows x 3 columns]

# %%
m = MetricsByQuantile(metrics=["quantiles_analytics"])
r = m.compute(
    y_true=data_dict['df_test'][TARGET_BIN].reset_index(drop=True), 
    y_pred=data_dict['df_test']['score'].round(3).reset_index(drop=True), 
    list_of_metrics = [
        "cum_precision_by_quantile", "cum_recall_by_quantile", 
        "precision_by_quantile", "recall_by_quantile",
    ], 
    n_quantiles = 200
)
df_deciles = r["other"]["quantiles_analytics"]
df_deciles.head(50)
# Out:
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#     % of total population  Cumulative % of total population  Total  Bad  \
# 0                    0.49                              0.49     55    9
# 1                    0.50                              0.99     57   13
# 2                    0.51                              1.50     58   12
# 3                    0.44                              1.95     50    5
# 4                    0.48                              2.43     54   10
# 5                    0.54                              2.97     61   10
# 6                    0.51                              3.48     58    8
# 7                    0.44                              3.92     50    8
# 8                    0.54                              4.46     61   12
# 9                    0.53                              4.99     60    6
# 10                   0.47                              5.46     53    4
# 11                   0.45                              5.91     51    5
# 12                   0.57                              6.48     64    2
# 13                   0.41                              6.89     46   10
# 14                   0.50                              7.38     56    5
# 15                   0.58                              7.97     66    8
# 16                   0.52                              8.49     59    4
# 17                   0.45                              8.94     51    4
# 18                   0.50                              9.44     57    1
# 19                   0.56                             10.00     63    2
# 20                   0.42                             10.43     48    5
# 21                   0.57                             10.99     64    7
# 22                   0.45                             11.44     51    5
# 23                   0.53                             11.98     60    5
# 24                   0.52                             12.50     59    2
# 25                   0.47                             12.97     53    5
# 26                   0.49                             13.45     55   11
# 27                   0.50                             13.96     57    8
# 28                   0.51                             14.47     58    6
# 29                   0.53                             15.00     60    5
# 30                   0.43                             15.44     49    2
# 31                   0.51                             15.95     58    1
# 32                   0.53                             16.48     60    3
# 33                   0.50                             16.98     56    5
# 34                   0.49                             17.46     55    3
# 35                   0.54                             18.00     61    4
# 36                   0.50                             18.50     56    6
# 37                   0.50                             18.99     56    1
# 38                   0.43                             19.43     49    6
# 39                   0.56                             19.99     63    3
# 40                   0.51                             20.50     58    3
# 41                   0.50                             21.00     57    5
# 42                   0.50                             21.50     56    2
# 43                   0.47                             21.97     53    5
# 44                   0.53                             22.50     60    1
# 45                   0.48                             22.98     54    4
# 46                   0.51                             23.49     58    5
# 47                   0.49                             23.98     55    5
# 48                   0.48                             24.46     54    1
# 49                   0.53                             24.99     60    0
#
#     Cumulative Bad        Quantile  #Quantile  Cumulative Precision  \
# 0                9    (0.92, 0.96]        195             16.363636
# 1               22   (0.907, 0.92]        194             19.642857
# 2               34  (0.898, 0.907]        193             20.000000
# 3               39  (0.891, 0.898]        192             17.727273
# 4               49  (0.884, 0.891]        191             17.883212
# 5               59  (0.877, 0.884]        190             17.611940
# 6               67  (0.868, 0.877]        189             17.048346
# 7               75  (0.861, 0.868]        188             16.930023
# 8               87  (0.853, 0.861]        187             17.261905
# 9               93  (0.846, 0.853]        186             16.489362
# 10              97  (0.839, 0.846]        185             15.721232
# 11             102  (0.833, 0.839]        184             15.269461
# 12             104  (0.826, 0.833]        183             14.207650
# 13             114  (0.819, 0.826]        182             14.652956
# 14             119  (0.814, 0.819]        181             14.268585
# 15             127  (0.807, 0.814]        180             14.111111
# 16             131    (0.8, 0.807]        179             13.660063
# 17             135    (0.795, 0.8]        178             13.366337
# 18             136  (0.789, 0.795]        177             12.746017
# 19             138  (0.782, 0.789]        176             12.212389
# 20             143  (0.779, 0.782]        175             12.139219
# 21             150   (0.77, 0.779]        174             12.077295
# 22             155   (0.762, 0.77]        173             11.987626
# 23             160  (0.754, 0.762]        172             11.825573
# 24             162  (0.746, 0.754]        171             11.473088
# 25             167   (0.74, 0.746]        170             11.399317
# 26             178   (0.735, 0.74]        169             11.710526
# 27             186  (0.728, 0.735]        168             11.794547
# 28             192   (0.72, 0.728]        167             11.743119
# 29             197   (0.713, 0.72]        166             11.622419
# 30             199  (0.706, 0.713]        165             11.410550
# 31             200  (0.699, 0.706]        164             11.098779
# 32             203  (0.692, 0.699]        163             10.902256
# 33             208  (0.684, 0.692]        162             10.844630
# 34             211  (0.678, 0.684]        161             10.694374
# 35             215  (0.671, 0.678]        160             10.570305
# 36             221  (0.662, 0.671]        159             10.574163
# 37             222  (0.656, 0.662]        158             10.344828
# 38             228  (0.649, 0.656]        157             10.387244
# 39             231  (0.642, 0.649]        156             10.230292
# 40             234  (0.634, 0.642]        155             10.103627
# 41             239  (0.628, 0.634]        154             10.071639
# 42             241  (0.619, 0.628]        153              9.921779
# 43             246  (0.613, 0.619]        152              9.911362
# 44             247  (0.605, 0.613]        151              9.716758
# 45             251  (0.596, 0.605]        150              9.668721
# 46             256  (0.589, 0.596]        149              9.645818
# 47             261   (0.58, 0.589]        148              9.634551
# 48             262   (0.572, 0.58]        147              9.482447
# 49             262  (0.564, 0.572]        146              9.280907
#
#     Cumulative Recall  Precision    Recall        Scores
# 0            2.521008  16.363636  2.521008    0.92--0.96
# 1            6.162465  22.807018  3.641457   0.907--0.92
# 2            9.523810  20.689655  3.361345  0.898--0.907
# 3           10.924370  10.000000  1.400560  0.891--0.898
# 4           13.725490  18.518519  2.801120  0.884--0.891
# 5           16.526611  16.393443  2.801120  0.877--0.884
# 6           18.767507  13.793103  2.240896  0.868--0.877
# 7           21.008403  16.000000  2.240896  0.861--0.868
# 8           24.369748  19.672131  3.361345  0.853--0.861
# 9           26.050420  10.000000  1.680672  0.846--0.853
# 10          27.170868   7.547170  1.120448  0.839--0.846
# 11          28.571429   9.803922  1.400560  0.833--0.839
# 12          29.131653   3.125000  0.560224  0.826--0.833
# 13          31.932773  21.739130  2.801120  0.819--0.826
# 14          33.333333   8.928571  1.400560  0.814--0.819
# 15          35.574230  12.121212  2.240896  0.807--0.814
# 16          36.694678   6.779661  1.120448    0.8--0.807
# 17          37.815126   7.843137  1.120448    0.795--0.8
# 18          38.095238   1.754386  0.280112  0.789--0.795
# 19          38.655462   3.174603  0.560224  0.782--0.789
# 20          40.056022  10.416667  1.400560  0.779--0.782
# 21          42.016807  10.937500  1.960784   0.77--0.779
# 22          43.417367   9.803922  1.400560   0.762--0.77
# 23          44.817927   8.333333  1.400560  0.754--0.762
# 24          45.378151   3.389831  0.560224  0.746--0.754
# 25          46.778711   9.433962  1.400560   0.74--0.746
# 26          49.859944  20.000000  3.081232   0.735--0.74
# 27          52.100840  14.035088  2.240896  0.728--0.735
# 28          53.781513  10.344828  1.680672   0.72--0.728
# 29          55.182073   8.333333  1.400560   0.713--0.72
# 30          55.742297   4.081633  0.560224  0.706--0.713
# 31          56.022409   1.724138  0.280112  0.699--0.706
# 32          56.862745   5.000000  0.840336  0.692--0.699
# 33          58.263305   8.928571  1.400560  0.684--0.692
# 34          59.103641   5.454545  0.840336  0.678--0.684
# 35          60.224090   6.557377  1.120448  0.671--0.678
# 36          61.904762  10.714286  1.680672  0.662--0.671
# 37          62.184874   1.785714  0.280112  0.656--0.662
# 38          63.865546  12.244898  1.680672  0.649--0.656
# 39          64.705882   4.761905  0.840336  0.642--0.649
# 40          65.546218   5.172414  0.840336  0.634--0.642
# 41          66.946779   8.771930  1.400560  0.628--0.634
# 42          67.507003   3.571429  0.560224  0.619--0.628
# 43          68.907563   9.433962  1.400560  0.613--0.619
# 44          69.187675   1.666667  0.280112  0.605--0.613
# 45          70.308123   7.407407  1.120448  0.596--0.605
# 46          71.708683   8.620690  1.400560  0.589--0.596
# 47          73.109244   9.090909  1.400560   0.58--0.589
# 48          73.389356   1.851852  0.280112   0.572--0.58
# 49          73.389356   0.000000  0.000000  0.564--0.572
