# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import copy
from typing import (
    Dict, 
    List,
    Any
)

import mlflow
from datetime import datetime


import numpy as np
import pandas as pd

from scipy.stats import uniform
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedShuffleSplit

from joblib import load, dump

import seaborn as sns
import matplotlib.pyplot as plt

# %%
sys.path.append(os.path.join(os.getcwd(), '..'))
from utils.metrics import Metrics
from utils.modelling_tools import (
    search_hyper_params_and_log, 
    update_solver_by_penalty, 
    evaluate_model
)
from utils.metrics_by_quantile import MetricsByQuantile
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %%
RUN_NAME: str = '04-LogRegression-hyperparams_tunning'

# %%
PROJECT_PATH: str = os.path.join(os.getcwd(), '..')
DATA_PATH: str = os.path.join(PROJECT_PATH, 'data')
OPT_BIN_PATH: str = os.path.join(os.path.join(PROJECT_PATH, 'objects'), 'optbinners')
MODELS_PATH: str = os.path.join(os.path.join(PROJECT_PATH, 'objects'), 'models')

# %%
TRAIN_FROM: datetime.date = pd.to_datetime('2021-12-01').date()
TRAIN_TO: datetime.date = pd.to_datetime('2022-01-01').date()

VAL_FROM: datetime.date = pd.to_datetime('2023-01-01').date()
VAL_TO: datetime.date = pd.to_datetime('2023-05-01').date()

TEST_FROM: datetime.date = pd.to_datetime('2023-05-01').date()
TEST_TO: datetime.date = pd.to_datetime('2023-08-01').date()

# %%
# set constants
COLS_TO_USE: List[str] = [
"OPTIN_11SCN_MLOptBin",
"AFF_B_09_01OptBin",
"TRD_A_20OptBin",
"VM01_SP_VM2_15OptBin",
"SP_G_37OptBin",
# "E4_Q_17OptBin", #inap.trend
"TRD_C_07OptBin",
"TRD_B_20OptBin",
"SP_B2_18OptBin",
"SPA_F2_33OptBin",
# "VM01_SP_VM2_14OptBin", #inap.trend
# "VM01_SP_VM2_24OptBin", #inap.trend
"SP_G_38OptBin",
"SP_B1_14OptBin",
"GEN11_SP_N_91OptBin",
# "GEN11_SP_EDI_07OptBin", #inap.trend
# "ND_ECC_06OptBin", #inap.trend
# "TRD_B_18OptBin", #inap.trend
# "TRD_B_08OptBin", #inap.trend
"EA5_S_01OptBin",
"CLU_CLI_L6M_NPR_L6MOptBin",
"SP_I_63_01OptBin",
# "VM08_SP_VM2_20OptBin",
# "EA1_D_02OptBin",
# "TRD_O_06OptBin",  #inap.trend
# "AFF_T_07_01OptBin",
# "VM02_SP_VM1_18OptBin",
# "GEN11_SP_K_80_TOOptBin",
"GEN11_SP_N_92_ABOtherOptBin",
]

# %%
TARGET_NAME: str = 'GB6_Flag_2Limit'
TARGET_VALS: List[int] = [0, 1]
TARGET_BIN: str = f'_{TARGET_NAME}_bin'
TARGET_BIN_0isB: str = f'_{TARGET_NAME}_bin_0isB'

PALETTE: Dict[str, str] = {
    TARGET_NAME: {
        'G': 'green',
        'B': 'red',
        'I': 'black'
    },
    TARGET_BIN: {0: 'green', 1: 'red'},
    'DataPart': {'Train+Val': 'black', 'Val': 'blue', 'Test': 'red', 'Train': 'orange'}
}

# %%
N_ITER: int = 100
RANDOM_SEED: int = 42
CONFIDENCE_LEVEL = 0.05

# %%
MODEL = LogisticRegression

# %%
PARAMS: Dict[str, Any] = dict(
    penalty=['l2', 'l1', 'elasticnet'], 
    C=uniform(loc=0, scale=20), 
    fit_intercept=[True], 
    class_weight=['balanced'], 
    random_state=[RANDOM_SEED], 
    n_jobs=[-1]
)

# %%
# read data
df: pd.DataFrame = pd.read_csv(os.path.join(DATA_PATH, 'final_aiq2_s_neg_sep_I_excl.csv'), low_memory=False)

# %%
print('Number of rows: %.0f; columns: %.0f' % df.shape)
# Out:
# Number of rows: 110462; columns: 1866

# %% [markdown]
# # Preprocessing

# %% [markdown]
# Convert dates to the corresponding types

# %%
for col in ['_RDATE_EOM', '_RDATE']:
    df[col] = pd.to_datetime(df[col]).dt.date

# %%
print('Available date range:')
df['_RDATE'].agg(['min', 'max'])
# Out:
# Available date range:
# min    2021-06-30
# max    2023-11-30
# Name: _RDATE, dtype: object

# %% [markdown]
# Generate Target, where `GB6_Flag_2Limit` in ('I','B') is '1' and GB6_Flag_2Limit in ('G') is '0'

# %%
df[f'_{TARGET_NAME}_bin_0isB'] = df[TARGET_NAME].replace(
    {
        'G': 0,
        'I': 1,
        'B': 1
    }
)
# Out:
# Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`

# %%
pd.merge(
    df[f'_{TARGET_NAME}_bin_0isB'].value_counts().reset_index(name='n'),
    (df[f'_{TARGET_NAME}_bin_0isB'].value_counts(normalize=True) * 100).reset_index(name='%'),
    on=f'_{TARGET_NAME}_bin_0isB', how='outer'
)
# Out:
#    _GB6_Flag_2Limit_bin_0isB      n          %
# 0                          0  99444  90.025529
# 1                          1  11018   9.974471

# %% [markdown]
# # Split data

# %%
df_train = df.loc[
    (df._RDATE >= TRAIN_FROM) &
    (df._RDATE < TRAIN_TO) & 
    (df[TARGET_NAME] != 'I'),
   :
].reset_index(drop=True)

df_train_val = df.loc[
    (df._RDATE >= TRAIN_FROM) &
    (df._RDATE < VAL_TO) &
    (df[TARGET_NAME] != 'I'),
    :
].reset_index(drop=True)

df_val = df.loc[
    (df._RDATE >= VAL_FROM) &
    (df._RDATE < VAL_TO) &
    (df[TARGET_NAME] != 'I'),
    :
].reset_index(drop=True)

df_test_same = df.loc[
    (df._RDATE >= TEST_FROM) &
    (df._RDATE < TEST_TO) &
    (df[TARGET_NAME] != 'I'),
    :
].reset_index(drop=True)

df_test = df.loc[
    (df._RDATE >= TEST_FROM) &
    (df._RDATE < TEST_TO),
    :
].reset_index(drop=True)

# %%
print(f'Distribution of _{TARGET_NAME}_bin_0isB on test')
pd.merge(
    df_test[f'_{TARGET_NAME}_bin_0isB'].value_counts().reset_index(name='n'),
    (df_test[f'_{TARGET_NAME}_bin_0isB'].value_counts(normalize=True) * 100).reset_index(name='%'),
    on=f'_{TARGET_NAME}_bin_0isB', how='outer'
)
# Out:
# Distribution of _GB6_Flag_2Limit_bin_0isB on test
#    _GB6_Flag_2Limit_bin_0isB      n          %
# 0                          0  13663  84.126593
# 1                          1   2578  15.873407

# %%
data_dict = {
    "df_train": df_train,
    "df_val": df_val,
    "df_train_val": df_train_val, 
    "df_test_same": df_test_same,
    "df_test": df_test
}

# %%
# randomly select N observations from test data
N = 10000
sss = StratifiedShuffleSplit(n_splits=1, train_size=N, random_state=RANDOM_SEED)
indx = sss.split(data_dict['df_test_same'].reset_index(drop=True), data_dict['df_test_same'][TARGET_BIN])
random_indx = list(indx)[0][0]

assert len(random_indx) == N, "Incorrect number of elements in the subsample"
test_sample = data_dict['df_test_same'].reset_index(drop=True).iloc[random_indx, :].reset_index(drop=True)

# %%
data_dict['df_test_same_sample'] = test_sample

# %% [markdown]
# # Run the experiment

# %%
mlflow.set_tracking_uri(uri="http://127.0.0.1:8800/")
mlflow.set_experiment("[Experian][Features 2.0]")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/562926978330189002', creation_time=1718121099087, experiment_id='562926978330189002', last_update_time=1718121099087, lifecycle_stage='active', name='[Experian][Features 2.0]', tags={}>

# %%
experiment_description = f"""
    'features': {len(COLS_TO_USE)},
    'target': {TARGET_BIN},
    'target_vals': '0==G, 1==B, 1=I',
    'model': {MODEL.__name__},
    'data_version': '22.05.2024', 
    'train_period': [{TRAIN_FROM.strftime('%Y-%m-%d') + ', ' + TRAIN_TO.strftime('%Y-%m-%d')}),
    'val_period': [{VAL_FROM.strftime('%Y-%m-%d') + ', ' + VAL_TO.strftime('%Y-%m-%d')}),
    'test_period': [{TEST_FROM.strftime('%Y-%m-%d') + ', ' + TEST_TO.strftime('%Y-%m-%d')}),
"""

# %%
print(experiment_description)
# Out:
#     'features': 16,
#     'target': _GB6_Flag_2Limit_bin,
#     'target_vals': '0==G, 1==B, 1=I',
#     'model': LogisticRegression,
#     'data_version': '22.05.2024',
#     'train_period': [2021-12-01, 2022-01-01),
#     'val_period': [2023-01-01, 2023-05-01),
#     'test_period': [2023-05-01, 2023-08-01),

# %%
with mlflow.start_run(run_name=RUN_NAME, log_system_metrics=True):
    res = search_hyper_params_and_log(
        run_name=RUN_NAME,
        data_dict=data_dict,
        cols_to_use=COLS_TO_USE,
        target_name=TARGET_BIN,
        distributions=PARAMS,
        n_iter=N_ITER,
        model=MODEL,
        custom_params_updates=update_solver_by_penalty,
        tags={'features': len(COLS_TO_USE)}, 
        palette=PALETTE['DataPart'],
        test_name='df_test_same',
        model_path=MODELS_PATH
    )
# Out:
# 2024/06/20 11:44:25 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/20 11:44:25 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# # 1 / 100
# # 2 / 100
# 2024/06/20 11:44:25 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 11:44:25 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:44:38 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:44:38 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 3 / 100
# # 4 / 100
# 2024/06/20 11:44:40 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 11:44:40 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:44:46 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:44:46 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 5 / 100
# # 6 / 100
# 2024/06/20 11:44:47 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# # 7 / 100
# Exception in thread 2024/06/20 11:44:47 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:44:53 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:44:53 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 2024/06/20 11:44:53 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/20 11:44:53 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# # 8 / 100
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:45:00 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:45:00 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 2024/06/20 11:45:00 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 11:45:00 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# # 9 / 100
# 2024/06/20 11:45:06 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:45:06 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 10 / 100
# # 11 / 100
# # 12 / 100
# 2024/06/20 11:45:09 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 11:45:09 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:45:15 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:45:15 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 13 / 100
# # 14 / 100
# 2024/06/20 11:45:15 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/20 11:45:15 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:45:21 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:45:21 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 15 / 100
# 2024/06/20 11:45:21 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/20 11:45:21 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:45:27 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:45:27 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 16 / 100
# 2024/06/20 11:45:27 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 11:45:27 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:45:33 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:45:33 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 17 / 100
# # 18 / 100
# # 19 / 100
# # 20 / 100
# 2024/06/20 11:45:34 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 11:45:34 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:45:40 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:45:40 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 21 / 100
# # 22 / 100
# # 23 / 100
# # 24 / 100
# 2024/06/20 11:45:41 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# # 25 / 100
# Exception in thread 2024/06/20 11:45:41 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:45:47 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:45:47 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 26 / 100
# # 27 / 100
# # 28 / 100
# 2024/06/20 11:45:50 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 11:45:50 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:45:56 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:45:56 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 29 / 100
# 2024/06/20 11:45:58 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 11:45:58 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:46:03 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:46:03 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 30 / 100
# # 31 / 100
# 2024/06/20 11:46:04 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 11:46:04 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:46:09 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:46:09 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 32 / 100
# # 33 / 100
# 2024/06/20 11:46:09 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 11:46:09 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:46:15 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:46:15 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 34 / 100
# # 35 / 100
# # 36 / 100
# # 37 / 100
# # 38 / 100
# # 39 / 100
# 2024/06/20 11:46:16 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# # 40 / 100
# Exception in thread 2024/06/20 11:46:16 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:46:21 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:46:21 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 41 / 100
# # 42 / 100
# # 43 / 100
# # 44 / 100
# # 45 / 100
# # 46 / 100
# # 47 / 100
# 2024/06/20 11:46:24 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 11:46:24 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:46:30 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:46:30 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 48 / 100
# # 49 / 100
# 2024/06/20 11:46:30 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 11:46:30 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:46:36 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:46:36 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 50 / 100
# # 51 / 100
# # 52 / 100
# # 53 / 100
# # 54 / 100
# # 55 / 100
# # 56 / 100
# # 57 / 100
# 2024/06/20 11:46:39 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 11:46:39 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:46:44 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:46:44 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 58 / 100
# 2024/06/20 11:46:44 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 11:46:44 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:46:50 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:46:50 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 59 / 100
# 2024/06/20 11:46:51 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/20 11:46:51 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:46:57 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:46:57 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 60 / 100
# # 61 / 100
# # 62 / 100
# # 63 / 100
# # 64 / 100
# # 65 / 100
# # 66 / 100
# # 67 / 100
# 2024/06/20 11:46:59 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/20 11:46:59 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:47:05 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:47:05 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 68 / 100
# # 69 / 100
# # 70 / 100
# # 71 / 100
# # 72 / 100
# 2024/06/20 11:47:06 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 11:47:06 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
# ...
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:47:44 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:47:44 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 88 / 100
# 2024/06/20 11:47:46 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 11:47:46 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:47:52 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:47:52 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 89 / 100
# # 90 / 100
# # 91 / 100
# # 92 / 100
# 2024/06/20 11:47:53 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 11:47:53 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:47:59 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:47:59 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 93 / 100
# # 94 / 100
# # 95 / 100
# 2024/06/20 11:48:00 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 11:48:00 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:48:06 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:48:06 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 96 / 100
# # 97 / 100
# 2024/06/20 11:48:06 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 11:48:06 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:48:13 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:48:13 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 98 / 100
# 2024/06/20 11:48:13 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 11:48:13 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:48:19 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:48:19 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 99 / 100
# 2024/06/20 11:48:19 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
# 2024/06/20 11:48:19 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:48:25 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:48:25 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# # 100 / 100
# 2024/06/20 11:48:25 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# Exception in thread 2024/06/20 11:48:25 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# SystemMetricsMonitor:
# Traceback (most recent call last):
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 122, in monitor
#     self.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\system_metrics_monitor.py", line 148, in collect_metrics
#     monitor.collect_metrics()
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\mlflow\system_metrics\metrics\disk_monitor.py", line 15, in collect_metrics
#     disk_usage = psutil.disk_usage(os.sep)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\__init__.py", line 2003, in disk_usage
#     return _psplatform.disk_usage(path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hdychko\AppData\Local\anaconda3\envs\experian_dev\Lib\site-packages\psutil\_pswindows.py", line 274, in disk_usage
#     total, free = cext.disk_usage(path)
#                   ^^^^^^^^^^^^^^^^^^^^^
# SystemError: argument 1 (impossible<bad format char>)
# 2024/06/20 11:48:31 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:48:31 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# Best params:
#  {'penalty': 'l2', 'C': 2.961738599067998, 'fit_intercept': True, 'class_weight': 'balanced', 'random_state': 42, 'n_jobs': -1, 'solver': 'lbfgs'}
# Val-PR_AUC:  0.12192925156732368
# Val-GINI:  0.5069625818934611
# Not saved
# Test-PR_AUC 0.23713734059278765
# Test-Gini 0.5718484715777221
# The option feature_dependence has been renamed to feature_perturbation!
# The feature_perturbation option is now deprecated in favor of using the appropriate masker (maskers.Independent, or maskers.Impute)
# 2024/06/20 11:48:45 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2024/06/20 11:48:45 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!

# %%
df_metrics, df_coeff, data_dict, model_obj, std_scaler = res

# %% [markdown]
# # Model's quality

# %% [markdown]
# ## Coefficients

# %%
df_coeff.sort_values('Importance(%)', ascending=False)
# Out:
#                         Feature     Coeff  Importance(%)       p-value  \
# 6          OPTIN_11SCN_MLOptBin -1.171317      39.069292  0.000000e+00
# 5                     Intercept -0.847269      28.260688  0.000000e+00
# 7               SPA_F2_33OptBin -0.150382       5.015999  0.000000e+00
# 2                EA5_S_01OptBin -0.140356       4.681578  0.000000e+00
# 15               TRD_C_07OptBin -0.089242       2.976657  8.422996e-11
# 10                SP_G_37OptBin -0.083871       2.797533  1.463910e-07
# 11                SP_G_38OptBin -0.080868       2.697359  1.601433e-06
# 12             SP_I_63_01OptBin -0.071104       2.371677  3.502750e-08
# 1     CLU_CLI_L6M_NPR_L6MOptBin -0.068041       2.269522  3.096938e-07
# 13               TRD_A_20OptBin -0.065072       2.170494  3.110797e-06
# 16         VM01_SP_VM2_15OptBin  0.064531       2.152422  2.369285e-05
# 3           GEN11_SP_N_91OptBin -0.048515       1.618216  6.468922e-04
# 4   GEN11_SP_N_92_ABOtherOptBin -0.042325       1.411758  2.001320e-03
# 8                SP_B1_14OptBin -0.039205       1.307684  6.294465e-03
# 0             AFF_B_09_01OptBin  0.020822       0.694519  2.598186e-01
# 9                SP_B2_18OptBin -0.012870       0.429285  4.023924e-01
# 14               TRD_B_20OptBin  0.002258       0.075317  8.600565e-01
#
#     Importance(SHAP)  Importance(SHAP, %)
# 6           1.501672            69.436627
# 5                NaN                  NaN
# 7           0.114390             5.289362
# 2           0.067959             3.142403
# 15          0.055314             2.557689
# 10          0.064950             3.003242
# 11          0.055580             2.569977
# 12          0.025079             1.159631
# 1           0.040493             1.872368
# 13          0.059525             2.752414
# 16          0.068249             3.155810
# 3           0.029352             1.357240
# 4           0.032106             1.484584
# 8           0.017049             0.788339
# 0           0.021335             0.986535
# 9           0.008000             0.369919
# 14          0.001597             0.073859

# %%
# features with 0 coefficients
df_coeff[df_coeff.Coeff == 0]
# Out:
# Empty DataFrame
# Columns: [Feature, Coeff, Importance(%), p-value, Importance(SHAP), Importance(SHAP, %)]
# Index: []

# %%
# features with high p-value
df_coeff[df_coeff['p-value'] > CONFIDENCE_LEVEL]
# Out:
#               Feature     Coeff  Importance(%)   p-value  Importance(SHAP)  \
# 0   AFF_B_09_01OptBin  0.020822       0.694519  0.259819          0.021335
# 9      SP_B2_18OptBin -0.012870       0.429285  0.402392          0.008000
# 14     TRD_B_20OptBin  0.002258       0.075317  0.860056          0.001597
#
#     Importance(SHAP, %)
# 0              0.986535
# 9              0.369919
# 14             0.073859

# %%
for col in COLS_TO_USE:
    if col not in df_coeff[df_coeff['p-value'] > CONFIDENCE_LEVEL].Feature.values:
        print(f'"{col}",')
# Out:
# "OPTIN_11SCN_MLOptBin",
# "TRD_A_20OptBin",
# "VM01_SP_VM2_15OptBin",
# "SP_G_37OptBin",
# "TRD_C_07OptBin",
# "SPA_F2_33OptBin",
# "SP_G_38OptBin",
# "SP_B1_14OptBin",
# "GEN11_SP_N_91OptBin",
# "EA5_S_01OptBin",
# "CLU_CLI_L6M_NPR_L6MOptBin",
# "SP_I_63_01OptBin",
# "GEN11_SP_N_92_ABOtherOptBin",

# %%
model_obj
# Out:
# LogisticRegression(C=2.961738599067998, class_weight='balanced', n_jobs=-1,
#                    random_state=42)

# %%
# with open(os.path.join(MODELS_PATH, '[Model][Modelling] [Final_AIQ2-50] [I excluded] LogRegression - woe-2 - feature selection - 3 (final).jblb'), 'wb') as f:
#     dump(model_obj, f)

# %%
# with open(os.path.join(MODELS_PATH, '[StdScaler][Modelling] [Final_AIQ2-50] [I excluded] LogRegression - woe-2 - feature selection - 3 (final).jblb'), 'wb') as f:
#     dump(std_scaler, f)

# %% [markdown]
# ## GINI, AU PRC

# %% [markdown]
# ## Test-same

# %%
evaluate_model(
    data=data_dict['df_test_same'], 
    cols_to_use=COLS_TO_USE,
    std_scaler=std_scaler,
    target_name=TARGET_BIN,
    model_obj=model_obj
)
# Out:
# PR_AUC 0.23713734059278765
# Gini 0.5718484715777221
# (0.23713734059278765, 0.5718484715777221)

# %% [markdown]
# ## Test-full

# %% [markdown]
# ### 'I' is 0

# %%
evaluate_model(
    data=data_dict['df_test'], 
    cols_to_use=COLS_TO_USE,
    std_scaler=std_scaler,
    target_name=TARGET_BIN,
    model_obj=model_obj
)
# Out:
# PR_AUC 0.19987770336918081
# Gini 0.5359643080452128
# (0.19987770336918081, 0.5359643080452128)

# %% [markdown]
# ### 'I' is 1

# %%
evaluate_model(
    data=data_dict['df_test'], 
    cols_to_use=COLS_TO_USE,
    std_scaler=std_scaler,
    target_name=TARGET_BIN_0isB,
    model_obj=model_obj
)
# Out:
# PR_AUC 0.338694434804534
# Gini 0.5136419975758033
# (0.338694434804534, 0.5136419975758033)

# %% [markdown]
# ## Outcomes distributions

# %%
data_dict['df_test']['score'] = model_obj.predict_proba(
    std_scaler.transform(data_dict['df_test'][COLS_TO_USE])
)[:, 1]
data_dict['df_test_same']['score'] = model_obj.predict_proba(
    std_scaler.transform(data_dict['df_test_same'][COLS_TO_USE])
)[:, 1]

# %% [markdown]
# ### Test-same

# %%
sns.histplot(x=data_dict['df_test_same']['score'], hue=data_dict['df_test_same'][TARGET_BIN], common_norm=False, stat='density')
# Out:
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# <Axes: xlabel='score', ylabel='Density'>

# %% [markdown]
# ### Test-full

# %% [markdown]
# ### 'I' is 0

# %%
sns.histplot(x=data_dict['df_test']['score'], hue=data_dict['df_test'][TARGET_BIN], common_norm=False, stat='density')
# Out:
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# <Axes: xlabel='score', ylabel='Density'>

# %% [markdown]
# ### 'I' is 1

# %%
sns.histplot(x=data_dict['df_test']['score'], hue=data_dict['df_test'][TARGET_BIN_0isB], common_norm=False, stat='density')
# Out:
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# <Axes: xlabel='score', ylabel='Density'>

# %% [markdown]
# ## Precision, Recall By Quantile

# %% [markdown]
# ### Test-same

# %%
m = MetricsByQuantile(metrics=["quantiles_analytics"])
r = m.compute(
    y_true=data_dict['df_test_same'][TARGET_BIN].reset_index(drop=True), 
    y_pred=data_dict['df_test_same']['score'].round(3).reset_index(drop=True), 
    list_of_metrics = [
        "cum_precision_by_quantile", "cum_recall_by_quantile", 
        "precision_by_quantile", "recall_by_quantile",
    ], 
    n_quantiles = 200
)
df_deciles = r["other"]["quantiles_analytics"]
df_deciles.head(50)
# Out:
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#     % of total population  Cumulative % of total population  Total  Bad  \
# 0                    0.48                              0.48     72   29
# 1                    0.51                              0.99     76   24
# 2                    0.51                              1.49     76   31
# 3                    0.49                              1.99     74   20
# 4                    0.46                              2.45     69   20
# 5                    0.41                              2.85     61   21
# 6                    0.61                              3.46     91   19
# 7                    0.47                              3.93     71   25
# 8                    0.47                              4.40     70   26
# 9                    0.53                              4.93     80   17
# 10                   0.43                              5.37     65   20
# 11                   0.57                              5.94     86   14
# 12                   0.52                              6.46     78   15
# 13                   0.43                              6.89     65   18
# 14                   0.53                              7.43     80   16
# 15                   0.51                              7.94     77   16
# 16                   0.53                              8.48     80   18
# 17                   0.51                              8.98     76   22
# 18                   0.39                              9.38     59   17
# 19                   0.50                              9.88     75   16
# 20                   0.63                             10.50     94   17
# 21                   0.49                             11.00     74   19
# 22                   0.41                             11.41     62    8
# 23                   0.45                             11.86     68   19
# 24                   0.63                             12.50     95   20
# 25                   0.42                             12.92     63   10
# 26                   0.57                             13.49     86   13
# 27                   0.41                             13.90     61   15
# 28                   0.49                             14.39     74   19
# 29                   0.50                             14.89     75    9
# 30                   0.60                             15.49     90   11
# 31                   0.45                             15.94     67   13
# 32                   0.53                             16.46     79   13
# 33                   0.47                             16.93     70   13
# 34                   0.44                             17.37     66   17
# 35                   0.56                             17.93     84   15
# 36                   0.49                             18.42     74   11
# 37                   0.53                             18.95     79   12
# 38                   0.49                             19.44     73   10
# 39                   0.49                             19.93     74    7
# 40                   0.39                             20.32     59    6
# 41                   0.58                             20.90     87    7
# 42                   0.51                             21.42     77   10
# 43                   0.45                             21.86     67    7
# 44                   0.53                             22.40     80    9
# 45                   0.52                             22.92     78    7
# 46                   0.56                             23.48     84    9
# 47                   0.43                             23.90     64   10
# 48                   0.49                             24.40     74   16
# 49                   0.60                             25.00     90   13
#
#     Cumulative Bad        Quantile  #Quantile  Cumulative Precision  \
# 0               29  (0.885, 0.906]        200             40.277778
# 1               53  (0.872, 0.885]        199             35.810811
# 2               84  (0.863, 0.872]        198             37.500000
# 3              104  (0.857, 0.863]        197             34.899329
# 4              124  (0.852, 0.857]        196             33.787466
# 5              145  (0.849, 0.852]        195             33.878505
# 6              164  (0.844, 0.849]        194             31.599229
# 7              189  (0.839, 0.844]        193             32.033898
# 8              215  (0.835, 0.839]        192             32.575758
# 9              232   (0.83, 0.835]        191             31.351351
# 10             252   (0.826, 0.83]        190             31.304348
# 11             266  (0.822, 0.826]        189             29.854097
# 12             281  (0.818, 0.822]        188             28.998968
# 13             299  (0.815, 0.818]        187             28.916828
# 14             315  (0.811, 0.815]        186             28.276481
# 15             331  (0.808, 0.811]        185             27.791772
# 16             349  (0.804, 0.808]        184             27.458694
# 17             371  (0.801, 0.804]        183             27.542687
# 18             388  (0.798, 0.801]        182             27.596017
# 19             404  (0.795, 0.798]        181             27.278866
# 20             421  (0.791, 0.795]        180             26.730159
# 21             440  (0.788, 0.791]        179             26.682838
# 22             448  (0.785, 0.788]        178             26.183518
# 23             467  (0.782, 0.785]        177             26.250703
# 24             487  (0.777, 0.782]        176             25.987193
# 25             497  (0.774, 0.777]        175             25.658234
# 26             510   (0.77, 0.774]        174             25.210084
# 27             525   (0.767, 0.77]        173             25.191939
# 28             544  (0.764, 0.767]        172             25.208526
# 29             553   (0.76, 0.764]        171             24.764890
# 30             564   (0.755, 0.76]        170             24.278950
# 31             577  (0.752, 0.755]        169             24.142259
# 32             590  (0.748, 0.752]        168             23.896314
# 33             603  (0.745, 0.748]        167             23.749508
# 34             620  (0.742, 0.745]        166             23.800384
# 35             635  (0.738, 0.742]        165             23.614727
# 36             646  (0.733, 0.738]        164             23.380384
# 37             658  (0.729, 0.733]        163             23.152709
# 38             668  (0.725, 0.729]        162             22.915952
# 39             675  (0.721, 0.725]        161             22.582804
# 40             681  (0.718, 0.721]        160             22.342520
# 41             688  (0.714, 0.718]        159             21.945774
# 42             698  (0.709, 0.714]        158             21.731009
# 43             705  (0.705, 0.709]        157             21.500457
# 44             714  (0.701, 0.705]        156             21.256326
# 45             721  (0.696, 0.701]        155             20.977597
# 46             730  (0.691, 0.696]        154             20.732746
# 47             740  (0.687, 0.691]        153             20.641562
# 48             756  (0.683, 0.687]        152             20.661383
# 49             769  (0.677, 0.683]        151             20.512137
#
#     Cumulative Recall  Precision    Recall        Scores
# 0            2.173913  40.277778  2.173913  0.885--0.906
# 1            3.973013  31.578947  1.799100  0.872--0.885
# 2            6.296852  40.789474  2.323838  0.863--0.872
# 3            7.796102  27.027027  1.499250  0.857--0.863
# 4            9.295352  28.985507  1.499250  0.852--0.857
# 5           10.869565  34.426230  1.574213  0.849--0.852
# 6           12.293853  20.879121  1.424288  0.844--0.849
# 7           14.167916  35.211268  1.874063  0.839--0.844
# 8           16.116942  37.142857  1.949025  0.835--0.839
# 9           17.391304  21.250000  1.274363   0.83--0.835
# 10          18.890555  30.769231  1.499250   0.826--0.83
# 11          19.940030  16.279070  1.049475  0.822--0.826
# 12          21.064468  19.230769  1.124438  0.818--0.822
# 13          22.413793  27.692308  1.349325  0.815--0.818
# 14          23.613193  20.000000  1.199400  0.811--0.815
# 15          24.812594  20.779221  1.199400  0.808--0.811
# 16          26.161919  22.500000  1.349325  0.804--0.808
# 17          27.811094  28.947368  1.649175  0.801--0.804
# 18          29.085457  28.813559  1.274363  0.798--0.801
# 19          30.284858  21.333333  1.199400  0.795--0.798
# 20          31.559220  18.085106  1.274363  0.791--0.795
# 21          32.983508  25.675676  1.424288  0.788--0.791
# 22          33.583208  12.903226  0.599700  0.785--0.788
# 23          35.007496  27.941176  1.424288  0.782--0.785
# 24          36.506747  21.052632  1.499250  0.777--0.782
# 25          37.256372  15.873016  0.749625  0.774--0.777
# 26          38.230885  15.116279  0.974513   0.77--0.774
# 27          39.355322  24.590164  1.124438   0.767--0.77
# 28          40.779610  25.675676  1.424288  0.764--0.767
# 29          41.454273  12.000000  0.674663   0.76--0.764
# 30          42.278861  12.222222  0.824588   0.755--0.76
# 31          43.253373  19.402985  0.974513  0.752--0.755
# 32          44.227886  16.455696  0.974513  0.748--0.752
# 33          45.202399  18.571429  0.974513  0.745--0.748
# 34          46.476762  25.757576  1.274363  0.742--0.745
# 35          47.601199  17.857143  1.124438  0.738--0.742
# 36          48.425787  14.864865  0.824588  0.733--0.738
# 37          49.325337  15.189873  0.899550  0.729--0.733
# 38          50.074963  13.698630  0.749625  0.725--0.729
# 39          50.599700   9.459459  0.524738  0.721--0.725
# 40          51.049475  10.169492  0.449775  0.718--0.721
# 41          51.574213   8.045977  0.524738  0.714--0.718
# 42          52.323838  12.987013  0.749625  0.709--0.714
# 43          52.848576  10.447761  0.524738  0.705--0.709
# 44          53.523238  11.250000  0.674663  0.701--0.705
# 45          54.047976   8.974359  0.524738  0.696--0.701
# 46          54.722639  10.714286  0.674663  0.691--0.696
# 47          55.472264  15.625000  0.749625  0.687--0.691
# 48          56.671664  21.621622  1.199400  0.683--0.687
# 49          57.646177  14.444444  0.974513  0.677--0.683

# %%
# df_deciles.to_csv('lr_metrics_by_quantile_test_same.csv')

# %% [markdown]
# ### Test-full

# %% [markdown]
# ### 'I' is 0

# %%
m = MetricsByQuantile(metrics=["quantiles_analytics"])
r = m.compute(
    y_true=data_dict['df_test'][TARGET_BIN].reset_index(drop=True), 
    y_pred=data_dict['df_test']['score'].round(3).reset_index(drop=True), 
    list_of_metrics = [
        "cum_precision_by_quantile", "cum_recall_by_quantile", 
        "precision_by_quantile", "recall_by_quantile",
    ], 
    n_quantiles = 200
)
df_deciles = r["other"]["quantiles_analytics"]
df_deciles.head(50)
# Out:
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#     % of total population  Cumulative % of total population  Total  Bad  \
# 0                    0.50                              0.50     81   23
# 1                    0.49                              0.99     79   23
# 2                    0.48                              1.47     78   31
# 3                    0.47                              1.93     76   16
# 4                    0.46                              2.40     75   18
# 5                    0.47                              2.87     77   23
# 6                    0.59                              3.46     96   19
# 7                    0.49                              3.95     79   13
# 8                    0.46                              4.41     75   23
# 9                    0.50                              4.91     81   26
# 10                   0.58                              5.49     94   17
# 11                   0.47                              5.96     77   20
# 12                   0.49                              6.45     80   12
# 13                   0.43                              6.88     70   13
# 14                   0.56                              7.44     91   13
# 15                   0.49                              7.93     79   19
# 16                   0.51                              8.44     83   12
# 17                   0.49                              8.93     79   14
# 18                   0.45                              9.38     73   14
# 19                   0.52                              9.90     85   22
# 20                   0.46                             10.36     74   17
# 21                   0.49                             10.85     80   16
# 22                   0.50                             11.35     82   15
# 23                   0.53                             11.88     86   11
# 24                   0.46                             12.34     74   17
# 25                   0.49                             12.83     79   16
# 26                   0.62                             13.44    100   19
# 27                   0.51                             13.95     83    9
# 28                   0.42                             14.37     68   14
# 29                   0.46                             14.83     75   10
# 30                   0.55                             15.38     89   15
# 31                   0.62                             16.00    100   19
# 32                   0.44                             16.43     71    7
# 33                   0.50                             16.93     81    8
# 34                   0.50                             17.43     81   13
# 35                   0.54                             17.97     87   13
# 36                   0.47                             18.44     77   13
# 37                   0.44                             18.88     71   17
# 38                   0.58                             19.46     95   15
# 39                   0.46                             19.92     74    9
# 40                   0.43                             20.35     70   10
# 41                   0.58                             20.93     95    8
# 42                   0.55                             21.49     90   11
# 43                   0.38                             21.86     61    6
# 44                   0.49                             22.36     80    6
# 45                   0.65                             23.00    105    9
# 46                   0.50                             23.50     81   10
# 47                   0.44                             23.94     71    8
# 48                   0.55                             24.49     89    7
# 49                   0.42                             24.91     69    5
#
#     Cumulative Bad        Quantile  #Quantile  Cumulative Precision  \
# 0               23  (0.888, 0.906]        200             28.395062
# 1               46  (0.876, 0.888]        199             28.750000
# 2               77  (0.867, 0.876]        198             32.352941
# 3               93   (0.86, 0.867]        197             29.617834
# 4              111   (0.855, 0.86]        196             28.534704
# 5              134  (0.851, 0.855]        195             28.755365
# 6              153  (0.847, 0.851]        194             27.224199
# 7              166  (0.843, 0.847]        193             25.897036
# 8              189  (0.839, 0.843]        192             26.396648
# 9              215  (0.835, 0.839]        191             26.976161
# 10             232   (0.83, 0.835]        190             26.038159
# 11             252   (0.826, 0.83]        189             26.033058
# 12             264  (0.823, 0.826]        188             25.190840
# 13             277   (0.82, 0.823]        187             24.776386
# 14             290   (0.816, 0.82]        186             23.986766
# 15             309  (0.813, 0.816]        185             23.990683
# 16             321   (0.81, 0.813]        184             23.413567
# 17             335   (0.807, 0.81]        183             23.103448
# 18             349  (0.804, 0.807]        182             22.915299
# 19             371  (0.801, 0.804]        181             23.072139
# 20             388  (0.798, 0.801]        180             23.067776
# 21             404  (0.795, 0.798]        179             22.928490
# 22             419  (0.792, 0.795]        178             22.722343
# 23             430  (0.789, 0.792]        177             22.279793
# 24             447  (0.786, 0.789]        176             22.305389
# 25             463  (0.783, 0.786]        175             22.227556
# 26             482  (0.779, 0.783]        174             22.079707
# 27             491  (0.775, 0.779]        173             21.668138
# 28             505  (0.772, 0.775]        172             21.636675
# 29             515  (0.769, 0.772]        171             21.378165
# 30             530  (0.766, 0.769]        170             21.216974
# 31             549  (0.762, 0.766]        169             21.131640
# 32             556  (0.759, 0.762]        168             20.831772
# 33             564  (0.755, 0.759]        167             20.509091
# 34             577  (0.752, 0.755]        166             20.381491
# 35             590  (0.748, 0.752]        165             20.219328
# 36             603  (0.745, 0.748]        164             20.133556
# 37             620  (0.742, 0.745]        163             20.221787
# 38             635  (0.738, 0.742]        162             20.088580
# 39             644  (0.734, 0.738]        161             19.907264
# 40             654   (0.73, 0.734]        160             19.788200
# 41             662   (0.726, 0.73]        159             19.470588
# 42             673  (0.722, 0.726]        158             19.283668
# 43             679  (0.719, 0.722]        157             19.121374
# 44             685  (0.716, 0.719]        156             18.865326
# 45             694  (0.712, 0.716]        155             18.576017
# 46             704  (0.707, 0.712]        154             18.443804
# 47             712  (0.703, 0.707]        153             18.312757
# 48             719  (0.698, 0.703]        152             18.078954
# 49             724  (0.694, 0.698]        151             17.894217
#
#     Cumulative Recall  Precision    Recall        Scores
# 0            1.724138  28.395062  1.724138  0.888--0.906
# 1            3.448276  29.113924  1.724138  0.876--0.888
# 2            5.772114  39.743590  2.323838  0.867--0.876
# 3            6.971514  21.052632  1.199400   0.86--0.867
# 4            8.320840  24.000000  1.349325   0.855--0.86
# 5           10.044978  29.870130  1.724138  0.851--0.855
# 6           11.469265  19.791667  1.424288  0.847--0.851
# 7           12.443778  16.455696  0.974513  0.843--0.847
# 8           14.167916  30.666667  1.724138  0.839--0.843
# 9           16.116942  32.098765  1.949025  0.835--0.839
# 10          17.391304  18.085106  1.274363   0.83--0.835
# 11          18.890555  25.974026  1.499250   0.826--0.83
# 12          19.790105  15.000000  0.899550  0.823--0.826
# 13          20.764618  18.571429  0.974513   0.82--0.823
# 14          21.739130  14.285714  0.974513   0.816--0.82
# 15          23.163418  24.050633  1.424288  0.813--0.816
# 16          24.062969  14.457831  0.899550   0.81--0.813
# 17          25.112444  17.721519  1.049475   0.807--0.81
# 18          26.161919  19.178082  1.049475  0.804--0.807
# 19          27.811094  25.882353  1.649175  0.801--0.804
# 20          29.085457  22.972973  1.274363  0.798--0.801
# 21          30.284858  20.000000  1.199400  0.795--0.798
# 22          31.409295  18.292683  1.124438  0.792--0.795
# 23          32.233883  12.790698  0.824588  0.789--0.792
# 24          33.508246  22.972973  1.274363  0.786--0.789
# 25          34.707646  20.253165  1.199400  0.783--0.786
# 26          36.131934  19.000000  1.424288  0.779--0.783
# 27          36.806597  10.843373  0.674663  0.775--0.779
# 28          37.856072  20.588235  1.049475  0.772--0.775
# 29          38.605697  13.333333  0.749625  0.769--0.772
# 30          39.730135  16.853933  1.124438  0.766--0.769
# 31          41.154423  19.000000  1.424288  0.762--0.766
# 32          41.679160   9.859155  0.524738  0.759--0.762
# 33          42.278861   9.876543  0.599700  0.755--0.759
# 34          43.253373  16.049383  0.974513  0.752--0.755
# 35          44.227886  14.942529  0.974513  0.748--0.752
# 36          45.202399  16.883117  0.974513  0.745--0.748
# 37          46.476762  23.943662  1.274363  0.742--0.745
# 38          47.601199  15.789474  1.124438  0.738--0.742
# 39          48.275862  12.162162  0.674663  0.734--0.738
# 40          49.025487  14.285714  0.749625   0.73--0.734
# 41          49.625187   8.421053  0.599700   0.726--0.73
# 42          50.449775  12.222222  0.824588  0.722--0.726
# 43          50.899550   9.836066  0.449775  0.719--0.722
# 44          51.349325   7.500000  0.449775  0.716--0.719
# 45          52.023988   8.571429  0.674663  0.712--0.716
# 46          52.773613  12.345679  0.749625  0.707--0.712
# 47          53.373313  11.267606  0.599700  0.703--0.707
# 48          53.898051   7.865169  0.524738  0.698--0.703
# 49          54.272864   7.246377  0.374813  0.694--0.698

# %%
# df_deciles.to_csv('lr_metrics_by_quantile_test_Iis0).csv')

# %% [markdown]
# ### 'I' is 1

# %%
m = MetricsByQuantile(metrics=["quantiles_analytics"])
r = m.compute(
    y_true=data_dict['df_test'][TARGET_BIN_0isB].reset_index(drop=True), 
    y_pred=data_dict['df_test']['score'].round(3).reset_index(drop=True), 
    list_of_metrics = [
        "cum_precision_by_quantile", "cum_recall_by_quantile", 
        "precision_by_quantile", "recall_by_quantile",
    ], 
    n_quantiles = 200
)
df_deciles = r["other"]["quantiles_analytics"]
df_deciles.head(50)
# Out:
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#     % of total population  Cumulative % of total population  Total  Bad  \
# 0                    0.50                              0.50     81   45
# 1                    0.49                              0.99     79   35
# 2                    0.48                              1.47     78   42
# 3                    0.47                              1.93     76   29
# 4                    0.46                              2.40     75   31
# 5                    0.47                              2.87     77   32
# 6                    0.59                              3.46     96   36
# 7                    0.49                              3.95     79   29
# 8                    0.46                              4.41     75   36
# 9                    0.50                              4.91     81   37
# 10                   0.58                              5.49     94   31
# 11                   0.47                              5.96     77   32
# 12                   0.49                              6.45     80   26
# 13                   0.43                              6.88     70   24
# 14                   0.56                              7.44     91   26
# 15                   0.49                              7.93     79   33
# 16                   0.51                              8.44     83   22
# 17                   0.49                              8.93     79   31
# 18                   0.45                              9.38     73   24
# 19                   0.52                              9.90     85   31
# 20                   0.46                             10.36     74   32
# 21                   0.49                             10.85     80   21
# 22                   0.50                             11.35     82   24
# 23                   0.53                             11.88     86   26
# 24                   0.46                             12.34     74   28
# 25                   0.49                             12.83     79   30
# 26                   0.62                             13.44    100   33
# 27                   0.51                             13.95     83   17
# 28                   0.42                             14.37     68   21
# 29                   0.46                             14.83     75   20
# 30                   0.55                             15.38     89   32
# 31                   0.62                             16.00    100   32
# 32                   0.44                             16.43     71   19
# 33                   0.50                             16.93     81   24
# 34                   0.50                             17.43     81   27
# 35                   0.54                             17.97     87   21
# 36                   0.47                             18.44     77   20
# 37                   0.44                             18.88     71   22
# 38                   0.58                             19.46     95   26
# 39                   0.46                             19.92     74   21
# 40                   0.43                             20.35     70   20
# 41                   0.58                             20.93     95   20
# 42                   0.55                             21.49     90   23
# 43                   0.38                             21.86     61   13
# 44                   0.49                             22.36     80   13
# 45                   0.65                             23.00    105   27
# 46                   0.50                             23.50     81   17
# 47                   0.44                             23.94     71   14
# 48                   0.55                             24.49     89   17
# 49                   0.42                             24.91     69    8
#
#     Cumulative Bad        Quantile  #Quantile  Cumulative Precision  \
# 0               45  (0.888, 0.906]        200             55.555556
# 1               80  (0.876, 0.888]        199             50.000000
# 2              122  (0.867, 0.876]        198             51.260504
# 3              151   (0.86, 0.867]        197             48.089172
# 4              182   (0.855, 0.86]        196             46.786632
# 5              214  (0.851, 0.855]        195             45.922747
# 6              250  (0.847, 0.851]        194             44.483986
# 7              279  (0.843, 0.847]        193             43.525741
# 8              315  (0.839, 0.843]        192             43.994413
# 9              352  (0.835, 0.839]        191             44.165621
# 10             383   (0.83, 0.835]        190             42.985410
# 11             415   (0.826, 0.83]        189             42.871901
# 12             441  (0.823, 0.826]        188             42.080153
# 13             465   (0.82, 0.823]        187             41.592129
# 14             491   (0.816, 0.82]        186             40.612076
# 15             524  (0.813, 0.816]        185             40.683230
# 16             546   (0.81, 0.813]        184             39.824945
# 17             577   (0.807, 0.81]        183             39.793103
# 18             601  (0.804, 0.807]        182             39.461589
# 19             632  (0.801, 0.804]        181             39.303483
# 20             664  (0.798, 0.801]        180             39.476813
# 21             685  (0.795, 0.798]        179             38.876277
# 22             709  (0.792, 0.795]        178             38.449024
# 23             735  (0.789, 0.792]        177             38.082902
# 24             763  (0.786, 0.789]        176             38.073852
# 25             793  (0.783, 0.786]        175             38.070091
# 26             826  (0.779, 0.783]        174             37.837838
# 27             843  (0.775, 0.779]        173             37.202118
# 28             864  (0.772, 0.775]        172             37.017995
# 29             884  (0.769, 0.772]        171             36.695724
# 30             916  (0.766, 0.769]        170             36.669335
# 31             948  (0.762, 0.766]        169             36.489607
# 32             967  (0.759, 0.762]        168             36.230798
# 33             991  (0.755, 0.759]        167             36.036364
# 34            1018  (0.752, 0.755]        166             35.959025
# 35            1039  (0.748, 0.752]        165             35.606580
# 36            1059  (0.745, 0.748]        164             35.358932
# 37            1081  (0.742, 0.745]        163             35.257665
# 38            1107  (0.738, 0.742]        162             35.020563
# 39            1128  (0.734, 0.738]        161             34.868624
# 40            1148   (0.73, 0.734]        160             34.735250
# 41            1168   (0.726, 0.73]        159             34.352941
# 42            1191  (0.722, 0.726]        158             34.126074
# 43            1204  (0.719, 0.722]        157             33.905942
# 44            1217  (0.716, 0.719]        156             33.516937
# 45            1244  (0.712, 0.716]        155             33.297645
# 46            1261  (0.707, 0.712]        154             33.036416
# 47            1275  (0.703, 0.707]        153             32.793210
# 48            1292  (0.698, 0.703]        152             32.486799
# 49            1300  (0.694, 0.698]        151             32.130499
#
#     Cumulative Recall  Precision    Recall        Scores
# 0            1.745539  55.555556  1.745539  0.888--0.906
# 1            3.103181  44.303797  1.357642  0.876--0.888
# 2            4.732351  53.846154  1.629170  0.867--0.876
# 3            5.857254  38.157895  1.124903   0.86--0.867
# 4            7.059736  41.333333  1.202483   0.855--0.86
# 5            8.301009  41.558442  1.241272  0.851--0.855
# 6            9.697440  37.500000  1.396431  0.847--0.851
# 7           10.822343  36.708861  1.124903  0.843--0.847
# 8           12.218774  48.000000  1.396431  0.839--0.843
# 9           13.653995  45.679012  1.435221  0.835--0.839
# 10          14.856478  32.978723  1.202483   0.83--0.835
# 11          16.097750  41.558442  1.241272   0.826--0.83
# 12          17.106284  32.500000  1.008534  0.823--0.826
# 13          18.037238  34.285714  0.930954   0.82--0.823
# 14          19.045772  28.571429  1.008534   0.816--0.82
# 15          20.325834  41.772152  1.280062  0.813--0.816
# 16          21.179209  26.506024  0.853375   0.81--0.813
# 17          22.381691  39.240506  1.202483   0.807--0.81
# 18          23.312645  32.876712  0.930954  0.804--0.807
# 19          24.515128  36.470588  1.202483  0.801--0.804
# 20          25.756400  43.243243  1.241272  0.798--0.801
# 21          26.570985  26.250000  0.814585  0.795--0.798
# 22          27.501939  29.268293  0.930954  0.792--0.795
# 23          28.510473  30.232558  1.008534  0.789--0.792
# 24          29.596587  37.837838  1.086113  0.786--0.789
# 25          30.760279  37.974684  1.163693  0.783--0.786
# 26          32.040341  33.000000  1.280062  0.779--0.783
# 27          32.699767  20.481928  0.659426  0.775--0.779
# 28          33.514352  30.882353  0.814585  0.772--0.775
# 29          34.290147  26.666667  0.775795  0.769--0.772
# 30          35.531420  35.955056  1.241272  0.766--0.769
# 31          36.772692  32.000000  1.241272  0.762--0.766
# 32          37.509697  26.760563  0.737005  0.759--0.762
# 33          38.440652  29.629630  0.930954  0.755--0.759
# 34          39.487975  33.333333  1.047324  0.752--0.755
# 35          40.302560  24.137931  0.814585  0.748--0.752
# 36          41.078355  25.974026  0.775795  0.745--0.748
# 37          41.931730  30.985915  0.853375  0.742--0.745
# 38          42.940264  27.368421  1.008534  0.738--0.742
# 39          43.754849  28.378378  0.814585  0.734--0.738
# 40          44.530644  28.571429  0.775795   0.73--0.734
# 41          45.306439  21.052632  0.775795   0.726--0.73
# 42          46.198604  25.555556  0.892164  0.722--0.726
# 43          46.702870  21.311475  0.504267  0.719--0.722
# 44          47.207137  16.250000  0.504267  0.716--0.719
# 45          48.254461  25.714286  1.047324  0.712--0.716
# 46          48.913887  20.987654  0.659426  0.707--0.712
# 47          49.456943  19.718310  0.543057  0.703--0.707
# 48          50.116369  19.101124  0.659426  0.698--0.703
# 49          50.426687  11.594203  0.310318  0.694--0.698
